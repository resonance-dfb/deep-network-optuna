# %%
#######################################################################################
##https://github.com/Huma97/Information-Bottleneck-Theory-of-Deep-Learning/tree/master#
#######################################################################################
##讲座7把神经网络可以分层定义，引入可学习激活函数
import os
from collections import defaultdict, OrderedDict#为了自动建目录
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import pickle
from torchvision import datasets
import torchvision.transforms as transforms
import matplotlib as mpl
#import scienceplots
import math
train_on_gpu = torch.cuda.is_available()
##判断是否有GPU
if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
    
def categorical_cross_entropy(output, target):
    num_classes = 10
    epsilon = 10e-8
        
    output = torch.clamp(output, epsilon, 1. - epsilon)
    ##使用torch.clamp函数将output张量中的值限制在一个范围内，防止出现数值过大或过小的情况，第一个参数是要处理的张量，第二个参数是下限，第三个参数是上限。
    target = target.float()  # Ensure target is float
    target = target.reshape(target.shape[0], 1).to(output.device)  # Move target to the same device as output
    one_hot_target = (target == torch.arange(num_classes).reshape(1, num_classes).to(output.device)).float()
    return torch.mean(-torch.sum(one_hot_target * torch.log(output), 1))
#将target张量转换为独热编码的形式，即将每个类别的索引转换为一个长度为num_classes的向量，其中对应类别的位置为1，其他位置为0。
#最小化这个损失函数意味着我们希望预测值与真实标签之间的差异越小越好，即模型的预测结果与真实情况越接近
def init_weights(m):
    if type(m) == nn.Linear:
        nn.init.xavier_uniform_(m.weight)  # 使用 nn.init.xavier_uniform_对于权系数进行初始化
        m.bias.data.fill_(0.0)  # 使用 fill_ 方法来设置偏置为 0
# Out:
# CUDA is available!  Training on GPU ...

# %% [markdown]
# # Downloading MNIST dataset

# %%
#分批训练size，Mnist数据集60000=5w：1w
batch_size = 128

# convert data to a normalized torch.FloatTensor
transform = transforms.Compose([
    transforms.ToTensor()
    ])

# choose the training and test datasets
train_data = datasets.MNIST('./MNIST_data/', download=True, train=True, transform=transform)
test_data = datasets.MNIST('./MNIST_data/', download=True, train=False, transform=transform)

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size)
#分批载入
full_data_loader = torch.utils.data.DataLoader(test_data, batch_size=10000)
#全部载入测试

# %% [markdown]
# # Class for creating NN

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 3, 1)
        self.conv2 = nn.Conv2d(32, 64, 3, 1)
        self.dropout1 = nn.Dropout(0.25)
        self.dropout2 = nn.Dropout(0.5)
        self.fc1 = nn.Linear(9216, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        activations = []
        x = self.conv1(x)
        x = F.relu(x)
        xx= torch.flatten(x, 1)
        activations.append(xx.cpu().data.numpy())#layer1
        x = self.conv2(x)
        x = F.relu(x)
        xx= torch.flatten(x, 1)
        activations.append(xx.cpu().data.numpy())#layer1
        x = F.max_pool2d(x, 2)
        x = self.dropout1(x)
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = F.relu(x)
        activations.append(x.cpu().data.numpy())#layer3
        x = self.dropout2(x)
        x = self.fc2(x)
        x = torch.softmax(x, dim=1)
        activations.append(x.cpu().data.numpy())#layer4
        return x, activations

# class Net(nn.Module):
#     def __init__(self):
#         super(Net, self).__init__()
#         self.fc1 = nn.Linear(784, 1024)
#         self.fc2 = nn.Linear(1024, 20)
#         self.fc3 = nn.Linear(20, 20)
#         self.fc4 = nn.Linear(20, 20)
#         self.fc5 = nn.Linear(20, 10)

#     def forward(self, x):
#         activations = []
#         x = x.view(-1, 784)
#         x = F.relu(self.fc1(x))
#         activations.append(x.cpu().data.numpy())  # 将激活值移动到 CPU 上
#         x = F.relu(self.fc2(x))
#         activations.append(x.cpu().data.numpy())  # 将激活值移动到 CPU 上
#         x = F.relu(self.fc3(x))
#         activations.append(x.cpu().data.numpy())  # 将激活值移动到 CPU 上
#         x = F.relu(self.fc4(x))
#         activations.append(x.cpu().data.numpy())  # 将激活值移动到 CPU 上
#         x = torch.softmax(self.fc5(x), dim=1)  # 添加dim参数以指定 softmax 在哪个维度上操作
#         activations.append(x.cpu().data.numpy())  # 将激活值移动到 CPU 上
#         return x, activations

# 设置设备 .cpu().data.numpy()
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Class for saving activations, computing MI and plotting

# %%
import kde
# 这段代码是用Python来实现一些熵估计方法，特别是用于估计混合高斯模型的熵。以下是对每个函数的简要解释：
#需要下载https://github.com/Huma97/Information-Bottleneck-Theory-of-Deep-Learning/tree/master，jupyter载入
# get_dists(X):
# 这个函数用来计算输入数据集X中样本之间的成对欧氏距离的平方。它首先计算每个样本向量的平方范数，并将结果扩展为列向量，然后使用矩阵乘法和广播来计算所有样本对之间的距离平方。

# get_shape(x):
# 这个函数用来获取输入矩阵x的形状信息，返回矩阵的列数（特征维度）和行数（样本数）。

# entropy_estimator_kl(x, var):
# 这个函数基于KL散度的方法估计输入数据集x的熵，假设数据集服从多个高斯分布的混合模型。它首先计算数据集中样本之间的成对欧氏距离的平方，然后根据给定的方差var计算距离的对数概率，并最终求取其均值。

# entropy_estimator_bd(x, var):
# 这个函数基于Bhattacharyya系数的方法估计输入数据集x的熵的下界，同样假设数据集服从多个高斯分布的混合模型。它首先利用entropy_estimator_kl函数计算KL散度的估计值，然后加上一个校正项。

# kde_condentropy(output, var):
# 这个函数计算输出的多元高斯分布的条件熵，假设每个维度的方差均为var。
import simplebinmi
#需要下载https://github.com/Huma97/Information-Bottleneck-Theory-of-Deep-Learning/tree/master，jupyter载入
# get_unique_probs(x):
# 这个函数用于计算输入数据集x中每个唯一样本出现的概率。首先，它将输入数据x转换为字节视图，并将其看作是void类型的视图，这样可以方便地比较数据集中的唯一样本。然后，使用NumPy的np.unique函数找到唯一的样本，同时计算出现的次数。最后，将每个唯一样本出现的次数除以总样本数，得到概率值。

# bin_calc_information(inputdata, layerdata, num_of_bins):
# 这个函数用于计算给定输入数据和某一层的输出数据之间的信息量。首先，使用get_unique_probs函数计算输入数据集中每个唯一样本的概率，并将结果存储在p_xs中。然后，将输出数据分成num_of_bins个区间，并计算每个区间中的样本出现的概率。接着，利用信息论中的熵的定义来计算层的熵（H_LAYER）和给定输入的条件下层的熵（H_LAYER_GIVEN_INPUT）。最后，返回两者之差，即信息量。

# bin_calc_information2(labelixs, layerdata, binsize):
# 这个函数也用于计算信息量，与上一个函数相似，但在计算输出的条件熵时使用了一种简化的方法。首先，将层的输出数据划分成多个区间，然后计算每个区间中样本出现的概率。接着，利用这些概率值计算层的熵（H_LAYER）。然后，对于每个标签，通过求取其样本在层输出中的平均位置，计算出条件熵，然后将所有标签对应的条件熵加和。最后，返回层的熵和在给定输出的情况下层的条件熵之差。

# %%
class MI_Plate():
    def __init__(self, n_epochs=100, DO_LOWER=False, DO_BINNED=False, PLOT_LAYERS=None):
        super(MI_Plate, self).__init__()
        
        self.n_epochs = n_epochs
        self.DO_LOWER = DO_LOWER
        self.DO_BINNED = DO_BINNED
        self.PLOT_LAYERS = PLOT_LAYERS
#DO_LOWER和DO_BINNED是用于控制数据预处理的布尔值，PLOT_LAYERS是用于指定绘制哪些层的激活值的列表
    def save_activations(self):
        
        if not os.path.exists('activations'):
            print("Making directory", 'activations')
            os.mkdir('activations')
            
        model = Net()
        model.apply(init_weights)

        optimizer = optim.SGD(model.parameters(), lr=0.001)
        #optimizer = optim.Adam(model.parameters(), lr=0.001)
        # Move model to GPU if available
        if train_on_gpu:
            model.cuda()
        
        for epoch in range(self.n_epochs):
            # monitor training loss
            train_loss = 0.0

            ###################
            # train the model #
            ###################
            model.train()

            for data, target in train_loader:
                if train_on_gpu:
                    data, target = data.cuda(), target.cuda()  # Move data to GPU
                optimizer.zero_grad()
                output, _ = model(data)
                loss = categorical_cross_entropy(output, target)
                # backward
                loss.backward()
                optimizer.step()
                train_loss += loss.item()#*data.size(0)

            # calculate average loss over an epoch
            train_loss = train_loss/len(train_loader.dataset)

            print('Epoch: {} \tTraining Loss: {:.6f}'.format(epoch+1, train_loss))

            model.eval()
########每次按照规定的epoch训练之后，都用full全部数据通过网络一次，记住标签和网络输出
###############################################################################            
            for data, _ in full_data_loader:
                if train_on_gpu:
                    data = data.cuda()  # Move data to GPU
                _, activations = model(data)
#定义多少epoch进行存储每层的输出，前20每次都存，高于200次100次再存一次
            if epoch < 20:       # Log for all first 20 epochs
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            #pickle.HIGHEST_PROTOCOL 用于指定 pickle 协议的版本，以确保最高的兼容性和效率
            elif (epoch < 100) and (epoch % 5 == 0):    # Then for every 5th epoch
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            elif (epoch < 200) and (epoch % 10 == 0):    # Then every 10th
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            elif (epoch % 100 == 0):                # Then every 100th
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
                    
      
    def compute_MI(self, noise_variance=1e-1):
        
        MAX_EPOCHS = self.n_epochs
        self.noise_variance = noise_variance
        
        def entropy_func_upper(x):
            return kde.entropy_estimator_kl(x,self.noise_variance)
        
        def entropy_func_lower(x):
            return kde.entropy_estimator_bd(x,self.noise_variance)

        # nats to bits conversion factor
        nats2bits = 1.0/np.log(2) 


        # Save indexes of tests data for each of the output classes
        saved_labelixs = {}
        for data, targets in full_data_loader:
            trg = targets.numpy()
        for i in range(10):
            saved_labelixs[i] = trg == i

        labelprobs = np.mean(np.eye(10)[test_data.targets], axis=0)

        MI_XM_upper_array = []
        MI_YM_upper_array = []
###这段代码的作用是计算每个类别在数据集中出现的频率，并保存每个类别的索引以供后续使用
        measures = OrderedDict()
        measures['tanh'] = {}

        cur_dir = 'activations'
        if not os.path.exists(cur_dir):
            print("Directory %s not found" % cur_dir)

        # Load files saved during each epoch, and compute MI measures of the activity in that epoch
        print('*** Doing %s ***' % cur_dir)
        for epochfile in sorted(os.listdir(cur_dir)):
            if not epochfile.startswith('epoch'):
                continue

            fname = cur_dir + "/" + epochfile
            with open(fname, 'rb') as f:
                d = pickle.load(f)

            epoch = d[1]
            d = d[0]
            if epoch in measures['tanh']:# Skip this epoch if its already been processed
                continue                # this is a trick to allow us to rerun this cell multiple times)

            if epoch > MAX_EPOCHS:
                continue

            print("Doing", fname)

            num_layers = len(d)

            MI_XM_upper_epoch = []
            MI_YM_upper_epoch = []
            
            if self.PLOT_LAYERS is None:
                PLOT_LAYERS = []
                for lndx in range(num_layers):
                    PLOT_LAYERS.append(lndx)

            cepochdata = defaultdict(list)
            for lndx in range(num_layers):
                activity = d[lndx]

                # Compute marginal entropies
                h_upper = entropy_func_upper(activity)
                if self.DO_LOWER:
                    #h_lower = entropy_func_lower([activity,])[0]
                    h_lower = entropy_func_lower(activity)

                # Layer activity given input. This is simply the entropy of the Gaussian noise
                hM_given_X = kde.kde_condentropy(activity, self.noise_variance)

                # Compute conditional entropies of layer activity given output
                hM_given_Y_upper=0.
                for i in range(10):
                    hcond_upper = entropy_func_upper(activity[saved_labelixs[i],:])
                    hM_given_Y_upper += labelprobs[i] * hcond_upper

                if self.DO_LOWER:
                    hM_given_Y_lower=0.
                    for i in range(10):
                        hcond_lower = entropy_func_lower(activity[saved_labelixs[i],:])
                        hM_given_Y_lower += labelprobs[i] * hcond_lower

                cepochdata['MI_XM_upper'].append( nats2bits * (h_upper - hM_given_X) )
                cepochdata['MI_YM_upper'].append( nats2bits * (h_upper - hM_given_Y_upper) )
                cepochdata['H_M_upper'  ].append( nats2bits * h_upper )


                MI_XM_upper = nats2bits * (h_upper - hM_given_X)
                MI_YM_upper = nats2bits * (h_upper - hM_given_Y_upper)

                MI_XM_upper_epoch.append(MI_XM_upper)
                MI_YM_upper_epoch.append(MI_YM_upper)
                
                pstr = 'upper: MI(X;M)=%0.3f, MI(Y;M)=%0.3f, h_upper=%0.3f, hM_given_X=%0.3f, hM_given_Y_upper=%0.3f ' % (cepochdata['MI_XM_upper'][-1], cepochdata['MI_YM_upper'][-1], h_upper, hM_given_X, hM_given_Y_upper)
                if self.DO_LOWER:  # Compute lower bounds
                    cepochdata['MI_XM_lower'].append( nats2bits * (h_lower - hM_given_X) )
                    cepochdata['MI_YM_lower'].append( nats2bits * (h_lower - hM_given_Y_lower) )
                    cepochdata['H_M_lower'  ].append( nats2bits * h_lower )
                    pstr += ' | lower: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_lower'][-1], cepochdata['MI_YM_lower'][-1])

                if self.DO_BINNED: # Compute binner estimates
                    binxm, binym = simplebinmi.bin_calc_information2(saved_labelixs, activity, 0.5)
                    cepochdata['MI_XM_bin'].append( nats2bits * binxm )
                    cepochdata['MI_YM_bin'].append( nats2bits * binym )
                    pstr += ' | bin: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_bin'][-1], cepochdata['MI_YM_bin'][-1])

                print('- Layer %d %s' % (lndx, pstr) )

            measures['tanh'][epoch] = cepochdata
            MI_XM_upper_array.append(MI_XM_upper_epoch)
            MI_YM_upper_array.append(MI_YM_upper_epoch)
             
            #epoch += 1
        MI_XM_upper_array = np.array(MI_XM_upper_array)
        MI_YM_upper_array = np.array(MI_YM_upper_array)

    # Save the results as arrays
        np.save('D:/深度学习与信息论/MI_XM_upper_array.npy', MI_XM_upper_array)
        np.save('D:/深度学习与信息论/MI_YM_upper_array.npy', MI_YM_upper_array)

        with open('MI', 'wb') as f:
            pickle.dump(measures, f, pickle.HIGHEST_PROTOCOL)

# %%
Plate = MI_Plate() #Create class object
Plate.save_activations() #save activations if they weren't saved already
Plate.compute_MI() #compute and save MIs if they weren't saved before
# Out:
# Epoch: 1 	Training Loss: 0.016723
# Saving activations/epoch00000000
# Epoch: 2 	Training Loss: 0.011382
# Saving activations/epoch00000001
# Epoch: 3 	Training Loss: 0.007307
# Saving activations/epoch00000002
# Epoch: 4 	Training Loss: 0.005823
# Saving activations/epoch00000003
# Epoch: 5 	Training Loss: 0.005067
# Saving activations/epoch00000004
# Epoch: 6 	Training Loss: 0.004617
# Saving activations/epoch00000005
# Epoch: 7 	Training Loss: 0.004299
# Saving activations/epoch00000006
# Epoch: 8 	Training Loss: 0.004015
# Saving activations/epoch00000007
# Epoch: 9 	Training Loss: 0.003854
# Saving activations/epoch00000008
# Epoch: 10 	Training Loss: 0.003682
# Saving activations/epoch00000009
# Epoch: 11 	Training Loss: 0.003558
# Saving activations/epoch00000010
# Epoch: 12 	Training Loss: 0.003473
# Saving activations/epoch00000011
# Epoch: 13 	Training Loss: 0.003346
# Saving activations/epoch00000012
# Epoch: 14 	Training Loss: 0.003256
# Saving activations/epoch00000013
# Epoch: 15 	Training Loss: 0.003184
# Saving activations/epoch00000014
# Epoch: 16 	Training Loss: 0.003099
# Saving activations/epoch00000015
# Epoch: 17 	Training Loss: 0.003013
# Saving activations/epoch00000016
# Epoch: 18 	Training Loss: 0.002951
# Saving activations/epoch00000017
# Epoch: 19 	Training Loss: 0.002896
# Saving activations/epoch00000018
# Epoch: 20 	Training Loss: 0.002831
# Saving activations/epoch00000019
# Epoch: 21 	Training Loss: 0.002807
# Saving activations/epoch00000020
# Epoch: 22 	Training Loss: 0.002766
# Epoch: 23 	Training Loss: 0.002716
# Epoch: 24 	Training Loss: 0.002684
# Epoch: 25 	Training Loss: 0.002632
# Epoch: 26 	Training Loss: 0.002563
# Saving activations/epoch00000025
# Epoch: 27 	Training Loss: 0.002572
# Epoch: 28 	Training Loss: 0.002510
# Epoch: 29 	Training Loss: 0.002502
# Epoch: 30 	Training Loss: 0.002469
# Epoch: 31 	Training Loss: 0.002411
# Saving activations/epoch00000030
# Epoch: 32 	Training Loss: 0.002412
# Epoch: 33 	Training Loss: 0.002382
# Epoch: 34 	Training Loss: 0.002370
# Epoch: 35 	Training Loss: 0.002313
# Epoch: 36 	Training Loss: 0.002282
# Saving activations/epoch00000035
# Epoch: 37 	Training Loss: 0.002296
# Epoch: 38 	Training Loss: 0.002237
# Epoch: 39 	Training Loss: 0.002225
# Epoch: 40 	Training Loss: 0.002216
# Epoch: 41 	Training Loss: 0.002204
# Saving activations/epoch00000040
# Epoch: 42 	Training Loss: 0.002187
# Epoch: 43 	Training Loss: 0.002142
# Epoch: 44 	Training Loss: 0.002128
# Epoch: 45 	Training Loss: 0.002144
# Epoch: 46 	Training Loss: 0.002112
# Saving activations/epoch00000045
# Epoch: 47 	Training Loss: 0.002080
# Epoch: 48 	Training Loss: 0.002056
# Epoch: 49 	Training Loss: 0.002071
# Epoch: 50 	Training Loss: 0.002038
# Epoch: 51 	Training Loss: 0.002036
# Saving activations/epoch00000050
# Epoch: 52 	Training Loss: 0.002002
# Epoch: 53 	Training Loss: 0.002009
# Epoch: 54 	Training Loss: 0.001982
# Epoch: 55 	Training Loss: 0.001949
# Epoch: 56 	Training Loss: 0.001927
# Saving activations/epoch00000055
# Epoch: 57 	Training Loss: 0.001946
# Epoch: 58 	Training Loss: 0.001912
# Epoch: 59 	Training Loss: 0.001914
# Epoch: 60 	Training Loss: 0.001890
# Epoch: 61 	Training Loss: 0.001899
# Saving activations/epoch00000060
# Epoch: 62 	Training Loss: 0.001890
# Epoch: 63 	Training Loss: 0.001848
# Epoch: 64 	Training Loss: 0.001856
# Epoch: 65 	Training Loss: 0.001860
# Epoch: 66 	Training Loss: 0.001814
# Saving activations/epoch00000065
# Epoch: 67 	Training Loss: 0.001818
# Epoch: 68 	Training Loss: 0.001809
# Epoch: 69 	Training Loss: 0.001802
# Epoch: 70 	Training Loss: 0.001781
# Epoch: 71 	Training Loss: 0.001771
# Saving activations/epoch00000070
# Epoch: 72 	Training Loss: 0.001764
# Epoch: 73 	Training Loss: 0.001757
# Epoch: 74 	Training Loss: 0.001747
# Epoch: 75 	Training Loss: 0.001733
# Epoch: 76 	Training Loss: 0.001709
# Saving activations/epoch00000075
# Epoch: 77 	Training Loss: 0.001724
# Epoch: 78 	Training Loss: 0.001698
# Epoch: 79 	Training Loss: 0.001688
# Epoch: 80 	Training Loss: 0.001698
# Epoch: 81 	Training Loss: 0.001691
# Saving activations/epoch00000080
# Epoch: 82 	Training Loss: 0.001685
# Epoch: 83 	Training Loss: 0.001674
# Epoch: 84 	Training Loss: 0.001667
# Epoch: 85 	Training Loss: 0.001653
# Epoch: 86 	Training Loss: 0.001652
# Saving activations/epoch00000085
# Epoch: 87 	Training Loss: 0.001626
# Epoch: 88 	Training Loss: 0.001605
# Epoch: 89 	Training Loss: 0.001606
# Epoch: 90 	Training Loss: 0.001594
# Epoch: 91 	Training Loss: 0.001589
# Saving activations/epoch00000090
# Epoch: 92 	Training Loss: 0.001580
# Epoch: 93 	Training Loss: 0.001578
# Epoch: 94 	Training Loss: 0.001576
# Epoch: 95 	Training Loss: 0.001565
# Epoch: 96 	Training Loss: 0.001550
# Saving activations/epoch00000095
# Epoch: 97 	Training Loss: 0.001549
# Epoch: 98 	Training Loss: 0.001532
# Epoch: 99 	Training Loss: 0.001532
# Epoch: 100 	Training Loss: 0.001546
# *** Doing activations ***
# Doing activations/epoch00000000
# - Layer 0 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=5798.927, hM_given_X=5789.718, hM_given_Y_upper=5796.626
# - Layer 1 upper: MI(X;M)=13.286, MI(Y;M)=3.317, h_upper=9875.711, hM_given_X=9866.502, hM_given_Y_upper=9873.411
# - Layer 2 upper: MI(X;M)=10.132, MI(Y;M)=2.932, h_upper=41.282, hM_given_X=34.259, hM_given_Y_upper=39.249
# - Layer 3 upper: MI(X;M)=0.251, MI(Y;M)=0.168, h_upper=2.851, hM_given_X=2.676, hM_given_Y_upper=2.734
# Doing activations/epoch00000001
# - Layer 0 upper: MI(X;M)=13.283, MI(Y;M)=3.319, h_upper=5798.925, hM_given_X=5789.718, hM_given_Y_upper=5796.624
# - Layer 1 upper: MI(X;M)=13.289, MI(Y;M)=3.319, h_upper=9875.713, hM_given_X=9866.502, hM_given_Y_upper=9873.412
# - Layer 2 upper: MI(X;M)=13.051, MI(Y;M)=3.319, h_upper=43.305, hM_given_X=34.259, hM_given_Y_upper=41.005
# - Layer 3 upper: MI(X;M)=2.570, MI(Y;M)=1.808, h_upper=4.458, hM_given_X=2.676, hM_given_Y_upper=3.204
# Doing activations/epoch00000002
# - Layer 0 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=5798.928, hM_given_X=5789.718, hM_given_Y_upper=5796.627
# - Layer 1 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=9875.711, hM_given_X=9866.502, hM_given_Y_upper=9873.410
# - Layer 2 upper: MI(X;M)=13.209, MI(Y;M)=3.319, h_upper=43.415, hM_given_X=34.259, hM_given_Y_upper=41.114
# - Layer 3 upper: MI(X;M)=3.435, MI(Y;M)=2.473, h_upper=5.058, hM_given_X=2.676, hM_given_Y_upper=3.343
# Doing activations/epoch00000003
# - Layer 0 upper: MI(X;M)=13.281, MI(Y;M)=3.320, h_upper=5798.924, hM_given_X=5789.718, hM_given_Y_upper=5796.623
# - Layer 1 upper: MI(X;M)=13.293, MI(Y;M)=3.318, h_upper=9875.716, hM_given_X=9866.502, hM_given_Y_upper=9873.416
# - Layer 2 upper: MI(X;M)=13.248, MI(Y;M)=3.319, h_upper=43.441, hM_given_X=34.259, hM_given_Y_upper=41.140
# - Layer 3 upper: MI(X;M)=3.597, MI(Y;M)=2.652, h_upper=5.170, hM_given_X=2.676, hM_given_Y_upper=3.332
# Doing activations/epoch00000004
# - Layer 0 upper: MI(X;M)=13.283, MI(Y;M)=3.320, h_upper=5798.925, hM_given_X=5789.718, hM_given_Y_upper=5796.624
# - Layer 1 upper: MI(X;M)=13.285, MI(Y;M)=3.317, h_upper=9875.710, hM_given_X=9866.502, hM_given_Y_upper=9873.411
# - Layer 2 upper: MI(X;M)=13.264, MI(Y;M)=3.319, h_upper=43.453, hM_given_X=34.259, hM_given_Y_upper=41.152
# - Layer 3 upper: MI(X;M)=3.645, MI(Y;M)=2.732, h_upper=5.203, hM_given_X=2.676, hM_given_Y_upper=3.309
# Doing activations/epoch00000005
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=5798.929, hM_given_X=5789.718, hM_given_Y_upper=5796.627
# - Layer 1 upper: MI(X;M)=13.296, MI(Y;M)=3.318, h_upper=9875.718, hM_given_X=9866.502, hM_given_Y_upper=9873.418
# - Layer 2 upper: MI(X;M)=13.272, MI(Y;M)=3.319, h_upper=43.458, hM_given_X=34.259, hM_given_Y_upper=41.157
# - Layer 3 upper: MI(X;M)=3.657, MI(Y;M)=2.780, h_upper=5.212, hM_given_X=2.676, hM_given_Y_upper=3.285
# Doing activations/epoch00000006
# - Layer 0 upper: MI(X;M)=13.292, MI(Y;M)=3.319, h_upper=5798.932, hM_given_X=5789.718, hM_given_Y_upper=5796.631
# - Layer 1 upper: MI(X;M)=13.292, MI(Y;M)=3.319, h_upper=9875.715, hM_given_X=9866.502, hM_given_Y_upper=9873.414
# - Layer 2 upper: MI(X;M)=13.276, MI(Y;M)=3.319, h_upper=43.461, hM_given_X=34.259, hM_given_Y_upper=41.160
# - Layer 3 upper: MI(X;M)=3.658, MI(Y;M)=2.813, h_upper=5.212, hM_given_X=2.676, hM_given_Y_upper=3.262
# Doing activations/epoch00000007
# - Layer 0 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=5798.926, hM_given_X=5789.718, hM_given_Y_upper=5796.625
# - Layer 1 upper: MI(X;M)=13.289, MI(Y;M)=3.318, h_upper=9875.713, hM_given_X=9866.502, hM_given_Y_upper=9873.413
# - Layer 2 upper: MI(X;M)=13.279, MI(Y;M)=3.319, h_upper=43.463, hM_given_X=34.259, hM_given_Y_upper=41.162
# - Layer 3 upper: MI(X;M)=3.654, MI(Y;M)=2.838, h_upper=5.210, hM_given_X=2.676, hM_given_Y_upper=3.243
# Doing activations/epoch00000008
# - Layer 0 upper: MI(X;M)=13.283, MI(Y;M)=3.319, h_upper=5798.925, hM_given_X=5789.718, hM_given_Y_upper=5796.624
# - Layer 1 upper: MI(X;M)=13.289, MI(Y;M)=3.319, h_upper=9875.713, hM_given_X=9866.502, hM_given_Y_upper=9873.413
# - Layer 2 upper: MI(X;M)=13.281, MI(Y;M)=3.319, h_upper=43.464, hM_given_X=34.259, hM_given_Y_upper=41.164
# - Layer 3 upper: MI(X;M)=3.652, MI(Y;M)=2.857, h_upper=5.208, hM_given_X=2.676, hM_given_Y_upper=3.228
# Doing activations/epoch00000009
# - Layer 0 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=5798.926, hM_given_X=5789.718, hM_given_Y_upper=5796.626
# - Layer 1 upper: MI(X;M)=13.289, MI(Y;M)=3.318, h_upper=9875.713, hM_given_X=9866.502, hM_given_Y_upper=9873.413
# - Layer 2 upper: MI(X;M)=13.282, MI(Y;M)=3.319, h_upper=43.465, hM_given_X=34.259, hM_given_Y_upper=41.165
# - Layer 3 upper: MI(X;M)=3.645, MI(Y;M)=2.874, h_upper=5.203, hM_given_X=2.676, hM_given_Y_upper=3.211
# Doing activations/epoch00000010
# - Layer 0 upper: MI(X;M)=13.291, MI(Y;M)=3.320, h_upper=5798.931, hM_given_X=5789.718, hM_given_Y_upper=5796.630
# - Layer 1 upper: MI(X;M)=13.289, MI(Y;M)=3.319, h_upper=9875.713, hM_given_X=9866.502, hM_given_Y_upper=9873.413
# - Layer 2 upper: MI(X;M)=13.283, MI(Y;M)=3.319, h_upper=43.466, hM_given_X=34.259, hM_given_Y_upper=41.165
# - Layer 3 upper: MI(X;M)=3.643, MI(Y;M)=2.891, h_upper=5.201, hM_given_X=2.676, hM_given_Y_upper=3.198
# Doing activations/epoch00000011
# - Layer 0 upper: MI(X;M)=13.293, MI(Y;M)=3.320, h_upper=5798.932, hM_given_X=5789.718, hM_given_Y_upper=5796.631
# - Layer 1 upper: MI(X;M)=13.293, MI(Y;M)=3.319, h_upper=9875.716, hM_given_X=9866.502, hM_given_Y_upper=9873.415
# - Layer 2 upper: MI(X;M)=13.284, MI(Y;M)=3.319, h_upper=43.466, hM_given_X=34.259, hM_given_Y_upper=41.166
# - Layer 3 upper: MI(X;M)=3.639, MI(Y;M)=2.905, h_upper=5.199, hM_given_X=2.676, hM_given_Y_upper=3.185
# Doing activations/epoch00000012
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=5798.929, hM_given_X=5789.718, hM_given_Y_upper=5796.628
# - Layer 1 upper: MI(X;M)=13.286, MI(Y;M)=3.318, h_upper=9875.711, hM_given_X=9866.502, hM_given_Y_upper=9873.411
# - Layer 2 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=43.467, hM_given_X=34.259, hM_given_Y_upper=41.166
# - Layer 3 upper: MI(X;M)=3.633, MI(Y;M)=2.915, h_upper=5.195, hM_given_X=2.676, hM_given_Y_upper=3.174
# Doing activations/epoch00000013
# - Layer 0 upper: MI(X;M)=13.284, MI(Y;M)=3.319, h_upper=5798.926, hM_given_X=5789.718, hM_given_Y_upper=5796.625
# - Layer 1 upper: MI(X;M)=13.297, MI(Y;M)=3.318, h_upper=9875.719, hM_given_X=9866.502, hM_given_Y_upper=9873.419
# - Layer 2 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=43.467, hM_given_X=34.259, hM_given_Y_upper=41.166
# - Layer 3 upper: MI(X;M)=3.630, MI(Y;M)=2.927, h_upper=5.192, hM_given_X=2.676, hM_given_Y_upper=3.164
# Doing activations/epoch00000014
# - Layer 0 upper: MI(X;M)=13.284, MI(Y;M)=3.320, h_upper=5798.926, hM_given_X=5789.718, hM_given_Y_upper=5796.625
# - Layer 1 upper: MI(X;M)=13.289, MI(Y;M)=3.319, h_upper=9875.713, hM_given_X=9866.502, hM_given_Y_upper=9873.413
# - Layer 2 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=43.467, hM_given_X=34.259, hM_given_Y_upper=41.167
# - Layer 3 upper: MI(X;M)=3.624, MI(Y;M)=2.935, h_upper=5.189, hM_given_X=2.676, hM_given_Y_upper=3.155
# Doing activations/epoch00000015
# - Layer 0 upper: MI(X;M)=13.290, MI(Y;M)=3.319, h_upper=5798.930, hM_given_X=5789.718, hM_given_Y_upper=5796.630
# - Layer 1 upper: MI(X;M)=13.292, MI(Y;M)=3.318, h_upper=9875.715, hM_given_X=9866.502, hM_given_Y_upper=9873.415
# - Layer 2 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=43.468, hM_given_X=34.259, hM_given_Y_upper=41.167
# - Layer 3 upper: MI(X;M)=3.619, MI(Y;M)=2.943, h_upper=5.185, hM_given_X=2.676, hM_given_Y_upper=3.145
# Doing activations/epoch00000016
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=5798.928, hM_given_X=5789.718, hM_given_Y_upper=5796.627
# - Layer 1 upper: MI(X;M)=13.290, MI(Y;M)=3.318, h_upper=9875.714, hM_given_X=9866.502, hM_given_Y_upper=9873.414
# - Layer 2 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=43.468, hM_given_X=34.259, hM_given_Y_upper=41.167
# - Layer 3 upper: MI(X;M)=3.614, MI(Y;M)=2.952, h_upper=5.181, hM_given_X=2.676, hM_given_Y_upper=3.135
# Doing activations/epoch00000017
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=5798.929, hM_given_X=5789.718, hM_given_Y_upper=5796.628
# - Layer 1 upper: MI(X;M)=13.295, MI(Y;M)=3.319, h_upper=9875.717, hM_given_X=9866.502, hM_given_Y_upper=9873.416
# - Layer 2 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=43.468, hM_given_X=34.259, hM_given_Y_upper=41.167
# - Layer 3 upper: MI(X;M)=3.611, MI(Y;M)=2.960, h_upper=5.179, hM_given_X=2.676, hM_given_Y_upper=3.128
# Doing activations/epoch00000018
# - Layer 0 upper: MI(X;M)=13.291, MI(Y;M)=3.320, h_upper=5798.931, hM_given_X=5789.718, hM_given_Y_upper=5796.630
# - Layer 1 upper: MI(X;M)=13.293, MI(Y;M)=3.319, h_upper=9875.716, hM_given_X=9866.502, hM_given_Y_upper=9873.416
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=43.468, hM_given_X=34.259, hM_given_Y_upper=41.167
# - Layer 3 upper: MI(X;M)=3.607, MI(Y;M)=2.967, h_upper=5.176, hM_given_X=2.676, hM_given_Y_upper=3.120
# Doing activations/epoch00000019
# - Layer 0 upper: MI(X;M)=13.290, MI(Y;M)=3.319, h_upper=5798.930, hM_given_X=5789.718, hM_given_Y_upper=5796.629
# - Layer 1 upper: MI(X;M)=13.296, MI(Y;M)=3.319, h_upper=9875.718, hM_given_X=9866.502, hM_given_Y_upper=9873.417
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=43.468, hM_given_X=34.259, hM_given_Y_upper=41.167
# - Layer 3 upper: MI(X;M)=3.603, MI(Y;M)=2.974, h_upper=5.174, hM_given_X=2.676, hM_given_Y_upper=3.113
# Doing activations/epoch00000020
# - Layer 0 upper: MI(X;M)=13.290, MI(Y;M)=3.320, h_upper=5798.930, hM_given_X=5789.718, hM_given_Y_upper=5796.628
# - Layer 1 upper: MI(X;M)=13.295, MI(Y;M)=3.318, h_upper=9875.717, hM_given_X=9866.502, hM_given_Y_upper=9873.417
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=43.468, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.600, MI(Y;M)=2.980, h_upper=5.172, hM_given_X=2.676, hM_given_Y_upper=3.106
# Doing activations/epoch00000025
# - Layer 0 upper: MI(X;M)=13.281, MI(Y;M)=3.319, h_upper=5798.923, hM_given_X=5789.718, hM_given_Y_upper=5796.623
# - Layer 1 upper: MI(X;M)=13.292, MI(Y;M)=3.319, h_upper=9875.715, hM_given_X=9866.502, hM_given_Y_upper=9873.414
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.581, MI(Y;M)=3.006, h_upper=5.159, hM_given_X=2.676, hM_given_Y_upper=3.075
# Doing activations/epoch00000030
# - Layer 0 upper: MI(X;M)=13.275, MI(Y;M)=3.319, h_upper=5798.919, hM_given_X=5789.718, hM_given_Y_upper=5796.619
# - Layer 1 upper: MI(X;M)=13.289, MI(Y;M)=3.318, h_upper=9875.713, hM_given_X=9866.502, hM_given_Y_upper=9873.413
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.569, MI(Y;M)=3.029, h_upper=5.150, hM_given_X=2.676, hM_given_Y_upper=3.051
# Doing activations/epoch00000035
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=5798.928, hM_given_X=5789.718, hM_given_Y_upper=5796.627
# - Layer 1 upper: MI(X;M)=13.289, MI(Y;M)=3.318, h_upper=9875.713, hM_given_X=9866.502, hM_given_Y_upper=9873.413
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.555, MI(Y;M)=3.042, h_upper=5.141, hM_given_X=2.676, hM_given_Y_upper=3.032
# Doing activations/epoch00000040
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=5798.929, hM_given_X=5789.718, hM_given_Y_upper=5796.628
# - Layer 1 upper: MI(X;M)=13.290, MI(Y;M)=3.319, h_upper=9875.714, hM_given_X=9866.502, hM_given_Y_upper=9873.413
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.547, MI(Y;M)=3.057, h_upper=5.135, hM_given_X=2.676, hM_given_Y_upper=3.017
# Doing activations/epoch00000045
# - Layer 0 upper: MI(X;M)=13.287, MI(Y;M)=3.320, h_upper=5798.928, hM_given_X=5789.718, hM_given_Y_upper=5796.627
# - Layer 1 upper: MI(X;M)=13.289, MI(Y;M)=3.318, h_upper=9875.713, hM_given_X=9866.502, hM_given_Y_upper=9873.413
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.538, MI(Y;M)=3.065, h_upper=5.129, hM_given_X=2.676, hM_given_Y_upper=3.004
# Doing activations/epoch00000050
# - Layer 0 upper: MI(X;M)=13.281, MI(Y;M)=3.319, h_upper=5798.923, hM_given_X=5789.718, hM_given_Y_upper=5796.623
# - Layer 1 upper: MI(X;M)=13.292, MI(Y;M)=3.319, h_upper=9875.715, hM_given_X=9866.502, hM_given_Y_upper=9873.414
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.533, MI(Y;M)=3.075, h_upper=5.125, hM_given_X=2.676, hM_given_Y_upper=2.994
# Doing activations/epoch00000055
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=5798.928, hM_given_X=5789.718, hM_given_Y_upper=5796.627
# - Layer 1 upper: MI(X;M)=13.292, MI(Y;M)=3.318, h_upper=9875.715, hM_given_X=9866.502, hM_given_Y_upper=9873.415
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.524, MI(Y;M)=3.085, h_upper=5.119, hM_given_X=2.676, hM_given_Y_upper=2.981
# Doing activations/epoch00000060
# - Layer 0 upper: MI(X;M)=13.297, MI(Y;M)=3.320, h_upper=5798.935, hM_given_X=5789.718, hM_given_Y_upper=5796.633
# - Layer 1 upper: MI(X;M)=13.292, MI(Y;M)=3.319, h_upper=9875.715, hM_given_X=9866.502, hM_given_Y_upper=9873.414
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.517, MI(Y;M)=3.093, h_upper=5.114, hM_given_X=2.676, hM_given_Y_upper=2.971
# Doing activations/epoch00000065
# - Layer 0 upper: MI(X;M)=13.292, MI(Y;M)=3.320, h_upper=5798.931, hM_given_X=5789.718, hM_given_Y_upper=5796.630
# - Layer 1 upper: MI(X;M)=13.292, MI(Y;M)=3.319, h_upper=9875.715, hM_given_X=9866.502, hM_given_Y_upper=9873.414
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.512, MI(Y;M)=3.098, h_upper=5.111, hM_given_X=2.676, hM_given_Y_upper=2.964
# Doing activations/epoch00000070
# - Layer 0 upper: MI(X;M)=13.290, MI(Y;M)=3.320, h_upper=5798.930, hM_given_X=5789.718, hM_given_Y_upper=5796.628
# - Layer 1 upper: MI(X;M)=13.290, MI(Y;M)=3.319, h_upper=9875.714, hM_given_X=9866.502, hM_given_Y_upper=9873.413
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.507, MI(Y;M)=3.105, h_upper=5.107, hM_given_X=2.676, hM_given_Y_upper=2.955
# Doing activations/epoch00000075
# - Layer 0 upper: MI(X;M)=13.290, MI(Y;M)=3.319, h_upper=5798.930, hM_given_X=5789.718, hM_given_Y_upper=5796.629
# - Layer 1 upper: MI(X;M)=13.292, MI(Y;M)=3.319, h_upper=9875.715, hM_given_X=9866.502, hM_given_Y_upper=9873.414
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.498, MI(Y;M)=3.109, h_upper=5.101, hM_given_X=2.676, hM_given_Y_upper=2.946
# Doing activations/epoch00000080
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.319, h_upper=5798.929, hM_given_X=5789.718, hM_given_Y_upper=5796.628
# - Layer 1 upper: MI(X;M)=13.289, MI(Y;M)=3.317, h_upper=9875.713, hM_given_X=9866.502, hM_given_Y_upper=9873.413
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.496, MI(Y;M)=3.115, h_upper=5.100, hM_given_X=2.676, hM_given_Y_upper=2.941
# Doing activations/epoch00000085
# - Layer 0 upper: MI(X;M)=13.291, MI(Y;M)=3.319, h_upper=5798.931, hM_given_X=5789.718, hM_given_Y_upper=5796.630
# - Layer 1 upper: MI(X;M)=13.289, MI(Y;M)=3.319, h_upper=9875.713, hM_given_X=9866.502, hM_given_Y_upper=9873.413
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.495, MI(Y;M)=3.122, h_upper=5.099, hM_given_X=2.676, hM_given_Y_upper=2.935
# Doing activations/epoch00000090
# - Layer 0 upper: MI(X;M)=13.283, MI(Y;M)=3.320, h_upper=5798.925, hM_given_X=5789.718, hM_given_Y_upper=5796.624
# - Layer 1 upper: MI(X;M)=13.292, MI(Y;M)=3.320, h_upper=9875.715, hM_given_X=9866.502, hM_given_Y_upper=9873.414
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.486, MI(Y;M)=3.123, h_upper=5.093, hM_given_X=2.676, hM_given_Y_upper=2.928
# Doing activations/epoch00000095
# - Layer 0 upper: MI(X;M)=13.290, MI(Y;M)=3.319, h_upper=5798.930, hM_given_X=5789.718, hM_given_Y_upper=5796.629
# - Layer 1 upper: MI(X;M)=13.290, MI(Y;M)=3.319, h_upper=9875.714, hM_given_X=9866.502, hM_given_Y_upper=9873.413
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.485, MI(Y;M)=3.129, h_upper=5.092, hM_given_X=2.676, hM_given_Y_upper=2.923

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import torch
import scienceplots
plt.rcParams['font.serif'] = ['Times New Roman']
mpl.rcParams['figure.dpi'] = 800
mpl.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
plt.style.use(['science', 'ieee'])
mpl.rcParams.update({'font.size': 15})

def plot_information_plane(IXT_array, ITY_array, num_epochs, every_n_early=1, every_n_late=5):
    assert len(IXT_array) == len(ITY_array)

    max_index = len(IXT_array)

    fig, ax = plt.subplots(figsize=(5, 3.5))
    ax.set_xlabel('$I(X;T)$', fontsize=15)
    ax.set_ylabel('$I(T;Y)$', fontsize=15)

    cmap = plt.get_cmap('gnuplot')
    colors = [cmap(i) for i in np.linspace(0, 1, num_epochs + 1)]

    for i in range(0, max_index):
        IXT = IXT_array[i, :]
        ITY = ITY_array[i, :]
        
        # 根据 epoch 的范围调整 every_n
        if i < 20:
            color_idx = i * every_n_early
        else:
            color_idx = 20 * every_n_early + (i - 20) * every_n_late

        ax.plot(IXT, ITY, marker='o', markersize=3, markeredgewidth=0.04,
                linestyle='-', linewidth=0.5, color=colors[color_idx], zorder=10)

    sm = plt.cm.ScalarMappable(cmap=cmap, norm=plt.Normalize(vmin=0, vmax=1))
    sm._A = []

    # 使用ax参数指定颜色条位置
    cbar = plt.colorbar(sm, ax=ax, ticks=[])
    cbar.set_label('epoch number', fontsize=15)
    cbar.ax.tick_params(labelsize=15)
    cbar.ax.text(0.5, -0.01, 0, transform=cbar.ax.transAxes, va='top', ha='center')
    cbar.ax.text(0.5, 1.0, str(num_epochs), transform=cbar.ax.transAxes, va='bottom', ha='center')

    ax.set_xticks([0, 2, 4, 6, 8, 10, 12, 14])
    ax.set_yticks([0, 0.5, 1, 1.5, 2, 2.5, 3.0, 3.5])
    ax.set_ylim(-0.05, 3.5)  # 修改y轴坐标范围
    # Adjust coordinates of text according to the plot area
    ax.text(-0.2, 0.98, '(a)', fontdict={'size': 15, 'color': 'black'}, transform=ax.transAxes)

    fig.savefig('D:/深度学习与信息论/Fig8a.eps', dpi=800)
    plt.show()

IXT_array = np.load('D:/深度学习与信息论/MI_XM_upper_array.npy')
ITY_array = np.load('D:/深度学习与信息论/MI_YM_upper_array.npy')


plot_information_plane(IXT_array, ITY_array, num_epochs=100, every_n_early=1, every_n_late=5)

# %%
class CustomActivation(nn.Module):
    def __init__(self):
        super(CustomActivation, self).__init__()
        self.sigma = nn.Parameter(torch.tensor(0.4))

    def forward(self, input):
        #temp = input/2*(1+torch.erf(input/math.sqrt(2)/self.sigma))#GELU
        temp = input*torch.sigmoid(input/self.sigma)#SiLU
        return temp

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 3, 1)
        self.conv2 = nn.Conv2d(32, 64, 3, 1)
        self.dropout1 = nn.Dropout(0.25)
        self.dropout2 = nn.Dropout(0.5)
        self.fc1 = nn.Linear(9216, 128)
        self.fc2 = nn.Linear(128, 10)
        self.act1 = CustomActivation()
        self.act2 = CustomActivation()
        self.act3 = CustomActivation()

    def forward(self, x):
        activations = []
        x = self.conv1(x)
        x = self.act1(x)
        xx= torch.flatten(x, 1)
        activations.append(xx.cpu().data.numpy())#layer1
        x = self.conv2(x)
        x = self.act2(x)
        xx= torch.flatten(x, 1)
        activations.append(xx.cpu().data.numpy())#layer1
        x = F.max_pool2d(x, 2)
        x = self.dropout1(x)
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = self.act3(x)
        activations.append(x.cpu().data.numpy())#layer3
        x = self.dropout2(x)
        x = self.fc2(x)
        x = torch.softmax(x, dim=1)
        activations.append(x.cpu().data.numpy())#layer4
        return x, activations


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
Plate = MI_Plate() #Create class object
Plate.save_activations() #save activations if they weren't saved already
Plate.compute_MI() #compute and save MIs if they weren't saved before
# Out:
# Epoch: 1 	Training Loss: 0.017747
# Saving activations/epoch00000000
# Epoch: 2 	Training Loss: 0.016370
# Saving activations/epoch00000001
# Epoch: 3 	Training Loss: 0.010067
# Saving activations/epoch00000002
# Epoch: 4 	Training Loss: 0.006371
# Saving activations/epoch00000003
# Epoch: 5 	Training Loss: 0.005244
# Saving activations/epoch00000004
# Epoch: 6 	Training Loss: 0.004629
# Saving activations/epoch00000005
# Epoch: 7 	Training Loss: 0.004259
# Saving activations/epoch00000006
# Epoch: 8 	Training Loss: 0.004003
# Saving activations/epoch00000007
# Epoch: 9 	Training Loss: 0.003767
# Saving activations/epoch00000008
# Epoch: 10 	Training Loss: 0.003564
# Saving activations/epoch00000009
# Epoch: 11 	Training Loss: 0.003426
# Saving activations/epoch00000010
# Epoch: 12 	Training Loss: 0.003290
# Saving activations/epoch00000011
# Epoch: 13 	Training Loss: 0.003212
# Saving activations/epoch00000012
# Epoch: 14 	Training Loss: 0.003065
# Saving activations/epoch00000013
# Epoch: 15 	Training Loss: 0.003012
# Saving activations/epoch00000014
# Epoch: 16 	Training Loss: 0.002888
# Saving activations/epoch00000015
# Epoch: 17 	Training Loss: 0.002842
# Saving activations/epoch00000016
# Epoch: 18 	Training Loss: 0.002778
# Saving activations/epoch00000017
# Epoch: 19 	Training Loss: 0.002725
# Saving activations/epoch00000018
# Epoch: 20 	Training Loss: 0.002672
# Saving activations/epoch00000019
# Epoch: 21 	Training Loss: 0.002611
# Saving activations/epoch00000020
# Epoch: 22 	Training Loss: 0.002570
# Epoch: 23 	Training Loss: 0.002527
# Epoch: 24 	Training Loss: 0.002500
# Epoch: 25 	Training Loss: 0.002449
# Epoch: 26 	Training Loss: 0.002409
# Saving activations/epoch00000025
# Epoch: 27 	Training Loss: 0.002371
# Epoch: 28 	Training Loss: 0.002353
# Epoch: 29 	Training Loss: 0.002308
# Epoch: 30 	Training Loss: 0.002283
# Epoch: 31 	Training Loss: 0.002234
# Saving activations/epoch00000030
# Epoch: 32 	Training Loss: 0.002225
# Epoch: 33 	Training Loss: 0.002193
# Epoch: 34 	Training Loss: 0.002160
# Epoch: 35 	Training Loss: 0.002111
# Epoch: 36 	Training Loss: 0.002108
# Saving activations/epoch00000035
# Epoch: 37 	Training Loss: 0.002082
# Epoch: 38 	Training Loss: 0.002058
# Epoch: 39 	Training Loss: 0.002038
# Epoch: 40 	Training Loss: 0.002035
# Epoch: 41 	Training Loss: 0.002007
# Saving activations/epoch00000040
# Epoch: 42 	Training Loss: 0.001982
# Epoch: 43 	Training Loss: 0.001943
# Epoch: 44 	Training Loss: 0.001945
# Epoch: 45 	Training Loss: 0.001911
# Epoch: 46 	Training Loss: 0.001915
# Saving activations/epoch00000045
# Epoch: 47 	Training Loss: 0.001924
# Epoch: 48 	Training Loss: 0.001890
# Epoch: 49 	Training Loss: 0.001881
# Epoch: 50 	Training Loss: 0.001837
# Epoch: 51 	Training Loss: 0.001842
# Saving activations/epoch00000050
# Epoch: 52 	Training Loss: 0.001830
# Epoch: 53 	Training Loss: 0.001803
# Epoch: 54 	Training Loss: 0.001806
# Epoch: 55 	Training Loss: 0.001771
# Epoch: 56 	Training Loss: 0.001741
# Saving activations/epoch00000055
# Epoch: 57 	Training Loss: 0.001740
# Epoch: 58 	Training Loss: 0.001725
# Epoch: 59 	Training Loss: 0.001729
# Epoch: 60 	Training Loss: 0.001737
# Epoch: 61 	Training Loss: 0.001707
# Saving activations/epoch00000060
# Epoch: 62 	Training Loss: 0.001680
# Epoch: 63 	Training Loss: 0.001683
# Epoch: 64 	Training Loss: 0.001683
# Epoch: 65 	Training Loss: 0.001663
# Epoch: 66 	Training Loss: 0.001630
# Saving activations/epoch00000065
# Epoch: 67 	Training Loss: 0.001625
# Epoch: 68 	Training Loss: 0.001644
# Epoch: 69 	Training Loss: 0.001630
# Epoch: 70 	Training Loss: 0.001588
# Epoch: 71 	Training Loss: 0.001580
# Saving activations/epoch00000070
# Epoch: 72 	Training Loss: 0.001574
# Epoch: 73 	Training Loss: 0.001572
# Epoch: 74 	Training Loss: 0.001560
# Epoch: 75 	Training Loss: 0.001563
# Epoch: 76 	Training Loss: 0.001540
# Saving activations/epoch00000075
# Epoch: 77 	Training Loss: 0.001537
# Epoch: 78 	Training Loss: 0.001544
# Epoch: 79 	Training Loss: 0.001510
# Epoch: 80 	Training Loss: 0.001523
# Epoch: 81 	Training Loss: 0.001516
# Saving activations/epoch00000080
# Epoch: 82 	Training Loss: 0.001479
# Epoch: 83 	Training Loss: 0.001494
# Epoch: 84 	Training Loss: 0.001464
# Epoch: 85 	Training Loss: 0.001468
# Epoch: 86 	Training Loss: 0.001460
# Saving activations/epoch00000085
# Epoch: 87 	Training Loss: 0.001445
# Epoch: 88 	Training Loss: 0.001460
# Epoch: 89 	Training Loss: 0.001448
# Epoch: 90 	Training Loss: 0.001427
# Epoch: 91 	Training Loss: 0.001411
# Saving activations/epoch00000090
# Epoch: 92 	Training Loss: 0.001423
# Epoch: 93 	Training Loss: 0.001410
# Epoch: 94 	Training Loss: 0.001400
# Epoch: 95 	Training Loss: 0.001390
# Epoch: 96 	Training Loss: 0.001385
# Saving activations/epoch00000095
# Epoch: 97 	Training Loss: 0.001376
# Epoch: 98 	Training Loss: 0.001373
# Epoch: 99 	Training Loss: 0.001365
# Epoch: 100 	Training Loss: 0.001352
# *** Doing activations ***
# Doing activations/epoch00000000
# - Layer 0 upper: MI(X;M)=13.290, MI(Y;M)=3.320, h_upper=5798.930, hM_given_X=5789.718, hM_given_Y_upper=5796.628
# - Layer 1 upper: MI(X;M)=13.286, MI(Y;M)=3.317, h_upper=9875.711, hM_given_X=9866.502, hM_given_Y_upper=9873.412
# - Layer 2 upper: MI(X;M)=1.352, MI(Y;M)=0.399, h_upper=35.196, hM_given_X=34.259, hM_given_Y_upper=34.919
# - Layer 3 upper: MI(X;M)=0.005, MI(Y;M)=0.003, h_upper=2.680, hM_given_X=2.676, hM_given_Y_upper=2.678
# Doing activations/epoch00000001
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=5798.929, hM_given_X=5789.718, hM_given_Y_upper=5796.628
# - Layer 1 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=9875.711, hM_given_X=9866.502, hM_given_Y_upper=9873.410
# - Layer 2 upper: MI(X;M)=9.967, MI(Y;M)=2.845, h_upper=41.167, hM_given_X=34.259, hM_given_Y_upper=39.195
# - Layer 3 upper: MI(X;M)=0.310, MI(Y;M)=0.204, h_upper=2.892, hM_given_X=2.676, hM_given_Y_upper=2.750
# Doing activations/epoch00000002
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=5798.928, hM_given_X=5789.718, hM_given_Y_upper=5796.627
# - Layer 1 upper: MI(X;M)=13.295, MI(Y;M)=3.319, h_upper=9875.717, hM_given_X=9866.502, hM_given_Y_upper=9873.416
# - Layer 2 upper: MI(X;M)=13.162, MI(Y;M)=3.319, h_upper=43.382, hM_given_X=34.259, hM_given_Y_upper=41.081
# - Layer 3 upper: MI(X;M)=3.112, MI(Y;M)=2.205, h_upper=4.834, hM_given_X=2.676, hM_given_Y_upper=3.305
# Doing activations/epoch00000003
# - Layer 0 upper: MI(X;M)=13.284, MI(Y;M)=3.320, h_upper=5798.926, hM_given_X=5789.718, hM_given_Y_upper=5796.625
# - Layer 1 upper: MI(X;M)=13.282, MI(Y;M)=3.320, h_upper=9875.708, hM_given_X=9866.502, hM_given_Y_upper=9873.407
# - Layer 2 upper: MI(X;M)=13.233, MI(Y;M)=3.319, h_upper=43.431, hM_given_X=34.259, hM_given_Y_upper=41.131
# - Layer 3 upper: MI(X;M)=3.561, MI(Y;M)=2.591, h_upper=5.144, hM_given_X=2.676, hM_given_Y_upper=3.349
# Doing activations/epoch00000004
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=5798.929, hM_given_X=5789.718, hM_given_Y_upper=5796.627
# - Layer 1 upper: MI(X;M)=13.285, MI(Y;M)=3.318, h_upper=9875.710, hM_given_X=9866.502, hM_given_Y_upper=9873.410
# - Layer 2 upper: MI(X;M)=13.255, MI(Y;M)=3.319, h_upper=43.446, hM_given_X=34.259, hM_given_Y_upper=41.146
# - Layer 3 upper: MI(X;M)=3.642, MI(Y;M)=2.706, h_upper=5.201, hM_given_X=2.676, hM_given_Y_upper=3.325
# Doing activations/epoch00000005
# - Layer 0 upper: MI(X;M)=13.295, MI(Y;M)=3.320, h_upper=5798.934, hM_given_X=5789.718, hM_given_Y_upper=5796.632
# - Layer 1 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=9875.710, hM_given_X=9866.502, hM_given_Y_upper=9873.410
# - Layer 2 upper: MI(X;M)=13.266, MI(Y;M)=3.319, h_upper=43.454, hM_given_X=34.259, hM_given_Y_upper=41.153
# - Layer 3 upper: MI(X;M)=3.661, MI(Y;M)=2.767, h_upper=5.214, hM_given_X=2.676, hM_given_Y_upper=3.296
# Doing activations/epoch00000006
# - Layer 0 upper: MI(X;M)=13.281, MI(Y;M)=3.319, h_upper=5798.924, hM_given_X=5789.718, hM_given_Y_upper=5796.623
# - Layer 1 upper: MI(X;M)=13.278, MI(Y;M)=3.320, h_upper=9875.705, hM_given_X=9866.502, hM_given_Y_upper=9873.404
# - Layer 2 upper: MI(X;M)=13.272, MI(Y;M)=3.319, h_upper=43.458, hM_given_X=34.259, hM_given_Y_upper=41.157
# - Layer 3 upper: MI(X;M)=3.664, MI(Y;M)=2.806, h_upper=5.216, hM_given_X=2.676, hM_given_Y_upper=3.271
# Doing activations/epoch00000007
# - Layer 0 upper: MI(X;M)=13.290, MI(Y;M)=3.320, h_upper=5798.930, hM_given_X=5789.718, hM_given_Y_upper=5796.629
# - Layer 1 upper: MI(X;M)=13.295, MI(Y;M)=3.320, h_upper=9875.717, hM_given_X=9866.502, hM_given_Y_upper=9873.416
# - Layer 2 upper: MI(X;M)=13.276, MI(Y;M)=3.319, h_upper=43.461, hM_given_X=34.259, hM_given_Y_upper=41.160
# - Layer 3 upper: MI(X;M)=3.659, MI(Y;M)=2.836, h_upper=5.213, hM_given_X=2.676, hM_given_Y_upper=3.247
# Doing activations/epoch00000008
# - Layer 0 upper: MI(X;M)=13.291, MI(Y;M)=3.319, h_upper=5798.931, hM_given_X=5789.718, hM_given_Y_upper=5796.630
# - Layer 1 upper: MI(X;M)=13.310, MI(Y;M)=3.319, h_upper=9875.728, hM_given_X=9866.502, hM_given_Y_upper=9873.427
# - Layer 2 upper: MI(X;M)=13.279, MI(Y;M)=3.319, h_upper=43.463, hM_given_X=34.259, hM_given_Y_upper=41.162
# - Layer 3 upper: MI(X;M)=3.655, MI(Y;M)=2.859, h_upper=5.210, hM_given_X=2.676, hM_given_Y_upper=3.229
# Doing activations/epoch00000009
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=5798.928, hM_given_X=5789.718, hM_given_Y_upper=5796.627
# - Layer 1 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=9875.712, hM_given_X=9866.502, hM_given_Y_upper=9873.411
# - Layer 2 upper: MI(X;M)=13.281, MI(Y;M)=3.319, h_upper=43.464, hM_given_X=34.259, hM_given_Y_upper=41.163
# - Layer 3 upper: MI(X;M)=3.647, MI(Y;M)=2.880, h_upper=5.205, hM_given_X=2.676, hM_given_Y_upper=3.208
# Doing activations/epoch00000010
# - Layer 0 upper: MI(X;M)=13.280, MI(Y;M)=3.319, h_upper=5798.923, hM_given_X=5789.718, hM_given_Y_upper=5796.622
# - Layer 1 upper: MI(X;M)=13.281, MI(Y;M)=3.318, h_upper=9875.707, hM_given_X=9866.502, hM_given_Y_upper=9873.407
# - Layer 2 upper: MI(X;M)=13.282, MI(Y;M)=3.319, h_upper=43.465, hM_given_X=34.259, hM_given_Y_upper=41.164
# - Layer 3 upper: MI(X;M)=3.643, MI(Y;M)=2.895, h_upper=5.201, hM_given_X=2.676, hM_given_Y_upper=3.195
# Doing activations/epoch00000011
# - Layer 0 upper: MI(X;M)=13.283, MI(Y;M)=3.320, h_upper=5798.925, hM_given_X=5789.718, hM_given_Y_upper=5796.624
# - Layer 1 upper: MI(X;M)=13.306, MI(Y;M)=3.319, h_upper=9875.725, hM_given_X=9866.502, hM_given_Y_upper=9873.424
# - Layer 2 upper: MI(X;M)=13.283, MI(Y;M)=3.319, h_upper=43.466, hM_given_X=34.259, hM_given_Y_upper=41.165
# - Layer 3 upper: MI(X;M)=3.638, MI(Y;M)=2.910, h_upper=5.198, hM_given_X=2.676, hM_given_Y_upper=3.181
# Doing activations/epoch00000012
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=5798.929, hM_given_X=5789.718, hM_given_Y_upper=5796.628
# - Layer 1 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=9875.710, hM_given_X=9866.502, hM_given_Y_upper=9873.409
# - Layer 2 upper: MI(X;M)=13.284, MI(Y;M)=3.319, h_upper=43.466, hM_given_X=34.259, hM_given_Y_upper=41.165
# - Layer 3 upper: MI(X;M)=3.632, MI(Y;M)=2.921, h_upper=5.194, hM_given_X=2.676, hM_given_Y_upper=3.169
# Doing activations/epoch00000013
# - Layer 0 upper: MI(X;M)=13.293, MI(Y;M)=3.319, h_upper=5798.932, hM_given_X=5789.718, hM_given_Y_upper=5796.631
# - Layer 1 upper: MI(X;M)=13.275, MI(Y;M)=3.319, h_upper=9875.703, hM_given_X=9866.502, hM_given_Y_upper=9873.403
# - Layer 2 upper: MI(X;M)=13.284, MI(Y;M)=3.319, h_upper=43.467, hM_given_X=34.259, hM_given_Y_upper=41.166
# - Layer 3 upper: MI(X;M)=3.627, MI(Y;M)=2.931, h_upper=5.190, hM_given_X=2.676, hM_given_Y_upper=3.159
# Doing activations/epoch00000014
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=5798.929, hM_given_X=5789.718, hM_given_Y_upper=5796.628
# - Layer 1 upper: MI(X;M)=13.297, MI(Y;M)=3.319, h_upper=9875.719, hM_given_X=9866.502, hM_given_Y_upper=9873.418
# - Layer 2 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=43.467, hM_given_X=34.259, hM_given_Y_upper=41.166
# - Layer 3 upper: MI(X;M)=3.620, MI(Y;M)=2.944, h_upper=5.186, hM_given_X=2.676, hM_given_Y_upper=3.145
# Doing activations/epoch00000015
# - Layer 0 upper: MI(X;M)=13.285, MI(Y;M)=3.320, h_upper=5798.927, hM_given_X=5789.718, hM_given_Y_upper=5796.626
# - Layer 1 upper: MI(X;M)=13.279, MI(Y;M)=3.319, h_upper=9875.706, hM_given_X=9866.502, hM_given_Y_upper=9873.405
# - Layer 2 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=43.467, hM_given_X=34.259, hM_given_Y_upper=41.166
# - Layer 3 upper: MI(X;M)=3.615, MI(Y;M)=2.951, h_upper=5.182, hM_given_X=2.676, hM_given_Y_upper=3.136
# Doing activations/epoch00000016
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.320, h_upper=5798.929, hM_given_X=5789.718, hM_given_Y_upper=5796.628
# - Layer 1 upper: MI(X;M)=13.264, MI(Y;M)=3.319, h_upper=9875.695, hM_given_X=9866.502, hM_given_Y_upper=9873.395
# - Layer 2 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=43.467, hM_given_X=34.259, hM_given_Y_upper=41.167
# - Layer 3 upper: MI(X;M)=3.609, MI(Y;M)=2.960, h_upper=5.178, hM_given_X=2.676, hM_given_Y_upper=3.126
# Doing activations/epoch00000017
# - Layer 0 upper: MI(X;M)=13.285, MI(Y;M)=3.320, h_upper=5798.927, hM_given_X=5789.718, hM_given_Y_upper=5796.625
# - Layer 1 upper: MI(X;M)=13.283, MI(Y;M)=3.319, h_upper=9875.709, hM_given_X=9866.502, hM_given_Y_upper=9873.408
# - Layer 2 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=43.468, hM_given_X=34.259, hM_given_Y_upper=41.167
# - Layer 3 upper: MI(X;M)=3.606, MI(Y;M)=2.967, h_upper=5.176, hM_given_X=2.676, hM_given_Y_upper=3.119
# Doing activations/epoch00000018
# - Layer 0 upper: MI(X;M)=13.283, MI(Y;M)=3.320, h_upper=5798.925, hM_given_X=5789.718, hM_given_Y_upper=5796.624
# - Layer 1 upper: MI(X;M)=13.266, MI(Y;M)=3.320, h_upper=9875.697, hM_given_X=9866.502, hM_given_Y_upper=9873.396
# - Layer 2 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=43.468, hM_given_X=34.259, hM_given_Y_upper=41.167
# - Layer 3 upper: MI(X;M)=3.601, MI(Y;M)=2.974, h_upper=5.173, hM_given_X=2.676, hM_given_Y_upper=3.111
# Doing activations/epoch00000019
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.320, h_upper=5798.929, hM_given_X=5789.718, hM_given_Y_upper=5796.628
# - Layer 1 upper: MI(X;M)=13.275, MI(Y;M)=3.318, h_upper=9875.703, hM_given_X=9866.502, hM_given_Y_upper=9873.403
# - Layer 2 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=43.468, hM_given_X=34.259, hM_given_Y_upper=41.167
# - Layer 3 upper: MI(X;M)=3.598, MI(Y;M)=2.981, h_upper=5.170, hM_given_X=2.676, hM_given_Y_upper=3.104
# Doing activations/epoch00000020
# - Layer 0 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=5798.926, hM_given_X=5789.718, hM_given_Y_upper=5796.626
# - Layer 1 upper: MI(X;M)=13.296, MI(Y;M)=3.319, h_upper=9875.718, hM_given_X=9866.502, hM_given_Y_upper=9873.417
# - Layer 2 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=43.468, hM_given_X=34.259, hM_given_Y_upper=41.167
# - Layer 3 upper: MI(X;M)=3.593, MI(Y;M)=2.989, h_upper=5.167, hM_given_X=2.676, hM_given_Y_upper=3.095
# Doing activations/epoch00000025
# - Layer 0 upper: MI(X;M)=13.284, MI(Y;M)=3.320, h_upper=5798.926, hM_given_X=5789.718, hM_given_Y_upper=5796.625
# - Layer 1 upper: MI(X;M)=13.269, MI(Y;M)=3.319, h_upper=9875.699, hM_given_X=9866.502, hM_given_Y_upper=9873.399
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=43.468, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.578, MI(Y;M)=3.016, h_upper=5.157, hM_given_X=2.676, hM_given_Y_upper=3.066
# Doing activations/epoch00000030
# - Layer 0 upper: MI(X;M)=13.292, MI(Y;M)=3.319, h_upper=5798.931, hM_given_X=5789.718, hM_given_Y_upper=5796.630
# - Layer 1 upper: MI(X;M)=13.297, MI(Y;M)=3.319, h_upper=9875.719, hM_given_X=9866.502, hM_given_Y_upper=9873.418
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.561, MI(Y;M)=3.035, h_upper=5.145, hM_given_X=2.676, hM_given_Y_upper=3.042
# Doing activations/epoch00000035
# - Layer 0 upper: MI(X;M)=13.298, MI(Y;M)=3.319, h_upper=5798.936, hM_given_X=5789.718, hM_given_Y_upper=5796.635
# - Layer 1 upper: MI(X;M)=13.310, MI(Y;M)=3.318, h_upper=9875.728, hM_given_X=9866.502, hM_given_Y_upper=9873.428
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.552, MI(Y;M)=3.049, h_upper=5.139, hM_given_X=2.676, hM_given_Y_upper=3.026
# Doing activations/epoch00000040
# - Layer 0 upper: MI(X;M)=13.290, MI(Y;M)=3.320, h_upper=5798.930, hM_given_X=5789.718, hM_given_Y_upper=5796.629
# - Layer 1 upper: MI(X;M)=13.321, MI(Y;M)=3.320, h_upper=9875.735, hM_given_X=9866.502, hM_given_Y_upper=9873.434
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.541, MI(Y;M)=3.061, h_upper=5.131, hM_given_X=2.676, hM_given_Y_upper=3.009
# Doing activations/epoch00000045
# - Layer 0 upper: MI(X;M)=13.290, MI(Y;M)=3.319, h_upper=5798.930, hM_given_X=5789.718, hM_given_Y_upper=5796.630
# - Layer 1 upper: MI(X;M)=13.285, MI(Y;M)=3.318, h_upper=9875.710, hM_given_X=9866.502, hM_given_Y_upper=9873.410
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.530, MI(Y;M)=3.071, h_upper=5.123, hM_given_X=2.676, hM_given_Y_upper=2.994
# Doing activations/epoch00000050
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=5798.929, hM_given_X=5789.718, hM_given_Y_upper=5796.628
# - Layer 1 upper: MI(X;M)=13.300, MI(Y;M)=3.318, h_upper=9875.721, hM_given_X=9866.502, hM_given_Y_upper=9873.421
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.526, MI(Y;M)=3.080, h_upper=5.120, hM_given_X=2.676, hM_given_Y_upper=2.986
# Doing activations/epoch00000055
# - Layer 0 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=5798.927, hM_given_X=5789.718, hM_given_Y_upper=5796.626
# - Layer 1 upper: MI(X;M)=13.266, MI(Y;M)=3.318, h_upper=9875.697, hM_given_X=9866.502, hM_given_Y_upper=9873.397
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.517, MI(Y;M)=3.086, h_upper=5.114, hM_given_X=2.676, hM_given_Y_upper=2.975
# Doing activations/epoch00000060
# - Layer 0 upper: MI(X;M)=13.280, MI(Y;M)=3.319, h_upper=5798.923, hM_given_X=5789.718, hM_given_Y_upper=5796.622
# - Layer 1 upper: MI(X;M)=13.272, MI(Y;M)=3.317, h_upper=9875.701, hM_given_X=9866.502, hM_given_Y_upper=9873.402
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.512, MI(Y;M)=3.096, h_upper=5.111, hM_given_X=2.676, hM_given_Y_upper=2.965
# Doing activations/epoch00000065
# - Layer 0 upper: MI(X;M)=13.281, MI(Y;M)=3.320, h_upper=5798.923, hM_given_X=5789.718, hM_given_Y_upper=5796.622
# - Layer 1 upper: MI(X;M)=13.295, MI(Y;M)=3.320, h_upper=9875.717, hM_given_X=9866.502, hM_given_Y_upper=9873.416
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.505, MI(Y;M)=3.101, h_upper=5.106, hM_given_X=2.676, hM_given_Y_upper=2.956
# Doing activations/epoch00000070
# - Layer 0 upper: MI(X;M)=13.285, MI(Y;M)=3.320, h_upper=5798.926, hM_given_X=5789.718, hM_given_Y_upper=5796.625
# - Layer 1 upper: MI(X;M)=13.293, MI(Y;M)=3.318, h_upper=9875.716, hM_given_X=9866.502, hM_given_Y_upper=9873.416
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.498, MI(Y;M)=3.109, h_upper=5.101, hM_given_X=2.676, hM_given_Y_upper=2.946
# Doing activations/epoch00000075
# - Layer 0 upper: MI(X;M)=13.294, MI(Y;M)=3.320, h_upper=5798.933, hM_given_X=5789.718, hM_given_Y_upper=5796.631
# - Layer 1 upper: MI(X;M)=13.320, MI(Y;M)=3.319, h_upper=9875.734, hM_given_X=9866.502, hM_given_Y_upper=9873.434
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.494, MI(Y;M)=3.116, h_upper=5.099, hM_given_X=2.676, hM_given_Y_upper=2.939
# Doing activations/epoch00000080
# - Layer 0 upper: MI(X;M)=13.281, MI(Y;M)=3.320, h_upper=5798.923, hM_given_X=5789.718, hM_given_Y_upper=5796.622
# - Layer 1 upper: MI(X;M)=13.293, MI(Y;M)=3.319, h_upper=9875.716, hM_given_X=9866.502, hM_given_Y_upper=9873.415
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.490, MI(Y;M)=3.120, h_upper=5.095, hM_given_X=2.676, hM_given_Y_upper=2.933
# Doing activations/epoch00000085
# - Layer 0 upper: MI(X;M)=13.283, MI(Y;M)=3.319, h_upper=5798.925, hM_given_X=5789.718, hM_given_Y_upper=5796.624
# - Layer 1 upper: MI(X;M)=13.293, MI(Y;M)=3.319, h_upper=9875.716, hM_given_X=9866.502, hM_given_Y_upper=9873.415
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.485, MI(Y;M)=3.124, h_upper=5.092, hM_given_X=2.676, hM_given_Y_upper=2.927
# Doing activations/epoch00000090
# - Layer 0 upper: MI(X;M)=13.290, MI(Y;M)=3.319, h_upper=5798.930, hM_given_X=5789.718, hM_given_Y_upper=5796.629
# - Layer 1 upper: MI(X;M)=13.282, MI(Y;M)=3.319, h_upper=9875.708, hM_given_X=9866.502, hM_given_Y_upper=9873.407
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.480, MI(Y;M)=3.127, h_upper=5.089, hM_given_X=2.676, hM_given_Y_upper=2.921
# Doing activations/epoch00000095
# - Layer 0 upper: MI(X;M)=13.285, MI(Y;M)=3.320, h_upper=5798.927, hM_given_X=5789.718, hM_given_Y_upper=5796.625
# - Layer 1 upper: MI(X;M)=13.279, MI(Y;M)=3.318, h_upper=9875.706, hM_given_X=9866.502, hM_given_Y_upper=9873.406
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.475, MI(Y;M)=3.132, h_upper=5.085, hM_given_X=2.676, hM_given_Y_upper=2.914

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import torch
import scienceplots
plt.rcParams['font.serif'] = ['Times New Roman']
mpl.rcParams['figure.dpi'] = 800
mpl.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
plt.style.use(['science', 'ieee'])
mpl.rcParams.update({'font.size': 15})

def plot_information_plane(IXT_array, ITY_array, num_epochs, every_n_early=1, every_n_late=5):
    assert len(IXT_array) == len(ITY_array)

    max_index = len(IXT_array)

    fig, ax = plt.subplots(figsize=(5, 3.5))
    ax.set_xlabel('$I(X;T)$', fontsize=15)
    ax.set_ylabel('$I(T;Y)$', fontsize=15)

    cmap = plt.get_cmap('gnuplot')
    colors = [cmap(i) for i in np.linspace(0, 1, num_epochs + 1)]

    for i in range(0, max_index):
        IXT = IXT_array[i, :]
        ITY = ITY_array[i, :]
        
        # 根据 epoch 的范围调整 every_n
        if i < 20:
            color_idx = i * every_n_early
        else:
            color_idx = 20 * every_n_early + (i - 20) * every_n_late

        ax.plot(IXT, ITY, marker='o', markersize=3, markeredgewidth=0.04,
                linestyle='-', linewidth=0.5, color=colors[color_idx], zorder=10)

    sm = plt.cm.ScalarMappable(cmap=cmap, norm=plt.Normalize(vmin=0, vmax=1))
    sm._A = []

    # 使用ax参数指定颜色条位置
    cbar = plt.colorbar(sm, ax=ax, ticks=[])
    cbar.set_label('epoch number', fontsize=15)
    cbar.ax.tick_params(labelsize=15)
    cbar.ax.text(0.5, -0.01, 0, transform=cbar.ax.transAxes, va='top', ha='center')
    cbar.ax.text(0.5, 1.0, str(num_epochs), transform=cbar.ax.transAxes, va='bottom', ha='center')

    ax.set_xticks([0, 2, 4, 6, 8, 10, 12, 14])
    ax.set_yticks([0, 0.5, 1, 1.5, 2, 2.5, 3.0, 3.5])
    ax.set_ylim(-0.05, 3.5)  # 修改y轴坐标范围
    # Adjust coordinates of text according to the plot area
    ax.text(-0.2, 0.98, '(b)', fontdict={'size': 15, 'color': 'black'}, transform=ax.transAxes)

    fig.savefig('D:/深度学习与信息论/Fig8b.eps', dpi=800)
    plt.show()

IXT_array = np.load('D:/深度学习与信息论/MI_XM_upper_array.npy')
ITY_array = np.load('D:/深度学习与信息论/MI_YM_upper_array.npy')


plot_information_plane(IXT_array, ITY_array, num_epochs=100, every_n_early=1, every_n_late=5)

# %%
class CustomActivation(nn.Module):
    def __init__(self):
        super(CustomActivation, self).__init__()
        self.sigma = nn.Parameter(torch.tensor(0.5))

    def forward(self, input):
        temp = input/2*(1+torch.erf(input/math.sqrt(2)/self.sigma))#GELU
        #temp = input*torch.sigmoid(input)#SiLU
        return temp

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 3, 1)
        self.conv2 = nn.Conv2d(32, 64, 3, 1)
        self.dropout1 = nn.Dropout(0.25)
        self.dropout2 = nn.Dropout(0.5)
        self.fc1 = nn.Linear(9216, 128)
        self.fc2 = nn.Linear(128, 10)
        self.act1 = CustomActivation()
        self.act2 = CustomActivation()
        self.act3 = CustomActivation()

    def forward(self, x):
        activations = []
        x = self.conv1(x)
        x = self.act1(x)
        xx= torch.flatten(x, 1)
        activations.append(xx.cpu().data.numpy())#layer1
        x = self.conv2(x)
        x = self.act2(x)
        xx= torch.flatten(x, 1)
        activations.append(xx.cpu().data.numpy())#layer1
        x = F.max_pool2d(x, 2)
        x = self.dropout1(x)
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = self.act3(x)
        activations.append(x.cpu().data.numpy())#layer3
        x = self.dropout2(x)
        x = self.fc2(x)
        x = torch.softmax(x, dim=1)
        activations.append(x.cpu().data.numpy())#layer4
        return x, activations

# %%
Plate = MI_Plate() #Create class object
Plate.save_activations() #save activations if they weren't saved already
Plate.compute_MI() #compute and save MIs if they weren't saved before
# Out:
# Epoch: 1 	Training Loss: 0.017779
# Saving activations/epoch00000000
# Epoch: 2 	Training Loss: 0.016100
# Saving activations/epoch00000001
# Epoch: 3 	Training Loss: 0.009453
# Saving activations/epoch00000002
# Epoch: 4 	Training Loss: 0.006210
# Saving activations/epoch00000003
# Epoch: 5 	Training Loss: 0.005115
# Saving activations/epoch00000004
# Epoch: 6 	Training Loss: 0.004545
# Saving activations/epoch00000005
# Epoch: 7 	Training Loss: 0.004180
# Saving activations/epoch00000006
# Epoch: 8 	Training Loss: 0.003921
# Saving activations/epoch00000007
# Epoch: 9 	Training Loss: 0.003700
# Saving activations/epoch00000008
# Epoch: 10 	Training Loss: 0.003539
# Saving activations/epoch00000009
# Epoch: 11 	Training Loss: 0.003414
# Saving activations/epoch00000010
# Epoch: 12 	Training Loss: 0.003257
# Saving activations/epoch00000011
# Epoch: 13 	Training Loss: 0.003198
# Saving activations/epoch00000012
# Epoch: 14 	Training Loss: 0.003069
# Saving activations/epoch00000013
# Epoch: 15 	Training Loss: 0.003018
# Saving activations/epoch00000014
# Epoch: 16 	Training Loss: 0.002934
# Saving activations/epoch00000015
# Epoch: 17 	Training Loss: 0.002870
# Saving activations/epoch00000016
# Epoch: 18 	Training Loss: 0.002783
# Saving activations/epoch00000017
# Epoch: 19 	Training Loss: 0.002751
# Saving activations/epoch00000018
# Epoch: 20 	Training Loss: 0.002697
# Saving activations/epoch00000019
# Epoch: 21 	Training Loss: 0.002631
# Saving activations/epoch00000020
# Epoch: 22 	Training Loss: 0.002599
# Epoch: 23 	Training Loss: 0.002534
# Epoch: 24 	Training Loss: 0.002519
# Epoch: 25 	Training Loss: 0.002480
# Epoch: 26 	Training Loss: 0.002437
# Saving activations/epoch00000025
# Epoch: 27 	Training Loss: 0.002414
# Epoch: 28 	Training Loss: 0.002367
# Epoch: 29 	Training Loss: 0.002336
# Epoch: 30 	Training Loss: 0.002292
# Epoch: 31 	Training Loss: 0.002243
# Saving activations/epoch00000030
# Epoch: 32 	Training Loss: 0.002223
# Epoch: 33 	Training Loss: 0.002206
# Epoch: 34 	Training Loss: 0.002171
# Epoch: 35 	Training Loss: 0.002139
# Epoch: 36 	Training Loss: 0.002110
# Saving activations/epoch00000035
# Epoch: 37 	Training Loss: 0.002111
# Epoch: 38 	Training Loss: 0.002074
# Epoch: 39 	Training Loss: 0.002040
# Epoch: 40 	Training Loss: 0.002005
# Epoch: 41 	Training Loss: 0.001959
# Saving activations/epoch00000040
# Epoch: 42 	Training Loss: 0.001976
# Epoch: 43 	Training Loss: 0.001967
# Epoch: 44 	Training Loss: 0.001948
# Epoch: 45 	Training Loss: 0.001937
# Epoch: 46 	Training Loss: 0.001912
# Saving activations/epoch00000045
# Epoch: 47 	Training Loss: 0.001890
# Epoch: 48 	Training Loss: 0.001861
# Epoch: 49 	Training Loss: 0.001850
# Epoch: 50 	Training Loss: 0.001841
# Epoch: 51 	Training Loss: 0.001820
# Saving activations/epoch00000050
# Epoch: 52 	Training Loss: 0.001797
# Epoch: 53 	Training Loss: 0.001776
# Epoch: 54 	Training Loss: 0.001747
# Epoch: 55 	Training Loss: 0.001744
# Epoch: 56 	Training Loss: 0.001729
# Saving activations/epoch00000055
# Epoch: 57 	Training Loss: 0.001730
# Epoch: 58 	Training Loss: 0.001679
# Epoch: 59 	Training Loss: 0.001688
# Epoch: 60 	Training Loss: 0.001661
# Epoch: 61 	Training Loss: 0.001643
# Saving activations/epoch00000060
# Epoch: 62 	Training Loss: 0.001633
# Epoch: 63 	Training Loss: 0.001618
# Epoch: 64 	Training Loss: 0.001601
# Epoch: 65 	Training Loss: 0.001584
# Epoch: 66 	Training Loss: 0.001570
# Saving activations/epoch00000065
# Epoch: 67 	Training Loss: 0.001570
# Epoch: 68 	Training Loss: 0.001550
# Epoch: 69 	Training Loss: 0.001546
# Epoch: 70 	Training Loss: 0.001528
# Epoch: 71 	Training Loss: 0.001533
# Saving activations/epoch00000070
# Epoch: 72 	Training Loss: 0.001486
# Epoch: 73 	Training Loss: 0.001490
# Epoch: 74 	Training Loss: 0.001471
# Epoch: 75 	Training Loss: 0.001463
# Epoch: 76 	Training Loss: 0.001459
# Saving activations/epoch00000075
# Epoch: 77 	Training Loss: 0.001425
# Epoch: 78 	Training Loss: 0.001427
# Epoch: 79 	Training Loss: 0.001418
# Epoch: 80 	Training Loss: 0.001408
# Epoch: 81 	Training Loss: 0.001390
# Saving activations/epoch00000080
# Epoch: 82 	Training Loss: 0.001405
# Epoch: 83 	Training Loss: 0.001353
# Epoch: 84 	Training Loss: 0.001369
# Epoch: 85 	Training Loss: 0.001375
# Epoch: 86 	Training Loss: 0.001353
# Saving activations/epoch00000085
# Epoch: 87 	Training Loss: 0.001334
# Epoch: 88 	Training Loss: 0.001325
# Epoch: 89 	Training Loss: 0.001323
# Epoch: 90 	Training Loss: 0.001325
# Epoch: 91 	Training Loss: 0.001302
# Saving activations/epoch00000090
# Epoch: 92 	Training Loss: 0.001278
# Epoch: 93 	Training Loss: 0.001276
# Epoch: 94 	Training Loss: 0.001276
# Epoch: 95 	Training Loss: 0.001264
# Epoch: 96 	Training Loss: 0.001248
# Saving activations/epoch00000095
# Epoch: 97 	Training Loss: 0.001257
# Epoch: 98 	Training Loss: 0.001223
# Epoch: 99 	Training Loss: 0.001213
# Epoch: 100 	Training Loss: 0.001212
# *** Doing activations ***
# Doing activations/epoch00000000
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=5798.929, hM_given_X=5789.718, hM_given_Y_upper=5796.628
# - Layer 1 upper: MI(X;M)=13.286, MI(Y;M)=3.317, h_upper=9875.711, hM_given_X=9866.502, hM_given_Y_upper=9873.412
# - Layer 2 upper: MI(X;M)=1.536, MI(Y;M)=0.434, h_upper=35.323, hM_given_X=34.259, hM_given_Y_upper=35.022
# - Layer 3 upper: MI(X;M)=0.005, MI(Y;M)=0.002, h_upper=2.680, hM_given_X=2.676, hM_given_Y_upper=2.678
# Doing activations/epoch00000001
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.321, h_upper=5798.929, hM_given_X=5789.718, hM_given_Y_upper=5796.627
# - Layer 1 upper: MI(X;M)=13.289, MI(Y;M)=3.319, h_upper=9875.713, hM_given_X=9866.502, hM_given_Y_upper=9873.412
# - Layer 2 upper: MI(X;M)=11.849, MI(Y;M)=3.203, h_upper=42.472, hM_given_X=34.259, hM_given_Y_upper=40.252
# - Layer 3 upper: MI(X;M)=0.544, MI(Y;M)=0.360, h_upper=3.053, hM_given_X=2.676, hM_given_Y_upper=2.804
# Doing activations/epoch00000002
# - Layer 0 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=5798.927, hM_given_X=5789.718, hM_given_Y_upper=5796.626
# - Layer 1 upper: MI(X;M)=13.283, MI(Y;M)=3.318, h_upper=9875.709, hM_given_X=9866.502, hM_given_Y_upper=9873.409
# - Layer 2 upper: MI(X;M)=13.156, MI(Y;M)=3.319, h_upper=43.378, hM_given_X=34.259, hM_given_Y_upper=41.077
# - Layer 3 upper: MI(X;M)=3.190, MI(Y;M)=2.259, h_upper=4.888, hM_given_X=2.676, hM_given_Y_upper=3.322
# Doing activations/epoch00000003
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=5798.929, hM_given_X=5789.718, hM_given_Y_upper=5796.627
# - Layer 1 upper: MI(X;M)=13.292, MI(Y;M)=3.319, h_upper=9875.715, hM_given_X=9866.502, hM_given_Y_upper=9873.414
# - Layer 2 upper: MI(X;M)=13.230, MI(Y;M)=3.319, h_upper=43.429, hM_given_X=34.259, hM_given_Y_upper=41.128
# - Layer 3 upper: MI(X;M)=3.592, MI(Y;M)=2.628, h_upper=5.166, hM_given_X=2.676, hM_given_Y_upper=3.344
# Doing activations/epoch00000004
# - Layer 0 upper: MI(X;M)=13.286, MI(Y;M)=3.320, h_upper=5798.927, hM_given_X=5789.718, hM_given_Y_upper=5796.626
# - Layer 1 upper: MI(X;M)=13.281, MI(Y;M)=3.318, h_upper=9875.707, hM_given_X=9866.502, hM_given_Y_upper=9873.407
# - Layer 2 upper: MI(X;M)=13.253, MI(Y;M)=3.319, h_upper=43.445, hM_given_X=34.259, hM_given_Y_upper=41.144
# - Layer 3 upper: MI(X;M)=3.657, MI(Y;M)=2.732, h_upper=5.211, hM_given_X=2.676, hM_given_Y_upper=3.318
# Doing activations/epoch00000005
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.320, h_upper=5798.929, hM_given_X=5789.718, hM_given_Y_upper=5796.628
# - Layer 1 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=9875.711, hM_given_X=9866.502, hM_given_Y_upper=9873.411
# - Layer 2 upper: MI(X;M)=13.264, MI(Y;M)=3.319, h_upper=43.453, hM_given_X=34.259, hM_given_Y_upper=41.152
# - Layer 3 upper: MI(X;M)=3.667, MI(Y;M)=2.787, h_upper=5.218, hM_given_X=2.676, hM_given_Y_upper=3.287
# Doing activations/epoch00000006
# - Layer 0 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=5798.927, hM_given_X=5789.718, hM_given_Y_upper=5796.626
# - Layer 1 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=9875.711, hM_given_X=9866.502, hM_given_Y_upper=9873.410
# - Layer 2 upper: MI(X;M)=13.271, MI(Y;M)=3.319, h_upper=43.458, hM_given_X=34.259, hM_given_Y_upper=41.157
# - Layer 3 upper: MI(X;M)=3.663, MI(Y;M)=2.824, h_upper=5.216, hM_given_X=2.676, hM_given_Y_upper=3.258
# Doing activations/epoch00000007
# - Layer 0 upper: MI(X;M)=13.284, MI(Y;M)=3.320, h_upper=5798.926, hM_given_X=5789.718, hM_given_Y_upper=5796.625
# - Layer 1 upper: MI(X;M)=13.274, MI(Y;M)=3.317, h_upper=9875.702, hM_given_X=9866.502, hM_given_Y_upper=9873.403
# - Layer 2 upper: MI(X;M)=13.275, MI(Y;M)=3.319, h_upper=43.460, hM_given_X=34.259, hM_given_Y_upper=41.159
# - Layer 3 upper: MI(X;M)=3.658, MI(Y;M)=2.850, h_upper=5.212, hM_given_X=2.676, hM_given_Y_upper=3.237
# Doing activations/epoch00000008
# - Layer 0 upper: MI(X;M)=13.287, MI(Y;M)=3.320, h_upper=5798.928, hM_given_X=5789.718, hM_given_Y_upper=5796.627
# - Layer 1 upper: MI(X;M)=13.282, MI(Y;M)=3.318, h_upper=9875.708, hM_given_X=9866.502, hM_given_Y_upper=9873.408
# - Layer 2 upper: MI(X;M)=13.278, MI(Y;M)=3.319, h_upper=43.462, hM_given_X=34.259, hM_given_Y_upper=41.161
# - Layer 3 upper: MI(X;M)=3.650, MI(Y;M)=2.869, h_upper=5.207, hM_given_X=2.676, hM_given_Y_upper=3.218
# Doing activations/epoch00000009
# - Layer 0 upper: MI(X;M)=13.283, MI(Y;M)=3.320, h_upper=5798.925, hM_given_X=5789.718, hM_given_Y_upper=5796.623
# - Layer 1 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=9875.711, hM_given_X=9866.502, hM_given_Y_upper=9873.411
# - Layer 2 upper: MI(X;M)=13.280, MI(Y;M)=3.319, h_upper=43.464, hM_given_X=34.259, hM_given_Y_upper=41.163
# - Layer 3 upper: MI(X;M)=3.645, MI(Y;M)=2.887, h_upper=5.203, hM_given_X=2.676, hM_given_Y_upper=3.202
# Doing activations/epoch00000010
# - Layer 0 upper: MI(X;M)=13.290, MI(Y;M)=3.319, h_upper=5798.930, hM_given_X=5789.718, hM_given_Y_upper=5796.629
# - Layer 1 upper: MI(X;M)=13.286, MI(Y;M)=3.318, h_upper=9875.711, hM_given_X=9866.502, hM_given_Y_upper=9873.411
# - Layer 2 upper: MI(X;M)=13.281, MI(Y;M)=3.319, h_upper=43.465, hM_given_X=34.259, hM_given_Y_upper=41.164
# - Layer 3 upper: MI(X;M)=3.638, MI(Y;M)=2.900, h_upper=5.198, hM_given_X=2.676, hM_given_Y_upper=3.189
# Doing activations/epoch00000011
# - Layer 0 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=5798.926, hM_given_X=5789.718, hM_given_Y_upper=5796.626
# - Layer 1 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=9875.711, hM_given_X=9866.502, hM_given_Y_upper=9873.411
# - Layer 2 upper: MI(X;M)=13.282, MI(Y;M)=3.319, h_upper=43.465, hM_given_X=34.259, hM_given_Y_upper=41.164
# - Layer 3 upper: MI(X;M)=3.631, MI(Y;M)=2.909, h_upper=5.193, hM_given_X=2.676, hM_given_Y_upper=3.177
# Doing activations/epoch00000012
# - Layer 0 upper: MI(X;M)=13.291, MI(Y;M)=3.320, h_upper=5798.931, hM_given_X=5789.718, hM_given_Y_upper=5796.630
# - Layer 1 upper: MI(X;M)=13.288, MI(Y;M)=3.318, h_upper=9875.712, hM_given_X=9866.502, hM_given_Y_upper=9873.412
# - Layer 2 upper: MI(X;M)=13.283, MI(Y;M)=3.319, h_upper=43.466, hM_given_X=34.259, hM_given_Y_upper=41.165
# - Layer 3 upper: MI(X;M)=3.626, MI(Y;M)=2.920, h_upper=5.190, hM_given_X=2.676, hM_given_Y_upper=3.166
# Doing activations/epoch00000013
# - Layer 0 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=5798.926, hM_given_X=5789.718, hM_given_Y_upper=5796.626
# - Layer 1 upper: MI(X;M)=13.278, MI(Y;M)=3.320, h_upper=9875.705, hM_given_X=9866.502, hM_given_Y_upper=9873.404
# - Layer 2 upper: MI(X;M)=13.284, MI(Y;M)=3.319, h_upper=43.466, hM_given_X=34.259, hM_given_Y_upper=41.165
# - Layer 3 upper: MI(X;M)=3.622, MI(Y;M)=2.931, h_upper=5.187, hM_given_X=2.676, hM_given_Y_upper=3.155
# Doing activations/epoch00000014
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=5798.929, hM_given_X=5789.718, hM_given_Y_upper=5796.628
# - Layer 1 upper: MI(X;M)=13.290, MI(Y;M)=3.319, h_upper=9875.714, hM_given_X=9866.502, hM_given_Y_upper=9873.414
# - Layer 2 upper: MI(X;M)=13.284, MI(Y;M)=3.319, h_upper=43.467, hM_given_X=34.259, hM_given_Y_upper=41.166
# - Layer 3 upper: MI(X;M)=3.617, MI(Y;M)=2.938, h_upper=5.183, hM_given_X=2.676, hM_given_Y_upper=3.147
# Doing activations/epoch00000015
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=5798.928, hM_given_X=5789.718, hM_given_Y_upper=5796.627
# - Layer 1 upper: MI(X;M)=13.279, MI(Y;M)=3.318, h_upper=9875.706, hM_given_X=9866.502, hM_given_Y_upper=9873.406
# - Layer 2 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=43.467, hM_given_X=34.259, hM_given_Y_upper=41.166
# - Layer 3 upper: MI(X;M)=3.612, MI(Y;M)=2.948, h_upper=5.180, hM_given_X=2.676, hM_given_Y_upper=3.137
# Doing activations/epoch00000016
# - Layer 0 upper: MI(X;M)=13.290, MI(Y;M)=3.320, h_upper=5798.930, hM_given_X=5789.718, hM_given_Y_upper=5796.629
# - Layer 1 upper: MI(X;M)=13.300, MI(Y;M)=3.319, h_upper=9875.721, hM_given_X=9866.502, hM_given_Y_upper=9873.420
# - Layer 2 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=43.467, hM_given_X=34.259, hM_given_Y_upper=41.166
# - Layer 3 upper: MI(X;M)=3.608, MI(Y;M)=2.954, h_upper=5.177, hM_given_X=2.676, hM_given_Y_upper=3.130
# Doing activations/epoch00000017
# - Layer 0 upper: MI(X;M)=13.292, MI(Y;M)=3.319, h_upper=5798.932, hM_given_X=5789.718, hM_given_Y_upper=5796.631
# - Layer 1 upper: MI(X;M)=13.281, MI(Y;M)=3.319, h_upper=9875.707, hM_given_X=9866.502, hM_given_Y_upper=9873.406
# - Layer 2 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=43.467, hM_given_X=34.259, hM_given_Y_upper=41.167
# - Layer 3 upper: MI(X;M)=3.605, MI(Y;M)=2.963, h_upper=5.175, hM_given_X=2.676, hM_given_Y_upper=3.122
# Doing activations/epoch00000018
# - Layer 0 upper: MI(X;M)=13.291, MI(Y;M)=3.320, h_upper=5798.931, hM_given_X=5789.718, hM_given_Y_upper=5796.630
# - Layer 1 upper: MI(X;M)=13.281, MI(Y;M)=3.317, h_upper=9875.707, hM_given_X=9866.502, hM_given_Y_upper=9873.408
# - Layer 2 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=43.468, hM_given_X=34.259, hM_given_Y_upper=41.167
# - Layer 3 upper: MI(X;M)=3.600, MI(Y;M)=2.969, h_upper=5.172, hM_given_X=2.676, hM_given_Y_upper=3.114
# Doing activations/epoch00000019
# - Layer 0 upper: MI(X;M)=13.284, MI(Y;M)=3.319, h_upper=5798.926, hM_given_X=5789.718, hM_given_Y_upper=5796.625
# - Layer 1 upper: MI(X;M)=13.283, MI(Y;M)=3.319, h_upper=9875.709, hM_given_X=9866.502, hM_given_Y_upper=9873.408
# - Layer 2 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=43.468, hM_given_X=34.259, hM_given_Y_upper=41.167
# - Layer 3 upper: MI(X;M)=3.597, MI(Y;M)=2.975, h_upper=5.170, hM_given_X=2.676, hM_given_Y_upper=3.107
# Doing activations/epoch00000020
# - Layer 0 upper: MI(X;M)=13.281, MI(Y;M)=3.319, h_upper=5798.924, hM_given_X=5789.718, hM_given_Y_upper=5796.623
# - Layer 1 upper: MI(X;M)=13.278, MI(Y;M)=3.318, h_upper=9875.705, hM_given_X=9866.502, hM_given_Y_upper=9873.405
# - Layer 2 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=43.468, hM_given_X=34.259, hM_given_Y_upper=41.167
# - Layer 3 upper: MI(X;M)=3.593, MI(Y;M)=2.983, h_upper=5.167, hM_given_X=2.676, hM_given_Y_upper=3.100
# Doing activations/epoch00000025
# - Layer 0 upper: MI(X;M)=13.290, MI(Y;M)=3.319, h_upper=5798.930, hM_given_X=5789.718, hM_given_Y_upper=5796.629
# - Layer 1 upper: MI(X;M)=13.289, MI(Y;M)=3.319, h_upper=9875.713, hM_given_X=9866.502, hM_given_Y_upper=9873.412
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=43.468, hM_given_X=34.259, hM_given_Y_upper=41.167
# - Layer 3 upper: MI(X;M)=3.576, MI(Y;M)=3.005, h_upper=5.155, hM_given_X=2.676, hM_given_Y_upper=3.072
# Doing activations/epoch00000030
# - Layer 0 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=5798.927, hM_given_X=5789.718, hM_given_Y_upper=5796.626
# - Layer 1 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=9875.710, hM_given_X=9866.502, hM_given_Y_upper=9873.409
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=43.468, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.563, MI(Y;M)=3.027, h_upper=5.146, hM_given_X=2.676, hM_given_Y_upper=3.047
# Doing activations/epoch00000035
# - Layer 0 upper: MI(X;M)=13.293, MI(Y;M)=3.319, h_upper=5798.932, hM_given_X=5789.718, hM_given_Y_upper=5796.631
# - Layer 1 upper: MI(X;M)=13.283, MI(Y;M)=3.320, h_upper=9875.709, hM_given_X=9866.502, hM_given_Y_upper=9873.408
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.549, MI(Y;M)=3.045, h_upper=5.136, hM_given_X=2.676, hM_given_Y_upper=3.026
# Doing activations/epoch00000040
# - Layer 0 upper: MI(X;M)=13.294, MI(Y;M)=3.320, h_upper=5798.933, hM_given_X=5789.718, hM_given_Y_upper=5796.632
# - Layer 1 upper: MI(X;M)=13.283, MI(Y;M)=3.320, h_upper=9875.709, hM_given_X=9866.502, hM_given_Y_upper=9873.407
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.537, MI(Y;M)=3.057, h_upper=5.128, hM_given_X=2.676, hM_given_Y_upper=3.009
# Doing activations/epoch00000045
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=5798.928, hM_given_X=5789.718, hM_given_Y_upper=5796.627
# - Layer 1 upper: MI(X;M)=13.272, MI(Y;M)=3.318, h_upper=9875.701, hM_given_X=9866.502, hM_given_Y_upper=9873.401
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.531, MI(Y;M)=3.071, h_upper=5.124, hM_given_X=2.676, hM_given_Y_upper=2.996
# Doing activations/epoch00000050
# - Layer 0 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=5798.927, hM_given_X=5789.718, hM_given_Y_upper=5796.626
# - Layer 1 upper: MI(X;M)=13.274, MI(Y;M)=3.318, h_upper=9875.702, hM_given_X=9866.502, hM_given_Y_upper=9873.402
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.521, MI(Y;M)=3.081, h_upper=5.117, hM_given_X=2.676, hM_given_Y_upper=2.981
# Doing activations/epoch00000055
# - Layer 0 upper: MI(X;M)=13.287, MI(Y;M)=3.320, h_upper=5798.928, hM_given_X=5789.718, hM_given_Y_upper=5796.626
# - Layer 1 upper: MI(X;M)=13.272, MI(Y;M)=3.318, h_upper=9875.701, hM_given_X=9866.502, hM_given_Y_upper=9873.401
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.513, MI(Y;M)=3.092, h_upper=5.112, hM_given_X=2.676, hM_given_Y_upper=2.969
# Doing activations/epoch00000060
# - Layer 0 upper: MI(X;M)=13.292, MI(Y;M)=3.320, h_upper=5798.932, hM_given_X=5789.718, hM_given_Y_upper=5796.631
# - Layer 1 upper: MI(X;M)=13.295, MI(Y;M)=3.318, h_upper=9875.717, hM_given_X=9866.502, hM_given_Y_upper=9873.417
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.507, MI(Y;M)=3.101, h_upper=5.107, hM_given_X=2.676, hM_given_Y_upper=2.958
# Doing activations/epoch00000065
# - Layer 0 upper: MI(X;M)=13.290, MI(Y;M)=3.320, h_upper=5798.930, hM_given_X=5789.718, hM_given_Y_upper=5796.629
# - Layer 1 upper: MI(X;M)=13.295, MI(Y;M)=3.319, h_upper=9875.717, hM_given_X=9866.502, hM_given_Y_upper=9873.416
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.498, MI(Y;M)=3.108, h_upper=5.101, hM_given_X=2.676, hM_given_Y_upper=2.947
# Doing activations/epoch00000070
# - Layer 0 upper: MI(X;M)=13.290, MI(Y;M)=3.319, h_upper=5798.930, hM_given_X=5789.718, hM_given_Y_upper=5796.629
# - Layer 1 upper: MI(X;M)=13.285, MI(Y;M)=3.318, h_upper=9875.710, hM_given_X=9866.502, hM_given_Y_upper=9873.410
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.492, MI(Y;M)=3.116, h_upper=5.097, hM_given_X=2.676, hM_given_Y_upper=2.937
# Doing activations/epoch00000075
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=5798.929, hM_given_X=5789.718, hM_given_Y_upper=5796.628
# - Layer 1 upper: MI(X;M)=13.266, MI(Y;M)=3.318, h_upper=9875.697, hM_given_X=9866.502, hM_given_Y_upper=9873.397
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.485, MI(Y;M)=3.122, h_upper=5.092, hM_given_X=2.676, hM_given_Y_upper=2.928
# Doing activations/epoch00000080
# - Layer 0 upper: MI(X;M)=13.284, MI(Y;M)=3.319, h_upper=5798.926, hM_given_X=5789.718, hM_given_Y_upper=5796.625
# - Layer 1 upper: MI(X;M)=13.309, MI(Y;M)=3.319, h_upper=9875.727, hM_given_X=9866.502, hM_given_Y_upper=9873.426
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.478, MI(Y;M)=3.128, h_upper=5.087, hM_given_X=2.676, hM_given_Y_upper=2.919
# Doing activations/epoch00000085
# - Layer 0 upper: MI(X;M)=13.294, MI(Y;M)=3.320, h_upper=5798.933, hM_given_X=5789.718, hM_given_Y_upper=5796.631
# - Layer 1 upper: MI(X;M)=13.295, MI(Y;M)=3.318, h_upper=9875.717, hM_given_X=9866.502, hM_given_Y_upper=9873.417
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.476, MI(Y;M)=3.135, h_upper=5.086, hM_given_X=2.676, hM_given_Y_upper=2.912
# Doing activations/epoch00000090
# - Layer 0 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=5798.926, hM_given_X=5789.718, hM_given_Y_upper=5796.626
# - Layer 1 upper: MI(X;M)=13.309, MI(Y;M)=3.319, h_upper=9875.727, hM_given_X=9866.502, hM_given_Y_upper=9873.426
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.470, MI(Y;M)=3.140, h_upper=5.081, hM_given_X=2.676, hM_given_Y_upper=2.905
# Doing activations/epoch00000095
# - Layer 0 upper: MI(X;M)=13.291, MI(Y;M)=3.320, h_upper=5798.931, hM_given_X=5789.718, hM_given_Y_upper=5796.630
# - Layer 1 upper: MI(X;M)=13.290, MI(Y;M)=3.319, h_upper=9875.714, hM_given_X=9866.502, hM_given_Y_upper=9873.413
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=43.469, hM_given_X=34.259, hM_given_Y_upper=41.168
# - Layer 3 upper: MI(X;M)=3.465, MI(Y;M)=3.145, h_upper=5.078, hM_given_X=2.676, hM_given_Y_upper=2.898

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import torch
import scienceplots
plt.rcParams['font.serif'] = ['Times New Roman']
mpl.rcParams['figure.dpi'] = 800
mpl.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
plt.style.use(['science', 'ieee'])
mpl.rcParams.update({'font.size': 15})

def plot_information_plane(IXT_array, ITY_array, num_epochs, every_n_early=1, every_n_late=5):
    assert len(IXT_array) == len(ITY_array)

    max_index = len(IXT_array)

    fig, ax = plt.subplots(figsize=(5, 3.5))
    ax.set_xlabel('$I(X;T)$', fontsize=15)
    ax.set_ylabel('$I(T;Y)$', fontsize=15)

    cmap = plt.get_cmap('gnuplot')
    colors = [cmap(i) for i in np.linspace(0, 1, num_epochs + 1)]

    for i in range(0, max_index):
        IXT = IXT_array[i, :]
        ITY = ITY_array[i, :]
        
        # 根据 epoch 的范围调整 every_n
        if i < 20:
            color_idx = i * every_n_early
        else:
            color_idx = 20 * every_n_early + (i - 20) * every_n_late

        ax.plot(IXT, ITY, marker='o', markersize=3, markeredgewidth=0.04,
                linestyle='-', linewidth=0.5, color=colors[color_idx], zorder=10)

    sm = plt.cm.ScalarMappable(cmap=cmap, norm=plt.Normalize(vmin=0, vmax=1))
    sm._A = []

    # 使用ax参数指定颜色条位置
    cbar = plt.colorbar(sm, ax=ax, ticks=[])
    cbar.set_label('epoch number', fontsize=15)
    cbar.ax.tick_params(labelsize=15)
    cbar.ax.text(0.5, -0.01, 0, transform=cbar.ax.transAxes, va='top', ha='center')
    cbar.ax.text(0.5, 1.0, str(num_epochs), transform=cbar.ax.transAxes, va='bottom', ha='center')

    ax.set_xticks([0, 2, 4, 6, 8, 10, 12, 14])
    ax.set_yticks([0, 0.5, 1, 1.5, 2, 2.5, 3.0, 3.5])
    ax.set_ylim(-0.05, 3.5)  # 修改y轴坐标范围
    # Adjust coordinates of text according to the plot area
    ax.text(-0.2, 0.98, '(c)', fontdict={'size': 15, 'color': 'black'}, transform=ax.transAxes)

    fig.savefig('D:/深度学习与信息论/Fig8c.eps', dpi=800)
    plt.show()

IXT_array = np.load('D:/深度学习与信息论/MI_XM_upper_array.npy')
ITY_array = np.load('D:/深度学习与信息论/MI_YM_upper_array.npy')


plot_information_plane(IXT_array, ITY_array, num_epochs=100, every_n_early=1, every_n_late=5)
