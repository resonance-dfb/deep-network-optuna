# %%
#######################################################################################
##https://github.com/Huma97/Information-Bottleneck-Theory-of-Deep-Learning/tree/master#
#######################################################################################
##讲座6的目的是把神经网络可以分层定义，这样就为我们引入任意的可学习激活函数带来了方便
##此程序改造于上面连接，程序save_activations方法用于在训练期间保存激活值。它首先自动创建一个名为activations的文件夹，
##然后使用一个神经网络模型进行训练，并保存每个时期的激活值。然后引入simplebinmi.py文件
##对于activations保存的每层都分别进行计算
import os
from collections import defaultdict, OrderedDict
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import pickle
from torchvision import datasets
import torchvision.transforms as transforms


train_on_gpu = torch.cuda.is_available()
##判断是否有GPU
if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
    
def categorical_cross_entropy(output, target):
    num_classes = 10
    epsilon = 10e-8
        
    output = torch.clamp(output, epsilon, 1. - epsilon)
    ##使用torch.clamp函数将output张量中的值限制在一个范围内，防止出现数值过大或过小的情况，第一个参数是要处理的张量，第二个参数是下限，第三个参数是上限。
    target = target.float()  # Ensure target is float
    target = target.reshape(target.shape[0], 1).to(output.device)  # Move target to the same device as output
    one_hot_target = (target == torch.arange(num_classes).reshape(1, num_classes).to(output.device)).float()
    return torch.mean(-torch.sum(one_hot_target * torch.log(output), 1))
#将target张量转换为独热编码的形式，即将每个类别的索引转换为一个长度为num_classes的向量，
#其中对应类别的位置为1，其他位置为0。这里用到了torch.arange生成从0到num_classes-1的序列，
#并将其转换为(1, num_classes)的形状

#独热编码的运算就是将一个类别索引转换为一个长度为类别总数的向量，其中对应真实类别的位置为1，其他位置为0。

def init_weights(m):
    if type(m) == nn.Linear:
        nn.init.xavier_uniform_(m.weight)  # 使用 nn.init.xavier_uniform_对于权系数进行初始化
        m.bias.data.fill_(0.0)  # 使用 fill_ 方法来设置偏置为 0
# Out:
# CUDA is available!  Training on GPU ...

# %% [markdown]
# # Downloading MNIST dataset

# %%
#分批训练size，Mnist数据集60000=5w：1w
batch_size = 128

# convert data to a normalized torch.FloatTensor
transform = transforms.Compose([
    transforms.ToTensor()
    ])

# choose the training and test datasets
train_data = datasets.MNIST('./MNIST_data/', download=True, train=True, transform=transform)
test_data = datasets.MNIST('./MNIST_data/', download=True, train=False, transform=transform)

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size)
#分批载入
full_data_loader = torch.utils.data.DataLoader(test_data, batch_size=10000)
#全部载入测试

# %% [markdown]
# # Class for creating NN

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(784, 1024)
        self.fc2 = nn.Linear(1024, 20)
        self.fc3 = nn.Linear(20, 20)
        self.fc4 = nn.Linear(20, 20)
        self.fc5 = nn.Linear(20, 10)

    def forward(self, x):
        activations = []
        x = x.view(-1, 784)
        x = torch.tanh(self.fc1(x))
        activations.append(x)  # 将激活值移动到 CPU 上
        x = torch.tanh(self.fc2(x))
        activations.append(x)  # 将激活值移动到 CPU 上
        x = torch.tanh(self.fc3(x))
        activations.append(x)  # 将激活值移动到 CPU 上
        x = torch.tanh(self.fc4(x))
        activations.append(x)  # 将激活值移动到 CPU 上
        x = torch.softmax(self.fc5(x), dim=1)  # 添加dim参数以指定 softmax 在哪个维度上操作
        activations.append(x.cpu().data.numpy())  # 将激活值移动到 CPU 上
        return x, activations

# 设置设备 .cpu().data.numpy()
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Class for saving activations, computing MI and plotting

# %%
import kde
# 这段代码是用Python来实现一些熵估计方法，特别是用于估计混合高斯模型的熵。以下是对每个函数的简要解释：
#需要下载https://github.com/Huma97/Information-Bottleneck-Theory-of-Deep-Learning/tree/master，jupyter载入
# get_dists(X):
# 这个函数用来计算输入数据集X中样本之间的成对欧氏距离的平方。它首先计算每个样本向量的平方范数，并将结果扩展为列向量，然后使用矩阵乘法和广播来计算所有样本对之间的距离平方。

# get_shape(x):
# 这个函数用来获取输入矩阵x的形状信息，返回矩阵的列数（特征维度）和行数（样本数）。

# entropy_estimator_kl(x, var):
# 这个函数基于KL散度的方法估计输入数据集x的熵，假设数据集服从多个高斯分布的混合模型。它首先计算数据集中样本之间的成对欧氏距离的平方，然后根据给定的方差var计算距离的对数概率，并最终求取其均值。

# entropy_estimator_bd(x, var):
# 这个函数基于Bhattacharyya系数的方法估计输入数据集x的熵的下界，同样假设数据集服从多个高斯分布的混合模型。它首先利用entropy_estimator_kl函数计算KL散度的估计值，然后加上一个校正项。

# kde_condentropy(output, var):
# 这个函数计算输出的多元高斯分布的条件熵，假设每个维度的方差均为var。
import simplebinmi
#需要下载https://github.com/Huma97/Information-Bottleneck-Theory-of-Deep-Learning/tree/master，jupyter载入
# get_unique_probs(x):
# 这个函数用于计算输入数据集x中每个唯一样本出现的概率。首先，它将输入数据x转换为字节视图，并将其看作是void类型的视图，这样可以方便地比较数据集中的唯一样本。然后，使用NumPy的np.unique函数找到唯一的样本，同时计算出现的次数。最后，将每个唯一样本出现的次数除以总样本数，得到概率值。

# bin_calc_information(inputdata, layerdata, num_of_bins):
# 这个函数用于计算给定输入数据和某一层的输出数据之间的信息量。首先，使用get_unique_probs函数计算输入数据集中每个唯一样本的概率，并将结果存储在p_xs中。然后，将输出数据分成num_of_bins个区间，并计算每个区间中的样本出现的概率。接着，利用信息论中的熵的定义来计算层的熵（H_LAYER）和给定输入的条件下层的熵（H_LAYER_GIVEN_INPUT）。最后，返回两者之差，即信息量。

# bin_calc_information2(labelixs, layerdata, binsize):
# 这个函数也用于计算信息量，与上一个函数相似，但在计算输出的条件熵时使用了一种简化的方法。首先，将层的输出数据划分成多个区间，然后计算每个区间中样本出现的概率。接着，利用这些概率值计算层的熵（H_LAYER）。然后，对于每个标签，通过求取其样本在层输出中的平均位置，计算出条件熵，然后将所有标签对应的条件熵加和。最后，返回层的熵和在给定输出的情况下层的条件熵之差。

# %%
class MI_Plate():
    def __init__(self, n_epochs=100, DO_LOWER=False, DO_BINNED=False, PLOT_LAYERS=None):
        super(MI_Plate, self).__init__()
        
        self.n_epochs = n_epochs
        self.DO_LOWER = DO_LOWER
        self.DO_BINNED = DO_BINNED
        self.PLOT_LAYERS = PLOT_LAYERS
#DO_LOWER和DO_BINNED是用于控制数据预处理的布尔值，PLOT_LAYERS是用于指定绘制哪些层的激活值的列表
    def save_activations(self):
        
        if not os.path.exists('activations'):
            print("Making directory", 'activations')
            os.mkdir('activations')
            
        model = Net()
        model.apply(init_weights)

        optimizer = optim.SGD(model.parameters(), lr=0.001)
        
        # Move model to GPU if available
        if train_on_gpu:
            model.cuda()
        
        for epoch in range(self.n_epochs):
            # monitor training loss
            train_loss = 0.0

            ###################
            # train the model #
            ###################
            model.train()

            for data, target in train_loader:
                if train_on_gpu:
                    data, target = data.cuda(), target.cuda()  # Move data to GPU
                # clear the gradients of all optimized variables
                optimizer.zero_grad()
                # forward pass: compute predicted outputs by passing inputs to the model
                output, _ = model(data)
                # calculate the loss
                loss = categorical_cross_entropy(output, target)
                # backward pass: compute gradient of the loss with respect to model parameters
                loss.backward()
                # perform a single optimization step (parameter update)
                optimizer.step()
                # update running training loss
                train_loss += loss.item()#*data.size(0)

            # print training statistics 
            # calculate average loss over an epoch
            train_loss = train_loss/len(train_loader.dataset)

            print('Epoch: {} \tTraining Loss: {:.6f}'.format(
                epoch+1, 
                train_loss
                ))

            model.eval()

            for data, _ in full_data_loader:
                if train_on_gpu:
                    data = data.cuda()  # Move data to GPU
                _, activations = model(data)
            
            if epoch < 20:       # Log for all first 20 epochs
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            elif (epoch < 100) and (epoch % 5 == 0):    # Then for every 5th epoch
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            elif (epoch < 200) and (epoch % 10 == 0):    # Then every 10th
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            elif (epoch % 100 == 0):                # Then every 100th
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
                    
      
    def compute_MI(self, noise_variance=1e-1):
        
        MAX_EPOCHS = self.n_epochs
        self.noise_variance = noise_variance
        
        def entropy_func_upper(x):
            return kde.entropy_estimator_kl(x,self.noise_variance)
        
        def entropy_func_lower(x):
            return kde.entropy_estimator_bd(x,self.noise_variance)

        # nats to bits conversion factor
        nats2bits = 1.0/np.log(2) 


        # Save indexes of tests data for each of the output classes
        saved_labelixs = {}
        for data, targets in full_data_loader:
            trg = targets.numpy()
        for i in range(10):
            saved_labelixs[i] = trg == i

        labelprobs = np.mean(np.eye(10)[test_data.targets], axis=0)

        measures = OrderedDict()
        measures['tanh'] = {}
        #measures['tanh'] = {}

        #epoch = 0

        cur_dir = 'activations'
        if not os.path.exists(cur_dir):
            print("Directory %s not found" % cur_dir)

        # Load files saved during each epoch, and compute MI measures of the activity in that epoch
        print('*** Doing %s ***' % cur_dir)
        for epochfile in sorted(os.listdir(cur_dir)):
            if not epochfile.startswith('epoch'):
                continue

            fname = cur_dir + "/" + epochfile
            with open(fname, 'rb') as f:
                d = pickle.load(f)

            epoch = d[1]
            d = d[0]
            if epoch in measures['tanh']:# Skip this epoch if its already been processed
                continue                # this is a trick to allow us to rerun this cell multiple times)

            if epoch > MAX_EPOCHS:
                continue

            print("Doing", fname)

            num_layers = len(d)

            if self.PLOT_LAYERS is None:
                PLOT_LAYERS = []
                for lndx in range(num_layers):
                    PLOT_LAYERS.append(lndx)

            cepochdata = defaultdict(list)
            for lndx in range(num_layers):
                activity = d[lndx]

                # Compute marginal entropies
                h_upper = entropy_func_upper(activity)
                if self.DO_LOWER:
                    #h_lower = entropy_func_lower([activity,])[0]
                    h_lower = entropy_func_lower(activity)

                # Layer activity given input. This is simply the entropy of the Gaussian noise
                hM_given_X = kde.kde_condentropy(activity, self.noise_variance)

                # Compute conditional entropies of layer activity given output
                hM_given_Y_upper=0.
                for i in range(10):
                    hcond_upper = entropy_func_upper(activity[saved_labelixs[i],:])
                    hM_given_Y_upper += labelprobs[i] * hcond_upper

                if self.DO_LOWER:
                    hM_given_Y_lower=0.
                    for i in range(10):
                        hcond_lower = entropy_func_lower(activity[saved_labelixs[i],:])
                        hM_given_Y_lower += labelprobs[i] * hcond_lower

                cepochdata['MI_XM_upper'].append( nats2bits * (h_upper - hM_given_X) )
                cepochdata['MI_YM_upper'].append( nats2bits * (h_upper - hM_given_Y_upper) )
                cepochdata['H_M_upper'  ].append( nats2bits * h_upper )

                pstr = 'upper: MI(X;M)=%0.3f, MI(Y;M)=%0.3f, h_upper=%0.3f, hM_given_X=%0.3f, hM_given_Y_upper=%0.3f ' % (cepochdata['MI_XM_upper'][-1], cepochdata['MI_YM_upper'][-1], h_upper, hM_given_X, hM_given_Y_upper)
                if self.DO_LOWER:  # Compute lower bounds
                    cepochdata['MI_XM_lower'].append( nats2bits * (h_lower - hM_given_X) )
                    cepochdata['MI_YM_lower'].append( nats2bits * (h_lower - hM_given_Y_lower) )
                    cepochdata['H_M_lower'  ].append( nats2bits * h_lower )
                    pstr += ' | lower: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_lower'][-1], cepochdata['MI_YM_lower'][-1])

                if self.DO_BINNED: # Compute binner estimates
                    binxm, binym = simplebinmi.bin_calc_information2(saved_labelixs, activity, 0.5)
                    cepochdata['MI_XM_bin'].append( nats2bits * binxm )
                    cepochdata['MI_YM_bin'].append( nats2bits * binym )
                    pstr += ' | bin: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_bin'][-1], cepochdata['MI_YM_bin'][-1])

                print('- Layer %d %s' % (lndx, pstr) )

            measures['tanh'][epoch] = cepochdata
             
            #epoch += 1
        
        with open('MI', 'wb') as f:
            pickle.dump(measures, f, pickle.HIGHEST_PROTOCOL)
            
    def plot(self, DO_SAVE=False):
        self.DO_SAVE = DO_SAVE
        with open('MI', 'rb') as f:
            measures = pickle.load(f)
            
        COLORBAR_MAX_EPOCHS = self.n_epochs
        infoplane_measure = 'upper'
        PLOT_LAYERS = [0,1,2,3,4] #Which layers to plot
        
        max_epoch = max( (max(vals.keys()) if len(vals) else 0) for vals in measures.values())
        sm = plt.cm.ScalarMappable(cmap='gnuplot', norm=plt.Normalize(vmin=0, vmax=COLORBAR_MAX_EPOCHS))
        sm._A = []

        fig=plt.figure(figsize=(10,5))
        for actndx, (activation, vals) in enumerate(measures.items()):
            epochs = sorted(vals.keys())
            if not len(epochs):
                continue
            plt.subplot(1,2,actndx+1)    
            for epoch in epochs:
                c = sm.to_rgba(epoch)
                xmvals = np.array(vals[epoch]['MI_XM_'+infoplane_measure])[PLOT_LAYERS]
                ymvals = np.array(vals[epoch]['MI_YM_'+infoplane_measure])[PLOT_LAYERS]

                plt.plot(xmvals, ymvals, c=c, alpha=0.1, zorder=1)
                plt.scatter(xmvals, ymvals, s=20, facecolors=[c for _ in PLOT_LAYERS], edgecolor='none', zorder=2)

            plt.ylim([0, 3.5])
            plt.xlim([0, 14])
            plt.xlabel('I(X;M)')
            plt.ylabel('I(Y;M)')
            plt.title(activation)

        cbaxes = fig.add_axes([1.0, 0.125, 0.03, 0.8]) 
        plt.colorbar(sm, label='Epoch', cax=cbaxes)
        plt.tight_layout()
        plt.show()

        if self.DO_SAVE:
            plt.savefig('plots/' + DIR_TEMPLATE % ('infoplane_'+ARCH),bbox_inches='tight')

# %%
Plate = MI_Plate() #Create class object
Plate.save_activations() #save activations if they weren't saved already
Plate.compute_MI() #compute and save MIs if they weren't saved before
Plate.plot() #plot
# Out:
# Epoch: 1 	Training Loss: 0.015167
# Saving activations/epoch00000000
# Epoch: 2 	Training Loss: 0.012462
# Saving activations/epoch00000001
# Epoch: 3 	Training Loss: 0.011197
# Saving activations/epoch00000002
# Epoch: 4 	Training Loss: 0.010274
# Saving activations/epoch00000003
# Epoch: 5 	Training Loss: 0.009520
# Saving activations/epoch00000004
# Epoch: 6 	Training Loss: 0.008876
# Saving activations/epoch00000005
# Epoch: 7 	Training Loss: 0.008317
# Saving activations/epoch00000006
# Epoch: 8 	Training Loss: 0.007823
# Saving activations/epoch00000007
# Epoch: 9 	Training Loss: 0.007387
# Saving activations/epoch00000008
# Epoch: 10 	Training Loss: 0.006999
# Saving activations/epoch00000009
# Epoch: 11 	Training Loss: 0.006654
# Saving activations/epoch00000010
# Epoch: 12 	Training Loss: 0.006345
# Saving activations/epoch00000011
# Epoch: 13 	Training Loss: 0.006068
# Saving activations/epoch00000012
# Epoch: 14 	Training Loss: 0.005819
# Saving activations/epoch00000013
# Epoch: 15 	Training Loss: 0.005594
# Saving activations/epoch00000014
# Epoch: 16 	Training Loss: 0.005390
# Saving activations/epoch00000015
# Epoch: 17 	Training Loss: 0.005204
# Saving activations/epoch00000016
# Epoch: 18 	Training Loss: 0.005035
# Saving activations/epoch00000017
# Epoch: 19 	Training Loss: 0.004880
# Saving activations/epoch00000018
# Epoch: 20 	Training Loss: 0.004737
# Saving activations/epoch00000019
# Epoch: 21 	Training Loss: 0.004606
# Saving activations/epoch00000020
# Epoch: 22 	Training Loss: 0.004484
# Epoch: 23 	Training Loss: 0.004370
# Epoch: 24 	Training Loss: 0.004264
# Epoch: 25 	Training Loss: 0.004165
# Epoch: 26 	Training Loss: 0.004072
# Saving activations/epoch00000025
# Epoch: 27 	Training Loss: 0.003985
# Epoch: 28 	Training Loss: 0.003903
# Epoch: 29 	Training Loss: 0.003824
# Epoch: 30 	Training Loss: 0.003752
# Epoch: 31 	Training Loss: 0.003681
# Saving activations/epoch00000030
# Epoch: 32 	Training Loss: 0.003615
# Epoch: 33 	Training Loss: 0.003552
# Epoch: 34 	Training Loss: 0.003493
# Epoch: 35 	Training Loss: 0.003436
# Epoch: 36 	Training Loss: 0.003382
# Saving activations/epoch00000035
# Epoch: 37 	Training Loss: 0.003330
# Epoch: 38 	Training Loss: 0.003280
# Epoch: 39 	Training Loss: 0.003232
# Epoch: 40 	Training Loss: 0.003187
# Epoch: 41 	Training Loss: 0.003144
# Saving activations/epoch00000040
# Epoch: 42 	Training Loss: 0.003101
# Epoch: 43 	Training Loss: 0.003060
# Epoch: 44 	Training Loss: 0.003021
# Epoch: 45 	Training Loss: 0.002984
# Epoch: 46 	Training Loss: 0.002948
# Saving activations/epoch00000045
# Epoch: 47 	Training Loss: 0.002912
# Epoch: 48 	Training Loss: 0.002879
# Epoch: 49 	Training Loss: 0.002846
# Epoch: 50 	Training Loss: 0.002814
# Epoch: 51 	Training Loss: 0.002784
# Saving activations/epoch00000050
# Epoch: 52 	Training Loss: 0.002754
# Epoch: 53 	Training Loss: 0.002725
# Epoch: 54 	Training Loss: 0.002697
# Epoch: 55 	Training Loss: 0.002669
# Epoch: 56 	Training Loss: 0.002643
# Saving activations/epoch00000055
# Epoch: 57 	Training Loss: 0.002617
# Epoch: 58 	Training Loss: 0.002592
# Epoch: 59 	Training Loss: 0.002568
# Epoch: 60 	Training Loss: 0.002544
# Epoch: 61 	Training Loss: 0.002520
# Saving activations/epoch00000060
# Epoch: 62 	Training Loss: 0.002498
# Epoch: 63 	Training Loss: 0.002476
# Epoch: 64 	Training Loss: 0.002454
# Epoch: 65 	Training Loss: 0.002433
# Epoch: 66 	Training Loss: 0.002412
# Saving activations/epoch00000065
# Epoch: 67 	Training Loss: 0.002393
# Epoch: 68 	Training Loss: 0.002373
# Epoch: 69 	Training Loss: 0.002354
# Epoch: 70 	Training Loss: 0.002334
# Epoch: 71 	Training Loss: 0.002316
# Saving activations/epoch00000070
# Epoch: 72 	Training Loss: 0.002298
# Epoch: 73 	Training Loss: 0.002280
# Epoch: 74 	Training Loss: 0.002263
# Epoch: 75 	Training Loss: 0.002247
# Epoch: 76 	Training Loss: 0.002229
# Saving activations/epoch00000075
# Epoch: 77 	Training Loss: 0.002213
# Epoch: 78 	Training Loss: 0.002196
# Epoch: 79 	Training Loss: 0.002181
# Epoch: 80 	Training Loss: 0.002166
# Epoch: 81 	Training Loss: 0.002151
# Saving activations/epoch00000080
# Epoch: 82 	Training Loss: 0.002135
# Epoch: 83 	Training Loss: 0.002121
# Epoch: 84 	Training Loss: 0.002106
# Epoch: 85 	Training Loss: 0.002092
# Epoch: 86 	Training Loss: 0.002078
# Saving activations/epoch00000085
# Epoch: 87 	Training Loss: 0.002064
# Epoch: 88 	Training Loss: 0.002051
# Epoch: 89 	Training Loss: 0.002038
# Epoch: 90 	Training Loss: 0.002025
# Epoch: 91 	Training Loss: 0.002012
# Saving activations/epoch00000090
# Epoch: 92 	Training Loss: 0.001999
# Epoch: 93 	Training Loss: 0.001987
# Epoch: 94 	Training Loss: 0.001974
# Epoch: 95 	Training Loss: 0.001962
# Epoch: 96 	Training Loss: 0.001950
# Saving activations/epoch00000095
# Epoch: 97 	Training Loss: 0.001938
# Epoch: 98 	Training Loss: 0.001927
# Epoch: 99 	Training Loss: 0.001915
# Epoch: 100 	Training Loss: 0.001904
# *** Doing activations ***
# Doing activations/epoch00000000
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=11.727, MI(Y;M)=3.123, h_upper=13.481, hM_given_X=5.353, hM_given_Y_upper=11.317
# - Layer 2 upper: MI(X;M)=10.167, MI(Y;M)=2.757, h_upper=12.400, hM_given_X=5.353, hM_given_Y_upper=10.489
# - Layer 3 upper: MI(X;M)=8.868, MI(Y;M)=2.468, h_upper=11.500, hM_given_X=5.353, hM_given_Y_upper=9.789
# - Layer 4 upper: MI(X;M)=0.455, MI(Y;M)=0.285, h_upper=2.992, hM_given_X=2.676, hM_given_Y_upper=2.794
# Doing activations/epoch00000001
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=11.895, MI(Y;M)=3.214, h_upper=13.598, hM_given_X=5.353, hM_given_Y_upper=11.370
# - Layer 2 upper: MI(X;M)=10.490, MI(Y;M)=2.985, h_upper=12.624, hM_given_X=5.353, hM_given_Y_upper=10.555
# - Layer 3 upper: MI(X;M)=9.312, MI(Y;M)=2.760, h_upper=11.808, hM_given_X=5.353, hM_given_Y_upper=9.895
# - Layer 4 upper: MI(X;M)=0.757, MI(Y;M)=0.513, h_upper=3.201, hM_given_X=2.676, hM_given_Y_upper=2.846
# Doing activations/epoch00000002
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=11.971, MI(Y;M)=3.247, h_upper=13.651, hM_given_X=5.353, hM_given_Y_upper=11.400
# - Layer 2 upper: MI(X;M)=10.635, MI(Y;M)=3.077, h_upper=12.724, hM_given_X=5.353, hM_given_Y_upper=10.592
# - Layer 3 upper: MI(X;M)=9.555, MI(Y;M)=2.900, h_upper=11.976, hM_given_X=5.353, hM_given_Y_upper=9.965
# - Layer 4 upper: MI(X;M)=1.020, MI(Y;M)=0.713, h_upper=3.383, hM_given_X=2.676, hM_given_Y_upper=2.889
# Doing activations/epoch00000003
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.018, MI(Y;M)=3.264, h_upper=13.683, hM_given_X=5.353, hM_given_Y_upper=11.421
# - Layer 2 upper: MI(X;M)=10.720, MI(Y;M)=3.126, h_upper=12.783, hM_given_X=5.353, hM_given_Y_upper=10.616
# - Layer 3 upper: MI(X;M)=9.723, MI(Y;M)=2.986, h_upper=12.093, hM_given_X=5.353, hM_given_Y_upper=10.023
# - Layer 4 upper: MI(X;M)=1.270, MI(Y;M)=0.906, h_upper=3.556, hM_given_X=2.676, hM_given_Y_upper=2.929
# Doing activations/epoch00000004
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.049, MI(Y;M)=3.274, h_upper=13.704, hM_given_X=5.353, hM_given_Y_upper=11.435
# - Layer 2 upper: MI(X;M)=10.773, MI(Y;M)=3.157, h_upper=12.820, hM_given_X=5.353, hM_given_Y_upper=10.632
# - Layer 3 upper: MI(X;M)=9.846, MI(Y;M)=3.043, h_upper=12.178, hM_given_X=5.353, hM_given_Y_upper=10.069
# - Layer 4 upper: MI(X;M)=1.507, MI(Y;M)=1.091, h_upper=3.721, hM_given_X=2.676, hM_given_Y_upper=2.965
# Doing activations/epoch00000005
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.072, MI(Y;M)=3.281, h_upper=13.721, hM_given_X=5.353, hM_given_Y_upper=11.446
# - Layer 2 upper: MI(X;M)=10.812, MI(Y;M)=3.178, h_upper=12.847, hM_given_X=5.353, hM_given_Y_upper=10.644
# - Layer 3 upper: MI(X;M)=9.938, MI(Y;M)=3.082, h_upper=12.241, hM_given_X=5.353, hM_given_Y_upper=10.105
# - Layer 4 upper: MI(X;M)=1.733, MI(Y;M)=1.267, h_upper=3.877, hM_given_X=2.676, hM_given_Y_upper=2.999
# Doing activations/epoch00000006
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.089, MI(Y;M)=3.286, h_upper=13.733, hM_given_X=5.353, hM_given_Y_upper=11.455
# - Layer 2 upper: MI(X;M)=10.838, MI(Y;M)=3.193, h_upper=12.865, hM_given_X=5.353, hM_given_Y_upper=10.652
# - Layer 3 upper: MI(X;M)=10.009, MI(Y;M)=3.112, h_upper=12.291, hM_given_X=5.353, hM_given_Y_upper=10.134
# - Layer 4 upper: MI(X;M)=1.937, MI(Y;M)=1.429, h_upper=4.019, hM_given_X=2.676, hM_given_Y_upper=3.029
# Doing activations/epoch00000007
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.107, MI(Y;M)=3.290, h_upper=13.745, hM_given_X=5.353, hM_given_Y_upper=11.464
# - Layer 2 upper: MI(X;M)=10.865, MI(Y;M)=3.205, h_upper=12.884, hM_given_X=5.353, hM_given_Y_upper=10.662
# - Layer 3 upper: MI(X;M)=10.070, MI(Y;M)=3.136, h_upper=12.333, hM_given_X=5.353, hM_given_Y_upper=10.160
# - Layer 4 upper: MI(X;M)=2.131, MI(Y;M)=1.581, h_upper=4.153, hM_given_X=2.676, hM_given_Y_upper=3.057
# Doing activations/epoch00000008
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.120, MI(Y;M)=3.293, h_upper=13.754, hM_given_X=5.353, hM_given_Y_upper=11.471
# - Layer 2 upper: MI(X;M)=10.882, MI(Y;M)=3.215, h_upper=12.895, hM_given_X=5.353, hM_given_Y_upper=10.667
# - Layer 3 upper: MI(X;M)=10.114, MI(Y;M)=3.153, h_upper=12.363, hM_given_X=5.353, hM_given_Y_upper=10.178
# - Layer 4 upper: MI(X;M)=2.299, MI(Y;M)=1.715, h_upper=4.270, hM_given_X=2.676, hM_given_Y_upper=3.081
# Doing activations/epoch00000009
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.132, MI(Y;M)=3.296, h_upper=13.762, hM_given_X=5.353, hM_given_Y_upper=11.477
# - Layer 2 upper: MI(X;M)=10.896, MI(Y;M)=3.222, h_upper=12.905, hM_given_X=5.353, hM_given_Y_upper=10.672
# - Layer 3 upper: MI(X;M)=10.149, MI(Y;M)=3.168, h_upper=12.387, hM_given_X=5.353, hM_given_Y_upper=10.191
# - Layer 4 upper: MI(X;M)=2.452, MI(Y;M)=1.837, h_upper=4.376, hM_given_X=2.676, hM_given_Y_upper=3.103
# Doing activations/epoch00000010
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.142, MI(Y;M)=3.298, h_upper=13.769, hM_given_X=5.353, hM_given_Y_upper=11.484
# - Layer 2 upper: MI(X;M)=10.908, MI(Y;M)=3.229, h_upper=12.914, hM_given_X=5.353, hM_given_Y_upper=10.676
# - Layer 3 upper: MI(X;M)=10.175, MI(Y;M)=3.180, h_upper=12.406, hM_given_X=5.353, hM_given_Y_upper=10.202
# - Layer 4 upper: MI(X;M)=2.587, MI(Y;M)=1.944, h_upper=4.470, hM_given_X=2.676, hM_given_Y_upper=3.122
# Doing activations/epoch00000011
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.151, MI(Y;M)=3.299, h_upper=13.776, hM_given_X=5.353, hM_given_Y_upper=11.489
# - Layer 2 upper: MI(X;M)=10.919, MI(Y;M)=3.235, h_upper=12.921, hM_given_X=5.353, hM_given_Y_upper=10.679
# - Layer 3 upper: MI(X;M)=10.196, MI(Y;M)=3.190, h_upper=12.420, hM_given_X=5.353, hM_given_Y_upper=10.209
# - Layer 4 upper: MI(X;M)=2.708, MI(Y;M)=2.039, h_upper=4.553, hM_given_X=2.676, hM_given_Y_upper=3.140
# Doing activations/epoch00000012
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.160, MI(Y;M)=3.301, h_upper=13.782, hM_given_X=5.353, hM_given_Y_upper=11.494
# - Layer 2 upper: MI(X;M)=10.928, MI(Y;M)=3.240, h_upper=12.928, hM_given_X=5.353, hM_given_Y_upper=10.682
# - Layer 3 upper: MI(X;M)=10.214, MI(Y;M)=3.198, h_upper=12.433, hM_given_X=5.353, hM_given_Y_upper=10.216
# - Layer 4 upper: MI(X;M)=2.814, MI(Y;M)=2.124, h_upper=4.627, hM_given_X=2.676, hM_given_Y_upper=3.155
# Doing activations/epoch00000013
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.167, MI(Y;M)=3.302, h_upper=13.787, hM_given_X=5.353, hM_given_Y_upper=11.498
# - Layer 2 upper: MI(X;M)=10.934, MI(Y;M)=3.244, h_upper=12.932, hM_given_X=5.353, hM_given_Y_upper=10.684
# - Layer 3 upper: MI(X;M)=10.225, MI(Y;M)=3.205, h_upper=12.440, hM_given_X=5.353, hM_given_Y_upper=10.219
# - Layer 4 upper: MI(X;M)=2.906, MI(Y;M)=2.196, h_upper=4.691, hM_given_X=2.676, hM_given_Y_upper=3.168
# Doing activations/epoch00000014
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.174, MI(Y;M)=3.303, h_upper=13.791, hM_given_X=5.353, hM_given_Y_upper=11.502
# - Layer 2 upper: MI(X;M)=10.939, MI(Y;M)=3.247, h_upper=12.935, hM_given_X=5.353, hM_given_Y_upper=10.685
# - Layer 3 upper: MI(X;M)=10.234, MI(Y;M)=3.211, h_upper=12.446, hM_given_X=5.353, hM_given_Y_upper=10.221
# - Layer 4 upper: MI(X;M)=2.988, MI(Y;M)=2.262, h_upper=4.748, hM_given_X=2.676, hM_given_Y_upper=3.180
# Doing activations/epoch00000015
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.183, MI(Y;M)=3.304, h_upper=13.797, hM_given_X=5.353, hM_given_Y_upper=11.507
# - Layer 2 upper: MI(X;M)=10.947, MI(Y;M)=3.251, h_upper=12.941, hM_given_X=5.353, hM_given_Y_upper=10.687
# - Layer 3 upper: MI(X;M)=10.241, MI(Y;M)=3.216, h_upper=12.452, hM_given_X=5.353, hM_given_Y_upper=10.222
# - Layer 4 upper: MI(X;M)=3.060, MI(Y;M)=2.319, h_upper=4.798, hM_given_X=2.676, hM_given_Y_upper=3.190
# Doing activations/epoch00000016
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.188, MI(Y;M)=3.305, h_upper=13.801, hM_given_X=5.353, hM_given_Y_upper=11.510
# - Layer 2 upper: MI(X;M)=10.950, MI(Y;M)=3.254, h_upper=12.943, hM_given_X=5.353, hM_given_Y_upper=10.688
# - Layer 3 upper: MI(X;M)=10.248, MI(Y;M)=3.220, h_upper=12.456, hM_given_X=5.353, hM_given_Y_upper=10.224
# - Layer 4 upper: MI(X;M)=3.123, MI(Y;M)=2.369, h_upper=4.841, hM_given_X=2.676, hM_given_Y_upper=3.199
# Doing activations/epoch00000017
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.195, MI(Y;M)=3.306, h_upper=13.806, hM_given_X=5.353, hM_given_Y_upper=11.515
# - Layer 2 upper: MI(X;M)=10.958, MI(Y;M)=3.257, h_upper=12.948, hM_given_X=5.353, hM_given_Y_upper=10.691
# - Layer 3 upper: MI(X;M)=10.258, MI(Y;M)=3.225, h_upper=12.463, hM_given_X=5.353, hM_given_Y_upper=10.228
# - Layer 4 upper: MI(X;M)=3.178, MI(Y;M)=2.413, h_upper=4.880, hM_given_X=2.676, hM_given_Y_upper=3.207
# Doing activations/epoch00000018
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.201, MI(Y;M)=3.306, h_upper=13.810, hM_given_X=5.353, hM_given_Y_upper=11.518
# - Layer 2 upper: MI(X;M)=10.962, MI(Y;M)=3.259, h_upper=12.951, hM_given_X=5.353, hM_given_Y_upper=10.692
# - Layer 3 upper: MI(X;M)=10.262, MI(Y;M)=3.228, h_upper=12.466, hM_given_X=5.353, hM_given_Y_upper=10.228
# - Layer 4 upper: MI(X;M)=3.226, MI(Y;M)=2.452, h_upper=4.913, hM_given_X=2.676, hM_given_Y_upper=3.213
# Doing activations/epoch00000019
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.207, MI(Y;M)=3.307, h_upper=13.814, hM_given_X=5.353, hM_given_Y_upper=11.522
# - Layer 2 upper: MI(X;M)=10.962, MI(Y;M)=3.261, h_upper=12.952, hM_given_X=5.353, hM_given_Y_upper=10.691
# - Layer 3 upper: MI(X;M)=10.259, MI(Y;M)=3.231, h_upper=12.464, hM_given_X=5.353, hM_given_Y_upper=10.225
# - Layer 4 upper: MI(X;M)=3.268, MI(Y;M)=2.486, h_upper=4.941, hM_given_X=2.676, hM_given_Y_upper=3.219
# Doing activations/epoch00000020
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.211, MI(Y;M)=3.308, h_upper=13.817, hM_given_X=5.353, hM_given_Y_upper=11.524
# - Layer 2 upper: MI(X;M)=10.967, MI(Y;M)=3.263, h_upper=12.955, hM_given_X=5.353, hM_given_Y_upper=10.693
# - Layer 3 upper: MI(X;M)=10.264, MI(Y;M)=3.234, h_upper=12.468, hM_given_X=5.353, hM_given_Y_upper=10.226
# - Layer 4 upper: MI(X;M)=3.306, MI(Y;M)=2.517, h_upper=4.968, hM_given_X=2.676, hM_given_Y_upper=3.223
# Doing activations/epoch00000025
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.230, MI(Y;M)=3.310, h_upper=13.830, hM_given_X=5.353, hM_given_Y_upper=11.536
# - Layer 2 upper: MI(X;M)=10.973, MI(Y;M)=3.272, h_upper=12.959, hM_given_X=5.353, hM_given_Y_upper=10.691
# - Layer 3 upper: MI(X;M)=10.266, MI(Y;M)=3.246, h_upper=12.469, hM_given_X=5.353, hM_given_Y_upper=10.219
# - Layer 4 upper: MI(X;M)=3.435, MI(Y;M)=2.629, h_upper=5.057, hM_given_X=2.676, hM_given_Y_upper=3.235
# Doing activations/epoch00000030
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.241, MI(Y;M)=3.312, h_upper=13.838, hM_given_X=5.353, hM_given_Y_upper=11.543
# - Layer 2 upper: MI(X;M)=10.973, MI(Y;M)=3.278, h_upper=12.959, hM_given_X=5.353, hM_given_Y_upper=10.687
# - Layer 3 upper: MI(X;M)=10.254, MI(Y;M)=3.253, h_upper=12.461, hM_given_X=5.353, hM_given_Y_upper=10.206
# - Layer 4 upper: MI(X;M)=3.506, MI(Y;M)=2.699, h_upper=5.107, hM_given_X=2.676, hM_given_Y_upper=3.236
# Doing activations/epoch00000035
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.249, MI(Y;M)=3.313, h_upper=13.844, hM_given_X=5.353, hM_given_Y_upper=11.547
# - Layer 2 upper: MI(X;M)=10.969, MI(Y;M)=3.282, h_upper=12.956, hM_given_X=5.353, hM_given_Y_upper=10.681
# - Layer 3 upper: MI(X;M)=10.237, MI(Y;M)=3.259, h_upper=12.449, hM_given_X=5.353, hM_given_Y_upper=10.190
# - Layer 4 upper: MI(X;M)=3.547, MI(Y;M)=2.747, h_upper=5.135, hM_given_X=2.676, hM_given_Y_upper=3.231
# Doing activations/epoch00000040
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.260, MI(Y;M)=3.314, h_upper=13.851, hM_given_X=5.353, hM_given_Y_upper=11.554
# - Layer 2 upper: MI(X;M)=10.972, MI(Y;M)=3.286, h_upper=12.958, hM_given_X=5.353, hM_given_Y_upper=10.681
# - Layer 3 upper: MI(X;M)=10.232, MI(Y;M)=3.265, h_upper=12.445, hM_given_X=5.353, hM_given_Y_upper=10.182
# - Layer 4 upper: MI(X;M)=3.570, MI(Y;M)=2.782, h_upper=5.151, hM_given_X=2.676, hM_given_Y_upper=3.223
# Doing activations/epoch00000045
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.272, MI(Y;M)=3.314, h_upper=13.859, hM_given_X=5.353, hM_given_Y_upper=11.562
# - Layer 2 upper: MI(X;M)=10.976, MI(Y;M)=3.289, h_upper=12.961, hM_given_X=5.353, hM_given_Y_upper=10.681
# - Layer 3 upper: MI(X;M)=10.222, MI(Y;M)=3.269, h_upper=12.439, hM_given_X=5.353, hM_given_Y_upper=10.173
# - Layer 4 upper: MI(X;M)=3.584, MI(Y;M)=2.808, h_upper=5.161, hM_given_X=2.676, hM_given_Y_upper=3.214
# Doing activations/epoch00000050
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.287, MI(Y;M)=3.315, h_upper=13.869, hM_given_X=5.353, hM_given_Y_upper=11.572
# - Layer 2 upper: MI(X;M)=10.988, MI(Y;M)=3.292, h_upper=12.969, hM_given_X=5.353, hM_given_Y_upper=10.688
# - Layer 3 upper: MI(X;M)=10.225, MI(Y;M)=3.273, h_upper=12.440, hM_given_X=5.353, hM_given_Y_upper=10.172
# - Layer 4 upper: MI(X;M)=3.591, MI(Y;M)=2.830, h_upper=5.166, hM_given_X=2.676, hM_given_Y_upper=3.204
# Doing activations/epoch00000055
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.302, MI(Y;M)=3.315, h_upper=13.880, hM_given_X=5.353, hM_given_Y_upper=11.582
# - Layer 2 upper: MI(X;M)=10.996, MI(Y;M)=3.294, h_upper=12.975, hM_given_X=5.353, hM_given_Y_upper=10.692
# - Layer 3 upper: MI(X;M)=10.227, MI(Y;M)=3.276, h_upper=12.441, hM_given_X=5.353, hM_given_Y_upper=10.171
# - Layer 4 upper: MI(X;M)=3.596, MI(Y;M)=2.848, h_upper=5.169, hM_given_X=2.676, hM_given_Y_upper=3.195
# Doing activations/epoch00000060
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.314, MI(Y;M)=3.316, h_upper=13.888, hM_given_X=5.353, hM_given_Y_upper=11.590
# - Layer 2 upper: MI(X;M)=11.005, MI(Y;M)=3.295, h_upper=12.981, hM_given_X=5.353, hM_given_Y_upper=10.697
# - Layer 3 upper: MI(X;M)=10.226, MI(Y;M)=3.279, h_upper=12.441, hM_given_X=5.353, hM_given_Y_upper=10.169
# - Layer 4 upper: MI(X;M)=3.598, MI(Y;M)=2.863, h_upper=5.170, hM_given_X=2.676, hM_given_Y_upper=3.186
# Doing activations/epoch00000065
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.329, MI(Y;M)=3.316, h_upper=13.899, hM_given_X=5.353, hM_given_Y_upper=11.600
# - Layer 2 upper: MI(X;M)=11.020, MI(Y;M)=3.297, h_upper=12.991, hM_given_X=5.353, hM_given_Y_upper=10.706
# - Layer 3 upper: MI(X;M)=10.234, MI(Y;M)=3.282, h_upper=12.446, hM_given_X=5.353, hM_given_Y_upper=10.172
# - Layer 4 upper: MI(X;M)=3.597, MI(Y;M)=2.878, h_upper=5.170, hM_given_X=2.676, hM_given_Y_upper=3.175
# Doing activations/epoch00000070
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.345, MI(Y;M)=3.316, h_upper=13.910, hM_given_X=5.353, hM_given_Y_upper=11.611
# - Layer 2 upper: MI(X;M)=11.034, MI(Y;M)=3.299, h_upper=13.001, hM_given_X=5.353, hM_given_Y_upper=10.715
# - Layer 3 upper: MI(X;M)=10.243, MI(Y;M)=3.284, h_upper=12.453, hM_given_X=5.353, hM_given_Y_upper=10.176
# - Layer 4 upper: MI(X;M)=3.596, MI(Y;M)=2.890, h_upper=5.169, hM_given_X=2.676, hM_given_Y_upper=3.166
# Doing activations/epoch00000075
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.363, MI(Y;M)=3.317, h_upper=13.922, hM_given_X=5.353, hM_given_Y_upper=11.623
# - Layer 2 upper: MI(X;M)=11.045, MI(Y;M)=3.300, h_upper=13.009, hM_given_X=5.353, hM_given_Y_upper=10.722
# - Layer 3 upper: MI(X;M)=10.251, MI(Y;M)=3.286, h_upper=12.458, hM_given_X=5.353, hM_given_Y_upper=10.181
# - Layer 4 upper: MI(X;M)=3.595, MI(Y;M)=2.901, h_upper=5.168, hM_given_X=2.676, hM_given_Y_upper=3.157
# Doing activations/epoch00000080
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.374, MI(Y;M)=3.317, h_upper=13.930, hM_given_X=5.353, hM_given_Y_upper=11.631
# - Layer 2 upper: MI(X;M)=11.059, MI(Y;M)=3.301, h_upper=13.018, hM_given_X=5.353, hM_given_Y_upper=10.730
# - Layer 3 upper: MI(X;M)=10.259, MI(Y;M)=3.288, h_upper=12.464, hM_given_X=5.353, hM_given_Y_upper=10.185
# - Layer 4 upper: MI(X;M)=3.592, MI(Y;M)=2.912, h_upper=5.166, hM_given_X=2.676, hM_given_Y_upper=3.148
# Doing activations/epoch00000085
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.389, MI(Y;M)=3.317, h_upper=13.940, hM_given_X=5.353, hM_given_Y_upper=11.641
# - Layer 2 upper: MI(X;M)=11.074, MI(Y;M)=3.302, h_upper=13.029, hM_given_X=5.353, hM_given_Y_upper=10.741
# - Layer 3 upper: MI(X;M)=10.269, MI(Y;M)=3.289, h_upper=12.471, hM_given_X=5.353, hM_given_Y_upper=10.191
# - Layer 4 upper: MI(X;M)=3.589, MI(Y;M)=2.922, h_upper=5.164, hM_given_X=2.676, hM_given_Y_upper=3.139
# Doing activations/epoch00000090
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.401, MI(Y;M)=3.317, h_upper=13.948, hM_given_X=5.353, hM_given_Y_upper=11.649
# - Layer 2 upper: MI(X;M)=11.083, MI(Y;M)=3.302, h_upper=13.035, hM_given_X=5.353, hM_given_Y_upper=10.746
# - Layer 3 upper: MI(X;M)=10.272, MI(Y;M)=3.290, h_upper=12.473, hM_given_X=5.353, hM_given_Y_upper=10.192
# - Layer 4 upper: MI(X;M)=3.587, MI(Y;M)=2.930, h_upper=5.163, hM_given_X=2.676, hM_given_Y_upper=3.132
# Doing activations/epoch00000095
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=283.280, hM_given_X=274.069, hM_given_Y_upper=280.979
# - Layer 1 upper: MI(X;M)=12.412, MI(Y;M)=3.317, h_upper=13.956, hM_given_X=5.353, hM_given_Y_upper=11.657
# - Layer 2 upper: MI(X;M)=11.094, MI(Y;M)=3.303, h_upper=13.043, hM_given_X=5.353, hM_given_Y_upper=10.753
# - Layer 3 upper: MI(X;M)=10.278, MI(Y;M)=3.291, h_upper=12.477, hM_given_X=5.353, hM_given_Y_upper=10.196
# - Layer 4 upper: MI(X;M)=3.583, MI(Y;M)=2.938, h_upper=5.160, hM_given_X=2.676, hM_given_Y_upper=3.124
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_2220\3040838568.py:238: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
