# %%
#######################################################################################
##https://github.com/Huma97/Information-Bottleneck-Theory-of-Deep-Learning/tree/master#
#######################################################################################
##讲座7把神经网络可以分层定义，引入可学习激活函数
import os
from collections import defaultdict, OrderedDict#为了自动建目录
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import pickle
from torchvision import datasets
import torchvision.transforms as transforms
import matplotlib as mpl
#import scienceplots
import math
train_on_gpu = torch.cuda.is_available()
##判断是否有GPU
if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
    
def categorical_cross_entropy(output, target):
    num_classes = 10
    epsilon = 10e-8
        
    output = torch.clamp(output, epsilon, 1. - epsilon)
    ##使用torch.clamp函数将output张量中的值限制在一个范围内，防止出现数值过大或过小的情况，第一个参数是要处理的张量，第二个参数是下限，第三个参数是上限。
    target = target.float()  # Ensure target is float
    target = target.reshape(target.shape[0], 1).to(output.device)  # Move target to the same device as output
    one_hot_target = (target == torch.arange(num_classes).reshape(1, num_classes).to(output.device)).float()
    return torch.mean(-torch.sum(one_hot_target * torch.log(output), 1))
#将target张量转换为独热编码的形式，即将每个类别的索引转换为一个长度为num_classes的向量，其中对应类别的位置为1，其他位置为0。
#最小化这个损失函数意味着我们希望预测值与真实标签之间的差异越小越好，即模型的预测结果与真实情况越接近
# Out:
# CUDA is available!  Training on GPU ...

# %% [markdown]
# # Downloading MNIST dataset

# %%
#分批训练size，Mnist数据集60000=5w：1w
batch_size = 128

# convert data to a normalized torch.FloatTensor
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))  # 标准化
])
# choose the training and test datasets
train_data = datasets.MNIST('./MNIST_data/', download=True, train=True, transform=transform)
test_data = datasets.MNIST('./MNIST_data/', download=True, train=False, transform=transform)

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size)
#分批载入
full_data_loader = torch.utils.data.DataLoader(test_data, batch_size=10000)
#全部载入测试

# %% [markdown]
# # Class for creating NN

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 8, kernel_size=3, padding=1)  # 输入通道数1，输出通道数8，卷积核大小3x3
        self.conv2 = nn.Conv2d(8, 16, kernel_size=3, padding=1)  # 输入通道数8，输出通道数16，卷积核大小3x3
        self.pool = nn.MaxPool2d(2, 2)                           # 2x2的最大池化层
        self.fc1 = nn.Linear(16 * 7 * 7, 20)                     # 全连接层，输入维度16*7*7，输出维度64
        self.fc3 = nn.Linear(20, 10)                             # 最后的全连接层，输出维度10（对应10个类别）
    
    def forward(self, x):
        activations = []
        x = F.relu(self.conv1(x))  # 第一层卷积 + ReLU激活 
        xx = torch.flatten(x, 1)
        activations.append(xx.cpu().data.numpy())  # 保存第一层的激活
        x = self.pool(x)
        x = F.relu(self.conv2(x))  # 第二层卷积 + ReLU激活
        xx = torch.flatten(x, 1)
        activations.append(xx.cpu().data.numpy())  # 保存第二层的激活
        x = self.pool(x)
        x = x.view(-1, 16 * 7 * 7)                # 展平操作，为全连接层做准备
        x = F.relu(self.fc1(x))                   # 第一个全连接层 + ReLU激活
        activations.append(x.cpu().data.numpy())  # 保存全连接层的激活
        x = self.fc3(x)
        x = torch.softmax(x, dim=1)
        activations.append(x.cpu().data.numpy())  # 保存输出层的激活
        return x, activations

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Class for saving activations, computing MI and plotting

# %%
import kde
# 这段代码是用Python来实现一些熵估计方法，特别是用于估计混合高斯模型的熵。以下是对每个函数的简要解释：
#需要下载https://github.com/Huma97/Information-Bottleneck-Theory-of-Deep-Learning/tree/master，jupyter载入
# get_dists(X):
# 这个函数用来计算输入数据集X中样本之间的成对欧氏距离的平方。它首先计算每个样本向量的平方范数，并将结果扩展为列向量，然后使用矩阵乘法和广播来计算所有样本对之间的距离平方。

# get_shape(x):
# 这个函数用来获取输入矩阵x的形状信息，返回矩阵的列数（特征维度）和行数（样本数）。

# entropy_estimator_kl(x, var):
# 这个函数基于KL散度的方法估计输入数据集x的熵，假设数据集服从多个高斯分布的混合模型。它首先计算数据集中样本之间的成对欧氏距离的平方，然后根据给定的方差var计算距离的对数概率，并最终求取其均值。

# entropy_estimator_bd(x, var):
# 这个函数基于Bhattacharyya系数的方法估计输入数据集x的熵的下界，同样假设数据集服从多个高斯分布的混合模型。它首先利用entropy_estimator_kl函数计算KL散度的估计值，然后加上一个校正项。

# kde_condentropy(output, var):
# 这个函数计算输出的多元高斯分布的条件熵，假设每个维度的方差均为var。
import simplebinmi
#需要下载https://github.com/Huma97/Information-Bottleneck-Theory-of-Deep-Learning/tree/master，jupyter载入
# get_unique_probs(x):
# 这个函数用于计算输入数据集x中每个唯一样本出现的概率。首先，它将输入数据x转换为字节视图，并将其看作是void类型的视图，这样可以方便地比较数据集中的唯一样本。然后，使用NumPy的np.unique函数找到唯一的样本，同时计算出现的次数。最后，将每个唯一样本出现的次数除以总样本数，得到概率值。

# bin_calc_information(inputdata, layerdata, num_of_bins):
# 这个函数用于计算给定输入数据和某一层的输出数据之间的信息量。首先，使用get_unique_probs函数计算输入数据集中每个唯一样本的概率，并将结果存储在p_xs中。然后，将输出数据分成num_of_bins个区间，并计算每个区间中的样本出现的概率。接着，利用信息论中的熵的定义来计算层的熵（H_LAYER）和给定输入的条件下层的熵（H_LAYER_GIVEN_INPUT）。最后，返回两者之差，即信息量。

# bin_calc_information2(labelixs, layerdata, binsize):
# 这个函数也用于计算信息量，与上一个函数相似，但在计算输出的条件熵时使用了一种简化的方法。首先，将层的输出数据划分成多个区间，然后计算每个区间中样本出现的概率。接着，利用这些概率值计算层的熵（H_LAYER）。然后，对于每个标签，通过求取其样本在层输出中的平均位置，计算出条件熵，然后将所有标签对应的条件熵加和。最后，返回层的熵和在给定输出的情况下层的条件熵之差。

# %%
class MI_Plate():
    def __init__(self, n_epochs=100, DO_LOWER=False, DO_BINNED=False, PLOT_LAYERS=None):
        super(MI_Plate, self).__init__()
        
        self.n_epochs = n_epochs
        self.DO_LOWER = DO_LOWER
        self.DO_BINNED = DO_BINNED
        self.PLOT_LAYERS = PLOT_LAYERS
#DO_LOWER和DO_BINNED是用于控制数据预处理的布尔值，PLOT_LAYERS是用于指定绘制哪些层的激活值的列表
    def save_activations(self):
        
        if not os.path.exists('activations'):
            print("Making directory", 'activations')
            os.mkdir('activations')
            
        model = Net()

        optimizer = optim.SGD(model.parameters(), lr=0.005)
        #optimizer = optim.Adam(model.parameters(), lr=0.001/2)
        # Move model to GPU if available
        if train_on_gpu:
            model.cuda()
        
        for epoch in range(self.n_epochs):
            # monitor training loss
            train_loss = 0.0

            ###################
            # train the model #
            ###################
            model.train()

            for data, target in train_loader:
                if train_on_gpu:
                    data, target = data.cuda(), target.cuda()  # Move data to GPU
                optimizer.zero_grad()
                output, _ = model(data)
                loss = categorical_cross_entropy(output, target)
                # backward
                loss.backward()
                optimizer.step()
                train_loss += loss.item()#*data.size(0)

            # calculate average loss over an epoch
            train_loss = train_loss/len(train_loader.dataset)

            print('Epoch: {} \tTraining Loss: {:.6f}'.format(epoch+1, train_loss))

            model.eval()
########每次按照规定的epoch训练之后，都用full全部数据通过网络一次，记住标签和网络输出
###############################################################################            
            for data, _ in full_data_loader:
                if train_on_gpu:
                    data = data.cuda()  # Move data to GPU
                _, activations = model(data)
#定义多少epoch进行存储每层的输出，前20每次都存，高于200次100次再存一次
            if epoch < 20:       # Log for all first 20 epochs
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            #pickle.HIGHEST_PROTOCOL 用于指定 pickle 协议的版本，以确保最高的兼容性和效率
            elif (epoch < 100) and (epoch % 5 == 0):    # Then for every 5th epoch
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            elif (epoch < 200) and (epoch % 10 == 0):    # Then every 10th
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            elif (epoch % 100 == 0):                # Then every 100th
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
         #####################****************************************
            correct = 0
            total = 0
            with torch.no_grad():
                for data, target in test_loader:  # Assuming test_loader is defined elsewhere
                    if train_on_gpu:
                        data, target = data.cuda(), target.cuda()  # Move data to GPU
                    output, _ = model(data)
                    _, predicted = torch.max(output.data, 1)
                    total += target.size(0)
                    correct += (predicted == target).sum().item()

            accuracy = 100 * correct / total
           
            print('Test Accuracy on 10,000 images: {:.2f}%'.format(accuracy))                    
      ###########################
    def compute_MI(self, noise_variance=1e-1):
        
        MAX_EPOCHS = self.n_epochs
        self.noise_variance = noise_variance
        
        def entropy_func_upper(x):
            return kde.entropy_estimator_kl(x,self.noise_variance)
        
        def entropy_func_lower(x):
            return kde.entropy_estimator_bd(x,self.noise_variance)

        # nats to bits conversion factor
        nats2bits = 1.0/np.log(2) 


        # Save indexes of tests data for each of the output classes
        saved_labelixs = {}
        for data, targets in full_data_loader:
            trg = targets.numpy()
        for i in range(10):
            saved_labelixs[i] = trg == i

        labelprobs = np.mean(np.eye(10)[test_data.targets], axis=0)

        MI_XM_upper_array = []
        MI_YM_upper_array = []
###这段代码的作用是计算每个类别在数据集中出现的频率，并保存每个类别的索引以供后续使用
        measures = OrderedDict()
        measures['tanh'] = {}

        cur_dir = 'activations'
        if not os.path.exists(cur_dir):
            print("Directory %s not found" % cur_dir)

        # Load files saved during each epoch, and compute MI measures of the activity in that epoch
        print('*** Doing %s ***' % cur_dir)
        for epochfile in sorted(os.listdir(cur_dir)):
            if not epochfile.startswith('epoch'):
                continue

            fname = cur_dir + "/" + epochfile
            with open(fname, 'rb') as f:
                d = pickle.load(f)

            epoch = d[1]
            d = d[0]
            if epoch in measures['tanh']:# Skip this epoch if its already been processed
                continue                # this is a trick to allow us to rerun this cell multiple times)

            if epoch > MAX_EPOCHS:
                continue

            print("Doing", fname)

            num_layers = len(d)

            MI_XM_upper_epoch = []
            MI_YM_upper_epoch = []
            
            if self.PLOT_LAYERS is None:
                PLOT_LAYERS = []
                for lndx in range(num_layers):
                    PLOT_LAYERS.append(lndx)

            cepochdata = defaultdict(list)
            for lndx in range(num_layers):
                activity = d[lndx]

                # Compute marginal entropies
                h_upper = entropy_func_upper(activity)
                if self.DO_LOWER:
                    #h_lower = entropy_func_lower([activity,])[0]
                    h_lower = entropy_func_lower(activity)

                # Layer activity given input. This is simply the entropy of the Gaussian noise
                hM_given_X = kde.kde_condentropy(activity, self.noise_variance)

                # Compute conditional entropies of layer activity given output
                hM_given_Y_upper=0.
                for i in range(10):
                    hcond_upper = entropy_func_upper(activity[saved_labelixs[i],:])
                    hM_given_Y_upper += labelprobs[i] * hcond_upper

                if self.DO_LOWER:
                    hM_given_Y_lower=0.
                    for i in range(10):
                        hcond_lower = entropy_func_lower(activity[saved_labelixs[i],:])
                        hM_given_Y_lower += labelprobs[i] * hcond_lower

                cepochdata['MI_XM_upper'].append( nats2bits * (h_upper - hM_given_X) )
                cepochdata['MI_YM_upper'].append( nats2bits * (h_upper - hM_given_Y_upper) )
                cepochdata['H_M_upper'  ].append( nats2bits * h_upper )


                MI_XM_upper = nats2bits * (h_upper - hM_given_X)
                MI_YM_upper = nats2bits * (h_upper - hM_given_Y_upper)

                MI_XM_upper_epoch.append(MI_XM_upper)
                MI_YM_upper_epoch.append(MI_YM_upper)
                
                pstr = 'upper: MI(X;M)=%0.3f, MI(Y;M)=%0.3f, h_upper=%0.3f, hM_given_X=%0.3f, hM_given_Y_upper=%0.3f ' % (cepochdata['MI_XM_upper'][-1], cepochdata['MI_YM_upper'][-1], h_upper, hM_given_X, hM_given_Y_upper)
                if self.DO_LOWER:  # Compute lower bounds
                    cepochdata['MI_XM_lower'].append( nats2bits * (h_lower - hM_given_X) )
                    cepochdata['MI_YM_lower'].append( nats2bits * (h_lower - hM_given_Y_lower) )
                    cepochdata['H_M_lower'  ].append( nats2bits * h_lower )
                    pstr += ' | lower: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_lower'][-1], cepochdata['MI_YM_lower'][-1])

                if self.DO_BINNED: # Compute binner estimates
                    binxm, binym = simplebinmi.bin_calc_information2(saved_labelixs, activity, 0.5)
                    cepochdata['MI_XM_bin'].append( nats2bits * binxm )
                    cepochdata['MI_YM_bin'].append( nats2bits * binym )
                    pstr += ' | bin: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_bin'][-1], cepochdata['MI_YM_bin'][-1])

                print('- Layer %d %s' % (lndx, pstr) )

            measures['tanh'][epoch] = cepochdata
            MI_XM_upper_array.append(MI_XM_upper_epoch)
            MI_YM_upper_array.append(MI_YM_upper_epoch)
             
            #epoch += 1
        MI_XM_upper_array = np.array(MI_XM_upper_array)
        MI_YM_upper_array = np.array(MI_YM_upper_array)

    # Save the results as arrays
        np.save('D:/2023年研究生文件/MI_XM_upper_array.npy', MI_XM_upper_array)
        np.save('D:/2023年研究生文件/MI_YM_upper_array.npy', MI_YM_upper_array)

        with open('MI', 'wb') as f:
            pickle.dump(measures, f, pickle.HIGHEST_PROTOCOL)   

Plate = MI_Plate() #Create class object
Plate.save_activations() #save activations if they weren't saved already
Plate.compute_MI() #compute and save MIs if they weren't saved before
# Out:
# Epoch: 1 	Training Loss: 0.016056
# Saving activations/epoch00000000
# Test Accuracy on 10,000 images: 72.36%
# Epoch: 2 	Training Loss: 0.004633
# Saving activations/epoch00000001
# Test Accuracy on 10,000 images: 89.99%
# Epoch: 3 	Training Loss: 0.002656
# Saving activations/epoch00000002
# Test Accuracy on 10,000 images: 91.67%
# Epoch: 4 	Training Loss: 0.002166
# Saving activations/epoch00000003
# Test Accuracy on 10,000 images: 93.26%
# Epoch: 5 	Training Loss: 0.001843
# Saving activations/epoch00000004
# Test Accuracy on 10,000 images: 94.19%
# Epoch: 6 	Training Loss: 0.001589
# Saving activations/epoch00000005
# Test Accuracy on 10,000 images: 94.78%
# Epoch: 7 	Training Loss: 0.001397
# Saving activations/epoch00000006
# Test Accuracy on 10,000 images: 95.20%
# Epoch: 8 	Training Loss: 0.001245
# Saving activations/epoch00000007
# Test Accuracy on 10,000 images: 95.76%
# Epoch: 9 	Training Loss: 0.001130
# Saving activations/epoch00000008
# Test Accuracy on 10,000 images: 96.26%
# Epoch: 10 	Training Loss: 0.001035
# Saving activations/epoch00000009
# Test Accuracy on 10,000 images: 96.47%
# Epoch: 11 	Training Loss: 0.000964
# Saving activations/epoch00000010
# Test Accuracy on 10,000 images: 96.71%
# Epoch: 12 	Training Loss: 0.000903
# Saving activations/epoch00000011
# Test Accuracy on 10,000 images: 96.67%
# Epoch: 13 	Training Loss: 0.000849
# Saving activations/epoch00000012
# Test Accuracy on 10,000 images: 97.11%
# Epoch: 14 	Training Loss: 0.000804
# Saving activations/epoch00000013
# Test Accuracy on 10,000 images: 97.11%
# Epoch: 15 	Training Loss: 0.000768
# Saving activations/epoch00000014
# Test Accuracy on 10,000 images: 97.27%
# Epoch: 16 	Training Loss: 0.000730
# Saving activations/epoch00000015
# Test Accuracy on 10,000 images: 97.28%
# Epoch: 17 	Training Loss: 0.000702
# Saving activations/epoch00000016
# Test Accuracy on 10,000 images: 97.38%
# Epoch: 18 	Training Loss: 0.000675
# Saving activations/epoch00000017
# Test Accuracy on 10,000 images: 97.62%
# Epoch: 19 	Training Loss: 0.000651
# Saving activations/epoch00000018
# Test Accuracy on 10,000 images: 97.56%
# Epoch: 20 	Training Loss: 0.000627
# Saving activations/epoch00000019
# Test Accuracy on 10,000 images: 97.71%
# Epoch: 21 	Training Loss: 0.000611
# Saving activations/epoch00000020
# Test Accuracy on 10,000 images: 97.83%
# Epoch: 22 	Training Loss: 0.000591
# Test Accuracy on 10,000 images: 97.87%
# Epoch: 23 	Training Loss: 0.000574
# Test Accuracy on 10,000 images: 97.90%
# Epoch: 24 	Training Loss: 0.000559
# Test Accuracy on 10,000 images: 97.85%
# Epoch: 25 	Training Loss: 0.000547
# Test Accuracy on 10,000 images: 98.04%
# Epoch: 26 	Training Loss: 0.000532
# Saving activations/epoch00000025
# Test Accuracy on 10,000 images: 97.92%
# Epoch: 27 	Training Loss: 0.000521
# Test Accuracy on 10,000 images: 97.96%
# Epoch: 28 	Training Loss: 0.000505
# Test Accuracy on 10,000 images: 98.03%
# Epoch: 29 	Training Loss: 0.000494
# Test Accuracy on 10,000 images: 98.08%
# Epoch: 30 	Training Loss: 0.000484
# Test Accuracy on 10,000 images: 98.07%
# Epoch: 31 	Training Loss: 0.000477
# Saving activations/epoch00000030
# Test Accuracy on 10,000 images: 98.13%
# Epoch: 32 	Training Loss: 0.000468
# Test Accuracy on 10,000 images: 98.18%
# Epoch: 33 	Training Loss: 0.000458
# Test Accuracy on 10,000 images: 98.06%
# Epoch: 34 	Training Loss: 0.000450
# Test Accuracy on 10,000 images: 98.09%
# Epoch: 35 	Training Loss: 0.000442
# Test Accuracy on 10,000 images: 98.12%
# Epoch: 36 	Training Loss: 0.000435
# Saving activations/epoch00000035
# Test Accuracy on 10,000 images: 98.16%
# Epoch: 37 	Training Loss: 0.000428
# Test Accuracy on 10,000 images: 98.29%
# Epoch: 38 	Training Loss: 0.000423
# Test Accuracy on 10,000 images: 98.05%
# Epoch: 39 	Training Loss: 0.000411
# Test Accuracy on 10,000 images: 98.26%
# Epoch: 40 	Training Loss: 0.000407
# Test Accuracy on 10,000 images: 98.24%
# Epoch: 41 	Training Loss: 0.000403
# Saving activations/epoch00000040
# Test Accuracy on 10,000 images: 98.26%
# Epoch: 42 	Training Loss: 0.000393
# Test Accuracy on 10,000 images: 98.32%
# Epoch: 43 	Training Loss: 0.000389
# Test Accuracy on 10,000 images: 98.17%
# Epoch: 44 	Training Loss: 0.000384
# Test Accuracy on 10,000 images: 98.38%
# Epoch: 45 	Training Loss: 0.000381
# Test Accuracy on 10,000 images: 98.24%
# Epoch: 46 	Training Loss: 0.000374
# Saving activations/epoch00000045
# Test Accuracy on 10,000 images: 98.06%
# Epoch: 47 	Training Loss: 0.000372
# Test Accuracy on 10,000 images: 98.35%
# Epoch: 48 	Training Loss: 0.000362
# Test Accuracy on 10,000 images: 98.30%
# Epoch: 49 	Training Loss: 0.000359
# Test Accuracy on 10,000 images: 98.22%
# Epoch: 50 	Training Loss: 0.000355
# Test Accuracy on 10,000 images: 98.15%
# Epoch: 51 	Training Loss: 0.000352
# Saving activations/epoch00000050
# Test Accuracy on 10,000 images: 98.28%
# Epoch: 52 	Training Loss: 0.000344
# Test Accuracy on 10,000 images: 98.12%
# Epoch: 53 	Training Loss: 0.000339
# Test Accuracy on 10,000 images: 98.22%
# Epoch: 54 	Training Loss: 0.000337
# Test Accuracy on 10,000 images: 98.32%
# Epoch: 55 	Training Loss: 0.000334
# Test Accuracy on 10,000 images: 98.19%
# Epoch: 56 	Training Loss: 0.000333
# Saving activations/epoch00000055
# Test Accuracy on 10,000 images: 98.43%
# Epoch: 57 	Training Loss: 0.000331
# Test Accuracy on 10,000 images: 98.23%
# Epoch: 58 	Training Loss: 0.000325
# Test Accuracy on 10,000 images: 98.39%
# Epoch: 59 	Training Loss: 0.000320
# Test Accuracy on 10,000 images: 98.13%
# Epoch: 60 	Training Loss: 0.000315
# Test Accuracy on 10,000 images: 98.36%
# Epoch: 61 	Training Loss: 0.000315
# Saving activations/epoch00000060
# Test Accuracy on 10,000 images: 98.49%
# Epoch: 62 	Training Loss: 0.000312
# Test Accuracy on 10,000 images: 98.43%
# Epoch: 63 	Training Loss: 0.000308
# Test Accuracy on 10,000 images: 98.28%
# Epoch: 64 	Training Loss: 0.000304
# Test Accuracy on 10,000 images: 98.49%
# Epoch: 65 	Training Loss: 0.000300
# Test Accuracy on 10,000 images: 98.30%
# Epoch: 66 	Training Loss: 0.000297
# Saving activations/epoch00000065
# Test Accuracy on 10,000 images: 98.44%
# Epoch: 67 	Training Loss: 0.000294
# Test Accuracy on 10,000 images: 98.47%
# Epoch: 68 	Training Loss: 0.000293
# Test Accuracy on 10,000 images: 98.40%
# Epoch: 69 	Training Loss: 0.000289
# Test Accuracy on 10,000 images: 98.45%
# Epoch: 70 	Training Loss: 0.000286
# Test Accuracy on 10,000 images: 98.31%
# Epoch: 71 	Training Loss: 0.000280
# Saving activations/epoch00000070
# Test Accuracy on 10,000 images: 98.44%
# Epoch: 72 	Training Loss: 0.000284
# Test Accuracy on 10,000 images: 98.33%
# Epoch: 73 	Training Loss: 0.000276
# Test Accuracy on 10,000 images: 98.36%
# Epoch: 74 	Training Loss: 0.000274
# Test Accuracy on 10,000 images: 98.41%
# Epoch: 75 	Training Loss: 0.000275
# Test Accuracy on 10,000 images: 98.41%
# Epoch: 76 	Training Loss: 0.000269
# Saving activations/epoch00000075
# Test Accuracy on 10,000 images: 98.28%
# Epoch: 77 	Training Loss: 0.000267
# Test Accuracy on 10,000 images: 98.51%
# Epoch: 78 	Training Loss: 0.000263
# Test Accuracy on 10,000 images: 98.49%
# Epoch: 79 	Training Loss: 0.000260
# Test Accuracy on 10,000 images: 98.36%
# Epoch: 80 	Training Loss: 0.000261
# Test Accuracy on 10,000 images: 98.34%
# Epoch: 81 	Training Loss: 0.000260
# Saving activations/epoch00000080
# Test Accuracy on 10,000 images: 98.36%
# Epoch: 82 	Training Loss: 0.000256
# Test Accuracy on 10,000 images: 98.29%
# Epoch: 83 	Training Loss: 0.000255
# Test Accuracy on 10,000 images: 98.44%
# Epoch: 84 	Training Loss: 0.000251
# Test Accuracy on 10,000 images: 98.37%
# Epoch: 85 	Training Loss: 0.000251
# Test Accuracy on 10,000 images: 98.40%
# Epoch: 86 	Training Loss: 0.000249
# Saving activations/epoch00000085
# Test Accuracy on 10,000 images: 98.44%
# Epoch: 87 	Training Loss: 0.000244
# Test Accuracy on 10,000 images: 98.44%
# Epoch: 88 	Training Loss: 0.000245
# Test Accuracy on 10,000 images: 98.46%
# Epoch: 89 	Training Loss: 0.000240
# Test Accuracy on 10,000 images: 98.49%
# Epoch: 90 	Training Loss: 0.000239
# Test Accuracy on 10,000 images: 98.46%
# Epoch: 91 	Training Loss: 0.000238
# Saving activations/epoch00000090
# Test Accuracy on 10,000 images: 98.31%
# Epoch: 92 	Training Loss: 0.000236
# Test Accuracy on 10,000 images: 98.45%
# Epoch: 93 	Training Loss: 0.000237
# Test Accuracy on 10,000 images: 98.46%
# Epoch: 94 	Training Loss: 0.000230
# Test Accuracy on 10,000 images: 98.46%
# Epoch: 95 	Training Loss: 0.000233
# Test Accuracy on 10,000 images: 98.42%
# Epoch: 96 	Training Loss: 0.000228
# Saving activations/epoch00000095
# Test Accuracy on 10,000 images: 98.48%
# Epoch: 97 	Training Loss: 0.000223
# Test Accuracy on 10,000 images: 98.45%
# Epoch: 98 	Training Loss: 0.000224
# Test Accuracy on 10,000 images: 98.42%
# Epoch: 99 	Training Loss: 0.000224
# Test Accuracy on 10,000 images: 98.46%
# Epoch: 100 	Training Loss: 0.000221
# Test Accuracy on 10,000 images: 98.44%
# *** Doing activations ***
# Doing activations/epoch00000000
# - Layer 0 upper: MI(X;M)=13.293, MI(Y;M)=3.319, h_upper=1687.889, hM_given_X=1678.676, hM_given_Y_upper=1685.589
# - Layer 1 upper: MI(X;M)=13.284, MI(Y;M)=3.319, h_upper=848.546, hM_given_X=839.338, hM_given_Y_upper=846.245
# - Layer 2 upper: MI(X;M)=12.883, MI(Y;M)=3.314, h_upper=14.283, hM_given_X=5.353, hM_given_Y_upper=11.986
# - Layer 3 upper: MI(X;M)=1.437, MI(Y;M)=1.006, h_upper=3.673, hM_given_X=2.676, hM_given_Y_upper=2.976
# Doing activations/epoch00000001
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=1687.886, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 1 upper: MI(X;M)=13.265, MI(Y;M)=3.319, h_upper=848.533, hM_given_X=839.338, hM_given_Y_upper=846.232
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.676, MI(Y;M)=2.771, h_upper=5.224, hM_given_X=2.676, hM_given_Y_upper=3.304
# Doing activations/epoch00000002
# - Layer 0 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=1687.886, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 1 upper: MI(X;M)=13.301, MI(Y;M)=3.319, h_upper=848.557, hM_given_X=839.338, hM_given_Y_upper=846.257
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.650, MI(Y;M)=2.871, h_upper=5.206, hM_given_X=2.676, hM_given_Y_upper=3.217
# Doing activations/epoch00000003
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.319, h_upper=1687.887, hM_given_X=1678.676, hM_given_Y_upper=1685.586
# - Layer 1 upper: MI(X;M)=13.264, MI(Y;M)=3.319, h_upper=848.531, hM_given_X=839.338, hM_given_Y_upper=846.231
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.616, MI(Y;M)=2.944, h_upper=5.183, hM_given_X=2.676, hM_given_Y_upper=3.142
# Doing activations/epoch00000004
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.319, h_upper=1687.887, hM_given_X=1678.676, hM_given_Y_upper=1685.586
# - Layer 1 upper: MI(X;M)=13.309, MI(Y;M)=3.319, h_upper=848.563, hM_given_X=839.338, hM_given_Y_upper=846.262
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.591, MI(Y;M)=2.990, h_upper=5.166, hM_given_X=2.676, hM_given_Y_upper=3.093
# Doing activations/epoch00000005
# - Layer 0 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=1687.885, hM_given_X=1678.676, hM_given_Y_upper=1685.584
# - Layer 1 upper: MI(X;M)=13.374, MI(Y;M)=3.319, h_upper=848.608, hM_given_X=839.338, hM_given_Y_upper=846.307
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.568, MI(Y;M)=3.021, h_upper=5.150, hM_given_X=2.676, hM_given_Y_upper=3.056
# Doing activations/epoch00000006
# - Layer 0 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=1687.885, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 1 upper: MI(X;M)=13.292, MI(Y;M)=3.319, h_upper=848.551, hM_given_X=839.338, hM_given_Y_upper=846.251
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.541, MI(Y;M)=3.046, h_upper=5.131, hM_given_X=2.676, hM_given_Y_upper=3.019
# Doing activations/epoch00000007
# - Layer 0 upper: MI(X;M)=13.290, MI(Y;M)=3.319, h_upper=1687.887, hM_given_X=1678.676, hM_given_Y_upper=1685.587
# - Layer 1 upper: MI(X;M)=13.299, MI(Y;M)=3.319, h_upper=848.556, hM_given_X=839.338, hM_given_Y_upper=846.255
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.523, MI(Y;M)=3.077, h_upper=5.119, hM_given_X=2.676, hM_given_Y_upper=2.985
# Doing activations/epoch00000008
# - Layer 0 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=1687.884, hM_given_X=1678.676, hM_given_Y_upper=1685.583
# - Layer 1 upper: MI(X;M)=13.296, MI(Y;M)=3.319, h_upper=848.554, hM_given_X=839.338, hM_given_Y_upper=846.253
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.508, MI(Y;M)=3.101, h_upper=5.108, hM_given_X=2.676, hM_given_Y_upper=2.958
# Doing activations/epoch00000009
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.319, h_upper=1687.887, hM_given_X=1678.676, hM_given_Y_upper=1685.586
# - Layer 1 upper: MI(X;M)=13.331, MI(Y;M)=3.319, h_upper=848.578, hM_given_X=839.338, hM_given_Y_upper=846.278
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.498, MI(Y;M)=3.114, h_upper=5.101, hM_given_X=2.676, hM_given_Y_upper=2.942
# Doing activations/epoch00000010
# - Layer 0 upper: MI(X;M)=13.293, MI(Y;M)=3.319, h_upper=1687.890, hM_given_X=1678.676, hM_given_Y_upper=1685.589
# - Layer 1 upper: MI(X;M)=13.319, MI(Y;M)=3.319, h_upper=848.570, hM_given_X=839.338, hM_given_Y_upper=846.269
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.487, MI(Y;M)=3.125, h_upper=5.093, hM_given_X=2.676, hM_given_Y_upper=2.927
# Doing activations/epoch00000011
# - Layer 0 upper: MI(X;M)=13.291, MI(Y;M)=3.320, h_upper=1687.888, hM_given_X=1678.676, hM_given_Y_upper=1685.587
# - Layer 1 upper: MI(X;M)=13.312, MI(Y;M)=3.319, h_upper=848.565, hM_given_X=839.338, hM_given_Y_upper=846.264
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.491, MI(Y;M)=3.126, h_upper=5.096, hM_given_X=2.676, hM_given_Y_upper=2.929
# Doing activations/epoch00000012
# - Layer 0 upper: MI(X;M)=13.298, MI(Y;M)=3.320, h_upper=1687.893, hM_given_X=1678.676, hM_given_Y_upper=1685.592
# - Layer 1 upper: MI(X;M)=13.310, MI(Y;M)=3.319, h_upper=848.563, hM_given_X=839.338, hM_given_Y_upper=846.263
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.471, MI(Y;M)=3.142, h_upper=5.083, hM_given_X=2.676, hM_given_Y_upper=2.905
# Doing activations/epoch00000013
# - Layer 0 upper: MI(X;M)=13.279, MI(Y;M)=3.319, h_upper=1687.880, hM_given_X=1678.676, hM_given_Y_upper=1685.579
# - Layer 1 upper: MI(X;M)=13.255, MI(Y;M)=3.319, h_upper=848.526, hM_given_X=839.338, hM_given_Y_upper=846.225
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.471, MI(Y;M)=3.148, h_upper=5.082, hM_given_X=2.676, hM_given_Y_upper=2.900
# Doing activations/epoch00000014
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=1687.886, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 1 upper: MI(X;M)=13.324, MI(Y;M)=3.319, h_upper=848.573, hM_given_X=839.338, hM_given_Y_upper=846.272
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.467, MI(Y;M)=3.154, h_upper=5.080, hM_given_X=2.676, hM_given_Y_upper=2.894
# Doing activations/epoch00000015
# - Layer 0 upper: MI(X;M)=13.278, MI(Y;M)=3.319, h_upper=1687.879, hM_given_X=1678.676, hM_given_Y_upper=1685.578
# - Layer 1 upper: MI(X;M)=13.293, MI(Y;M)=3.319, h_upper=848.552, hM_given_X=839.338, hM_given_Y_upper=846.251
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.458, MI(Y;M)=3.157, h_upper=5.073, hM_given_X=2.676, hM_given_Y_upper=2.885
# Doing activations/epoch00000016
# - Layer 0 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=1687.884, hM_given_X=1678.676, hM_given_Y_upper=1685.583
# - Layer 1 upper: MI(X;M)=13.271, MI(Y;M)=3.319, h_upper=848.536, hM_given_X=839.338, hM_given_Y_upper=846.236
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.454, MI(Y;M)=3.157, h_upper=5.070, hM_given_X=2.676, hM_given_Y_upper=2.882
# Doing activations/epoch00000017
# - Layer 0 upper: MI(X;M)=13.298, MI(Y;M)=3.320, h_upper=1687.893, hM_given_X=1678.676, hM_given_Y_upper=1685.592
# - Layer 1 upper: MI(X;M)=13.248, MI(Y;M)=3.319, h_upper=848.521, hM_given_X=839.338, hM_given_Y_upper=846.220
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.452, MI(Y;M)=3.170, h_upper=5.069, hM_given_X=2.676, hM_given_Y_upper=2.872
# Doing activations/epoch00000018
# - Layer 0 upper: MI(X;M)=13.295, MI(Y;M)=3.319, h_upper=1687.891, hM_given_X=1678.676, hM_given_Y_upper=1685.590
# - Layer 1 upper: MI(X;M)=13.264, MI(Y;M)=3.319, h_upper=848.532, hM_given_X=839.338, hM_given_Y_upper=846.231
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.444, MI(Y;M)=3.167, h_upper=5.064, hM_given_X=2.676, hM_given_Y_upper=2.869
# Doing activations/epoch00000019
# - Layer 0 upper: MI(X;M)=13.286, MI(Y;M)=3.320, h_upper=1687.885, hM_given_X=1678.676, hM_given_Y_upper=1685.584
# - Layer 1 upper: MI(X;M)=13.314, MI(Y;M)=3.319, h_upper=848.566, hM_given_X=839.338, hM_given_Y_upper=846.266
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.442, MI(Y;M)=3.173, h_upper=5.062, hM_given_X=2.676, hM_given_Y_upper=2.863
# Doing activations/epoch00000020
# - Layer 0 upper: MI(X;M)=13.283, MI(Y;M)=3.319, h_upper=1687.882, hM_given_X=1678.676, hM_given_Y_upper=1685.582
# - Layer 1 upper: MI(X;M)=13.308, MI(Y;M)=3.319, h_upper=848.562, hM_given_X=839.338, hM_given_Y_upper=846.262
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.437, MI(Y;M)=3.181, h_upper=5.058, hM_given_X=2.676, hM_given_Y_upper=2.854
# Doing activations/epoch00000025
# - Layer 0 upper: MI(X;M)=13.294, MI(Y;M)=3.319, h_upper=1687.890, hM_given_X=1678.676, hM_given_Y_upper=1685.590
# - Layer 1 upper: MI(X;M)=13.359, MI(Y;M)=3.319, h_upper=848.598, hM_given_X=839.338, hM_given_Y_upper=846.297
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.423, MI(Y;M)=3.188, h_upper=5.049, hM_given_X=2.676, hM_given_Y_upper=2.840
# Doing activations/epoch00000030
# - Layer 0 upper: MI(X;M)=13.293, MI(Y;M)=3.319, h_upper=1687.890, hM_given_X=1678.676, hM_given_Y_upper=1685.589
# - Layer 1 upper: MI(X;M)=13.326, MI(Y;M)=3.319, h_upper=848.575, hM_given_X=839.338, hM_given_Y_upper=846.274
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.412, MI(Y;M)=3.196, h_upper=5.042, hM_given_X=2.676, hM_given_Y_upper=2.826
# Doing activations/epoch00000035
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.319, h_upper=1687.887, hM_given_X=1678.676, hM_given_Y_upper=1685.586
# - Layer 1 upper: MI(X;M)=13.289, MI(Y;M)=3.319, h_upper=848.549, hM_given_X=839.338, hM_given_Y_upper=846.248
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.409, MI(Y;M)=3.202, h_upper=5.040, hM_given_X=2.676, hM_given_Y_upper=2.820
# Doing activations/epoch00000040
# - Layer 0 upper: MI(X;M)=13.282, MI(Y;M)=3.319, h_upper=1687.882, hM_given_X=1678.676, hM_given_Y_upper=1685.581
# - Layer 1 upper: MI(X;M)=13.327, MI(Y;M)=3.319, h_upper=848.575, hM_given_X=839.338, hM_given_Y_upper=846.274
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.405, MI(Y;M)=3.206, h_upper=5.037, hM_given_X=2.676, hM_given_Y_upper=2.815
# Doing activations/epoch00000045
# - Layer 0 upper: MI(X;M)=13.285, MI(Y;M)=3.320, h_upper=1687.884, hM_given_X=1678.676, hM_given_Y_upper=1685.583
# - Layer 1 upper: MI(X;M)=13.226, MI(Y;M)=3.319, h_upper=848.505, hM_given_X=839.338, hM_given_Y_upper=846.205
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.406, MI(Y;M)=3.196, h_upper=5.038, hM_given_X=2.676, hM_given_Y_upper=2.822
# Doing activations/epoch00000050
# - Layer 0 upper: MI(X;M)=13.291, MI(Y;M)=3.319, h_upper=1687.889, hM_given_X=1678.676, hM_given_Y_upper=1685.588
# - Layer 1 upper: MI(X;M)=13.407, MI(Y;M)=3.319, h_upper=848.631, hM_given_X=839.338, hM_given_Y_upper=846.330
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.397, MI(Y;M)=3.202, h_upper=5.031, hM_given_X=2.676, hM_given_Y_upper=2.811
# Doing activations/epoch00000055
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.319, h_upper=1687.887, hM_given_X=1678.676, hM_given_Y_upper=1685.586
# - Layer 1 upper: MI(X;M)=13.297, MI(Y;M)=3.319, h_upper=848.555, hM_given_X=839.338, hM_given_Y_upper=846.254
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.390, MI(Y;M)=3.214, h_upper=5.026, hM_given_X=2.676, hM_given_Y_upper=2.798
# Doing activations/epoch00000060
# - Layer 0 upper: MI(X;M)=13.280, MI(Y;M)=3.319, h_upper=1687.881, hM_given_X=1678.676, hM_given_Y_upper=1685.580
# - Layer 1 upper: MI(X;M)=13.247, MI(Y;M)=3.319, h_upper=848.520, hM_given_X=839.338, hM_given_Y_upper=846.219
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.388, MI(Y;M)=3.214, h_upper=5.025, hM_given_X=2.676, hM_given_Y_upper=2.797
# Doing activations/epoch00000065
# - Layer 0 upper: MI(X;M)=13.293, MI(Y;M)=3.319, h_upper=1687.890, hM_given_X=1678.676, hM_given_Y_upper=1685.589
# - Layer 1 upper: MI(X;M)=13.252, MI(Y;M)=3.319, h_upper=848.523, hM_given_X=839.338, hM_given_Y_upper=846.222
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.387, MI(Y;M)=3.214, h_upper=5.024, hM_given_X=2.676, hM_given_Y_upper=2.796
# Doing activations/epoch00000070
# - Layer 0 upper: MI(X;M)=13.292, MI(Y;M)=3.319, h_upper=1687.889, hM_given_X=1678.676, hM_given_Y_upper=1685.588
# - Layer 1 upper: MI(X;M)=13.270, MI(Y;M)=3.319, h_upper=848.536, hM_given_X=839.338, hM_given_Y_upper=846.235
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.388, MI(Y;M)=3.215, h_upper=5.025, hM_given_X=2.676, hM_given_Y_upper=2.796
# Doing activations/epoch00000075
# - Layer 0 upper: MI(X;M)=13.282, MI(Y;M)=3.319, h_upper=1687.882, hM_given_X=1678.676, hM_given_Y_upper=1685.581
# - Layer 1 upper: MI(X;M)=13.311, MI(Y;M)=3.319, h_upper=848.564, hM_given_X=839.338, hM_given_Y_upper=846.264
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.388, MI(Y;M)=3.202, h_upper=5.025, hM_given_X=2.676, hM_given_Y_upper=2.805
# Doing activations/epoch00000080
# - Layer 0 upper: MI(X;M)=13.292, MI(Y;M)=3.319, h_upper=1687.889, hM_given_X=1678.676, hM_given_Y_upper=1685.588
# - Layer 1 upper: MI(X;M)=13.261, MI(Y;M)=3.319, h_upper=848.529, hM_given_X=839.338, hM_given_Y_upper=846.229
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.383, MI(Y;M)=3.208, h_upper=5.021, hM_given_X=2.676, hM_given_Y_upper=2.797
# Doing activations/epoch00000085
# - Layer 0 upper: MI(X;M)=13.296, MI(Y;M)=3.319, h_upper=1687.892, hM_given_X=1678.676, hM_given_Y_upper=1685.591
# - Layer 1 upper: MI(X;M)=13.303, MI(Y;M)=3.319, h_upper=848.559, hM_given_X=839.338, hM_given_Y_upper=846.258
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.378, MI(Y;M)=3.210, h_upper=5.018, hM_given_X=2.676, hM_given_Y_upper=2.793
# Doing activations/epoch00000090
# - Layer 0 upper: MI(X;M)=13.298, MI(Y;M)=3.319, h_upper=1687.893, hM_given_X=1678.676, hM_given_Y_upper=1685.592
# - Layer 1 upper: MI(X;M)=13.277, MI(Y;M)=3.319, h_upper=848.541, hM_given_X=839.338, hM_given_Y_upper=846.240
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.381, MI(Y;M)=3.199, h_upper=5.020, hM_given_X=2.676, hM_given_Y_upper=2.802
# Doing activations/epoch00000095
# - Layer 0 upper: MI(X;M)=13.301, MI(Y;M)=3.319, h_upper=1687.895, hM_given_X=1678.676, hM_given_Y_upper=1685.594
# - Layer 1 upper: MI(X;M)=13.313, MI(Y;M)=3.319, h_upper=848.565, hM_given_X=839.338, hM_given_Y_upper=846.265
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.378, MI(Y;M)=3.206, h_upper=5.018, hM_given_X=2.676, hM_given_Y_upper=2.796

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import torch
import scienceplots
plt.rcParams['font.serif'] = ['Times New Roman']
mpl.rcParams['figure.dpi'] = 800
mpl.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
plt.style.use(['science', 'ieee'])
mpl.rcParams.update({'font.size': 15})

def plot_information_plane(IXT_array, ITY_array, num_epochs, every_n_early=1, every_n_late=5):
    assert len(IXT_array) == len(ITY_array)

    max_index = len(IXT_array)

    fig, ax = plt.subplots(figsize=(5, 3.5))
    ax.set_xlabel('$I(X;T)$', fontsize=15)
    ax.set_ylabel('$I(T;Y)$', fontsize=15)

    cmap = plt.get_cmap('gnuplot')
    colors = [cmap(i) for i in np.linspace(0, 1, num_epochs + 1)]

    for i in range(0, max_index):
        IXT = IXT_array[i, :]
        ITY = ITY_array[i, :]
        
        # 根据 epoch 的范围调整 every_n
        if i < 20:
            color_idx = i * every_n_early
        else:
            color_idx = 20 * every_n_early + (i - 20) * every_n_late

        ax.plot(IXT, ITY, marker='o', markersize=3, markeredgewidth=0.04,
                linestyle='-', linewidth=0.5, color=colors[color_idx], zorder=10)

    sm = plt.cm.ScalarMappable(cmap=cmap, norm=plt.Normalize(vmin=0, vmax=1))
    sm._A = []

    # 使用ax参数指定颜色条位置
    cbar = plt.colorbar(sm, ax=ax, ticks=[])
    cbar.set_label('epoch number', fontsize=15)
    cbar.ax.tick_params(labelsize=15)
    cbar.ax.text(0.5, -0.01, 0, transform=cbar.ax.transAxes, va='top', ha='center')
    cbar.ax.text(0.5, 1.0, str(num_epochs), transform=cbar.ax.transAxes, va='bottom', ha='center')

    ax.set_xticks([0, 2, 4, 6, 8, 10, 12, 14])
    ax.set_yticks([0, 0.5, 1, 1.5, 2, 2.5, 3.0, 3.5])
    ax.set_ylim(0.9, 3.5)  # 修改y轴坐标范围
    # Adjust coordinates of text according to the plot area
    ax.text(-0.2, 0.98, '(b)', fontdict={'size': 15, 'color': 'black'}, transform=ax.transAxes)

    fig.savefig('D:/2023年研究生文件/Fig8b.eps', dpi=800)
    plt.show()

IXT_array = np.load('D:/2023年研究生文件/MI_XM_upper_array.npy')

ITY_array = np.load('D:/2023年研究生文件/MI_YM_upper_array.npy')

plot_information_plane(IXT_array, ITY_array, num_epochs=100, every_n_early=1, every_n_late=5)

# %%
class CustomActivation(nn.Module):
    def __init__(self):
        super(CustomActivation, self).__init__()
        self.sigma = nn.Parameter(torch.tensor(0.3))

    def forward(self, input):
        #temp = input/2*(1+torch.erf(input/math.sqrt(2)/self.sigma))#GELU
        temp = input*torch.sigmoid(input)#SiLU
        return temp

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 8, kernel_size=3, padding=1)  # 输入通道数1，输出通道数8，卷积核大小3x3
        self.conv2 = nn.Conv2d(8, 16, kernel_size=3, padding=1)  # 输入通道数8，输出通道数16，卷积核大小3x3
        self.pool = nn.MaxPool2d(2, 2)                           # 2x2的最大池化层
        self.fc1 = nn.Linear(16 * 7 * 7, 20)                     # 全连接层，输入维度16*7*7，输出维度64
        self.fc3 = nn.Linear(20, 10)                             # 最后的全连接层，输出维度10（对应10个类别）
        self.act1 = CustomActivation()
        self.act2 = CustomActivation()
        self.act3 = CustomActivation()
        
    def forward(self, x):
        activations = []
        x = self.act1(self.conv1(x))  # 第一层卷积 + ReLU激活 
        xx = torch.flatten(x, 1)
        activations.append(xx.cpu().data.numpy())  # 保存第一层的激活
        x = self.pool(x)
        x = self.act2(self.conv2(x))  # 第二层卷积 + ReLU激活
        xx = torch.flatten(x, 1)
        activations.append(xx.cpu().data.numpy())  # 保存第二层的激活
        x = self.pool(x)
        x = x.view(-1, 16 * 7 * 7)                # 展平操作，为全连接层做准备
        x = self.act3(self.fc1(x))                   # 第一个全连接层 + ReLU激活
        activations.append(x.cpu().data.numpy())  # 保存全连接层的激活
        x = self.fc3(x)
        x = torch.softmax(x, dim=1)
        activations.append(x.cpu().data.numpy())  # 保存输出层的激活
        return x, activations
        

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

class MI_Plate():
    def __init__(self, n_epochs=100, DO_LOWER=False, DO_BINNED=False, PLOT_LAYERS=None):
        super(MI_Plate, self).__init__()
        
        self.n_epochs = n_epochs
        self.DO_LOWER = DO_LOWER
        self.DO_BINNED = DO_BINNED
        self.PLOT_LAYERS = PLOT_LAYERS
#DO_LOWER和DO_BINNED是用于控制数据预处理的布尔值，PLOT_LAYERS是用于指定绘制哪些层的激活值的列表
    def save_activations(self):
        
        if not os.path.exists('activations'):
            print("Making directory", 'activations')
            os.mkdir('activations')
            
        model = Net()
        optimizer = optim.SGD(model.parameters(), lr=0.005)
        #optimizer = optim.Adam(model.parameters(), lr=0.001/2)
        # Move model to GPU if available
        if train_on_gpu:
            model.cuda()
        
        for epoch in range(self.n_epochs):
            # monitor training loss
            train_loss = 0.0

            ###################
            # train the model #
            ###################
            model.train()

            for data, target in train_loader:
                if train_on_gpu:
                    data, target = data.cuda(), target.cuda()  # Move data to GPU
                optimizer.zero_grad()
                output, _ = model(data)
                loss = categorical_cross_entropy(output, target)
                # backward
                loss.backward()
                optimizer.step()
                train_loss += loss.item()#*data.size(0)

            # calculate average loss over an epoch
            train_loss = train_loss/len(train_loader.dataset)

            print('Epoch: {} \tTraining Loss: {:.6f}'.format(epoch+1, train_loss))

            model.eval()
########每次按照规定的epoch训练之后，都用full全部数据通过网络一次，记住标签和网络输出
###############################################################################            
            for data, _ in full_data_loader:
                if train_on_gpu:
                    data = data.cuda()  # Move data to GPU
                _, activations = model(data)
#定义多少epoch进行存储每层的输出，前20每次都存，高于200次100次再存一次
            if epoch < 20:       # Log for all first 20 epochs
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            #pickle.HIGHEST_PROTOCOL 用于指定 pickle 协议的版本，以确保最高的兼容性和效率
            elif (epoch < 100) and (epoch % 5 == 0):    # Then for every 5th epoch
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            elif (epoch < 200) and (epoch % 10 == 0):    # Then every 10th
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            elif (epoch % 100 == 0):                # Then every 100th
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
         #####################****************************************
            correct = 0
            total = 0
            with torch.no_grad():
                for data, target in test_loader:  # Assuming test_loader is defined elsewhere
                    if train_on_gpu:
                        data, target = data.cuda(), target.cuda()  # Move data to GPU
                    output, _ = model(data)
                    _, predicted = torch.max(output.data, 1)
                    total += target.size(0)
                    correct += (predicted == target).sum().item()

            accuracy = 100 * correct / total
           
            print('Test Accuracy on 10,000 images: {:.2f}%'.format(accuracy))                    
      ###########################
    def compute_MI(self, noise_variance=1e-1):
        
        MAX_EPOCHS = self.n_epochs
        self.noise_variance = noise_variance
        
        def entropy_func_upper(x):
            return kde.entropy_estimator_kl(x,self.noise_variance)
        
        def entropy_func_lower(x):
            return kde.entropy_estimator_bd(x,self.noise_variance)

        # nats to bits conversion factor
        nats2bits = 1.0/np.log(2) 


        # Save indexes of tests data for each of the output classes
        saved_labelixs = {}
        for data, targets in full_data_loader:
            trg = targets.numpy()
        for i in range(10):
            saved_labelixs[i] = trg == i

        labelprobs = np.mean(np.eye(10)[test_data.targets], axis=0)

        MI_XM_upper_array = []
        MI_YM_upper_array = []
###这段代码的作用是计算每个类别在数据集中出现的频率，并保存每个类别的索引以供后续使用
        measures = OrderedDict()
        measures['tanh'] = {}

        cur_dir = 'activations'
        if not os.path.exists(cur_dir):
            print("Directory %s not found" % cur_dir)

        # Load files saved during each epoch, and compute MI measures of the activity in that epoch
        print('*** Doing %s ***' % cur_dir)
        for epochfile in sorted(os.listdir(cur_dir)):
            if not epochfile.startswith('epoch'):
                continue

            fname = cur_dir + "/" + epochfile
            with open(fname, 'rb') as f:
                d = pickle.load(f)

            epoch = d[1]
            d = d[0]
            if epoch in measures['tanh']:# Skip this epoch if its already been processed
                continue                # this is a trick to allow us to rerun this cell multiple times)

            if epoch > MAX_EPOCHS:
                continue

            print("Doing", fname)

            num_layers = len(d)

            MI_XM_upper_epoch = []
            MI_YM_upper_epoch = []
            
            if self.PLOT_LAYERS is None:
                PLOT_LAYERS = []
                for lndx in range(num_layers):
                    PLOT_LAYERS.append(lndx)

            cepochdata = defaultdict(list)
            for lndx in range(num_layers):
                activity = d[lndx]

                # Compute marginal entropies
                h_upper = entropy_func_upper(activity)
                if self.DO_LOWER:
                    #h_lower = entropy_func_lower([activity,])[0]
                    h_lower = entropy_func_lower(activity)

                # Layer activity given input. This is simply the entropy of the Gaussian noise
                hM_given_X = kde.kde_condentropy(activity, self.noise_variance)

                # Compute conditional entropies of layer activity given output
                hM_given_Y_upper=0.
                for i in range(10):
                    hcond_upper = entropy_func_upper(activity[saved_labelixs[i],:])
                    hM_given_Y_upper += labelprobs[i] * hcond_upper

                if self.DO_LOWER:
                    hM_given_Y_lower=0.
                    for i in range(10):
                        hcond_lower = entropy_func_lower(activity[saved_labelixs[i],:])
                        hM_given_Y_lower += labelprobs[i] * hcond_lower

                cepochdata['MI_XM_upper'].append( nats2bits * (h_upper - hM_given_X) )
                cepochdata['MI_YM_upper'].append( nats2bits * (h_upper - hM_given_Y_upper) )
                cepochdata['H_M_upper'  ].append( nats2bits * h_upper )


                MI_XM_upper = nats2bits * (h_upper - hM_given_X)
                MI_YM_upper = nats2bits * (h_upper - hM_given_Y_upper)

                MI_XM_upper_epoch.append(MI_XM_upper)
                MI_YM_upper_epoch.append(MI_YM_upper)
                
                pstr = 'upper: MI(X;M)=%0.3f, MI(Y;M)=%0.3f, h_upper=%0.3f, hM_given_X=%0.3f, hM_given_Y_upper=%0.3f ' % (cepochdata['MI_XM_upper'][-1], cepochdata['MI_YM_upper'][-1], h_upper, hM_given_X, hM_given_Y_upper)
                if self.DO_LOWER:  # Compute lower bounds
                    cepochdata['MI_XM_lower'].append( nats2bits * (h_lower - hM_given_X) )
                    cepochdata['MI_YM_lower'].append( nats2bits * (h_lower - hM_given_Y_lower) )
                    cepochdata['H_M_lower'  ].append( nats2bits * h_lower )
                    pstr += ' | lower: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_lower'][-1], cepochdata['MI_YM_lower'][-1])

                if self.DO_BINNED: # Compute binner estimates
                    binxm, binym = simplebinmi.bin_calc_information2(saved_labelixs, activity, 0.5)
                    cepochdata['MI_XM_bin'].append( nats2bits * binxm )
                    cepochdata['MI_YM_bin'].append( nats2bits * binym )
                    pstr += ' | bin: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_bin'][-1], cepochdata['MI_YM_bin'][-1])

                print('- Layer %d %s' % (lndx, pstr) )

            measures['tanh'][epoch] = cepochdata
            MI_XM_upper_array.append(MI_XM_upper_epoch)
            MI_YM_upper_array.append(MI_YM_upper_epoch)
             
            #epoch += 1
        MI_XM_upper_array = np.array(MI_XM_upper_array)
        MI_YM_upper_array = np.array(MI_YM_upper_array)

    # Save the results as arrays
        np.save('D:/深度学习与信息论/MI_XM_upper_arrayS.npy', MI_XM_upper_array)
        np.save('D:/深度学习与信息论/MI_YM_upper_arrayS.npy', MI_YM_upper_array)

        with open('MI', 'wb') as f:
            pickle.dump(measures, f, pickle.HIGHEST_PROTOCOL)   

Plate = MI_Plate() #Create class object
Plate.save_activations() #save activations if they weren't saved already
Plate.compute_MI() #compute and save MIs if they weren't saved before
# Out:
# Epoch: 1 	Training Loss: 0.017592
# Saving activations/epoch00000000
# Test Accuracy on 10,000 images: 40.06%
# Epoch: 2 	Training Loss: 0.006264
# Saving activations/epoch00000001
# Test Accuracy on 10,000 images: 88.24%
# Epoch: 3 	Training Loss: 0.002945
# Saving activations/epoch00000002
# Test Accuracy on 10,000 images: 88.84%
# Epoch: 4 	Training Loss: 0.002422
# Saving activations/epoch00000003
# Test Accuracy on 10,000 images: 92.11%
# Epoch: 5 	Training Loss: 0.002038
# Saving activations/epoch00000004
# Test Accuracy on 10,000 images: 93.47%
# Epoch: 6 	Training Loss: 0.001753
# Saving activations/epoch00000005
# Test Accuracy on 10,000 images: 94.44%
# Epoch: 7 	Training Loss: 0.001523
# Saving activations/epoch00000006
# Test Accuracy on 10,000 images: 95.15%
# Epoch: 8 	Training Loss: 0.001350
# Saving activations/epoch00000007
# Test Accuracy on 10,000 images: 95.27%
# Epoch: 9 	Training Loss: 0.001210
# Saving activations/epoch00000008
# Test Accuracy on 10,000 images: 96.05%
# Epoch: 10 	Training Loss: 0.001096
# Saving activations/epoch00000009
# Test Accuracy on 10,000 images: 96.50%
# Epoch: 11 	Training Loss: 0.001006
# Saving activations/epoch00000010
# Test Accuracy on 10,000 images: 96.69%
# Epoch: 12 	Training Loss: 0.000928
# Saving activations/epoch00000011
# Test Accuracy on 10,000 images: 96.75%
# Epoch: 13 	Training Loss: 0.000863
# Saving activations/epoch00000012
# Test Accuracy on 10,000 images: 96.95%
# Epoch: 14 	Training Loss: 0.000807
# Saving activations/epoch00000013
# Test Accuracy on 10,000 images: 97.16%
# Epoch: 15 	Training Loss: 0.000761
# Saving activations/epoch00000014
# Test Accuracy on 10,000 images: 97.34%
# Epoch: 16 	Training Loss: 0.000722
# Saving activations/epoch00000015
# Test Accuracy on 10,000 images: 97.34%
# Epoch: 17 	Training Loss: 0.000689
# Saving activations/epoch00000016
# Test Accuracy on 10,000 images: 97.63%
# Epoch: 18 	Training Loss: 0.000658
# Saving activations/epoch00000017
# Test Accuracy on 10,000 images: 97.55%
# Epoch: 19 	Training Loss: 0.000626
# Saving activations/epoch00000018
# Test Accuracy on 10,000 images: 97.76%
# Epoch: 20 	Training Loss: 0.000605
# Saving activations/epoch00000019
# Test Accuracy on 10,000 images: 97.80%
# Epoch: 21 	Training Loss: 0.000583
# Saving activations/epoch00000020
# Test Accuracy on 10,000 images: 97.98%
# Epoch: 22 	Training Loss: 0.000564
# Test Accuracy on 10,000 images: 98.09%
# Epoch: 23 	Training Loss: 0.000543
# Test Accuracy on 10,000 images: 98.13%
# Epoch: 24 	Training Loss: 0.000529
# Test Accuracy on 10,000 images: 98.03%
# Epoch: 25 	Training Loss: 0.000512
# Test Accuracy on 10,000 images: 98.05%
# Epoch: 26 	Training Loss: 0.000495
# Saving activations/epoch00000025
# Test Accuracy on 10,000 images: 98.18%
# Epoch: 27 	Training Loss: 0.000482
# Test Accuracy on 10,000 images: 98.18%
# Epoch: 28 	Training Loss: 0.000468
# Test Accuracy on 10,000 images: 98.09%
# Epoch: 29 	Training Loss: 0.000458
# Test Accuracy on 10,000 images: 98.13%
# Epoch: 30 	Training Loss: 0.000444
# Test Accuracy on 10,000 images: 98.15%
# Epoch: 31 	Training Loss: 0.000437
# Saving activations/epoch00000030
# Test Accuracy on 10,000 images: 98.31%
# Epoch: 32 	Training Loss: 0.000424
# Test Accuracy on 10,000 images: 98.18%
# Epoch: 33 	Training Loss: 0.000416
# Test Accuracy on 10,000 images: 98.19%
# Epoch: 34 	Training Loss: 0.000407
# Test Accuracy on 10,000 images: 98.36%
# Epoch: 35 	Training Loss: 0.000396
# Test Accuracy on 10,000 images: 98.46%
# Epoch: 36 	Training Loss: 0.000389
# Saving activations/epoch00000035
# Test Accuracy on 10,000 images: 98.44%
# Epoch: 37 	Training Loss: 0.000383
# Test Accuracy on 10,000 images: 98.46%
# Epoch: 38 	Training Loss: 0.000372
# Test Accuracy on 10,000 images: 98.06%
# Epoch: 39 	Training Loss: 0.000367
# Test Accuracy on 10,000 images: 98.53%
# Epoch: 40 	Training Loss: 0.000358
# Test Accuracy on 10,000 images: 98.47%
# Epoch: 41 	Training Loss: 0.000353
# Saving activations/epoch00000040
# Test Accuracy on 10,000 images: 98.48%
# Epoch: 42 	Training Loss: 0.000345
# Test Accuracy on 10,000 images: 98.49%
# Epoch: 43 	Training Loss: 0.000342
# Test Accuracy on 10,000 images: 98.50%
# Epoch: 44 	Training Loss: 0.000334
# Test Accuracy on 10,000 images: 98.52%
# Epoch: 45 	Training Loss: 0.000327
# Test Accuracy on 10,000 images: 98.43%
# Epoch: 46 	Training Loss: 0.000322
# Saving activations/epoch00000045
# Test Accuracy on 10,000 images: 98.43%
# Epoch: 47 	Training Loss: 0.000320
# Test Accuracy on 10,000 images: 98.43%
# Epoch: 48 	Training Loss: 0.000310
# Test Accuracy on 10,000 images: 98.55%
# Epoch: 49 	Training Loss: 0.000309
# Test Accuracy on 10,000 images: 98.52%
# Epoch: 50 	Training Loss: 0.000302
# Test Accuracy on 10,000 images: 98.40%
# Epoch: 51 	Training Loss: 0.000299
# Saving activations/epoch00000050
# Test Accuracy on 10,000 images: 98.53%
# Epoch: 52 	Training Loss: 0.000296
# Test Accuracy on 10,000 images: 98.61%
# Epoch: 53 	Training Loss: 0.000290
# Test Accuracy on 10,000 images: 98.63%
# Epoch: 54 	Training Loss: 0.000289
# Test Accuracy on 10,000 images: 98.49%
# Epoch: 55 	Training Loss: 0.000281
# Test Accuracy on 10,000 images: 98.58%
# Epoch: 56 	Training Loss: 0.000278
# Saving activations/epoch00000055
# Test Accuracy on 10,000 images: 98.66%
# Epoch: 57 	Training Loss: 0.000273
# Test Accuracy on 10,000 images: 98.56%
# Epoch: 58 	Training Loss: 0.000270
# Test Accuracy on 10,000 images: 98.62%
# Epoch: 59 	Training Loss: 0.000269
# Test Accuracy on 10,000 images: 98.51%
# Epoch: 60 	Training Loss: 0.000262
# Test Accuracy on 10,000 images: 98.52%
# Epoch: 61 	Training Loss: 0.000262
# Saving activations/epoch00000060
# Test Accuracy on 10,000 images: 98.63%
# Epoch: 62 	Training Loss: 0.000256
# Test Accuracy on 10,000 images: 98.47%
# Epoch: 63 	Training Loss: 0.000253
# Test Accuracy on 10,000 images: 98.55%
# Epoch: 64 	Training Loss: 0.000250
# Test Accuracy on 10,000 images: 98.54%
# Epoch: 65 	Training Loss: 0.000248
# Test Accuracy on 10,000 images: 98.52%
# Epoch: 66 	Training Loss: 0.000243
# Saving activations/epoch00000065
# Test Accuracy on 10,000 images: 98.54%
# Epoch: 67 	Training Loss: 0.000240
# Test Accuracy on 10,000 images: 98.75%
# Epoch: 68 	Training Loss: 0.000238
# Test Accuracy on 10,000 images: 98.57%
# Epoch: 69 	Training Loss: 0.000234
# Test Accuracy on 10,000 images: 98.55%
# Epoch: 70 	Training Loss: 0.000232
# Test Accuracy on 10,000 images: 98.53%
# Epoch: 71 	Training Loss: 0.000230
# Saving activations/epoch00000070
# Test Accuracy on 10,000 images: 98.64%
# Epoch: 72 	Training Loss: 0.000227
# Test Accuracy on 10,000 images: 98.62%
# Epoch: 73 	Training Loss: 0.000223
# Test Accuracy on 10,000 images: 98.66%
# Epoch: 74 	Training Loss: 0.000221
# Test Accuracy on 10,000 images: 98.67%
# Epoch: 75 	Training Loss: 0.000219
# Test Accuracy on 10,000 images: 98.69%
# Epoch: 76 	Training Loss: 0.000219
# Saving activations/epoch00000075
# Test Accuracy on 10,000 images: 98.50%
# Epoch: 77 	Training Loss: 0.000214
# Test Accuracy on 10,000 images: 98.58%
# Epoch: 78 	Training Loss: 0.000210
# Test Accuracy on 10,000 images: 98.57%
# Epoch: 79 	Training Loss: 0.000208
# Test Accuracy on 10,000 images: 98.63%
# Epoch: 80 	Training Loss: 0.000209
# Test Accuracy on 10,000 images: 98.77%
# Epoch: 81 	Training Loss: 0.000206
# Saving activations/epoch00000080
# Test Accuracy on 10,000 images: 98.74%
# Epoch: 82 	Training Loss: 0.000204
# Test Accuracy on 10,000 images: 98.62%
# Epoch: 83 	Training Loss: 0.000202
# Test Accuracy on 10,000 images: 98.66%
# Epoch: 84 	Training Loss: 0.000198
# Test Accuracy on 10,000 images: 98.67%
# Epoch: 85 	Training Loss: 0.000197
# Test Accuracy on 10,000 images: 98.72%
# Epoch: 86 	Training Loss: 0.000196
# Saving activations/epoch00000085
# Test Accuracy on 10,000 images: 98.68%
# Epoch: 87 	Training Loss: 0.000192
# Test Accuracy on 10,000 images: 98.70%
# Epoch: 88 	Training Loss: 0.000191
# Test Accuracy on 10,000 images: 98.69%
# Epoch: 89 	Training Loss: 0.000187
# Test Accuracy on 10,000 images: 98.75%
# Epoch: 90 	Training Loss: 0.000186
# Test Accuracy on 10,000 images: 98.56%
# Epoch: 91 	Training Loss: 0.000183
# Saving activations/epoch00000090
# Test Accuracy on 10,000 images: 98.66%
# Epoch: 92 	Training Loss: 0.000181
# Test Accuracy on 10,000 images: 98.68%
# Epoch: 93 	Training Loss: 0.000179
# Test Accuracy on 10,000 images: 98.50%
# Epoch: 94 	Training Loss: 0.000181
# Test Accuracy on 10,000 images: 98.48%
# Epoch: 95 	Training Loss: 0.000175
# Test Accuracy on 10,000 images: 98.65%
# Epoch: 96 	Training Loss: 0.000175
# Saving activations/epoch00000095
# Test Accuracy on 10,000 images: 98.63%
# Epoch: 97 	Training Loss: 0.000175
# Test Accuracy on 10,000 images: 98.53%
# Epoch: 98 	Training Loss: 0.000171
# Test Accuracy on 10,000 images: 98.72%
# Epoch: 99 	Training Loss: 0.000169
# Test Accuracy on 10,000 images: 98.60%
# Epoch: 100 	Training Loss: 0.000168
# Test Accuracy on 10,000 images: 98.74%
# *** Doing activations ***
# Doing activations/epoch00000000
# - Layer 0 upper: MI(X;M)=13.315, MI(Y;M)=3.319, h_upper=1687.905, hM_given_X=1678.676, hM_given_Y_upper=1685.604
# - Layer 1 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=848.549, hM_given_X=839.338, hM_given_Y_upper=846.248
# - Layer 2 upper: MI(X;M)=8.740, MI(Y;M)=2.377, h_upper=11.411, hM_given_X=5.353, hM_given_Y_upper=9.764
# - Layer 3 upper: MI(X;M)=0.185, MI(Y;M)=0.113, h_upper=2.805, hM_given_X=2.676, hM_given_Y_upper=2.727
# Doing activations/epoch00000001
# - Layer 0 upper: MI(X;M)=13.257, MI(Y;M)=3.319, h_upper=1687.865, hM_given_X=1678.676, hM_given_Y_upper=1685.564
# - Layer 1 upper: MI(X;M)=13.281, MI(Y;M)=3.319, h_upper=848.544, hM_given_X=839.338, hM_given_Y_upper=846.243
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.683, MI(Y;M)=2.687, h_upper=5.229, hM_given_X=2.676, hM_given_Y_upper=3.367
# Doing activations/epoch00000002
# - Layer 0 upper: MI(X;M)=13.302, MI(Y;M)=3.320, h_upper=1687.896, hM_given_X=1678.676, hM_given_Y_upper=1685.595
# - Layer 1 upper: MI(X;M)=13.276, MI(Y;M)=3.319, h_upper=848.540, hM_given_X=839.338, hM_given_Y_upper=846.239
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.661, MI(Y;M)=2.762, h_upper=5.214, hM_given_X=2.676, hM_given_Y_upper=3.300
# Doing activations/epoch00000003
# - Layer 0 upper: MI(X;M)=13.239, MI(Y;M)=3.319, h_upper=1687.852, hM_given_X=1678.676, hM_given_Y_upper=1685.551
# - Layer 1 upper: MI(X;M)=13.299, MI(Y;M)=3.319, h_upper=848.556, hM_given_X=839.338, hM_given_Y_upper=846.255
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.644, MI(Y;M)=2.892, h_upper=5.202, hM_given_X=2.676, hM_given_Y_upper=3.197
# Doing activations/epoch00000004
# - Layer 0 upper: MI(X;M)=13.384, MI(Y;M)=3.320, h_upper=1687.953, hM_given_X=1678.676, hM_given_Y_upper=1685.652
# - Layer 1 upper: MI(X;M)=13.289, MI(Y;M)=3.319, h_upper=848.549, hM_given_X=839.338, hM_given_Y_upper=846.248
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.602, MI(Y;M)=2.957, h_upper=5.173, hM_given_X=2.676, hM_given_Y_upper=3.124
# Doing activations/epoch00000005
# - Layer 0 upper: MI(X;M)=13.391, MI(Y;M)=3.320, h_upper=1687.957, hM_given_X=1678.676, hM_given_Y_upper=1685.656
# - Layer 1 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=848.546, hM_given_X=839.338, hM_given_Y_upper=846.246
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.580, MI(Y;M)=3.008, h_upper=5.158, hM_given_X=2.676, hM_given_Y_upper=3.073
# Doing activations/epoch00000006
# - Layer 0 upper: MI(X;M)=13.223, MI(Y;M)=3.319, h_upper=1687.841, hM_given_X=1678.676, hM_given_Y_upper=1685.541
# - Layer 1 upper: MI(X;M)=13.296, MI(Y;M)=3.319, h_upper=848.554, hM_given_X=839.338, hM_given_Y_upper=846.253
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.558, MI(Y;M)=3.031, h_upper=5.142, hM_given_X=2.676, hM_given_Y_upper=3.042
# Doing activations/epoch00000007
# - Layer 0 upper: MI(X;M)=13.267, MI(Y;M)=3.320, h_upper=1687.871, hM_given_X=1678.676, hM_given_Y_upper=1685.570
# - Layer 1 upper: MI(X;M)=13.266, MI(Y;M)=3.319, h_upper=848.533, hM_given_X=839.338, hM_given_Y_upper=846.232
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.537, MI(Y;M)=3.054, h_upper=5.128, hM_given_X=2.676, hM_given_Y_upper=3.011
# Doing activations/epoch00000008
# - Layer 0 upper: MI(X;M)=13.130, MI(Y;M)=3.319, h_upper=1687.777, hM_given_X=1678.676, hM_given_Y_upper=1685.476
# - Layer 1 upper: MI(X;M)=13.289, MI(Y;M)=3.320, h_upper=848.549, hM_given_X=839.338, hM_given_Y_upper=846.248
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.518, MI(Y;M)=3.082, h_upper=5.115, hM_given_X=2.676, hM_given_Y_upper=2.979
# Doing activations/epoch00000009
# - Layer 0 upper: MI(X;M)=13.216, MI(Y;M)=3.319, h_upper=1687.836, hM_given_X=1678.676, hM_given_Y_upper=1685.535
# - Layer 1 upper: MI(X;M)=13.324, MI(Y;M)=3.320, h_upper=848.573, hM_given_X=839.338, hM_given_Y_upper=846.272
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.506, MI(Y;M)=3.109, h_upper=5.107, hM_given_X=2.676, hM_given_Y_upper=2.951
# Doing activations/epoch00000010
# - Layer 0 upper: MI(X;M)=13.191, MI(Y;M)=3.319, h_upper=1687.819, hM_given_X=1678.676, hM_given_Y_upper=1685.518
# - Layer 1 upper: MI(X;M)=13.295, MI(Y;M)=3.319, h_upper=848.553, hM_given_X=839.338, hM_given_Y_upper=846.252
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.491, MI(Y;M)=3.119, h_upper=5.097, hM_given_X=2.676, hM_given_Y_upper=2.935
# Doing activations/epoch00000011
# - Layer 0 upper: MI(X;M)=13.447, MI(Y;M)=3.320, h_upper=1687.996, hM_given_X=1678.676, hM_given_Y_upper=1685.695
# - Layer 1 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=848.547, hM_given_X=839.338, hM_given_Y_upper=846.246
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.484, MI(Y;M)=3.128, h_upper=5.091, hM_given_X=2.676, hM_given_Y_upper=2.923
# Doing activations/epoch00000012
# - Layer 0 upper: MI(X;M)=13.248, MI(Y;M)=3.320, h_upper=1687.858, hM_given_X=1678.676, hM_given_Y_upper=1685.557
# - Layer 1 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=848.546, hM_given_X=839.338, hM_given_Y_upper=846.245
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.474, MI(Y;M)=3.137, h_upper=5.085, hM_given_X=2.676, hM_given_Y_upper=2.910
# Doing activations/epoch00000013
# - Layer 0 upper: MI(X;M)=13.363, MI(Y;M)=3.320, h_upper=1687.938, hM_given_X=1678.676, hM_given_Y_upper=1685.637
# - Layer 1 upper: MI(X;M)=13.323, MI(Y;M)=3.320, h_upper=848.573, hM_given_X=839.338, hM_given_Y_upper=846.272
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.470, MI(Y;M)=3.142, h_upper=5.082, hM_given_X=2.676, hM_given_Y_upper=2.904
# Doing activations/epoch00000014
# - Layer 0 upper: MI(X;M)=13.180, MI(Y;M)=3.319, h_upper=1687.811, hM_given_X=1678.676, hM_given_Y_upper=1685.511
# - Layer 1 upper: MI(X;M)=13.324, MI(Y;M)=3.320, h_upper=848.573, hM_given_X=839.338, hM_given_Y_upper=846.272
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.458, MI(Y;M)=3.156, h_upper=5.073, hM_given_X=2.676, hM_given_Y_upper=2.886
# Doing activations/epoch00000015
# - Layer 0 upper: MI(X;M)=13.271, MI(Y;M)=3.319, h_upper=1687.874, hM_given_X=1678.676, hM_given_Y_upper=1685.573
# - Layer 1 upper: MI(X;M)=13.297, MI(Y;M)=3.320, h_upper=848.555, hM_given_X=839.338, hM_given_Y_upper=846.254
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.459, MI(Y;M)=3.156, h_upper=5.074, hM_given_X=2.676, hM_given_Y_upper=2.886
# Doing activations/epoch00000016
# - Layer 0 upper: MI(X;M)=13.201, MI(Y;M)=3.319, h_upper=1687.826, hM_given_X=1678.676, hM_given_Y_upper=1685.526
# - Layer 1 upper: MI(X;M)=13.306, MI(Y;M)=3.319, h_upper=848.561, hM_given_X=839.338, hM_given_Y_upper=846.260
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.452, MI(Y;M)=3.166, h_upper=5.069, hM_given_X=2.676, hM_given_Y_upper=2.875
# Doing activations/epoch00000017
# - Layer 0 upper: MI(X;M)=13.260, MI(Y;M)=3.319, h_upper=1687.866, hM_given_X=1678.676, hM_given_Y_upper=1685.566
# - Layer 1 upper: MI(X;M)=13.283, MI(Y;M)=3.319, h_upper=848.545, hM_given_X=839.338, hM_given_Y_upper=846.244
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.446, MI(Y;M)=3.171, h_upper=5.065, hM_given_X=2.676, hM_given_Y_upper=2.867
# Doing activations/epoch00000018
# - Layer 0 upper: MI(X;M)=13.216, MI(Y;M)=3.319, h_upper=1687.836, hM_given_X=1678.676, hM_given_Y_upper=1685.536
# - Layer 1 upper: MI(X;M)=13.299, MI(Y;M)=3.319, h_upper=848.556, hM_given_X=839.338, hM_given_Y_upper=846.256
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.444, MI(Y;M)=3.180, h_upper=5.063, hM_given_X=2.676, hM_given_Y_upper=2.859
# Doing activations/epoch00000019
# - Layer 0 upper: MI(X;M)=13.369, MI(Y;M)=3.320, h_upper=1687.942, hM_given_X=1678.676, hM_given_Y_upper=1685.641
# - Layer 1 upper: MI(X;M)=13.334, MI(Y;M)=3.320, h_upper=848.580, hM_given_X=839.338, hM_given_Y_upper=846.279
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.442, MI(Y;M)=3.182, h_upper=5.062, hM_given_X=2.676, hM_given_Y_upper=2.857
# Doing activations/epoch00000020
# - Layer 0 upper: MI(X;M)=13.321, MI(Y;M)=3.319, h_upper=1687.909, hM_given_X=1678.676, hM_given_Y_upper=1685.608
# - Layer 1 upper: MI(X;M)=13.290, MI(Y;M)=3.319, h_upper=848.550, hM_given_X=839.338, hM_given_Y_upper=846.249
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.428, MI(Y;M)=3.190, h_upper=5.053, hM_given_X=2.676, hM_given_Y_upper=2.842
# Doing activations/epoch00000025
# - Layer 0 upper: MI(X;M)=13.334, MI(Y;M)=3.320, h_upper=1687.918, hM_given_X=1678.676, hM_given_Y_upper=1685.617
# - Layer 1 upper: MI(X;M)=13.286, MI(Y;M)=3.320, h_upper=848.547, hM_given_X=839.338, hM_given_Y_upper=846.246
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.421, MI(Y;M)=3.204, h_upper=5.048, hM_given_X=2.676, hM_given_Y_upper=2.827
# Doing activations/epoch00000030
# - Layer 0 upper: MI(X;M)=13.207, MI(Y;M)=3.319, h_upper=1687.830, hM_given_X=1678.676, hM_given_Y_upper=1685.529
# - Layer 1 upper: MI(X;M)=13.307, MI(Y;M)=3.319, h_upper=848.562, hM_given_X=839.338, hM_given_Y_upper=846.261
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.410, MI(Y;M)=3.207, h_upper=5.040, hM_given_X=2.676, hM_given_Y_upper=2.817
# Doing activations/epoch00000035
# - Layer 0 upper: MI(X;M)=13.191, MI(Y;M)=3.319, h_upper=1687.819, hM_given_X=1678.676, hM_given_Y_upper=1685.519
# - Layer 1 upper: MI(X;M)=13.311, MI(Y;M)=3.320, h_upper=848.565, hM_given_X=839.338, hM_given_Y_upper=846.264
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.405, MI(Y;M)=3.216, h_upper=5.036, hM_given_X=2.676, hM_given_Y_upper=2.808
# Doing activations/epoch00000040
# - Layer 0 upper: MI(X;M)=13.524, MI(Y;M)=3.321, h_upper=1688.050, hM_given_X=1678.676, hM_given_Y_upper=1685.748
# - Layer 1 upper: MI(X;M)=13.296, MI(Y;M)=3.319, h_upper=848.554, hM_given_X=839.338, hM_given_Y_upper=846.253
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.401, MI(Y;M)=3.216, h_upper=5.034, hM_given_X=2.676, hM_given_Y_upper=2.804
# Doing activations/epoch00000045
# - Layer 0 upper: MI(X;M)=13.239, MI(Y;M)=3.319, h_upper=1687.852, hM_given_X=1678.676, hM_given_Y_upper=1685.551
# - Layer 1 upper: MI(X;M)=13.318, MI(Y;M)=3.319, h_upper=848.569, hM_given_X=839.338, hM_given_Y_upper=846.268
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.397, MI(Y;M)=3.215, h_upper=5.031, hM_given_X=2.676, hM_given_Y_upper=2.802
# Doing activations/epoch00000050
# - Layer 0 upper: MI(X;M)=13.110, MI(Y;M)=3.319, h_upper=1687.763, hM_given_X=1678.676, hM_given_Y_upper=1685.462
# - Layer 1 upper: MI(X;M)=13.307, MI(Y;M)=3.319, h_upper=848.561, hM_given_X=839.338, hM_given_Y_upper=846.261
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.395, MI(Y;M)=3.222, h_upper=5.029, hM_given_X=2.676, hM_given_Y_upper=2.796
# Doing activations/epoch00000055
# - Layer 0 upper: MI(X;M)=13.203, MI(Y;M)=3.319, h_upper=1687.827, hM_given_X=1678.676, hM_given_Y_upper=1685.527
# - Layer 1 upper: MI(X;M)=13.285, MI(Y;M)=3.320, h_upper=848.546, hM_given_X=839.338, hM_given_Y_upper=846.245
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.387, MI(Y;M)=3.227, h_upper=5.024, hM_given_X=2.676, hM_given_Y_upper=2.788
# Doing activations/epoch00000060
# - Layer 0 upper: MI(X;M)=13.300, MI(Y;M)=3.319, h_upper=1687.895, hM_given_X=1678.676, hM_given_Y_upper=1685.594
# - Layer 1 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=848.549, hM_given_X=839.338, hM_given_Y_upper=846.248
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.385, MI(Y;M)=3.222, h_upper=5.023, hM_given_X=2.676, hM_given_Y_upper=2.789
# Doing activations/epoch00000065
# - Layer 0 upper: MI(X;M)=13.284, MI(Y;M)=3.319, h_upper=1687.883, hM_given_X=1678.676, hM_given_Y_upper=1685.583
# - Layer 1 upper: MI(X;M)=13.275, MI(Y;M)=3.319, h_upper=848.540, hM_given_X=839.338, hM_given_Y_upper=846.239
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.389, MI(Y;M)=3.219, h_upper=5.025, hM_given_X=2.676, hM_given_Y_upper=2.794
# Doing activations/epoch00000070
# - Layer 0 upper: MI(X;M)=13.087, MI(Y;M)=3.319, h_upper=1687.747, hM_given_X=1678.676, hM_given_Y_upper=1685.447
# - Layer 1 upper: MI(X;M)=13.292, MI(Y;M)=3.319, h_upper=848.551, hM_given_X=839.338, hM_given_Y_upper=846.250
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.382, MI(Y;M)=3.226, h_upper=5.021, hM_given_X=2.676, hM_given_Y_upper=2.785
# Doing activations/epoch00000075
# - Layer 0 upper: MI(X;M)=13.307, MI(Y;M)=3.319, h_upper=1687.899, hM_given_X=1678.676, hM_given_Y_upper=1685.598
# - Layer 1 upper: MI(X;M)=13.303, MI(Y;M)=3.319, h_upper=848.558, hM_given_X=839.338, hM_given_Y_upper=846.258
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.388, MI(Y;M)=3.220, h_upper=5.025, hM_given_X=2.676, hM_given_Y_upper=2.793
# Doing activations/epoch00000080
# - Layer 0 upper: MI(X;M)=13.193, MI(Y;M)=3.319, h_upper=1687.820, hM_given_X=1678.676, hM_given_Y_upper=1685.519
# - Layer 1 upper: MI(X;M)=13.277, MI(Y;M)=3.319, h_upper=848.541, hM_given_X=839.338, hM_given_Y_upper=846.240
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.377, MI(Y;M)=3.230, h_upper=5.017, hM_given_X=2.676, hM_given_Y_upper=2.779
# Doing activations/epoch00000085
# - Layer 0 upper: MI(X;M)=13.265, MI(Y;M)=3.320, h_upper=1687.870, hM_given_X=1678.676, hM_given_Y_upper=1685.569
# - Layer 1 upper: MI(X;M)=13.317, MI(Y;M)=3.320, h_upper=848.568, hM_given_X=839.338, hM_given_Y_upper=846.268
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.376, MI(Y;M)=3.226, h_upper=5.016, hM_given_X=2.676, hM_given_Y_upper=2.780
# Doing activations/epoch00000090
# - Layer 0 upper: MI(X;M)=13.329, MI(Y;M)=3.320, h_upper=1687.914, hM_given_X=1678.676, hM_given_Y_upper=1685.613
# - Layer 1 upper: MI(X;M)=13.305, MI(Y;M)=3.319, h_upper=848.560, hM_given_X=839.338, hM_given_Y_upper=846.260
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.373, MI(Y;M)=3.229, h_upper=5.015, hM_given_X=2.676, hM_given_Y_upper=2.776
# Doing activations/epoch00000095
# - Layer 0 upper: MI(X;M)=13.419, MI(Y;M)=3.320, h_upper=1687.977, hM_given_X=1678.676, hM_given_Y_upper=1685.675
# - Layer 1 upper: MI(X;M)=13.317, MI(Y;M)=3.319, h_upper=848.568, hM_given_X=839.338, hM_given_Y_upper=846.267
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.373, MI(Y;M)=3.229, h_upper=5.014, hM_given_X=2.676, hM_given_Y_upper=2.776

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import torch
import scienceplots
plt.rcParams['font.serif'] = ['Times New Roman']
mpl.rcParams['figure.dpi'] = 800
mpl.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
plt.style.use(['science', 'ieee'])
mpl.rcParams.update({'font.size': 15})

def plot_information_plane(IXT_array, ITY_array, num_epochs, every_n_early=1, every_n_late=5):
    assert len(IXT_array) == len(ITY_array)

    max_index = len(IXT_array)

    fig, ax = plt.subplots(figsize=(5, 3.5))
    ax.set_xlabel('$I(X;T)$', fontsize=15)
    ax.set_ylabel('$I(T;Y)$', fontsize=15)

    cmap = plt.get_cmap('gnuplot')
    colors = [cmap(i) for i in np.linspace(0, 1, num_epochs + 1)]

    for i in range(0, max_index):
        IXT = IXT_array[i, :]
        ITY = ITY_array[i, :]
        
        # 根据 epoch 的范围调整 every_n
        if i < 20:
            color_idx = i * every_n_early
        else:
            color_idx = 20 * every_n_early + (i - 20) * every_n_late

        ax.plot(IXT, ITY, marker='o', markersize=3, markeredgewidth=0.04,
                linestyle='-', linewidth=0.5, color=colors[color_idx], zorder=10)

    sm = plt.cm.ScalarMappable(cmap=cmap, norm=plt.Normalize(vmin=0, vmax=1))
    sm._A = []

    # 使用ax参数指定颜色条位置
    cbar = plt.colorbar(sm, ax=ax, ticks=[])
    cbar.set_label('epoch number', fontsize=15)
    cbar.ax.tick_params(labelsize=15)
    cbar.ax.text(0.5, -0.01, 0, transform=cbar.ax.transAxes, va='top', ha='center')
    cbar.ax.text(0.5, 1.0, str(num_epochs), transform=cbar.ax.transAxes, va='bottom', ha='center')

    ax.set_xticks([0, 2, 4, 6, 8, 10, 12, 14])
    ax.set_yticks([0,0.5,1.0, 1.5, 2.0, 2.5, 3.0, 3.5])
    ax.set_ylim(0.0, 3.5)  # 修改y轴坐标范围
    # Adjust coordinates of text according to the plot area
    ax.text(-0.2, 0.98, '(c)', fontdict={'size': 15, 'color': 'black'}, transform=ax.transAxes)

    fig.savefig('D:/深度学习与信息论/Fig8c.eps', dpi=800)
    plt.show()

IXT_array = np.load('D:/深度学习与信息论/MI_XM_upper_arrayS.npy')
ITY_array = np.load('D:/深度学习与信息论/MI_YM_upper_arrayS.npy')


plot_information_plane(IXT_array, ITY_array, num_epochs=100, every_n_early=1, every_n_late=5)

# %%
IXT_array
# Out:
# array([[13.31468224, 13.28833172,  8.74005731,  0.18546426],
#        [13.25709419, 13.2811112 , 13.28755893,  3.68317922],
#        [13.30182619, 13.27565179, 13.28770202,  3.66133044],
#        [13.23877873, 13.29933861, 13.28768551,  3.64376329],
#        [13.38389356, 13.28868394, 13.28768895,  3.60215955],
#        [13.39076186, 13.28516174, 13.28769239,  3.58039792],
#        [13.22345714, 13.2964328 , 13.28770546,  3.55752736],
#        [13.26660415, 13.26570156, 13.28770477,  3.5370903 ],
#        [13.12994261, 13.28859589, 13.28775499,  3.51831694],
#        [13.21553218, 13.32417016, 13.28771922,  3.50621121],
#        [13.19087675, 13.29467169, 13.28769996,  3.49138099],
#        [13.44711714, 13.28604229, 13.28772059,  3.48361665],
#        [13.24758424, 13.28489757, 13.28773023,  3.47415998],
#        [13.36276034, 13.32328961, 13.28773711,  3.47021349],
#        [13.1797818 , 13.32381794, 13.28771853,  3.45816331],
#        [13.27065468, 13.29722529, 13.28773642,  3.45934509],
#        [13.20144336, 13.30620691, 13.28772266,  3.45158528],
#        [13.25955974, 13.28260814, 13.28772472,  3.44577795],
#        [13.2158844 , 13.29942667, 13.28774536,  3.44363817],
#        [13.36892419, 13.333504  , 13.28773435,  3.44217433],
#        [13.32137443, 13.29035699, 13.2877261 ,  3.4283179 ],
#        [13.33440659, 13.28560202, 13.28769583,  3.42122034],
#        [13.20655056, 13.30726357, 13.28776325,  3.41007926],
#        [13.19105286, 13.31149022, 13.28773779,  3.40469105],
#        [13.52442953, 13.29599252, 13.2877316 ,  3.40054157],
#        [13.23877873, 13.31818241, 13.28772472,  3.39677111],
#        [13.10986604, 13.30691135, 13.28774261,  3.39452577],
#        [13.20285224, 13.28507369, 13.28772679,  3.38741337],
#        [13.3002412 , 13.28824367, 13.28779558,  3.38492843],
#        [13.28403906, 13.27547568, 13.28775843,  3.38880427],
#        [13.08714782, 13.29176587, 13.2878114 ,  3.38212983],
#        [13.30658117, 13.30259665, 13.28776669,  3.38763184],
#        [13.19281396, 13.2767965 , 13.28778457,  3.37706858],
#        [13.26519527, 13.31703769, 13.28774536,  3.37550914],
#        [13.32859495, 13.30541442, 13.28780521,  3.37315704],
#        [13.41911561, 13.31650936, 13.28779833,  3.37269012]])

# %%
ITY_array
# Out:
# array([[3.31936284, 3.31949248, 2.37676052, 0.11290715],
#        [3.31907863, 3.31936613, 3.3194228 , 2.68716007],
#        [3.31954526, 3.31933641, 3.31942294, 2.7619958 ],
#        [3.31914816, 3.3194714 , 3.31942155, 2.89229729],
#        [3.31983529, 3.31928774, 3.3194196 , 2.95714244],
#        [3.32021675, 3.31922028, 3.31942404, 3.00815719],
#        [3.31932626, 3.31945242, 3.31942031, 3.03064141],
#        [3.31955399, 3.31922556, 3.31942119, 3.05386308],
#        [3.31852123, 3.31950156, 3.31942654, 3.08185375],
#        [3.319362  , 3.31967954, 3.31942103, 3.10944631],
#        [3.31900477, 3.31935382, 3.31942197, 3.11851853],
#        [3.31983818, 3.31923241, 3.3194232 , 3.12762447],
#        [3.31956192, 3.31939109, 3.31942259, 3.1367618 ],
#        [3.32002856, 3.3195855 , 3.31942269, 3.14205367],
#        [3.31897978, 3.31955948, 3.31942165, 3.15618742],
#        [3.31929965, 3.31951386, 3.31942041, 3.15641065],
#        [3.31893755, 3.31939159, 3.31942394, 3.165761  ],
#        [3.31933209, 3.31932086, 3.3194216 , 3.17079477],
#        [3.3189194 , 3.31920082, 3.31942313, 3.17989392],
#        [3.31957232, 3.31953349, 3.31941979, 3.18224171],
#        [3.31937191, 3.31942243, 3.31942011, 3.18965722],
#        [3.31967582, 3.31955099, 3.31942148, 3.2035021 ],
#        [3.31902084, 3.31936541, 3.31942207, 3.20672501],
#        [3.31870572, 3.31958585, 3.31942093, 3.21558742],
#        [3.32062874, 3.31931775, 3.31942254, 3.2162029 ],
#        [3.31924744, 3.31940351, 3.31942096, 3.21549682],
#        [3.31865081, 3.31948983, 3.31942058, 3.2218707 ],
#        [3.31861416, 3.31951102, 3.31942156, 3.2270499 ],
#        [3.31945032, 3.31953204, 3.31942175, 3.22228189],
#        [3.31918654, 3.3193676 , 3.31942229, 3.21874794],
#        [3.31862913, 3.31937285, 3.31942154, 3.22579753],
#        [3.31945459, 3.31929138, 3.31942095, 3.21980272],
#        [3.31920415, 3.31927752, 3.31942102, 3.22980597],
#        [3.31973498, 3.31952257, 3.31942093, 3.22551587],
#        [3.319792  , 3.31943372, 3.31942195, 3.22947706],
#        [3.32047355, 3.31939158, 3.31942633, 3.22860097]])

# %%
class CustomActivation(nn.Module):
    def __init__(self):
        super(CustomActivation, self).__init__()
        self.sigma = nn.Parameter(torch.tensor(1.3))

    def forward(self, input):
        temp = input/2*(1+torch.erf(input/math.sqrt(2)/self.sigma))#GELU
        #temp = input*torch.sigmoid(input)#SiLU
        return temp

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 8, kernel_size=3, padding=1)  # 输入通道数1，输出通道数8，卷积核大小3x3
        self.conv2 = nn.Conv2d(8, 16, kernel_size=3, padding=1)  # 输入通道数8，输出通道数16，卷积核大小3x3
        self.pool = nn.MaxPool2d(2, 2)                           # 2x2的最大池化层
        self.fc1 = nn.Linear(16 * 7 * 7, 20)                     # 全连接层，输入维度16*7*7，输出维度64
        self.fc3 = nn.Linear(20, 10)                             # 最后的全连接层，输出维度10（对应10个类别）
        self.act1 = CustomActivation()
        self.act2 = CustomActivation()
        self.act3 = CustomActivation()
        
    def forward(self, x):
        activations = []
        x = self.act1(self.conv1(x))  # 第一层卷积 + ReLU激活 
        xx = torch.flatten(x, 1)
        activations.append(xx.cpu().data.numpy())  # 保存第一层的激活
        x = self.pool(x)
        x = self.act2(self.conv2(x))  # 第二层卷积 + ReLU激活
        xx = torch.flatten(x, 1)
        activations.append(xx.cpu().data.numpy())  # 保存第二层的激活
        x = self.pool(x)
        x = x.view(-1, 16 * 7 * 7)                # 展平操作，为全连接层做准备
        x = self.act3(self.fc1(x))                   # 第一个全连接层 + ReLU激活
        activations.append(x.cpu().data.numpy())  # 保存全连接层的激活
        x = self.fc3(x)
        x = torch.softmax(x, dim=1)
        activations.append(x.cpu().data.numpy())  # 保存输出层的激活
        return x, activations
        

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
class MI_Plate():
    def __init__(self, n_epochs=100, DO_LOWER=False, DO_BINNED=False, PLOT_LAYERS=None):
        super(MI_Plate, self).__init__()
        
        self.n_epochs = n_epochs
        self.DO_LOWER = DO_LOWER
        self.DO_BINNED = DO_BINNED
        self.PLOT_LAYERS = PLOT_LAYERS
#DO_LOWER和DO_BINNED是用于控制数据预处理的布尔值，PLOT_LAYERS是用于指定绘制哪些层的激活值的列表
    def save_activations(self):
        
        if not os.path.exists('activations'):
            print("Making directory", 'activations')
            os.mkdir('activations')
            
        model = Net()
        optimizer = optim.SGD(model.parameters(), lr=0.005)
        #optimizer = optim.Adam(model.parameters(), lr=0.001/2)
        # Move model to GPU if available
        if train_on_gpu:
            model.cuda()
        
        for epoch in range(self.n_epochs):
            # monitor training loss
            train_loss = 0.0

            ###################
            # train the model #
            ###################
            model.train()

            for data, target in train_loader:
                if train_on_gpu:
                    data, target = data.cuda(), target.cuda()  # Move data to GPU
                optimizer.zero_grad()
                output, _ = model(data)
                loss = categorical_cross_entropy(output, target)
                # backward
                loss.backward()
                optimizer.step()
                train_loss += loss.item()#*data.size(0)

            # calculate average loss over an epoch
            train_loss = train_loss/len(train_loader.dataset)

            print('Epoch: {} \tTraining Loss: {:.6f}'.format(epoch+1, train_loss))

            model.eval()
########每次按照规定的epoch训练之后，都用full全部数据通过网络一次，记住标签和网络输出
###############################################################################            
            for data, _ in full_data_loader:
                if train_on_gpu:
                    data = data.cuda()  # Move data to GPU
                _, activations = model(data)
#定义多少epoch进行存储每层的输出，前20每次都存，高于200次100次再存一次
            if epoch < 20:       # Log for all first 20 epochs
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            #pickle.HIGHEST_PROTOCOL 用于指定 pickle 协议的版本，以确保最高的兼容性和效率
            elif (epoch < 100) and (epoch % 5 == 0):    # Then for every 5th epoch
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            elif (epoch < 200) and (epoch % 10 == 0):    # Then every 10th
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            elif (epoch % 100 == 0):                # Then every 100th
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
         #####################****************************************
            correct = 0
            total = 0
            with torch.no_grad():
                for data, target in test_loader:  # Assuming test_loader is defined elsewhere
                    if train_on_gpu:
                        data, target = data.cuda(), target.cuda()  # Move data to GPU
                    output, _ = model(data)
                    _, predicted = torch.max(output.data, 1)
                    total += target.size(0)
                    correct += (predicted == target).sum().item()

            accuracy = 100 * correct / total
           
            print('Test Accuracy on 10,000 images: {:.2f}%'.format(accuracy))                    
      ###########################
    def compute_MI(self, noise_variance=1e-1):
        
        MAX_EPOCHS = self.n_epochs
        self.noise_variance = noise_variance
        
        def entropy_func_upper(x):
            return kde.entropy_estimator_kl(x,self.noise_variance)
        
        def entropy_func_lower(x):
            return kde.entropy_estimator_bd(x,self.noise_variance)

        # nats to bits conversion factor
        nats2bits = 1.0/np.log(2) 


        # Save indexes of tests data for each of the output classes
        saved_labelixs = {}
        for data, targets in full_data_loader:
            trg = targets.numpy()
        for i in range(10):
            saved_labelixs[i] = trg == i

        labelprobs = np.mean(np.eye(10)[test_data.targets], axis=0)

        MI_XM_upper_array = []
        MI_YM_upper_array = []
###这段代码的作用是计算每个类别在数据集中出现的频率，并保存每个类别的索引以供后续使用
        measures = OrderedDict()
        measures['tanh'] = {}

        cur_dir = 'activations'
        if not os.path.exists(cur_dir):
            print("Directory %s not found" % cur_dir)

        # Load files saved during each epoch, and compute MI measures of the activity in that epoch
        print('*** Doing %s ***' % cur_dir)
        for epochfile in sorted(os.listdir(cur_dir)):
            if not epochfile.startswith('epoch'):
                continue

            fname = cur_dir + "/" + epochfile
            with open(fname, 'rb') as f:
                d = pickle.load(f)

            epoch = d[1]
            d = d[0]
            if epoch in measures['tanh']:# Skip this epoch if its already been processed
                continue                # this is a trick to allow us to rerun this cell multiple times)

            if epoch > MAX_EPOCHS:
                continue

            print("Doing", fname)

            num_layers = len(d)

            MI_XM_upper_epoch = []
            MI_YM_upper_epoch = []
            
            if self.PLOT_LAYERS is None:
                PLOT_LAYERS = []
                for lndx in range(num_layers):
                    PLOT_LAYERS.append(lndx)

            cepochdata = defaultdict(list)
            for lndx in range(num_layers):
                activity = d[lndx]

                # Compute marginal entropies
                h_upper = entropy_func_upper(activity)
                if self.DO_LOWER:
                    #h_lower = entropy_func_lower([activity,])[0]
                    h_lower = entropy_func_lower(activity)

                # Layer activity given input. This is simply the entropy of the Gaussian noise
                hM_given_X = kde.kde_condentropy(activity, self.noise_variance)

                # Compute conditional entropies of layer activity given output
                hM_given_Y_upper=0.
                for i in range(10):
                    hcond_upper = entropy_func_upper(activity[saved_labelixs[i],:])
                    hM_given_Y_upper += labelprobs[i] * hcond_upper

                if self.DO_LOWER:
                    hM_given_Y_lower=0.
                    for i in range(10):
                        hcond_lower = entropy_func_lower(activity[saved_labelixs[i],:])
                        hM_given_Y_lower += labelprobs[i] * hcond_lower

                cepochdata['MI_XM_upper'].append( nats2bits * (h_upper - hM_given_X) )
                cepochdata['MI_YM_upper'].append( nats2bits * (h_upper - hM_given_Y_upper) )
                cepochdata['H_M_upper'  ].append( nats2bits * h_upper )


                MI_XM_upper = nats2bits * (h_upper - hM_given_X)
                MI_YM_upper = nats2bits * (h_upper - hM_given_Y_upper)

                MI_XM_upper_epoch.append(MI_XM_upper)
                MI_YM_upper_epoch.append(MI_YM_upper)
                
                pstr = 'upper: MI(X;M)=%0.3f, MI(Y;M)=%0.3f, h_upper=%0.3f, hM_given_X=%0.3f, hM_given_Y_upper=%0.3f ' % (cepochdata['MI_XM_upper'][-1], cepochdata['MI_YM_upper'][-1], h_upper, hM_given_X, hM_given_Y_upper)
                if self.DO_LOWER:  # Compute lower bounds
                    cepochdata['MI_XM_lower'].append( nats2bits * (h_lower - hM_given_X) )
                    cepochdata['MI_YM_lower'].append( nats2bits * (h_lower - hM_given_Y_lower) )
                    cepochdata['H_M_lower'  ].append( nats2bits * h_lower )
                    pstr += ' | lower: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_lower'][-1], cepochdata['MI_YM_lower'][-1])

                if self.DO_BINNED: # Compute binner estimates
                    binxm, binym = simplebinmi.bin_calc_information2(saved_labelixs, activity, 0.5)
                    cepochdata['MI_XM_bin'].append( nats2bits * binxm )
                    cepochdata['MI_YM_bin'].append( nats2bits * binym )
                    pstr += ' | bin: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_bin'][-1], cepochdata['MI_YM_bin'][-1])

                print('- Layer %d %s' % (lndx, pstr) )

            measures['tanh'][epoch] = cepochdata
            MI_XM_upper_array.append(MI_XM_upper_epoch)
            MI_YM_upper_array.append(MI_YM_upper_epoch)
             
            #epoch += 1
        MI_XM_upper_array = np.array(MI_XM_upper_array)
        MI_YM_upper_array = np.array(MI_YM_upper_array)

    # Save the results as arrays
        np.save('D:/深度学习与信息论/MI_XM_upper_arrayG.npy', MI_XM_upper_array)
        np.save('D:/深度学习与信息论/MI_YM_upper_arrayG.npy', MI_YM_upper_array)

        with open('MI', 'wb') as f:
            pickle.dump(measures, f, pickle.HIGHEST_PROTOCOL)   

Plate = MI_Plate() #Create class object
Plate.save_activations() #save activations if they weren't saved already
Plate.compute_MI() #compute and save MIs if they weren't saved before
# Out:
# Epoch: 1 	Training Loss: 0.017433
# Saving activations/epoch00000000
# Test Accuracy on 10,000 images: 52.65%
# Epoch: 2 	Training Loss: 0.006018
# Saving activations/epoch00000001
# Test Accuracy on 10,000 images: 88.99%
# Epoch: 3 	Training Loss: 0.002656
# Saving activations/epoch00000002
# Test Accuracy on 10,000 images: 92.00%
# Epoch: 4 	Training Loss: 0.002039
# Saving activations/epoch00000003
# Test Accuracy on 10,000 images: 93.86%
# Epoch: 5 	Training Loss: 0.001692
# Saving activations/epoch00000004
# Test Accuracy on 10,000 images: 94.48%
# Epoch: 6 	Training Loss: 0.001455
# Saving activations/epoch00000005
# Test Accuracy on 10,000 images: 94.12%
# Epoch: 7 	Training Loss: 0.001279
# Saving activations/epoch00000006
# Test Accuracy on 10,000 images: 95.88%
# Epoch: 8 	Training Loss: 0.001142
# Saving activations/epoch00000007
# Test Accuracy on 10,000 images: 96.33%
# Epoch: 9 	Training Loss: 0.001032
# Saving activations/epoch00000008
# Test Accuracy on 10,000 images: 96.21%
# Epoch: 10 	Training Loss: 0.000952
# Saving activations/epoch00000009
# Test Accuracy on 10,000 images: 96.68%
# Epoch: 11 	Training Loss: 0.000877
# Saving activations/epoch00000010
# Test Accuracy on 10,000 images: 96.97%
# Epoch: 12 	Training Loss: 0.000819
# Saving activations/epoch00000011
# Test Accuracy on 10,000 images: 97.13%
# Epoch: 13 	Training Loss: 0.000770
# Saving activations/epoch00000012
# Test Accuracy on 10,000 images: 97.26%
# Epoch: 14 	Training Loss: 0.000723
# Saving activations/epoch00000013
# Test Accuracy on 10,000 images: 97.54%
# Epoch: 15 	Training Loss: 0.000682
# Saving activations/epoch00000014
# Test Accuracy on 10,000 images: 97.61%
# Epoch: 16 	Training Loss: 0.000655
# Saving activations/epoch00000015
# Test Accuracy on 10,000 images: 97.51%
# Epoch: 17 	Training Loss: 0.000625
# Saving activations/epoch00000016
# Test Accuracy on 10,000 images: 97.63%
# Epoch: 18 	Training Loss: 0.000606
# Saving activations/epoch00000017
# Test Accuracy on 10,000 images: 97.70%
# Epoch: 19 	Training Loss: 0.000577
# Saving activations/epoch00000018
# Test Accuracy on 10,000 images: 97.91%
# Epoch: 20 	Training Loss: 0.000557
# Saving activations/epoch00000019
# Test Accuracy on 10,000 images: 98.02%
# Epoch: 21 	Training Loss: 0.000541
# Saving activations/epoch00000020
# Test Accuracy on 10,000 images: 97.87%
# Epoch: 22 	Training Loss: 0.000523
# Test Accuracy on 10,000 images: 97.77%
# Epoch: 23 	Training Loss: 0.000508
# Test Accuracy on 10,000 images: 98.10%
# Epoch: 24 	Training Loss: 0.000493
# Test Accuracy on 10,000 images: 97.99%
# Epoch: 25 	Training Loss: 0.000484
# Test Accuracy on 10,000 images: 98.19%
# Epoch: 26 	Training Loss: 0.000468
# Saving activations/epoch00000025
# Test Accuracy on 10,000 images: 98.23%
# Epoch: 27 	Training Loss: 0.000458
# Test Accuracy on 10,000 images: 98.30%
# Epoch: 28 	Training Loss: 0.000447
# Test Accuracy on 10,000 images: 98.25%
# Epoch: 29 	Training Loss: 0.000438
# Test Accuracy on 10,000 images: 98.06%
# Epoch: 30 	Training Loss: 0.000429
# Test Accuracy on 10,000 images: 98.39%
# Epoch: 31 	Training Loss: 0.000417
# Saving activations/epoch00000030
# Test Accuracy on 10,000 images: 98.29%
# Epoch: 32 	Training Loss: 0.000409
# Test Accuracy on 10,000 images: 98.37%
# Epoch: 33 	Training Loss: 0.000401
# Test Accuracy on 10,000 images: 98.23%
# Epoch: 34 	Training Loss: 0.000397
# Test Accuracy on 10,000 images: 98.47%
# Epoch: 35 	Training Loss: 0.000388
# Test Accuracy on 10,000 images: 98.33%
# Epoch: 36 	Training Loss: 0.000381
# Saving activations/epoch00000035
# Test Accuracy on 10,000 images: 98.47%
# Epoch: 37 	Training Loss: 0.000375
# Test Accuracy on 10,000 images: 98.51%
# Epoch: 38 	Training Loss: 0.000366
# Test Accuracy on 10,000 images: 98.47%
# Epoch: 39 	Training Loss: 0.000360
# Test Accuracy on 10,000 images: 98.45%
# Epoch: 40 	Training Loss: 0.000352
# Test Accuracy on 10,000 images: 98.48%
# Epoch: 41 	Training Loss: 0.000348
# Saving activations/epoch00000040
# Test Accuracy on 10,000 images: 98.58%
# Epoch: 42 	Training Loss: 0.000344
# Test Accuracy on 10,000 images: 98.54%
# Epoch: 43 	Training Loss: 0.000339
# Test Accuracy on 10,000 images: 98.41%
# Epoch: 44 	Training Loss: 0.000330
# Test Accuracy on 10,000 images: 98.49%
# Epoch: 45 	Training Loss: 0.000328
# Test Accuracy on 10,000 images: 98.64%
# Epoch: 46 	Training Loss: 0.000322
# Saving activations/epoch00000045
# Test Accuracy on 10,000 images: 98.66%
# Epoch: 47 	Training Loss: 0.000317
# Test Accuracy on 10,000 images: 98.69%
# Epoch: 48 	Training Loss: 0.000312
# Test Accuracy on 10,000 images: 98.52%
# Epoch: 49 	Training Loss: 0.000310
# Test Accuracy on 10,000 images: 98.66%
# Epoch: 50 	Training Loss: 0.000306
# Test Accuracy on 10,000 images: 98.60%
# Epoch: 51 	Training Loss: 0.000300
# Saving activations/epoch00000050
# Test Accuracy on 10,000 images: 98.51%
# Epoch: 52 	Training Loss: 0.000296
# Test Accuracy on 10,000 images: 98.44%
# Epoch: 53 	Training Loss: 0.000293
# Test Accuracy on 10,000 images: 98.64%
# Epoch: 54 	Training Loss: 0.000287
# Test Accuracy on 10,000 images: 98.74%
# Epoch: 55 	Training Loss: 0.000284
# Test Accuracy on 10,000 images: 98.57%
# Epoch: 56 	Training Loss: 0.000279
# Saving activations/epoch00000055
# Test Accuracy on 10,000 images: 98.45%
# Epoch: 57 	Training Loss: 0.000278
# Test Accuracy on 10,000 images: 98.71%
# Epoch: 58 	Training Loss: 0.000272
# Test Accuracy on 10,000 images: 98.54%
# Epoch: 59 	Training Loss: 0.000270
# Test Accuracy on 10,000 images: 98.75%
# Epoch: 60 	Training Loss: 0.000268
# Test Accuracy on 10,000 images: 98.63%
# Epoch: 61 	Training Loss: 0.000264
# Saving activations/epoch00000060
# Test Accuracy on 10,000 images: 98.68%
# Epoch: 62 	Training Loss: 0.000260
# Test Accuracy on 10,000 images: 98.71%
# Epoch: 63 	Training Loss: 0.000257
# Test Accuracy on 10,000 images: 98.63%
# Epoch: 64 	Training Loss: 0.000253
# Test Accuracy on 10,000 images: 98.77%
# Epoch: 65 	Training Loss: 0.000250
# Test Accuracy on 10,000 images: 98.70%
# Epoch: 66 	Training Loss: 0.000249
# Saving activations/epoch00000065
# Test Accuracy on 10,000 images: 98.73%
# Epoch: 67 	Training Loss: 0.000243
# Test Accuracy on 10,000 images: 98.68%
# Epoch: 68 	Training Loss: 0.000243
# Test Accuracy on 10,000 images: 98.47%
# Epoch: 69 	Training Loss: 0.000239
# Test Accuracy on 10,000 images: 98.76%
# Epoch: 70 	Training Loss: 0.000237
# Test Accuracy on 10,000 images: 98.81%
# Epoch: 71 	Training Loss: 0.000237
# Saving activations/epoch00000070
# Test Accuracy on 10,000 images: 98.75%
# Epoch: 72 	Training Loss: 0.000231
# Test Accuracy on 10,000 images: 98.74%
# Epoch: 73 	Training Loss: 0.000228
# Test Accuracy on 10,000 images: 98.71%
# Epoch: 74 	Training Loss: 0.000225
# Test Accuracy on 10,000 images: 98.72%
# Epoch: 75 	Training Loss: 0.000223
# Test Accuracy on 10,000 images: 98.74%
# Epoch: 76 	Training Loss: 0.000221
# Saving activations/epoch00000075
# Test Accuracy on 10,000 images: 98.74%
# Epoch: 77 	Training Loss: 0.000220
# Test Accuracy on 10,000 images: 98.68%
# Epoch: 78 	Training Loss: 0.000218
# Test Accuracy on 10,000 images: 98.71%
# Epoch: 79 	Training Loss: 0.000214
# Test Accuracy on 10,000 images: 98.68%
# Epoch: 80 	Training Loss: 0.000211
# Test Accuracy on 10,000 images: 98.71%
# Epoch: 81 	Training Loss: 0.000210
# Saving activations/epoch00000080
# Test Accuracy on 10,000 images: 98.77%
# Epoch: 82 	Training Loss: 0.000209
# Test Accuracy on 10,000 images: 98.74%
# Epoch: 83 	Training Loss: 0.000206
# Test Accuracy on 10,000 images: 98.78%
# Epoch: 84 	Training Loss: 0.000207
# Test Accuracy on 10,000 images: 98.76%
# Epoch: 85 	Training Loss: 0.000201
# Test Accuracy on 10,000 images: 98.85%
# Epoch: 86 	Training Loss: 0.000199
# Saving activations/epoch00000085
# Test Accuracy on 10,000 images: 98.72%
# Epoch: 87 	Training Loss: 0.000195
# Test Accuracy on 10,000 images: 98.85%
# Epoch: 88 	Training Loss: 0.000194
# Test Accuracy on 10,000 images: 98.78%
# Epoch: 89 	Training Loss: 0.000195
# Test Accuracy on 10,000 images: 98.79%
# Epoch: 90 	Training Loss: 0.000192
# Test Accuracy on 10,000 images: 98.80%
# Epoch: 91 	Training Loss: 0.000191
# Saving activations/epoch00000090
# Test Accuracy on 10,000 images: 98.66%
# Epoch: 92 	Training Loss: 0.000185
# Test Accuracy on 10,000 images: 98.65%
# Epoch: 93 	Training Loss: 0.000187
# Test Accuracy on 10,000 images: 98.74%
# Epoch: 94 	Training Loss: 0.000184
# Test Accuracy on 10,000 images: 98.64%
# Epoch: 95 	Training Loss: 0.000182
# Test Accuracy on 10,000 images: 98.86%
# Epoch: 96 	Training Loss: 0.000180
# Saving activations/epoch00000095
# Test Accuracy on 10,000 images: 98.64%
# Epoch: 97 	Training Loss: 0.000180
# Test Accuracy on 10,000 images: 98.76%
# Epoch: 98 	Training Loss: 0.000177
# Test Accuracy on 10,000 images: 98.83%
# Epoch: 99 	Training Loss: 0.000175
# Test Accuracy on 10,000 images: 98.82%
# Epoch: 100 	Training Loss: 0.000172
# Test Accuracy on 10,000 images: 98.81%
# *** Doing activations ***
# Doing activations/epoch00000000
# - Layer 0 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=1687.885, hM_given_X=1678.676, hM_given_Y_upper=1685.584
# - Layer 1 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=848.548, hM_given_X=839.338, hM_given_Y_upper=846.247
# - Layer 2 upper: MI(X;M)=9.819, MI(Y;M)=2.831, h_upper=12.159, hM_given_X=5.353, hM_given_Y_upper=10.196
# - Layer 3 upper: MI(X;M)=0.233, MI(Y;M)=0.151, h_upper=2.838, hM_given_X=2.676, hM_given_Y_upper=2.734
# Doing activations/epoch00000001
# - Layer 0 upper: MI(X;M)=13.296, MI(Y;M)=3.319, h_upper=1687.892, hM_given_X=1678.676, hM_given_Y_upper=1685.591
# - Layer 1 upper: MI(X;M)=13.290, MI(Y;M)=3.319, h_upper=848.550, hM_given_X=839.338, hM_given_Y_upper=846.249
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.660, MI(Y;M)=2.731, h_upper=5.213, hM_given_X=2.676, hM_given_Y_upper=3.320
# Doing activations/epoch00000002
# - Layer 0 upper: MI(X;M)=13.291, MI(Y;M)=3.320, h_upper=1687.888, hM_given_X=1678.676, hM_given_Y_upper=1685.588
# - Layer 1 upper: MI(X;M)=13.284, MI(Y;M)=3.319, h_upper=848.545, hM_given_X=839.338, hM_given_Y_upper=846.245
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.646, MI(Y;M)=2.884, h_upper=5.204, hM_given_X=2.676, hM_given_Y_upper=3.205
# Doing activations/epoch00000003
# - Layer 0 upper: MI(X;M)=13.315, MI(Y;M)=3.320, h_upper=1687.905, hM_given_X=1678.676, hM_given_Y_upper=1685.604
# - Layer 1 upper: MI(X;M)=13.282, MI(Y;M)=3.319, h_upper=848.544, hM_given_X=839.338, hM_given_Y_upper=846.244
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.608, MI(Y;M)=2.971, h_upper=5.177, hM_given_X=2.676, hM_given_Y_upper=3.118
# Doing activations/epoch00000004
# - Layer 0 upper: MI(X;M)=13.277, MI(Y;M)=3.319, h_upper=1687.879, hM_given_X=1678.676, hM_given_Y_upper=1685.578
# - Layer 1 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=848.547, hM_given_X=839.338, hM_given_Y_upper=846.246
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.579, MI(Y;M)=3.011, h_upper=5.157, hM_given_X=2.676, hM_given_Y_upper=3.070
# Doing activations/epoch00000005
# - Layer 0 upper: MI(X;M)=13.317, MI(Y;M)=3.319, h_upper=1687.906, hM_given_X=1678.676, hM_given_Y_upper=1685.606
# - Layer 1 upper: MI(X;M)=13.280, MI(Y;M)=3.319, h_upper=848.543, hM_given_X=839.338, hM_given_Y_upper=846.242
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.570, MI(Y;M)=2.997, h_upper=5.151, hM_given_X=2.676, hM_given_Y_upper=3.073
# Doing activations/epoch00000006
# - Layer 0 upper: MI(X;M)=13.274, MI(Y;M)=3.319, h_upper=1687.876, hM_given_X=1678.676, hM_given_Y_upper=1685.576
# - Layer 1 upper: MI(X;M)=13.297, MI(Y;M)=3.319, h_upper=848.554, hM_given_X=839.338, hM_given_Y_upper=846.254
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.527, MI(Y;M)=3.072, h_upper=5.121, hM_given_X=2.676, hM_given_Y_upper=2.991
# Doing activations/epoch00000007
# - Layer 0 upper: MI(X;M)=13.215, MI(Y;M)=3.319, h_upper=1687.835, hM_given_X=1678.676, hM_given_Y_upper=1685.535
# - Layer 1 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=848.547, hM_given_X=839.338, hM_given_Y_upper=846.246
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.517, MI(Y;M)=3.099, h_upper=5.115, hM_given_X=2.676, hM_given_Y_upper=2.966
# Doing activations/epoch00000008
# - Layer 0 upper: MI(X;M)=13.229, MI(Y;M)=3.319, h_upper=1687.845, hM_given_X=1678.676, hM_given_Y_upper=1685.545
# - Layer 1 upper: MI(X;M)=13.268, MI(Y;M)=3.319, h_upper=848.535, hM_given_X=839.338, hM_given_Y_upper=846.234
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.515, MI(Y;M)=3.110, h_upper=5.113, hM_given_X=2.676, hM_given_Y_upper=2.957
# Doing activations/epoch00000009
# - Layer 0 upper: MI(X;M)=13.293, MI(Y;M)=3.320, h_upper=1687.890, hM_given_X=1678.676, hM_given_Y_upper=1685.589
# - Layer 1 upper: MI(X;M)=13.268, MI(Y;M)=3.319, h_upper=848.535, hM_given_X=839.338, hM_given_Y_upper=846.234
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.499, MI(Y;M)=3.123, h_upper=5.102, hM_given_X=2.676, hM_given_Y_upper=2.937
# Doing activations/epoch00000010
# - Layer 0 upper: MI(X;M)=13.306, MI(Y;M)=3.319, h_upper=1687.899, hM_given_X=1678.676, hM_given_Y_upper=1685.598
# - Layer 1 upper: MI(X;M)=13.266, MI(Y;M)=3.319, h_upper=848.533, hM_given_X=839.338, hM_given_Y_upper=846.232
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.474, MI(Y;M)=3.136, h_upper=5.084, hM_given_X=2.676, hM_given_Y_upper=2.910
# Doing activations/epoch00000011
# - Layer 0 upper: MI(X;M)=13.253, MI(Y;M)=3.319, h_upper=1687.862, hM_given_X=1678.676, hM_given_Y_upper=1685.562
# - Layer 1 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=848.548, hM_given_X=839.338, hM_given_Y_upper=846.247
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.476, MI(Y;M)=3.145, h_upper=5.086, hM_given_X=2.676, hM_given_Y_upper=2.906
# Doing activations/epoch00000012
# - Layer 0 upper: MI(X;M)=13.299, MI(Y;M)=3.320, h_upper=1687.894, hM_given_X=1678.676, hM_given_Y_upper=1685.593
# - Layer 1 upper: MI(X;M)=13.300, MI(Y;M)=3.319, h_upper=848.557, hM_given_X=839.338, hM_given_Y_upper=846.256
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.466, MI(Y;M)=3.150, h_upper=5.079, hM_given_X=2.676, hM_given_Y_upper=2.895
# Doing activations/epoch00000013
# - Layer 0 upper: MI(X;M)=13.318, MI(Y;M)=3.320, h_upper=1687.907, hM_given_X=1678.676, hM_given_Y_upper=1685.606
# - Layer 1 upper: MI(X;M)=13.257, MI(Y;M)=3.319, h_upper=848.527, hM_given_X=839.338, hM_given_Y_upper=846.226
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.456, MI(Y;M)=3.164, h_upper=5.072, hM_given_X=2.676, hM_given_Y_upper=2.879
# Doing activations/epoch00000014
# - Layer 0 upper: MI(X;M)=13.278, MI(Y;M)=3.319, h_upper=1687.879, hM_given_X=1678.676, hM_given_Y_upper=1685.579
# - Layer 1 upper: MI(X;M)=13.275, MI(Y;M)=3.319, h_upper=848.539, hM_given_X=839.338, hM_given_Y_upper=846.238
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.453, MI(Y;M)=3.169, h_upper=5.070, hM_given_X=2.676, hM_given_Y_upper=2.873
# Doing activations/epoch00000015
# - Layer 0 upper: MI(X;M)=13.259, MI(Y;M)=3.319, h_upper=1687.866, hM_given_X=1678.676, hM_given_Y_upper=1685.565
# - Layer 1 upper: MI(X;M)=13.298, MI(Y;M)=3.319, h_upper=848.556, hM_given_X=839.338, hM_given_Y_upper=846.255
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.455, MI(Y;M)=3.160, h_upper=5.071, hM_given_X=2.676, hM_given_Y_upper=2.881
# Doing activations/epoch00000016
# - Layer 0 upper: MI(X;M)=13.311, MI(Y;M)=3.320, h_upper=1687.902, hM_given_X=1678.676, hM_given_Y_upper=1685.601
# - Layer 1 upper: MI(X;M)=13.279, MI(Y;M)=3.319, h_upper=848.542, hM_given_X=839.338, hM_given_Y_upper=846.241
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.450, MI(Y;M)=3.173, h_upper=5.068, hM_given_X=2.676, hM_given_Y_upper=2.869
# Doing activations/epoch00000017
# - Layer 0 upper: MI(X;M)=13.293, MI(Y;M)=3.320, h_upper=1687.890, hM_given_X=1678.676, hM_given_Y_upper=1685.589
# - Layer 1 upper: MI(X;M)=13.313, MI(Y;M)=3.320, h_upper=848.566, hM_given_X=839.338, hM_given_Y_upper=846.265
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.445, MI(Y;M)=3.178, h_upper=5.064, hM_given_X=2.676, hM_given_Y_upper=2.861
# Doing activations/epoch00000018
# - Layer 0 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=1687.885, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 1 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=848.546, hM_given_X=839.338, hM_given_Y_upper=846.245
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.434, MI(Y;M)=3.187, h_upper=5.057, hM_given_X=2.676, hM_given_Y_upper=2.848
# Doing activations/epoch00000019
# - Layer 0 upper: MI(X;M)=13.311, MI(Y;M)=3.320, h_upper=1687.902, hM_given_X=1678.676, hM_given_Y_upper=1685.601
# - Layer 1 upper: MI(X;M)=13.295, MI(Y;M)=3.319, h_upper=848.553, hM_given_X=839.338, hM_given_Y_upper=846.252
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.431, MI(Y;M)=3.192, h_upper=5.054, hM_given_X=2.676, hM_given_Y_upper=2.842
# Doing activations/epoch00000020
# - Layer 0 upper: MI(X;M)=13.273, MI(Y;M)=3.320, h_upper=1687.876, hM_given_X=1678.676, hM_given_Y_upper=1685.575
# - Layer 1 upper: MI(X;M)=13.254, MI(Y;M)=3.319, h_upper=848.525, hM_given_X=839.338, hM_given_Y_upper=846.224
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.427, MI(Y;M)=3.181, h_upper=5.052, hM_given_X=2.676, hM_given_Y_upper=2.847
# Doing activations/epoch00000025
# - Layer 0 upper: MI(X;M)=13.294, MI(Y;M)=3.319, h_upper=1687.890, hM_given_X=1678.676, hM_given_Y_upper=1685.590
# - Layer 1 upper: MI(X;M)=13.314, MI(Y;M)=3.319, h_upper=848.566, hM_given_X=839.338, hM_given_Y_upper=846.266
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.413, MI(Y;M)=3.203, h_upper=5.042, hM_given_X=2.676, hM_given_Y_upper=2.822
# Doing activations/epoch00000030
# - Layer 0 upper: MI(X;M)=13.328, MI(Y;M)=3.320, h_upper=1687.914, hM_given_X=1678.676, hM_given_Y_upper=1685.613
# - Layer 1 upper: MI(X;M)=13.290, MI(Y;M)=3.319, h_upper=848.549, hM_given_X=839.338, hM_given_Y_upper=846.249
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.406, MI(Y;M)=3.209, h_upper=5.037, hM_given_X=2.676, hM_given_Y_upper=2.813
# Doing activations/epoch00000035
# - Layer 0 upper: MI(X;M)=13.327, MI(Y;M)=3.320, h_upper=1687.913, hM_given_X=1678.676, hM_given_Y_upper=1685.612
# - Layer 1 upper: MI(X;M)=13.297, MI(Y;M)=3.320, h_upper=848.554, hM_given_X=839.338, hM_given_Y_upper=846.253
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.402, MI(Y;M)=3.218, h_upper=5.034, hM_given_X=2.676, hM_given_Y_upper=2.803
# Doing activations/epoch00000040
# - Layer 0 upper: MI(X;M)=13.295, MI(Y;M)=3.319, h_upper=1687.891, hM_given_X=1678.676, hM_given_Y_upper=1685.590
# - Layer 1 upper: MI(X;M)=13.317, MI(Y;M)=3.319, h_upper=848.568, hM_given_X=839.338, hM_given_Y_upper=846.267
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.397, MI(Y;M)=3.224, h_upper=5.031, hM_given_X=2.676, hM_given_Y_upper=2.797
# Doing activations/epoch00000045
# - Layer 0 upper: MI(X;M)=13.232, MI(Y;M)=3.319, h_upper=1687.848, hM_given_X=1678.676, hM_given_Y_upper=1685.547
# - Layer 1 upper: MI(X;M)=13.298, MI(Y;M)=3.319, h_upper=848.555, hM_given_X=839.338, hM_given_Y_upper=846.255
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.391, MI(Y;M)=3.230, h_upper=5.027, hM_given_X=2.676, hM_given_Y_upper=2.788
# Doing activations/epoch00000050
# - Layer 0 upper: MI(X;M)=13.230, MI(Y;M)=3.319, h_upper=1687.846, hM_given_X=1678.676, hM_given_Y_upper=1685.545
# - Layer 1 upper: MI(X;M)=13.275, MI(Y;M)=3.319, h_upper=848.539, hM_given_X=839.338, hM_given_Y_upper=846.239
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.396, MI(Y;M)=3.220, h_upper=5.030, hM_given_X=2.676, hM_given_Y_upper=2.798
# Doing activations/epoch00000055
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=1687.886, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 1 upper: MI(X;M)=13.274, MI(Y;M)=3.319, h_upper=848.539, hM_given_X=839.338, hM_given_Y_upper=846.238
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.395, MI(Y;M)=3.218, h_upper=5.029, hM_given_X=2.676, hM_given_Y_upper=2.799
# Doing activations/epoch00000060
# - Layer 0 upper: MI(X;M)=13.358, MI(Y;M)=3.320, h_upper=1687.935, hM_given_X=1678.676, hM_given_Y_upper=1685.634
# - Layer 1 upper: MI(X;M)=13.257, MI(Y;M)=3.319, h_upper=848.527, hM_given_X=839.338, hM_given_Y_upper=846.226
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.383, MI(Y;M)=3.225, h_upper=5.021, hM_given_X=2.676, hM_given_Y_upper=2.786
# Doing activations/epoch00000065
# - Layer 0 upper: MI(X;M)=13.322, MI(Y;M)=3.320, h_upper=1687.910, hM_given_X=1678.676, hM_given_Y_upper=1685.609
# - Layer 1 upper: MI(X;M)=13.290, MI(Y;M)=3.320, h_upper=848.549, hM_given_X=839.338, hM_given_Y_upper=846.249
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.378, MI(Y;M)=3.232, h_upper=5.018, hM_given_X=2.676, hM_given_Y_upper=2.778
# Doing activations/epoch00000070
# - Layer 0 upper: MI(X;M)=13.252, MI(Y;M)=3.319, h_upper=1687.861, hM_given_X=1678.676, hM_given_Y_upper=1685.561
# - Layer 1 upper: MI(X;M)=13.301, MI(Y;M)=3.319, h_upper=848.557, hM_given_X=839.338, hM_given_Y_upper=846.257
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.380, MI(Y;M)=3.232, h_upper=5.019, hM_given_X=2.676, hM_given_Y_upper=2.779
# Doing activations/epoch00000075
# - Layer 0 upper: MI(X;M)=13.245, MI(Y;M)=3.319, h_upper=1687.856, hM_given_X=1678.676, hM_given_Y_upper=1685.556
# - Layer 1 upper: MI(X;M)=13.289, MI(Y;M)=3.319, h_upper=848.549, hM_given_X=839.338, hM_given_Y_upper=846.248
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.374, MI(Y;M)=3.228, h_upper=5.015, hM_given_X=2.676, hM_given_Y_upper=2.778
# Doing activations/epoch00000080
# - Layer 0 upper: MI(X;M)=13.276, MI(Y;M)=3.319, h_upper=1687.878, hM_given_X=1678.676, hM_given_Y_upper=1685.577
# - Layer 1 upper: MI(X;M)=13.281, MI(Y;M)=3.319, h_upper=848.543, hM_given_X=839.338, hM_given_Y_upper=846.243
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.375, MI(Y;M)=3.233, h_upper=5.016, hM_given_X=2.676, hM_given_Y_upper=2.775
# Doing activations/epoch00000085
# - Layer 0 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=1687.885, hM_given_X=1678.676, hM_given_Y_upper=1685.584
# - Layer 1 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=848.548, hM_given_X=839.338, hM_given_Y_upper=846.248
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.379, MI(Y;M)=3.229, h_upper=5.018, hM_given_X=2.676, hM_given_Y_upper=2.780
# Doing activations/epoch00000090
# - Layer 0 upper: MI(X;M)=13.313, MI(Y;M)=3.319, h_upper=1687.904, hM_given_X=1678.676, hM_given_Y_upper=1685.603
# - Layer 1 upper: MI(X;M)=13.320, MI(Y;M)=3.320, h_upper=848.571, hM_given_X=839.338, hM_given_Y_upper=846.270
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.372, MI(Y;M)=3.226, h_upper=5.014, hM_given_X=2.676, hM_given_Y_upper=2.778
# Doing activations/epoch00000095
# - Layer 0 upper: MI(X;M)=13.263, MI(Y;M)=3.319, h_upper=1687.869, hM_given_X=1678.676, hM_given_Y_upper=1685.568
# - Layer 1 upper: MI(X;M)=13.294, MI(Y;M)=3.320, h_upper=848.552, hM_given_X=839.338, hM_given_Y_upper=846.251
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 3 upper: MI(X;M)=3.379, MI(Y;M)=3.227, h_upper=5.018, hM_given_X=2.676, hM_given_Y_upper=2.782

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import torch
import scienceplots
plt.rcParams['font.serif'] = ['Times New Roman']
mpl.rcParams['figure.dpi'] = 800
mpl.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
plt.style.use(['science', 'ieee'])
mpl.rcParams.update({'font.size': 15})

def plot_information_plane(IXT_array, ITY_array, num_epochs, every_n_early=1, every_n_late=5):
    assert len(IXT_array) == len(ITY_array)

    max_index = len(IXT_array)

    fig, ax = plt.subplots(figsize=(5, 3.5))
    ax.set_xlabel('$I(X;T)$', fontsize=15)
    ax.set_ylabel('$I(T;Y)$', fontsize=15)

    cmap = plt.get_cmap('gnuplot')
    colors = [cmap(i) for i in np.linspace(0, 1, num_epochs + 1)]

    for i in range(0, max_index):
        IXT = IXT_array[i, :]
        ITY = ITY_array[i, :]
        
        # 根据 epoch 的范围调整 every_n
        if i < 20:
            color_idx = i * every_n_early
        else:
            color_idx = 20 * every_n_early + (i - 20) * every_n_late

        ax.plot(IXT, ITY, marker='o', markersize=3, markeredgewidth=0.04,
                linestyle='-', linewidth=0.5, color=colors[color_idx], zorder=10)

    sm = plt.cm.ScalarMappable(cmap=cmap, norm=plt.Normalize(vmin=0, vmax=1))
    sm._A = []

    # 使用ax参数指定颜色条位置
    cbar = plt.colorbar(sm, ax=ax, ticks=[])
    cbar.set_label('epoch number', fontsize=15)
    cbar.ax.tick_params(labelsize=15)
    cbar.ax.text(0.5, -0.01, 0, transform=cbar.ax.transAxes, va='top', ha='center')
    cbar.ax.text(0.5, 1.0, str(num_epochs), transform=cbar.ax.transAxes, va='bottom', ha='center')

    ax.set_xticks([0, 2, 4, 6, 8, 10, 12, 14])
    ax.set_yticks([0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5])
    ax.set_ylim(0, 3.5)  # 修改y轴坐标范围
    # Adjust coordinates of text according to the plot area
    ax.text(-0.2, 0.98, '(d)', fontdict={'size': 15, 'color': 'black'}, transform=ax.transAxes)

    fig.savefig('D:/深度学习与信息论/Fig8d.eps', dpi=800)
    plt.show()

IXT_array = np.load('D:/深度学习与信息论/MI_XM_upper_arrayG.npy')
ITY_array = np.load('D:/深度学习与信息论/MI_YM_upper_arrayG.npy')


plot_information_plane(IXT_array, ITY_array, num_epochs=100, every_n_early=1, every_n_late=5)

# %%
IXT_array
# Out:
# array([[13.28668071, 13.28736312,  9.81877205,  0.23291427],
#        [13.29583845, 13.29035699, 13.2871159 ,  3.65951488],
#        [13.29125958, 13.28357675, 13.28760777,  3.6464692 ],
#        [13.31538668, 13.28243203, 13.2876862 ,  3.60764816],
#        [13.27699465, 13.28613035, 13.28771165,  3.57897255],
#        [13.31732389, 13.27996649, 13.28771165,  3.56951533],
#        [13.27382467, 13.29660891, 13.28772954,  3.52650221],
#        [13.21482774, 13.28542591, 13.28769583,  3.5174449 ],
#        [13.22926878, 13.26843127, 13.28771165,  3.5150843 ],
#        [13.29284457, 13.26834321, 13.28768551,  3.49897656],
#        [13.30587673, 13.26552545, 13.28770271,  3.4737421 ],
#        [13.25339588, 13.28780339, 13.28772266,  3.47580078],
#        [13.29865621, 13.29986694, 13.28771372,  3.46612058],
#        [13.31802834, 13.25733632, 13.28772059,  3.45598486],
#        [13.27822742, 13.27468318, 13.28770684,  3.45275999],
#        [13.25903141, 13.29845806, 13.28772472,  3.45515295],
#        [13.31063171, 13.27855761, 13.28770271,  3.4503514 ],
#        [13.29302068, 13.31281105, 13.28773848,  3.4445332 ],
#        [13.28668071, 13.28489757, 13.28773435,  3.43446725],
#        [13.31098393, 13.29493586, 13.28769308,  3.43069068],
#        [13.27276801, 13.25363801, 13.28770821,  3.4268673 ],
#        [13.29407734, 13.31386771, 13.28771647,  3.41324053],
#        [13.32806662, 13.28965255, 13.28770202,  3.40606597],
#        [13.32700996, 13.29660891, 13.28771716,  3.40161534],
#        [13.29460567, 13.31677353, 13.28769308,  3.39740317],
#        [13.23243876, 13.29810584, 13.28773023,  3.39107542],
#        [13.22997322, 13.27512346, 13.28771784,  3.3955749 ],
#        [13.28773738, 13.27380263, 13.28772954,  3.39470888],
#        [13.35782925, 13.25689605, 13.28775568,  3.38286238],
#        [13.32243109, 13.28965255, 13.28770133,  3.37775208],
#        [13.25233922, 13.30101166, 13.28775981,  3.37952314],
#        [13.2451187 , 13.28903617, 13.28766762,  3.37412883],
#        [13.27593799, 13.28067093, 13.28776737,  3.37475952],
#        [13.28580016, 13.2879795 , 13.28771372,  3.37855478],
#        [13.31327336, 13.32047184, 13.28772059,  3.3722597 ],
#        [13.26255361, 13.29361503, 13.28771234,  3.37875378]])

# %%
ITY_array
# Out:
# array([[3.31931506, 3.31938376, 2.83141352, 0.15052917],
#        [3.31949128, 3.31937378, 3.31942154, 2.73117769],
#        [3.31952287, 3.31927701, 3.31942283, 2.88394448],
#        [3.31953434, 3.31926868, 3.31941908, 2.97074701],
#        [3.3192116 , 3.31936042, 3.31941924, 3.01105854],
#        [3.31931452, 3.31929499, 3.3194203 , 2.99688145],
#        [3.3192306 , 3.31936809, 3.31942226, 3.07217845],
#        [3.31906816, 3.31930101, 3.31941882, 3.09947878],
#        [3.31923109, 3.31909556, 3.31942395, 3.10967969],
#        [3.31962123, 3.31917154, 3.31942316, 3.12325809],
#        [3.31944366, 3.31928312, 3.31942137, 3.13632393],
#        [3.31913902, 3.31939333, 3.31941894, 3.14487356],
#        [3.31953788, 3.31936502, 3.31942176, 3.15047129],
#        [3.31953677, 3.31907505, 3.3194227 , 3.16421588],
#        [3.3194277 , 3.31929664, 3.31942188, 3.16946874],
#        [3.31918768, 3.31941368, 3.31942377, 3.15972872],
#        [3.31958178, 3.31933743, 3.31941905, 3.17250107],
#        [3.31954677, 3.31967488, 3.31942078, 3.17790709],
#        [3.31926704, 3.3194874 , 3.31942215, 3.18748965],
#        [3.31956887, 3.31940358, 3.31942136, 3.19243877],
#        [3.3195486 , 3.31915467, 3.31942446, 3.18103391],
#        [3.31945745, 3.31930315, 3.31942234, 3.2027139 ],
#        [3.31951782, 3.31924368, 3.31941864, 3.20946142],
#        [3.31964328, 3.31959766, 3.31942395, 3.21842534],
#        [3.31944653, 3.31945232, 3.31942329, 3.22390131],
#        [3.31905747, 3.31942057, 3.31942508, 3.2299924 ],
#        [3.31914461, 3.31937963, 3.31942401, 3.2196183 ],
#        [3.31941095, 3.31911741, 3.31942072, 3.21833268],
#        [3.31967523, 3.31907588, 3.31942469, 3.22517173],
#        [3.31972484, 3.31954401, 3.31942084, 3.23175835],
#        [3.31944396, 3.31944406, 3.31942445, 3.23172058],
#        [3.31948069, 3.31934431, 3.31942518, 3.22761872],
#        [3.31932339, 3.31930438, 3.31942078, 3.23253785],
#        [3.31931286, 3.31935498, 3.31942481, 3.22910896],
#        [3.31941756, 3.31967766, 3.3194215 , 3.22556223],
#        [3.31933421, 3.31960159, 3.31941705, 3.22672439]])

# %%
accuracyReLU = np.array([
    72.36, 89.99, 91.67, 93.26, 94.19, 94.78, 95.20, 95.76, 96.26, 96.47, 
    96.71, 96.67, 97.11, 97.11, 97.27, 97.28, 97.38, 97.62, 97.56, 97.71, 
    97.83, 97.87, 97.90, 97.85, 98.04, 97.92, 97.96, 98.03, 98.08, 98.07, 
    98.13, 98.18, 98.06, 98.09, 98.12, 98.16, 98.29, 98.05, 98.26, 98.24, 
    98.26, 98.32, 98.17, 98.38, 98.24, 98.06, 98.35, 98.30, 98.22, 98.15, 
    98.28, 98.12, 98.22, 98.32, 98.19, 98.43, 98.23, 98.39, 98.13, 98.36, 
    98.49, 98.43, 98.28, 98.49, 98.30, 98.44, 98.47, 98.40, 98.45, 98.31, 
    98.44, 98.33, 98.36, 98.41, 98.41, 98.28, 98.51, 98.49, 98.36, 98.34, 
    98.36, 98.29, 98.44, 98.37, 98.40, 98.44, 98.44, 98.46, 98.49, 98.46, 
    98.31, 98.45, 98.46, 98.46, 98.42, 98.48, 98.45, 98.42, 98.46, 98.44])

accuracyS= np.array([
    40.06, 88.24, 88.84, 92.11, 93.47, 94.44, 95.15, 95.27, 96.05,
    96.50, 96.69, 96.75, 96.95, 97.16, 97.34, 97.34, 97.63, 97.55, 97.76,
    97.80, 97.98, 98.09, 98.13, 98.03, 98.05, 98.18, 98.18, 98.09, 98.13,
    98.15, 98.31, 98.18, 98.19, 98.36, 98.46, 98.44, 98.46, 98.06, 98.53,
    98.47, 98.48, 98.49, 98.50, 98.52, 98.43, 98.43, 98.43, 98.55, 98.52,
    98.40, 98.53, 98.61, 98.63, 98.49, 98.58, 98.66, 98.56, 98.62, 98.51,
    98.52, 98.63, 98.47, 98.55, 98.54, 98.52, 98.54, 98.75, 98.57, 98.55,
    98.53, 98.64, 98.62, 98.66, 98.67, 98.69, 98.50, 98.58, 98.57, 98.63,
    98.77, 98.74, 98.62, 98.66, 98.67, 98.72, 98.68, 98.70, 98.69, 98.75,
    98.56, 98.66, 98.68, 98.50, 98.48, 98.65, 98.63, 98.53, 98.72, 98.60,
    98.74
])


accuracyG = np.array([
    52.65, 88.99, 92.00, 93.86, 94.48, 94.12, 95.88, 96.33, 96.21,
    96.68, 96.97, 97.13, 97.26, 97.54, 97.61, 97.51, 97.63, 97.70, 97.91,
    98.02, 97.87, 97.77, 98.10, 97.99, 98.19, 98.23, 98.30, 98.25, 98.06,
    98.39, 98.29, 98.37, 98.23, 98.47, 98.33, 98.47, 98.51, 98.47, 98.45,
    98.48, 98.58, 98.54, 98.41, 98.49, 98.64, 98.66, 98.69, 98.52, 98.66,
    98.60, 98.51, 98.44, 98.64, 98.74, 98.57, 98.45, 98.71, 98.54, 98.75,
    98.63, 98.68, 98.71, 98.63, 98.77, 98.70, 98.73, 98.68, 98.47, 98.76,
    98.81, 98.75, 98.74, 98.71, 98.72, 98.74, 98.74, 98.68, 98.71, 98.68,
    98.71, 98.77, 98.74, 98.78, 98.76, 98.85, 98.72, 98.85, 98.78, 98.79,
    98.80, 98.66, 98.65, 98.74, 98.64, 98.86, 98.64, 98.76, 98.83, 98.82,
    98.81
])


import matplotlib.pyplot as plt
import matplotlib as mpl
import scienceplots

plt.rcParams['font.serif'] = ['Times New Roman']
mpl.rcParams['figure.dpi'] = 800
mpl.rcParams['axes.unicode_minus'] = False

plt.rcParams['text.usetex'] = True
plt.rcParams['text.latex.preamble'] = r'\usepackage{amsmath, amssymb}'
plt.style.use(['science','ieee'])

fig, ax = plt.subplots(figsize=(5, 4))
plt.cla()
plt.tick_params(labelsize=15)
ax.set_xlabel('epoch number', fontsize=15)
ax.set_ylabel(r"Test accuracy", fontsize=15, labelpad=1)
ax.set_xlim(-5, len(accuracyReLU)+2)  # Adjust x-axis limits to start from epoch 1
ax.set_ylim(0.6, 1)

# Create the x-axis array to represent epoch numbers
epochs = np.arange(1, len(accuracyReLU) + 1)

# Plot the accuracy curves
ax.plot(epochs, 0.01*accuracyReLU, 'g--', lw=1, label=r"ReLU")
ax.plot(epochs, 0.01*accuracyS, 'b:', lw=1, label=r"SiLU")
ax.plot(epochs, 0.01*accuracyG, 'r-', lw=0.5, label=r"GELU")

ax.text(-21, 0.99, '(a)', fontdict={'size': 15, 'color': 'black'})
ax.legend(loc='upper right', fontsize=15)

patch = mpl.patches.Rectangle((0.980,85),0.022,15,linewidth=1,linestyle='--',edgecolor='gray',facecolor='none')
ax.add_patch(patch)
left, bottom, width, height = [0.3, 0.2, 0.57, 0.3]
ax2 = fig.add_axes([left, bottom, width, height])

step = np.arange(1,101)

ax2.plot(step[85:], 0.01*accuracyReLU[85:], 'g--')
ax2.plot(step[85:], 0.01*accuracyS[85:], 'b:')
ax2.plot(step[85:], 0.01*accuracyG[85:], 'r-')
ax2.set_yticks([0.982,0.984,0.986,0.988])

plt.show()

fig.savefig('D:/深度学习与信息论/Fig8a.eps', dpi=800)
