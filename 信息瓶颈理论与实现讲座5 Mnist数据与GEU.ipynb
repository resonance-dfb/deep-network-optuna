# %%
##############################################################
##https://github.com/shalomma/PytorchBottleneck/tree/master###
##############################################################
##激活函数的全连接网络7层 784*1024*1024*20*20*20*10
##改成简单的定参数，很明显地将tanh的（4.1698，3.295）
import torch
import torch.nn as nn
# Define custom activation function
class CustomActivation(nn.Module):
    def __init__(self):
        super(CustomActivation, self).__init__()
        #self.sigma = nn.Parameter(torch.randn(1))

    def forward(self, input):
        x = torch.erf(input/0.5)
        return x

class FeedForward(nn.Module):
    def __init__(self, input_size, hidden_sizes, output_size):
        super(FeedForward, self).__init__()
        torch.manual_seed(1234)
        self.hidden_sizes = hidden_sizes
        self.layers = torch.nn.ModuleList()
        hidden_sizes += [output_size]
        self.n_layers = len(hidden_sizes)
        self.custom = CustomActivation()
        prev = input_size
        for h in hidden_sizes:
            self.layers.append(torch.nn.Linear(prev, h))
            prev = h

    def forward(self, x):
        hiddens = []
        for j, layer in enumerate(self.layers):
            if j != (self.n_layers - 1):
                x = self.custom(layer(x))
                hiddens.append(x)
            else:
                x = layer(x)
                hiddens.append(x)
        return x, hiddens

# %%
import torch
from torch.utils import data
from torchvision import datasets
import scipy.io as sio

##########################################################################
class MNIST(datasets.MNIST):
    def __init__(self, root, train=True, download=False, randomize=False):
        super(MNIST, self).__init__(root, train, download)

        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.targets = self.targets.to(device)
        self.data = self.data / 255.0
        self.data = self.data.view(-1, 28 * 28).to(device)

        if randomize:
            idx_rnd = torch.randperm(len(self.targets))
            self.targets = self.targets[idx_rnd]

    def __getitem__(self, index):
        img, targets = self.data[index], self.targets[index]
        return img, targets
######################################################################

class IBDataset(data.Dataset):
    def __init__(self, train=True, ratio=0.8):
        super(IBDataset, self).__init__()
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        data_, targets_ = self.load_data(train, ratio)

        self.targets = targets_.to(device)
        self.target = targets_.to(device)
        self.data = data_.to(device)

    @staticmethod
    def load_data(train, ratio):
        d = sio.loadmat('D:/深度学习与信息论/PytorchBottleneck-master\dataset/var_u.mat')
        x = d['F']
        y = d['y'][0]

        r = ratio if train else (1 - ratio)
        n = int(r * len(x))
        if train:
            x = x[:n, :]
            y = y[:n]
        else:
            x = x[-n:, :]
            y = y[-n:]
        return torch.tensor(x, dtype=torch.float), torch.tensor(y, dtype=torch.long)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        sample, target = self.data[index], self.target[index]
        return sample, target

# %%
import numpy as np
import torch
from torch.utils.data import DataLoader
from random import seed

from dataset import MNIST

# %%
import numpy as np


def get_unique_probs(x):
    uniqueids = np.ascontiguousarray(x).view(np.dtype((np.void, x.dtype.itemsize * x.shape[1])))
    _, unique_inverse, unique_counts = np.unique(uniqueids, return_index=False, return_inverse=True, return_counts=True)
    return np.asarray(unique_counts / float(sum(unique_counts))), unique_inverse


def bin_calc_information(labelixs, layerdata, binsize):
    # This is even further simplified, where we use np.floor instead of digitize
    nats2bits = 1.0 / np.log(2)

    def get_h(d):
        digitized = np.floor(d / binsize).astype('int')
        p_ts, _ = get_unique_probs( digitized )
        return -np.sum(p_ts * np.log(p_ts))

    H_LAYER = get_h(layerdata)
    H_LAYER_GIVEN_OUTPUT = 0
    for label, ixs in labelixs.items():
        h = get_h(layerdata[ixs])
        H_LAYER_GIVEN_OUTPUT += ixs.mean() * h
    return nats2bits * H_LAYER, nats2bits * (H_LAYER - H_LAYER_GIVEN_OUTPUT)

# %%
import pickle
class TrainConfig:
    def __init__(self, model, criterion, optimizer, scheduler=None):
        self.model = model
        self.criterion = criterion
        self.optimizer = optimizer
        self.scheduler = scheduler


class Train:
    def __init__(self, config):
        self.config = config
        self.epochs = 5000
        self.mi_cycle = 10
        self.n_layers = None
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        self.losses = dict()
        self.accuracy = dict()
        self.running_mis_xt = dict()
        self.running_mis_ty = dict()
        for phase in ['train', 'test']:
            self.losses[phase] = []
            self.accuracy[phase] = []
            self.running_mis_xt[phase] = []
            self.running_mis_ty[phase] = []

        self.n_classes = 10

    def get_class_masks(self, loader):
        samples_split = dict()
        for phase in ['train', 'test']:
            samples_split[phase] = {}
            classes = loader[phase].dataset.targets.cpu().detach().numpy()
            for i in range(self.n_classes):
                samples_split[phase][i] = classes == i
        return samples_split

    def run(self, loader):
        class_masks = self.get_class_masks(loader)
        self.n_layers = self.config.model.n_layers
        for i in range(self.epochs):
            to_print = ''
            for phase in ['train', 'test']:
                phase_loss = 0.0
                phase_labels = torch.tensor([], dtype=torch.long).to(self.device)
                phase_outputs = torch.tensor([]).to(self.device)

                for inputs, labels in loader[phase]:
                    inputs, labels = inputs, labels
                    if phase == 'train':
                        self.config.model.train()
                    else:
                        self.config.model.eval()

                    self.config.optimizer.zero_grad()
                    with torch.set_grad_enabled(phase == 'train'):
                        outputs, hiddens = self.config.model(inputs)
                        loss = self.config.criterion(outputs, labels)
                        if phase == 'train':
                            loss.backward()
                            self.config.optimizer.step()

                    phase_loss += loss.item()
                    phase_labels = torch.cat((phase_labels, labels))
                    phase_outputs = torch.cat((phase_outputs, outputs))

                if i % self.mi_cycle == 0:
                    running_mi_xt = []
                    running_mi_ty = []
                    _, hiddens = self.config.model(loader[phase].dataset.data)
                    for j in range(self.n_layers):
                        activity = hiddens[j].cpu().detach().numpy()
                        binxm, binym = bin_calc_information(class_masks[phase], activity, binsize=0.5)
                        running_mi_xt.append(binxm)
                        running_mi_ty.append(binym)

                    self.running_mis_xt[phase].append(running_mi_xt)
                    self.running_mis_ty[phase].append(running_mi_ty)

                n = float(len(loader[phase].dataset))
                loss = phase_loss / n
                acc = (phase_labels == phase_outputs.argmax(dim=1)).sum() / n
                self.accuracy[phase].append(float(acc))

                to_print += f'{phase}: loss {loss:>.4f} - acc {acc:>.4f} \t'
                self.losses[phase].append(loss)
                if phase == 'test':
                    if self.config.scheduler is not None:
                        self.config.scheduler.step(loss)
            print(f'Epoch {i:>4}: {to_print}')

    def dump(self):
        tracking = {
            'n_layers': self.n_layers,
            'mi_cycle': self.mi_cycle,
            'losses': self.losses,
            'accuracy': self.accuracy,
            'running_mis_xt': self.running_mis_xt,
            'running_mis_ty': self.running_mis_ty,
        }
        with open('train.pkl', 'wb') as f:
            pickle.dump(tracking, f)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib as mpl
#import scienceplots
class Plotter:
    def __init__(self, trainer):
        self.trainer = trainer

    def plot_losses(self):
        plt.figure()
        for phase in ['train', 'test']:
            plt.plot(self.trainer.losses[phase], label=phase)
        plt.legend()
        plt.savefig('losses.png')
        plt.show()

    def plot_accuracy(self):
        plt.figure()
        for phase in ['train', 'test']:
            plt.plot(self.trainer.accuracy[phase], label=phase)
        plt.legend()
        plt.savefig('acc.png')
        plt.show()

    def format_epochs(self, x, pos):
        return int(x * self.trainer.mi_cycle)

    def plot_info_plan(self, phase):
        running_mis_xt = np.array(self.trainer.running_mis_xt[phase])
        running_mis_ty = np.array(self.trainer.running_mis_ty[phase])
        print("running_mis_xt:", running_mis_xt)
        print("running_mis_ty:", running_mis_ty)
        # plt.rcParams ['font.serif'] = ['Times New Roman']
        # mpl.rcParams['figure.dpi'] = 800
        # mpl.rcParams['axes.unicode_minus']=False  # #用来正常显示负号
        # plt.style.use(['science','ieee'])
        fig, ax = plt.subplots()
        plt.title(phase)
        for i in range(self.trainer.n_layers):
            plt.plot(running_mis_xt[:, i], label=f'{i}')
        plt.legend()
        ax.xaxis.set_major_formatter(ticker.FuncFormatter(self.format_epochs))
        plt.ylabel('I(X;T)')
        plt.savefig(f'plot_{phase}.png')
        plt.show()

        plt.figure()
        plt.title(f'IP - {phase}')
        c = list(range(len(running_mis_xt[:, 0])))
        for j in range(self.trainer.n_layers):
            plt.scatter(running_mis_xt[:, j], running_mis_ty[:, j], c=c, cmap='plasma', s=20, alpha=0.85, zorder=1)
        for j in range(len(running_mis_xt[:, 0])):
            plt.plot(running_mis_xt[j, :], running_mis_ty[j, :], alpha=0.1, zorder=0)

        cbar = plt.colorbar(format=ticker.FuncFormatter(self.format_epochs))
        cbar.set_label('Epochs')

        plt.xlabel('I(X;T)')
        plt.ylabel('I(T;Y)')
        plt.savefig(f'IP_{phase}.png')
        plt.show()

# %%
np.random.seed(1234)
seed(1234)
torch.manual_seed(1234)

# %%
data = dict()
data['train'] = MNIST('./dataset', train=True, download=True, randomize=False)
data['test'] = MNIST('./dataset', train=False)

loader = dict()
loader['train'] = torch.utils.data.DataLoader(data['train'], batch_size=60000, shuffle=False)
loader['test'] = torch.utils.data.DataLoader(data['test'], batch_size=10000, shuffle=False)

# %%
# setup
input_size = 28 * 28
output_size = 10
hidden_sizes = [784, 1024, 1024, 20, 20, 20, 10]
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'to device: {device}')
net = FeedForward(input_size, hidden_sizes, output_size).to(device)
# Out:
# to device: cuda

# %%
criterion = torch.nn.CrossEntropyLoss(reduction='sum')
optimizer = torch.optim.Adam(net.parameters(), lr=0.001)

cfg = TrainConfig(net, criterion, optimizer)
train = Train(cfg)
train.epochs = 400
train.mi_cycle = 20
train.run(loader)
train.dump()
# Out:
# Epoch    0: train: loss 2.4133 - acc 0.0558 	test: loss 2.2097 - acc 0.1792
# Epoch    1: train: loss 2.2127 - acc 0.1771 	test: loss 2.1334 - acc 0.2179
# Epoch    2: train: loss 2.1420 - acc 0.2104 	test: loss 2.0840 - acc 0.2732
# Epoch    3: train: loss 2.0880 - acc 0.2743 	test: loss 1.9709 - acc 0.4220
# Epoch    4: train: loss 1.9783 - acc 0.4148 	test: loss 1.9747 - acc 0.4410
# Epoch    5: train: loss 1.9803 - acc 0.4361 	test: loss 1.9055 - acc 0.4542
# Epoch    6: train: loss 1.9092 - acc 0.4557 	test: loss 1.8743 - acc 0.4576
# Epoch    7: train: loss 1.8796 - acc 0.4477 	test: loss 1.8274 - acc 0.4925
# Epoch    8: train: loss 1.8334 - acc 0.4888 	test: loss 1.7965 - acc 0.5144
# Epoch    9: train: loss 1.8022 - acc 0.5162 	test: loss 1.7743 - acc 0.5373
# Epoch   10: train: loss 1.7811 - acc 0.5311 	test: loss 1.7467 - acc 0.5749
# Epoch   11: train: loss 1.7548 - acc 0.5664 	test: loss 1.7316 - acc 0.5791
# Epoch   12: train: loss 1.7395 - acc 0.5743 	test: loss 1.7150 - acc 0.5850
# Epoch   13: train: loss 1.7226 - acc 0.5821 	test: loss 1.6945 - acc 0.6034
# Epoch   14: train: loss 1.7012 - acc 0.5991 	test: loss 1.6771 - acc 0.6186
# Epoch   15: train: loss 1.6821 - acc 0.6179 	test: loss 1.6622 - acc 0.6557
# Epoch   16: train: loss 1.6663 - acc 0.6492 	test: loss 1.6438 - acc 0.6658
# Epoch   17: train: loss 1.6481 - acc 0.6607 	test: loss 1.6259 - acc 0.6732
# Epoch   18: train: loss 1.6299 - acc 0.6698 	test: loss 1.6106 - acc 0.6788
# Epoch   19: train: loss 1.6142 - acc 0.6754 	test: loss 1.5937 - acc 0.6868
# Epoch   20: train: loss 1.5968 - acc 0.6845 	test: loss 1.5768 - acc 0.6929
# Epoch   21: train: loss 1.5798 - acc 0.6914 	test: loss 1.5616 - acc 0.6986
# Epoch   22: train: loss 1.5647 - acc 0.6957 	test: loss 1.5473 - acc 0.7027
# Epoch   23: train: loss 1.5503 - acc 0.7003 	test: loss 1.5336 - acc 0.7063
# Epoch   24: train: loss 1.5359 - acc 0.7053 	test: loss 1.5201 - acc 0.7092
# Epoch   25: train: loss 1.5214 - acc 0.7089 	test: loss 1.5064 - acc 0.7141
# Epoch   26: train: loss 1.5067 - acc 0.7141 	test: loss 1.4925 - acc 0.7207
# Epoch   27: train: loss 1.4919 - acc 0.7220 	test: loss 1.4784 - acc 0.7359
# Epoch   28: train: loss 1.4775 - acc 0.7369 	test: loss 1.4641 - acc 0.7498
# Epoch   29: train: loss 1.4631 - acc 0.7496 	test: loss 1.4510 - acc 0.7601
# Epoch   30: train: loss 1.4498 - acc 0.7595 	test: loss 1.4382 - acc 0.7671
# Epoch   31: train: loss 1.4365 - acc 0.7671 	test: loss 1.4251 - acc 0.7758
# Epoch   32: train: loss 1.4228 - acc 0.7756 	test: loss 1.4125 - acc 0.7814
# Epoch   33: train: loss 1.4097 - acc 0.7828 	test: loss 1.4001 - acc 0.7846
# Epoch   34: train: loss 1.3968 - acc 0.7881 	test: loss 1.3876 - acc 0.7872
# Epoch   35: train: loss 1.3840 - acc 0.7914 	test: loss 1.3749 - acc 0.7900
# Epoch   36: train: loss 1.3714 - acc 0.7945 	test: loss 1.3627 - acc 0.7936
# Epoch   37: train: loss 1.3591 - acc 0.7977 	test: loss 1.3509 - acc 0.7954
# Epoch   38: train: loss 1.3469 - acc 0.8011 	test: loss 1.3394 - acc 0.7989
# Epoch   39: train: loss 1.3348 - acc 0.8043 	test: loss 1.3278 - acc 0.8020
# Epoch   40: train: loss 1.3227 - acc 0.8081 	test: loss 1.3165 - acc 0.8090
# Epoch   41: train: loss 1.3109 - acc 0.8143 	test: loss 1.3053 - acc 0.8611
# Epoch   42: train: loss 1.2993 - acc 0.8640 	test: loss 1.2943 - acc 0.9135
# Epoch   43: train: loss 1.2880 - acc 0.9186 	test: loss 1.2830 - acc 0.9168
# Epoch   44: train: loss 1.2765 - acc 0.9216 	test: loss 1.2721 - acc 0.9197
# Epoch   45: train: loss 1.2654 - acc 0.9248 	test: loss 1.2616 - acc 0.9223
# Epoch   46: train: loss 1.2545 - acc 0.9275 	test: loss 1.2512 - acc 0.9243
# Epoch   47: train: loss 1.2436 - acc 0.9296 	test: loss 1.2407 - acc 0.9267
# Epoch   48: train: loss 1.2328 - acc 0.9314 	test: loss 1.2302 - acc 0.9263
# Epoch   49: train: loss 1.2223 - acc 0.9329 	test: loss 1.2200 - acc 0.9281
# Epoch   50: train: loss 1.2118 - acc 0.9348 	test: loss 1.2102 - acc 0.9299
# Epoch   51: train: loss 1.2015 - acc 0.9365 	test: loss 1.2002 - acc 0.9318
# Epoch   52: train: loss 1.1915 - acc 0.9387 	test: loss 1.1905 - acc 0.9336
# Epoch   53: train: loss 1.1817 - acc 0.9400 	test: loss 1.1816 - acc 0.9349
# Epoch   54: train: loss 1.1728 - acc 0.9415 	test: loss 1.1762 - acc 0.9323
# Epoch   55: train: loss 1.1681 - acc 0.9377 	test: loss 1.1826 - acc 0.9263
# Epoch   56: train: loss 1.1746 - acc 0.9320 	test: loss 1.2295 - acc 0.8866
# Epoch   57: train: loss 1.2261 - acc 0.8876 	test: loss 1.1883 - acc 0.9158
# Epoch   58: train: loss 1.1806 - acc 0.9212 	test: loss 1.1640 - acc 0.9243
# Epoch   59: train: loss 1.1550 - acc 0.9312 	test: loss 1.1423 - acc 0.9310
# Epoch   60: train: loss 1.1353 - acc 0.9355 	test: loss 1.1558 - acc 0.9185
# Epoch   61: train: loss 1.1518 - acc 0.9215 	test: loss 1.1273 - acc 0.9328
# Epoch   62: train: loss 1.1197 - acc 0.9374 	test: loss 1.1205 - acc 0.9334
# Epoch   63: train: loss 1.1114 - acc 0.9388 	test: loss 1.1227 - acc 0.9298
# Epoch   64: train: loss 1.1142 - acc 0.9350 	test: loss 1.1059 - acc 0.9334
# Epoch   65: train: loss 1.0958 - acc 0.9404 	test: loss 1.0944 - acc 0.9342
# Epoch   66: train: loss 1.0835 - acc 0.9424 	test: loss 1.0912 - acc 0.9332
# Epoch   67: train: loss 1.0804 - acc 0.9409 	test: loss 1.0797 - acc 0.9360
# Epoch   68: train: loss 1.0690 - acc 0.9447 	test: loss 1.0674 - acc 0.9397
# Epoch   69: train: loss 1.0568 - acc 0.9477 	test: loss 1.0606 - acc 0.9426
# Epoch   70: train: loss 1.0510 - acc 0.9478 	test: loss 1.0535 - acc 0.9425
# Epoch   71: train: loss 1.0421 - acc 0.9490 	test: loss 1.0439 - acc 0.9416
# Epoch   72: train: loss 1.0313 - acc 0.9507 	test: loss 1.0353 - acc 0.9440
# Epoch   73: train: loss 1.0225 - acc 0.9520 	test: loss 1.0277 - acc 0.9431
# Epoch   74: train: loss 1.0153 - acc 0.9527 	test: loss 1.0170 - acc 0.9462
# Epoch   75: train: loss 1.0047 - acc 0.9547 	test: loss 1.0079 - acc 0.9482
# Epoch   76: train: loss 0.9956 - acc 0.9570 	test: loss 1.0010 - acc 0.9483
# Epoch   77: train: loss 0.9885 - acc 0.9574 	test: loss 0.9941 - acc 0.9488
# Epoch   78: train: loss 0.9802 - acc 0.9578 	test: loss 0.9847 - acc 0.9526
# Epoch   79: train: loss 0.9707 - acc 0.9603 	test: loss 0.9769 - acc 0.9518
# Epoch   80: train: loss 0.9632 - acc 0.9611 	test: loss 0.9689 - acc 0.9527
# Epoch   81: train: loss 0.9552 - acc 0.9615 	test: loss 0.9611 - acc 0.9537
# Epoch   82: train: loss 0.9462 - acc 0.9631 	test: loss 0.9541 - acc 0.9539
# Epoch   83: train: loss 0.9386 - acc 0.9636 	test: loss 0.9470 - acc 0.9551
# Epoch   84: train: loss 0.9311 - acc 0.9642 	test: loss 0.9387 - acc 0.9557
# Epoch   85: train: loss 0.9225 - acc 0.9656 	test: loss 0.9313 - acc 0.9561
# Epoch   86: train: loss 0.9152 - acc 0.9665 	test: loss 0.9243 - acc 0.9553
# Epoch   87: train: loss 0.9076 - acc 0.9666 	test: loss 0.9165 - acc 0.9572
# Epoch   88: train: loss 0.8992 - acc 0.9685 	test: loss 0.9100 - acc 0.9572
# Epoch   89: train: loss 0.8923 - acc 0.9689 	test: loss 0.9029 - acc 0.9577
# Epoch   90: train: loss 0.8848 - acc 0.9694 	test: loss 0.8946 - acc 0.9595
# Epoch   91: train: loss 0.8766 - acc 0.9709 	test: loss 0.8884 - acc 0.9594
# Epoch   92: train: loss 0.8701 - acc 0.9711 	test: loss 0.8811 - acc 0.9603
# Epoch   93: train: loss 0.8622 - acc 0.9724 	test: loss 0.8746 - acc 0.9605
# Epoch   94: train: loss 0.8550 - acc 0.9733 	test: loss 0.8685 - acc 0.9606
# Epoch   95: train: loss 0.8482 - acc 0.9738 	test: loss 0.8613 - acc 0.9612
# Epoch   96: train: loss 0.8404 - acc 0.9750 	test: loss 0.8550 - acc 0.9618
# Epoch   97: train: loss 0.8338 - acc 0.9752 	test: loss 0.8484 - acc 0.9624
# Epoch   98: train: loss 0.8267 - acc 0.9758 	test: loss 0.8425 - acc 0.9623
# Epoch   99: train: loss 0.8197 - acc 0.9766 	test: loss 0.8362 - acc 0.9622
# Epoch  100: train: loss 0.8131 - acc 0.9772 	test: loss 0.8312 - acc 0.9635
# Epoch  101: train: loss 0.8071 - acc 0.9773 	test: loss 0.8266 - acc 0.9621
# Epoch  102: train: loss 0.8048 - acc 0.9756 	test: loss 0.8631 - acc 0.9476
# Epoch  103: train: loss 0.8460 - acc 0.9552 	test: loss 0.9750 - acc 0.8964
# Epoch  104: train: loss 0.9609 - acc 0.9057 	test: loss 0.9311 - acc 0.9107
# Epoch  105: train: loss 0.9228 - acc 0.9141 	test: loss 0.8993 - acc 0.9276
# Epoch  106: train: loss 0.8884 - acc 0.9324 	test: loss 0.8743 - acc 0.9295
# Epoch  107: train: loss 0.8571 - acc 0.9391 	test: loss 0.8838 - acc 0.9185
# Epoch  108: train: loss 0.8693 - acc 0.9252 	test: loss 0.8481 - acc 0.9364
# Epoch  109: train: loss 0.8310 - acc 0.9448 	test: loss 0.8407 - acc 0.9367
# Epoch  110: train: loss 0.8263 - acc 0.9440 	test: loss 0.8381 - acc 0.9367
# Epoch  111: train: loss 0.8253 - acc 0.9424 	test: loss 0.8259 - acc 0.9431
# Epoch  112: train: loss 0.8104 - acc 0.9495 	test: loss 0.8154 - acc 0.9447
# Epoch  113: train: loss 0.7997 - acc 0.9522 	test: loss 0.8060 - acc 0.9453
# Epoch  114: train: loss 0.7910 - acc 0.9541 	test: loss 0.7993 - acc 0.9457
# Epoch  115: train: loss 0.7848 - acc 0.9528 	test: loss 0.7926 - acc 0.9468
# Epoch  116: train: loss 0.7773 - acc 0.9546 	test: loss 0.7794 - acc 0.9503
# Epoch  117: train: loss 0.7634 - acc 0.9593 	test: loss 0.7714 - acc 0.9524
# Epoch  118: train: loss 0.7543 - acc 0.9618 	test: loss 0.7665 - acc 0.9526
# Epoch  119: train: loss 0.7492 - acc 0.9617 	test: loss 0.7598 - acc 0.9545
# Epoch  120: train: loss 0.7431 - acc 0.9627 	test: loss 0.7520 - acc 0.9552
# Epoch  121: train: loss 0.7351 - acc 0.9646 	test: loss 0.7434 - acc 0.9580
# Epoch  122: train: loss 0.7255 - acc 0.9671 	test: loss 0.7381 - acc 0.9583
# Epoch  123: train: loss 0.7190 - acc 0.9678 	test: loss 0.7334 - acc 0.9582
# Epoch  124: train: loss 0.7134 - acc 0.9684 	test: loss 0.7272 - acc 0.9597
# Epoch  125: train: loss 0.7065 - acc 0.9696 	test: loss 0.7206 - acc 0.9600
# Epoch  126: train: loss 0.6995 - acc 0.9708 	test: loss 0.7140 - acc 0.9607
# Epoch  127: train: loss 0.6922 - acc 0.9716 	test: loss 0.7087 - acc 0.9609
# Epoch  128: train: loss 0.6864 - acc 0.9720 	test: loss 0.7031 - acc 0.9617
# Epoch  129: train: loss 0.6807 - acc 0.9725 	test: loss 0.6972 - acc 0.9618
# Epoch  130: train: loss 0.6742 - acc 0.9738 	test: loss 0.6916 - acc 0.9636
# Epoch  131: train: loss 0.6686 - acc 0.9748 	test: loss 0.6855 - acc 0.9643
# Epoch  132: train: loss 0.6624 - acc 0.9757 	test: loss 0.6800 - acc 0.9646
# Epoch  133: train: loss 0.6562 - acc 0.9765 	test: loss 0.6751 - acc 0.9650
# Epoch  134: train: loss 0.6503 - acc 0.9774 	test: loss 0.6706 - acc 0.9653
# Epoch  135: train: loss 0.6451 - acc 0.9782 	test: loss 0.6660 - acc 0.9653
# Epoch  136: train: loss 0.6398 - acc 0.9787 	test: loss 0.6608 - acc 0.9661
# Epoch  137: train: loss 0.6341 - acc 0.9795 	test: loss 0.6557 - acc 0.9666
# Epoch  138: train: loss 0.6285 - acc 0.9806 	test: loss 0.6512 - acc 0.9669
# Epoch  139: train: loss 0.6235 - acc 0.9812 	test: loss 0.6470 - acc 0.9674
# Epoch  140: train: loss 0.6188 - acc 0.9818 	test: loss 0.6428 - acc 0.9672
# Epoch  141: train: loss 0.6136 - acc 0.9821 	test: loss 0.6390 - acc 0.9671
# Epoch  142: train: loss 0.6085 - acc 0.9825 	test: loss 0.6354 - acc 0.9677
# Epoch  143: train: loss 0.6037 - acc 0.9829 	test: loss 0.6310 - acc 0.9680
# Epoch  144: train: loss 0.5990 - acc 0.9833 	test: loss 0.6261 - acc 0.9683
# Epoch  145: train: loss 0.5942 - acc 0.9837 	test: loss 0.6212 - acc 0.9686
# Epoch  146: train: loss 0.5896 - acc 0.9840 	test: loss 0.6165 - acc 0.9691
# Epoch  147: train: loss 0.5850 - acc 0.9847 	test: loss 0.6126 - acc 0.9694
# Epoch  148: train: loss 0.5805 - acc 0.9851 	test: loss 0.6092 - acc 0.9692
# Epoch  149: train: loss 0.5760 - acc 0.9855 	test: loss 0.6059 - acc 0.9694
# Epoch  150: train: loss 0.5716 - acc 0.9859 	test: loss 0.6026 - acc 0.9696
# Epoch  151: train: loss 0.5673 - acc 0.9863 	test: loss 0.5990 - acc 0.9695
# Epoch  152: train: loss 0.5630 - acc 0.9863 	test: loss 0.5952 - acc 0.9699
# Epoch  153: train: loss 0.5587 - acc 0.9866 	test: loss 0.5913 - acc 0.9701
# Epoch  154: train: loss 0.5545 - acc 0.9867 	test: loss 0.5874 - acc 0.9703
# Epoch  155: train: loss 0.5503 - acc 0.9871 	test: loss 0.5835 - acc 0.9705
# Epoch  156: train: loss 0.5462 - acc 0.9875 	test: loss 0.5798 - acc 0.9704
# Epoch  157: train: loss 0.5421 - acc 0.9876 	test: loss 0.5761 - acc 0.9710
# Epoch  158: train: loss 0.5381 - acc 0.9879 	test: loss 0.5725 - acc 0.9713
# Epoch  159: train: loss 0.5342 - acc 0.9882 	test: loss 0.5691 - acc 0.9713
# Epoch  160: train: loss 0.5303 - acc 0.9884 	test: loss 0.5657 - acc 0.9712
# Epoch  161: train: loss 0.5264 - acc 0.9886 	test: loss 0.5625 - acc 0.9714
# Epoch  162: train: loss 0.5225 - acc 0.9888 	test: loss 0.5592 - acc 0.9713
# Epoch  163: train: loss 0.5187 - acc 0.9890 	test: loss 0.5559 - acc 0.9711
# Epoch  164: train: loss 0.5150 - acc 0.9891 	test: loss 0.5526 - acc 0.9713
# Epoch  165: train: loss 0.5113 - acc 0.9892 	test: loss 0.5494 - acc 0.9717
# Epoch  166: train: loss 0.5076 - acc 0.9895 	test: loss 0.5461 - acc 0.9721
# Epoch  167: train: loss 0.5040 - acc 0.9898 	test: loss 0.5428 - acc 0.9719
# Epoch  168: train: loss 0.5004 - acc 0.9901 	test: loss 0.5397 - acc 0.9726
# Epoch  169: train: loss 0.4968 - acc 0.9902 	test: loss 0.5367 - acc 0.9722
# Epoch  170: train: loss 0.4933 - acc 0.9905 	test: loss 0.5336 - acc 0.9721
# Epoch  171: train: loss 0.4899 - acc 0.9907 	test: loss 0.5305 - acc 0.9722
# Epoch  172: train: loss 0.4864 - acc 0.9908 	test: loss 0.5274 - acc 0.9726
# Epoch  173: train: loss 0.4830 - acc 0.9910 	test: loss 0.5243 - acc 0.9726
# Epoch  174: train: loss 0.4797 - acc 0.9912 	test: loss 0.5213 - acc 0.9727
# Epoch  175: train: loss 0.4763 - acc 0.9912 	test: loss 0.5183 - acc 0.9726
# Epoch  176: train: loss 0.4730 - acc 0.9915 	test: loss 0.5154 - acc 0.9727
# Epoch  177: train: loss 0.4697 - acc 0.9916 	test: loss 0.5125 - acc 0.9725
# Epoch  178: train: loss 0.4665 - acc 0.9918 	test: loss 0.5097 - acc 0.9727
# Epoch  179: train: loss 0.4632 - acc 0.9920 	test: loss 0.5069 - acc 0.9729
# Epoch  180: train: loss 0.4601 - acc 0.9921 	test: loss 0.5041 - acc 0.9732
# Epoch  181: train: loss 0.4569 - acc 0.9923 	test: loss 0.5013 - acc 0.9734
# Epoch  182: train: loss 0.4538 - acc 0.9925 	test: loss 0.4984 - acc 0.9737
# Epoch  183: train: loss 0.4507 - acc 0.9926 	test: loss 0.4956 - acc 0.9742
# Epoch  184: train: loss 0.4477 - acc 0.9927 	test: loss 0.4928 - acc 0.9745
# Epoch  185: train: loss 0.4446 - acc 0.9928 	test: loss 0.4899 - acc 0.9747
# Epoch  186: train: loss 0.4416 - acc 0.9929 	test: loss 0.4872 - acc 0.9748
# Epoch  187: train: loss 0.4387 - acc 0.9930 	test: loss 0.4846 - acc 0.9747
# Epoch  188: train: loss 0.4357 - acc 0.9932 	test: loss 0.4820 - acc 0.9746
# Epoch  189: train: loss 0.4328 - acc 0.9933 	test: loss 0.4794 - acc 0.9746
# Epoch  190: train: loss 0.4300 - acc 0.9933 	test: loss 0.4769 - acc 0.9747
# Epoch  191: train: loss 0.4271 - acc 0.9934 	test: loss 0.4744 - acc 0.9745
# Epoch  192: train: loss 0.4243 - acc 0.9934 	test: loss 0.4719 - acc 0.9743
# Epoch  193: train: loss 0.4215 - acc 0.9936 	test: loss 0.4695 - acc 0.9742
# Epoch  194: train: loss 0.4188 - acc 0.9937 	test: loss 0.4670 - acc 0.9739
# Epoch  195: train: loss 0.4160 - acc 0.9938 	test: loss 0.4644 - acc 0.9739
# Epoch  196: train: loss 0.4133 - acc 0.9939 	test: loss 0.4620 - acc 0.9741
# Epoch  197: train: loss 0.4106 - acc 0.9940 	test: loss 0.4596 - acc 0.9743
# Epoch  198: train: loss 0.4080 - acc 0.9941 	test: loss 0.4574 - acc 0.9741
# Epoch  199: train: loss 0.4054 - acc 0.9942 	test: loss 0.4551 - acc 0.9741
# Epoch  200: train: loss 0.4028 - acc 0.9942 	test: loss 0.4528 - acc 0.9740
# Epoch  201: train: loss 0.4002 - acc 0.9942 	test: loss 0.4505 - acc 0.9742
# Epoch  202: train: loss 0.3977 - acc 0.9943 	test: loss 0.4482 - acc 0.9744
# Epoch  203: train: loss 0.3952 - acc 0.9944 	test: loss 0.4460 - acc 0.9740
# Epoch  204: train: loss 0.3927 - acc 0.9944 	test: loss 0.4438 - acc 0.9740
# Epoch  205: train: loss 0.3902 - acc 0.9945 	test: loss 0.4417 - acc 0.9739
# Epoch  206: train: loss 0.3878 - acc 0.9945 	test: loss 0.4395 - acc 0.9740
# Epoch  207: train: loss 0.3854 - acc 0.9946 	test: loss 0.4373 - acc 0.9742
# Epoch  208: train: loss 0.3829 - acc 0.9947 	test: loss 0.4351 - acc 0.9744
# Epoch  209: train: loss 0.3806 - acc 0.9947 	test: loss 0.4330 - acc 0.9745
# Epoch  210: train: loss 0.3782 - acc 0.9948 	test: loss 0.4309 - acc 0.9746
# Epoch  211: train: loss 0.3759 - acc 0.9949 	test: loss 0.4288 - acc 0.9746
# Epoch  212: train: loss 0.3735 - acc 0.9949 	test: loss 0.4267 - acc 0.9744
# Epoch  213: train: loss 0.3712 - acc 0.9949 	test: loss 0.4247 - acc 0.9742
# Epoch  214: train: loss 0.3690 - acc 0.9950 	test: loss 0.4226 - acc 0.9740
# Epoch  215: train: loss 0.3667 - acc 0.9951 	test: loss 0.4206 - acc 0.9740
# Epoch  216: train: loss 0.3645 - acc 0.9951 	test: loss 0.4186 - acc 0.9742
# Epoch  217: train: loss 0.3623 - acc 0.9952 	test: loss 0.4166 - acc 0.9743
# Epoch  218: train: loss 0.3601 - acc 0.9953 	test: loss 0.4148 - acc 0.9744
# Epoch  219: train: loss 0.3579 - acc 0.9954 	test: loss 0.4129 - acc 0.9740
# Epoch  220: train: loss 0.3558 - acc 0.9954 	test: loss 0.4109 - acc 0.9742
# Epoch  221: train: loss 0.3536 - acc 0.9955 	test: loss 0.4089 - acc 0.9742
# Epoch  222: train: loss 0.3514 - acc 0.9956 	test: loss 0.4070 - acc 0.9745
# Epoch  223: train: loss 0.3493 - acc 0.9957 	test: loss 0.4048 - acc 0.9745
# Epoch  224: train: loss 0.3472 - acc 0.9958 	test: loss 0.4027 - acc 0.9750
# Epoch  225: train: loss 0.3452 - acc 0.9958 	test: loss 0.4007 - acc 0.9752
# Epoch  226: train: loss 0.3431 - acc 0.9958 	test: loss 0.3987 - acc 0.9752
# Epoch  227: train: loss 0.3411 - acc 0.9959 	test: loss 0.3968 - acc 0.9753
# Epoch  228: train: loss 0.3391 - acc 0.9959 	test: loss 0.3950 - acc 0.9751
# Epoch  229: train: loss 0.3371 - acc 0.9959 	test: loss 0.3932 - acc 0.9756
# Epoch  230: train: loss 0.3351 - acc 0.9960 	test: loss 0.3915 - acc 0.9758
# Epoch  231: train: loss 0.3332 - acc 0.9961 	test: loss 0.3899 - acc 0.9756
# Epoch  232: train: loss 0.3313 - acc 0.9961 	test: loss 0.3881 - acc 0.9759
# Epoch  233: train: loss 0.3294 - acc 0.9961 	test: loss 0.3864 - acc 0.9759
# Epoch  234: train: loss 0.3275 - acc 0.9962 	test: loss 0.3847 - acc 0.9760
# Epoch  235: train: loss 0.3256 - acc 0.9963 	test: loss 0.3831 - acc 0.9758
# Epoch  236: train: loss 0.3238 - acc 0.9963 	test: loss 0.3813 - acc 0.9760
# Epoch  237: train: loss 0.3219 - acc 0.9963 	test: loss 0.3795 - acc 0.9759
# Epoch  238: train: loss 0.3201 - acc 0.9963 	test: loss 0.3779 - acc 0.9760
# Epoch  239: train: loss 0.3183 - acc 0.9964 	test: loss 0.3761 - acc 0.9762
# Epoch  240: train: loss 0.3165 - acc 0.9965 	test: loss 0.3743 - acc 0.9763
# Epoch  241: train: loss 0.3148 - acc 0.9965 	test: loss 0.3727 - acc 0.9761
# Epoch  242: train: loss 0.3130 - acc 0.9966 	test: loss 0.3712 - acc 0.9760
# Epoch  243: train: loss 0.3113 - acc 0.9966 	test: loss 0.3697 - acc 0.9764
# Epoch  244: train: loss 0.3096 - acc 0.9967 	test: loss 0.3681 - acc 0.9761
# Epoch  245: train: loss 0.3080 - acc 0.9967 	test: loss 0.3667 - acc 0.9760
# Epoch  246: train: loss 0.3063 - acc 0.9967 	test: loss 0.3653 - acc 0.9759
# Epoch  247: train: loss 0.3046 - acc 0.9968 	test: loss 0.3638 - acc 0.9759
# Epoch  248: train: loss 0.3030 - acc 0.9968 	test: loss 0.3623 - acc 0.9759
# Epoch  249: train: loss 0.3014 - acc 0.9968 	test: loss 0.3608 - acc 0.9762
# Epoch  250: train: loss 0.2998 - acc 0.9968 	test: loss 0.3593 - acc 0.9763
# Epoch  251: train: loss 0.2981 - acc 0.9968 	test: loss 0.3578 - acc 0.9763
# Epoch  252: train: loss 0.2966 - acc 0.9969 	test: loss 0.3564 - acc 0.9760
# Epoch  253: train: loss 0.2950 - acc 0.9969 	test: loss 0.3549 - acc 0.9762
# Epoch  254: train: loss 0.2934 - acc 0.9969 	test: loss 0.3535 - acc 0.9761
# Epoch  255: train: loss 0.2919 - acc 0.9969 	test: loss 0.3520 - acc 0.9764
# Epoch  256: train: loss 0.2904 - acc 0.9970 	test: loss 0.3506 - acc 0.9765
# Epoch  257: train: loss 0.2888 - acc 0.9970 	test: loss 0.3491 - acc 0.9764
# Epoch  258: train: loss 0.2873 - acc 0.9970 	test: loss 0.3476 - acc 0.9764
# Epoch  259: train: loss 0.2859 - acc 0.9970 	test: loss 0.3461 - acc 0.9764
# Epoch  260: train: loss 0.2844 - acc 0.9971 	test: loss 0.3446 - acc 0.9764
# Epoch  261: train: loss 0.2829 - acc 0.9971 	test: loss 0.3433 - acc 0.9767
# Epoch  262: train: loss 0.2815 - acc 0.9971 	test: loss 0.3420 - acc 0.9768
# Epoch  263: train: loss 0.2800 - acc 0.9972 	test: loss 0.3408 - acc 0.9768
# Epoch  264: train: loss 0.2786 - acc 0.9972 	test: loss 0.3395 - acc 0.9767
# Epoch  265: train: loss 0.2772 - acc 0.9972 	test: loss 0.3383 - acc 0.9766
# Epoch  266: train: loss 0.2758 - acc 0.9972 	test: loss 0.3373 - acc 0.9764
# Epoch  267: train: loss 0.2744 - acc 0.9972 	test: loss 0.3363 - acc 0.9758
# Epoch  268: train: loss 0.2730 - acc 0.9972 	test: loss 0.3351 - acc 0.9760
# Epoch  269: train: loss 0.2717 - acc 0.9972 	test: loss 0.3340 - acc 0.9761
# Epoch  270: train: loss 0.2703 - acc 0.9973 	test: loss 0.3329 - acc 0.9762
# Epoch  271: train: loss 0.2690 - acc 0.9973 	test: loss 0.3318 - acc 0.9765
# Epoch  272: train: loss 0.2677 - acc 0.9973 	test: loss 0.3305 - acc 0.9766
# Epoch  273: train: loss 0.2663 - acc 0.9973 	test: loss 0.3291 - acc 0.9769
# Epoch  274: train: loss 0.2650 - acc 0.9973 	test: loss 0.3277 - acc 0.9771
# Epoch  275: train: loss 0.2638 - acc 0.9974 	test: loss 0.3266 - acc 0.9773
# Epoch  276: train: loss 0.2625 - acc 0.9974 	test: loss 0.3255 - acc 0.9773
# Epoch  277: train: loss 0.2612 - acc 0.9974 	test: loss 0.3243 - acc 0.9772
# Epoch  278: train: loss 0.2600 - acc 0.9974 	test: loss 0.3232 - acc 0.9774
# Epoch  279: train: loss 0.2587 - acc 0.9974 	test: loss 0.3221 - acc 0.9771
# Epoch  280: train: loss 0.2575 - acc 0.9974 	test: loss 0.3212 - acc 0.9768
# Epoch  281: train: loss 0.2562 - acc 0.9974 	test: loss 0.3199 - acc 0.9770
# Epoch  282: train: loss 0.2550 - acc 0.9975 	test: loss 0.3187 - acc 0.9771
# Epoch  283: train: loss 0.2538 - acc 0.9975 	test: loss 0.3178 - acc 0.9770
# Epoch  284: train: loss 0.2526 - acc 0.9975 	test: loss 0.3170 - acc 0.9765
# Epoch  285: train: loss 0.2514 - acc 0.9975 	test: loss 0.3161 - acc 0.9762
# Epoch  286: train: loss 0.2502 - acc 0.9975 	test: loss 0.3150 - acc 0.9763
# Epoch  287: train: loss 0.2491 - acc 0.9975 	test: loss 0.3141 - acc 0.9762
# Epoch  288: train: loss 0.2479 - acc 0.9976 	test: loss 0.3133 - acc 0.9761
# Epoch  289: train: loss 0.2467 - acc 0.9976 	test: loss 0.3121 - acc 0.9760
# Epoch  290: train: loss 0.2456 - acc 0.9976 	test: loss 0.3108 - acc 0.9759
# Epoch  291: train: loss 0.2445 - acc 0.9976 	test: loss 0.3097 - acc 0.9761
# Epoch  292: train: loss 0.2433 - acc 0.9976 	test: loss 0.3090 - acc 0.9758
# Epoch  293: train: loss 0.2422 - acc 0.9976 	test: loss 0.3081 - acc 0.9758
# Epoch  294: train: loss 0.2411 - acc 0.9976 	test: loss 0.3070 - acc 0.9761
# Epoch  295: train: loss 0.2400 - acc 0.9976 	test: loss 0.3059 - acc 0.9764
# Epoch  296: train: loss 0.2389 - acc 0.9977 	test: loss 0.3050 - acc 0.9762
# Epoch  297: train: loss 0.2379 - acc 0.9977 	test: loss 0.3041 - acc 0.9761
# Epoch  298: train: loss 0.2368 - acc 0.9977 	test: loss 0.3031 - acc 0.9763
# Epoch  299: train: loss 0.2357 - acc 0.9977 	test: loss 0.3020 - acc 0.9760
# Epoch  300: train: loss 0.2347 - acc 0.9977 	test: loss 0.3010 - acc 0.9761
# Epoch  301: train: loss 0.2336 - acc 0.9977 	test: loss 0.3001 - acc 0.9761
# Epoch  302: train: loss 0.2326 - acc 0.9977 	test: loss 0.2992 - acc 0.9762
# Epoch  303: train: loss 0.2315 - acc 0.9977 	test: loss 0.2981 - acc 0.9762
# Epoch  304: train: loss 0.2305 - acc 0.9977 	test: loss 0.2971 - acc 0.9763
# Epoch  305: train: loss 0.2295 - acc 0.9977 	test: loss 0.2963 - acc 0.9762
# Epoch  306: train: loss 0.2284 - acc 0.9978 	test: loss 0.2955 - acc 0.9762
# Epoch  307: train: loss 0.2274 - acc 0.9978 	test: loss 0.2946 - acc 0.9760
# Epoch  308: train: loss 0.2264 - acc 0.9978 	test: loss 0.2938 - acc 0.9760
# Epoch  309: train: loss 0.2254 - acc 0.9978 	test: loss 0.2929 - acc 0.9760
# Epoch  310: train: loss 0.2244 - acc 0.9978 	test: loss 0.2918 - acc 0.9763
# Epoch  311: train: loss 0.2234 - acc 0.9979 	test: loss 0.2906 - acc 0.9765
# Epoch  312: train: loss 0.2224 - acc 0.9979 	test: loss 0.2894 - acc 0.9768
# Epoch  313: train: loss 0.2214 - acc 0.9979 	test: loss 0.2886 - acc 0.9762
# Epoch  314: train: loss 0.2205 - acc 0.9979 	test: loss 0.2879 - acc 0.9762
# Epoch  315: train: loss 0.2195 - acc 0.9979 	test: loss 0.2871 - acc 0.9764
# Epoch  316: train: loss 0.2186 - acc 0.9979 	test: loss 0.2861 - acc 0.9766
# Epoch  317: train: loss 0.2176 - acc 0.9979 	test: loss 0.2852 - acc 0.9765
# Epoch  318: train: loss 0.2167 - acc 0.9979 	test: loss 0.2844 - acc 0.9764
# Epoch  319: train: loss 0.2157 - acc 0.9979 	test: loss 0.2836 - acc 0.9765
# Epoch  320: train: loss 0.2148 - acc 0.9979 	test: loss 0.2827 - acc 0.9764
# Epoch  321: train: loss 0.2139 - acc 0.9979 	test: loss 0.2818 - acc 0.9763
# Epoch  322: train: loss 0.2130 - acc 0.9979 	test: loss 0.2809 - acc 0.9767
# Epoch  323: train: loss 0.2121 - acc 0.9979 	test: loss 0.2801 - acc 0.9767
# Epoch  324: train: loss 0.2111 - acc 0.9979 	test: loss 0.2793 - acc 0.9769
# Epoch  325: train: loss 0.2102 - acc 0.9979 	test: loss 0.2785 - acc 0.9767
# Epoch  326: train: loss 0.2093 - acc 0.9980 	test: loss 0.2777 - acc 0.9766
# Epoch  327: train: loss 0.2085 - acc 0.9980 	test: loss 0.2768 - acc 0.9766
# Epoch  328: train: loss 0.2076 - acc 0.9980 	test: loss 0.2760 - acc 0.9768
# Epoch  329: train: loss 0.2067 - acc 0.9980 	test: loss 0.2754 - acc 0.9766
# Epoch  330: train: loss 0.2058 - acc 0.9980 	test: loss 0.2748 - acc 0.9767
# Epoch  331: train: loss 0.2050 - acc 0.9980 	test: loss 0.2742 - acc 0.9766
# Epoch  332: train: loss 0.2041 - acc 0.9980 	test: loss 0.2734 - acc 0.9768
# Epoch  333: train: loss 0.2032 - acc 0.9980 	test: loss 0.2727 - acc 0.9769
# Epoch  334: train: loss 0.2023 - acc 0.9980 	test: loss 0.2719 - acc 0.9762
# Epoch  335: train: loss 0.2015 - acc 0.9980 	test: loss 0.2713 - acc 0.9764
# Epoch  336: train: loss 0.2006 - acc 0.9980 	test: loss 0.2706 - acc 0.9764
# Epoch  337: train: loss 0.1998 - acc 0.9980 	test: loss 0.2700 - acc 0.9766
# Epoch  338: train: loss 0.1990 - acc 0.9981 	test: loss 0.2693 - acc 0.9766
# Epoch  339: train: loss 0.1981 - acc 0.9981 	test: loss 0.2683 - acc 0.9768
# Epoch  340: train: loss 0.1973 - acc 0.9981 	test: loss 0.2676 - acc 0.9768
# Epoch  341: train: loss 0.1964 - acc 0.9981 	test: loss 0.2671 - acc 0.9767
# Epoch  342: train: loss 0.1956 - acc 0.9981 	test: loss 0.2666 - acc 0.9760
# Epoch  343: train: loss 0.1948 - acc 0.9981 	test: loss 0.2656 - acc 0.9758
# Epoch  344: train: loss 0.1940 - acc 0.9981 	test: loss 0.2645 - acc 0.9761
# Epoch  345: train: loss 0.1932 - acc 0.9981 	test: loss 0.2636 - acc 0.9764
# Epoch  346: train: loss 0.1923 - acc 0.9981 	test: loss 0.2630 - acc 0.9766
# Epoch  347: train: loss 0.1915 - acc 0.9981 	test: loss 0.2624 - acc 0.9763
# Epoch  348: train: loss 0.1907 - acc 0.9981 	test: loss 0.2616 - acc 0.9765
# Epoch  349: train: loss 0.1899 - acc 0.9982 	test: loss 0.2605 - acc 0.9769
# Epoch  350: train: loss 0.1891 - acc 0.9982 	test: loss 0.2596 - acc 0.9771
# Epoch  351: train: loss 0.1883 - acc 0.9982 	test: loss 0.2589 - acc 0.9769
# Epoch  352: train: loss 0.1875 - acc 0.9982 	test: loss 0.2585 - acc 0.9767
# Epoch  353: train: loss 0.1867 - acc 0.9982 	test: loss 0.2579 - acc 0.9768
# Epoch  354: train: loss 0.1859 - acc 0.9982 	test: loss 0.2574 - acc 0.9767
# Epoch  355: train: loss 0.1851 - acc 0.9982 	test: loss 0.2568 - acc 0.9768
# Epoch  356: train: loss 0.1844 - acc 0.9982 	test: loss 0.2563 - acc 0.9765
# Epoch  357: train: loss 0.1836 - acc 0.9982 	test: loss 0.2556 - acc 0.9766
# Epoch  358: train: loss 0.1829 - acc 0.9982 	test: loss 0.2548 - acc 0.9766
# Epoch  359: train: loss 0.1821 - acc 0.9982 	test: loss 0.2539 - acc 0.9769
# Epoch  360: train: loss 0.1814 - acc 0.9982 	test: loss 0.2531 - acc 0.9766
# Epoch  361: train: loss 0.1806 - acc 0.9983 	test: loss 0.2523 - acc 0.9766
# Epoch  362: train: loss 0.1799 - acc 0.9983 	test: loss 0.2514 - acc 0.9768
# Epoch  363: train: loss 0.1791 - acc 0.9983 	test: loss 0.2505 - acc 0.9771
# Epoch  364: train: loss 0.1784 - acc 0.9983 	test: loss 0.2495 - acc 0.9771
# Epoch  365: train: loss 0.1776 - acc 0.9983 	test: loss 0.2487 - acc 0.9771
# Epoch  366: train: loss 0.1769 - acc 0.9983 	test: loss 0.2474 - acc 0.9770
# Epoch  367: train: loss 0.1762 - acc 0.9983 	test: loss 0.2469 - acc 0.9768
# Epoch  368: train: loss 0.1755 - acc 0.9983 	test: loss 0.2468 - acc 0.9771
# Epoch  369: train: loss 0.1747 - acc 0.9983 	test: loss 0.2469 - acc 0.9768
# Epoch  370: train: loss 0.1740 - acc 0.9983 	test: loss 0.2465 - acc 0.9770
# Epoch  371: train: loss 0.1733 - acc 0.9983 	test: loss 0.2457 - acc 0.9770
# Epoch  372: train: loss 0.1726 - acc 0.9983 	test: loss 0.2449 - acc 0.9772
# Epoch  373: train: loss 0.1719 - acc 0.9984 	test: loss 0.2445 - acc 0.9774
# Epoch  374: train: loss 0.1712 - acc 0.9984 	test: loss 0.2444 - acc 0.9770
# Epoch  375: train: loss 0.1705 - acc 0.9984 	test: loss 0.2441 - acc 0.9770
# Epoch  376: train: loss 0.1699 - acc 0.9984 	test: loss 0.2435 - acc 0.9770
# Epoch  377: train: loss 0.1692 - acc 0.9984 	test: loss 0.2425 - acc 0.9769
# Epoch  378: train: loss 0.1685 - acc 0.9984 	test: loss 0.2416 - acc 0.9773
# Epoch  379: train: loss 0.1678 - acc 0.9984 	test: loss 0.2410 - acc 0.9770
# Epoch  380: train: loss 0.1672 - acc 0.9984 	test: loss 0.2407 - acc 0.9770
# Epoch  381: train: loss 0.1665 - acc 0.9984 	test: loss 0.2403 - acc 0.9770
# Epoch  382: train: loss 0.1658 - acc 0.9984 	test: loss 0.2398 - acc 0.9769
# Epoch  383: train: loss 0.1652 - acc 0.9984 	test: loss 0.2390 - acc 0.9769
# Epoch  384: train: loss 0.1645 - acc 0.9984 	test: loss 0.2382 - acc 0.9765
# Epoch  385: train: loss 0.1638 - acc 0.9985 	test: loss 0.2376 - acc 0.9767
# Epoch  386: train: loss 0.1631 - acc 0.9985 	test: loss 0.2371 - acc 0.9768
# Epoch  387: train: loss 0.1625 - acc 0.9985 	test: loss 0.2368 - acc 0.9765
# Epoch  388: train: loss 0.1618 - acc 0.9985 	test: loss 0.2365 - acc 0.9766
# Epoch  389: train: loss 0.1612 - acc 0.9985 	test: loss 0.2361 - acc 0.9766
# Epoch  390: train: loss 0.1605 - acc 0.9985 	test: loss 0.2357 - acc 0.9765
# Epoch  391: train: loss 0.1599 - acc 0.9985 	test: loss 0.2353 - acc 0.9769
# Epoch  392: train: loss 0.1592 - acc 0.9985 	test: loss 0.2349 - acc 0.9769
# Epoch  393: train: loss 0.1586 - acc 0.9985 	test: loss 0.2343 - acc 0.9766
# Epoch  394: train: loss 0.1579 - acc 0.9985 	test: loss 0.2338 - acc 0.9764
# Epoch  395: train: loss 0.1573 - acc 0.9985 	test: loss 0.2331 - acc 0.9766
# Epoch  396: train: loss 0.1566 - acc 0.9985 	test: loss 0.2324 - acc 0.9768
# Epoch  397: train: loss 0.1560 - acc 0.9985 	test: loss 0.2316 - acc 0.9769
# Epoch  398: train: loss 0.1554 - acc 0.9986 	test: loss 0.2308 - acc 0.9770
# Epoch  399: train: loss 0.1548 - acc 0.9986 	test: loss 0.2301 - acc 0.9772

# %%
plot = Plotter(train)
plot.plot_losses()
plot.plot_accuracy()
plot.plot_info_plan('train')
plot.plot_info_plan('test')
# Out:
# running_mis_xt: [[15.87267488 15.87267488 15.87267488 11.61305221 10.73251586  9.35586575
#    5.9239836   5.34662728]
#  [15.87267488 15.87267488 15.87267488 11.83789706 10.18842938  9.57810064
#    7.23785405  7.12196556]
#  [15.87267488 15.87267488 15.87267488 10.75819788  8.03744327  7.76012998
#    5.59109887  6.11125102]
#  [15.87267488 15.87267488 15.87267488 10.58657736  7.48897838  7.20756534
#    5.25671621  5.80531429]
#  [15.87267488 15.87267488 15.87267488 10.4163427   6.73761393  6.20869608
#    4.67918597  5.31143901]
#  [15.87267488 15.87267488 15.87267488  9.79132985  6.54839911  6.35136017
#    4.34922292  5.16024801]
#  [15.87267488 15.87267488 15.87267488 10.46911443  6.80785509  6.41296306
#    4.53319738  5.16857142]
#  [15.87267488 15.87267488 15.87267488 10.39771694  6.533979    5.76689868
#    3.96576262  4.74333432]
#  [15.87267488 15.87267488 15.87267488  9.9426663   6.37623548  5.38804206
#    3.75704327  4.57948477]
#  [15.87267488 15.87267488 15.87267488  9.53068191  6.12402539  5.21569803
#    3.63526541  4.21991419]
#  [15.87267488 15.87267488 15.87267488  9.18729916  6.06121979  5.16505693
#    3.52979375  4.06635115]
#  [15.87267488 15.87267488 15.87267488  8.88764532  6.03557653  4.89461564
#    3.44574285  4.02045604]
#  [15.87267488 15.87267488 15.87267488  8.64142283  6.02307172  4.72868807
#    3.40162901  3.83978196]
#  [15.87267488 15.87267488 15.87267488  8.55926004  6.01859182  4.68617429
#    3.37364352  3.83701352]
#  [15.87267488 15.87267488 15.87267488  8.53736366  6.03256208  4.68329088
#    3.35917452  3.656899  ]
#  [15.87267488 15.87267488 15.87267488  8.42971032  5.91297946  4.69624878
#    3.3490998   3.63167365]
#  [15.87267488 15.87267488 15.87267488  8.44493356  5.92353334  4.77842089
#    3.44272084  3.61547321]
#  [15.87267488 15.87267488 15.87267488  8.40920429  5.93638822  4.75494578
#    3.39855238  3.788338  ]
#  [15.87267488 15.87267488 15.87267488  8.43209138  5.99533217  4.71225621
#    3.37471522  3.63149078]
#  [15.87267488 15.87267488 15.87267488  8.50877723  5.89408379  4.67251213
#    3.42760766  3.61825945]]
# running_mis_ty: [[3.31987093 3.31987093 3.31987093 2.46163893 2.25420649 2.01595134
#   1.4570431  1.33197175]
#  [3.31987093 3.31987093 3.31987093 3.16208686 3.06978324 3.02725634
#   2.79491297 2.72354626]
#  [3.31987093 3.31987093 3.31987093 3.23846601 3.17743756 3.1479604
#   2.99579748 2.98880659]
#  [3.31987093 3.31987093 3.31987093 3.24148946 3.188166   3.16669886
#   3.02678041 3.06141467]
#  [3.31987093 3.31987093 3.31987093 3.27886787 3.2501715  3.23474171
#   3.15639848 3.17933806]
#  [3.31987093 3.31987093 3.31987093 3.29257108 3.27383899 3.2621384
#   3.20762222 3.22825691]
#  [3.31987093 3.31987093 3.31987093 3.28604498 3.25203647 3.23986537
#   3.16443232 3.1933437 ]
#  [3.31987093 3.31987093 3.31987093 3.29508737 3.27761818 3.26668459
#   3.2224653  3.24109767]
#  [3.31987093 3.31987093 3.31987093 3.30054043 3.28808635 3.2773073
#   3.24997607 3.26048837]
#  [3.31987093 3.31987093 3.31987093 3.3033493  3.29411155 3.28634621
#   3.26613714 3.27410586]
#  [3.31987093 3.31987093 3.31987093 3.30610392 3.29637739 3.2906419
#   3.27653453 3.28257392]
#  [3.31987093 3.31987093 3.31987093 3.30711072 3.30034494 3.29570357
#   3.28467528 3.28930093]
#  [3.31987093 3.31987093 3.31987093 3.30773423 3.30210439 3.2978086
#   3.29009912 3.29327133]
#  [3.31987093 3.31987093 3.31987093 3.30830841 3.30319484 3.29991385
#   3.29337558 3.29625748]
#  [3.31987093 3.31987093 3.31987093 3.30872199 3.30416642 3.300995
#   3.29578015 3.29744655]
#  [3.31987093 3.31987093 3.31987093 3.30864971 3.30452592 3.30162078
#   3.29709251 3.29888639]
#  [3.31987093 3.31987093 3.31987093 3.3100575  3.30574981 3.30293146
#   3.29916505 3.30022949]
#  [3.31987093 3.31987093 3.31987093 3.31034481 3.30680749 3.3040509
#   3.30063082 3.30210259]
#  [3.31987093 3.31987093 3.31987093 3.31177666 3.30750291 3.30562998
#   3.30253555 3.30319493]
#  [3.31987093 3.31987093 3.31987093 3.31221031 3.30841489 3.30630764
#   3.303205   3.30423025]]
# running_mis_xt: [[13.28771238 13.28771238 13.28771238 10.90678065 10.23649649  9.09125031
#    5.9084239   5.31672088]
#  [13.28771238 13.28771238 13.28771238 10.86852671  9.45739132  8.92688581
#    6.97722893  6.92837507]
#  [13.28771238 13.28771238 13.28771238  9.98900392  7.55016285  7.32219923
#    5.44741091  5.97298803]
#  [13.28771238 13.28771238 13.28771238  9.91761532  7.04461232  6.82135454
#    5.09607552  5.63633802]
#  [13.28771238 13.28771238 13.28771238  9.86619886  6.4409218   5.98181082
#    4.63020735  5.24710727]
#  [13.28771238 13.28771238 13.28771238  9.28365102  6.2839763   6.13852383
#    4.36407868  5.11770692]
#  [13.28771238 13.28771238 13.28771238  9.84020922  6.49735624  6.1952182
#    4.46651012  5.06848595]
#  [13.28771238 13.28771238 13.28771238  9.89271216  6.31485222  5.62581704
#    4.01597292  4.70330272]
#  [13.28771238 13.28771238 13.28771238  9.48926537  6.20453349  5.30930447
#    3.90180738  4.65760746]
#  [13.28771238 13.28771238 13.28771238  9.09373585  5.97161052  5.19684789
#    3.83391391  4.33599859]
#  [13.28771238 13.28771238 13.28771238  8.8005459   5.97962645  5.18671848
#    3.76733999  4.22791715]
#  [13.28771238 13.28771238 13.28771238  8.54101885  5.95448882  4.94300218
#    3.69694875  4.23488502]
#  [13.28771238 13.28771238 13.28771238  8.32206374  5.94245703  4.82315892
#    3.68372685  4.09608339]
#  [13.28771238 13.28771238 13.28771238  8.26228628  5.943867    4.76173266
#    3.65982284  4.10104538]
#  [13.28771238 13.28771238 13.28771238  8.23626268  5.95435553  4.81036136
#    3.63492512  3.96704059]
#  [13.28771238 13.28771238 13.28771238  8.12480125  5.85176978  4.84250717
#    3.61466645  3.95994442]
#  [13.28771238 13.28771238 13.28771238  8.14496982  5.88016005  4.95092742
#    3.72187052  3.94633994]
#  [13.28771238 13.28771238 13.28771238  8.10733544  5.91008011  4.91914646
#    3.66595847  4.11403673]
#  [13.28771238 13.28771238 13.28771238  8.15045452  5.99021185  4.8889467
#    3.64813575  3.98167881]
#  [13.28771238 13.28771238 13.28771238  8.21298993  5.91076371  4.85192048
#    3.71283769  3.950253  ]]
# running_mis_ty: [[3.31942253 3.31942253 3.31942253 2.70371928 2.51405795 2.25527556
#   1.54572808 1.40746296]
#  [3.31942253 3.31942253 3.31942253 3.23705225 3.16340107 3.12893625
#   2.92654066 2.85333744]
#  [3.31942253 3.31942253 3.31942253 3.27520171 3.22837035 3.20684324
#   3.04931646 3.05029125]
#  [3.31942253 3.31942253 3.31942253 3.27006926 3.22057804 3.20201274
#   3.05843108 3.10120816]
#  [3.31942253 3.31942253 3.31942253 3.29521553 3.2725909  3.25616529
#   3.16618381 3.21037471]
#  [3.31942253 3.31942253 3.31942253 3.30258506 3.28348533 3.27077782
#   3.19281849 3.22958703]
#  [3.31942253 3.31942253 3.31942253 3.29938665 3.26946468 3.25838496
#   3.15934074 3.19681167]
#  [3.31942253 3.31942253 3.31942253 3.30057756 3.28162486 3.27473871
#   3.19227468 3.22867763]
#  [3.31942253 3.31942253 3.31942253 3.30662998 3.29212545 3.27746965
#   3.20752263 3.24688916]
#  [3.31942253 3.31942253 3.31942253 3.30732853 3.2944476  3.27981753
#   3.20897157 3.25011856]
#  [3.31942253 3.31942253 3.31942253 3.30802801 3.29568947 3.28026086
#   3.20467452 3.24735993]
#  [3.31942253 3.31942253 3.31942253 3.31110575 3.29974302 3.28350091
#   3.20613594 3.25468867]
#  [3.31942253 3.31942253 3.31942253 3.30846751 3.29778727 3.28545772
#   3.20860241 3.25359074]
#  [3.31942253 3.31942253 3.31942253 3.30755245 3.29640329 3.28248915
#   3.21448401 3.25107751]
#  [3.31942253 3.31942253 3.31942253 3.30720729 3.29798835 3.28334606
#   3.20998375 3.24959316]
#  [3.31942253 3.31942253 3.31942253 3.30647426 3.29589477 3.28192761
#   3.20321635 3.24963611]
#  [3.31942253 3.31942253 3.31942253 3.30605714 3.29586575 3.28062064
#   3.21338381 3.24840713]
#  [3.31942253 3.31942253 3.31942253 3.30723021 3.29136707 3.28050252
#   3.21281059 3.25013106]
#  [3.31942253 3.31942253 3.31942253 3.30686128 3.29398089 3.28531488
#   3.21158684 3.25567957]
#  [3.31942253 3.31942253 3.31942253 3.30800414 3.29414614 3.28105089
#   3.21884804 3.24989158]]
