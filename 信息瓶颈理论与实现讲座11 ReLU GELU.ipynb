# %%
#######################################################################################
##https://github.com/Huma97/Information-Bottleneck-Theory-of-Deep-Learning/tree/master#
#######################################################################################
##讲座7把神经网络可以分层定义，引入可学习激活函数
import os
from collections import defaultdict, OrderedDict#为了自动建目录
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import pickle
from torchvision import datasets
import torchvision.transforms as transforms
import matplotlib as mpl
#import scienceplots
import math
train_on_gpu = torch.cuda.is_available()
##判断是否有GPU
if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
    
def categorical_cross_entropy(output, target):
    num_classes = 10
    epsilon = 10e-8
        
    output = torch.clamp(output, epsilon, 1. - epsilon)
    ##使用torch.clamp函数将output张量中的值限制在一个范围内，防止出现数值过大或过小的情况，第一个参数是要处理的张量，第二个参数是下限，第三个参数是上限。
    target = target.float()  # Ensure target is float
    target = target.reshape(target.shape[0], 1).to(output.device)  # Move target to the same device as output
    one_hot_target = (target == torch.arange(num_classes).reshape(1, num_classes).to(output.device)).float()
    return torch.mean(-torch.sum(one_hot_target * torch.log(output), 1))
#将target张量转换为独热编码的形式，即将每个类别的索引转换为一个长度为num_classes的向量，其中对应类别的位置为1，其他位置为0。
#最小化这个损失函数意味着我们希望预测值与真实标签之间的差异越小越好，即模型的预测结果与真实情况越接近
def init_weights(m):
    if type(m) == nn.Linear:
        nn.init.xavier_uniform_(m.weight)  # 使用 nn.init.xavier_uniform_对于权系数进行初始化
        m.bias.data.fill_(0.0)  # 使用 fill_ 方法来设置偏置为 0
# Out:
# CUDA is available!  Training on GPU ...

# %% [markdown]
# # Downloading MNIST dataset

# %%
#分批训练size，Mnist数据集60000=5w：1w
batch_size = 128

# convert data to a normalized torch.FloatTensor
transform = transforms.Compose([
    transforms.ToTensor()])
#    transforms.Normalize((0.1307,), (0.3081,))  # 标准化
#])
# choose the training and test datasets
train_data = datasets.MNIST('./MNIST_data/', download=True, train=True, transform=transform)
test_data = datasets.MNIST('./MNIST_data/', download=True, train=False, transform=transform)

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size)
#分批载入
full_data_loader = torch.utils.data.DataLoader(test_data, batch_size=10000)
#全部载入测试

# %% [markdown]
# # Class for creating NN

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, padding=1)  # 输入通道数1，输出通道数16，卷积核大小3x3
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1) # 输入通道数16，输出通道数32，卷积核大小3x3
        self.pool = nn.MaxPool2d(2, 2)                           # 2x2的最大池化层
        self.fc1 = nn.Linear(32 * 7 * 7, 64)                    # 全连接层，输入维度32*7*7，输出维度64
        self.fc2 = nn.Linear(64, 20)                            # 全连接层，输入维度64，输出维度10（对应10个类别）
        self.fc3 = nn.Linear(20, 10)
    def forward(self, x):
        activations = []
        x = F.relu(self.conv1(x))  # 第一层卷积 + ReLU激活 
        xx= torch.flatten(x, 1)
        activations.append(xx.cpu().data.numpy())#layer1
        x = self.pool(x)
        x = F.relu(self.conv2(x))  # 第二层卷积 + ReLU激活
        xx= torch.flatten(x, 1)
        activations.append(xx.cpu().data.numpy())#layer1
        x = self.pool(x)
        x = x.view(-1, 32 * 7 * 7)            # 展平操作，为全连接层做准备
        x = F.relu(self.fc1(x))               # 第一个全连接层 + ReLU激活
        activations.append(x.cpu().data.numpy())#layer1
        x = F.relu(self.fc2(x))               # 第一个全连接层 + ReLU激活
        activations.append(x.cpu().data.numpy())#layer1
        x=self.fc3(x)
        x = torch.softmax(x, dim=1)
        activations.append(x.cpu().data.numpy())
        return x, activations

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Class for saving activations, computing MI and plotting

# %%
import kde
# 这段代码是用Python来实现一些熵估计方法，特别是用于估计混合高斯模型的熵。以下是对每个函数的简要解释：
#需要下载https://github.com/Huma97/Information-Bottleneck-Theory-of-Deep-Learning/tree/master，jupyter载入
# get_dists(X):
# 这个函数用来计算输入数据集X中样本之间的成对欧氏距离的平方。它首先计算每个样本向量的平方范数，并将结果扩展为列向量，然后使用矩阵乘法和广播来计算所有样本对之间的距离平方。

# get_shape(x):
# 这个函数用来获取输入矩阵x的形状信息，返回矩阵的列数（特征维度）和行数（样本数）。

# entropy_estimator_kl(x, var):
# 这个函数基于KL散度的方法估计输入数据集x的熵，假设数据集服从多个高斯分布的混合模型。它首先计算数据集中样本之间的成对欧氏距离的平方，然后根据给定的方差var计算距离的对数概率，并最终求取其均值。

# entropy_estimator_bd(x, var):
# 这个函数基于Bhattacharyya系数的方法估计输入数据集x的熵的下界，同样假设数据集服从多个高斯分布的混合模型。它首先利用entropy_estimator_kl函数计算KL散度的估计值，然后加上一个校正项。

# kde_condentropy(output, var):
# 这个函数计算输出的多元高斯分布的条件熵，假设每个维度的方差均为var。
import simplebinmi
#需要下载https://github.com/Huma97/Information-Bottleneck-Theory-of-Deep-Learning/tree/master，jupyter载入
# get_unique_probs(x):
# 这个函数用于计算输入数据集x中每个唯一样本出现的概率。首先，它将输入数据x转换为字节视图，并将其看作是void类型的视图，这样可以方便地比较数据集中的唯一样本。然后，使用NumPy的np.unique函数找到唯一的样本，同时计算出现的次数。最后，将每个唯一样本出现的次数除以总样本数，得到概率值。

# bin_calc_information(inputdata, layerdata, num_of_bins):
# 这个函数用于计算给定输入数据和某一层的输出数据之间的信息量。首先，使用get_unique_probs函数计算输入数据集中每个唯一样本的概率，并将结果存储在p_xs中。然后，将输出数据分成num_of_bins个区间，并计算每个区间中的样本出现的概率。接着，利用信息论中的熵的定义来计算层的熵（H_LAYER）和给定输入的条件下层的熵（H_LAYER_GIVEN_INPUT）。最后，返回两者之差，即信息量。

# bin_calc_information2(labelixs, layerdata, binsize):
# 这个函数也用于计算信息量，与上一个函数相似，但在计算输出的条件熵时使用了一种简化的方法。首先，将层的输出数据划分成多个区间，然后计算每个区间中样本出现的概率。接着，利用这些概率值计算层的熵（H_LAYER）。然后，对于每个标签，通过求取其样本在层输出中的平均位置，计算出条件熵，然后将所有标签对应的条件熵加和。最后，返回层的熵和在给定输出的情况下层的条件熵之差。

# %%
class MI_Plate():
    def __init__(self, n_epochs=100, DO_LOWER=False, DO_BINNED=False, PLOT_LAYERS=None):
        super(MI_Plate, self).__init__()
        
        self.n_epochs = n_epochs
        self.DO_LOWER = DO_LOWER
        self.DO_BINNED = DO_BINNED
        self.PLOT_LAYERS = PLOT_LAYERS
#DO_LOWER和DO_BINNED是用于控制数据预处理的布尔值，PLOT_LAYERS是用于指定绘制哪些层的激活值的列表
    def save_activations(self):
        
        if not os.path.exists('activations'):
            print("Making directory", 'activations')
            os.mkdir('activations')
            
        model = Net()
        #model.apply(init_weights)

        optimizer = optim.SGD(model.parameters(), lr=0.01)
        #optimizer = optim.Adam(model.parameters(), lr=0.001)
        # Move model to GPU if available
        if train_on_gpu:
            model.cuda()
        
        for epoch in range(self.n_epochs):
            # monitor training loss
            train_loss = 0.0

            ###################
            # train the model #
            ###################
            model.train()

            for data, target in train_loader:
                if train_on_gpu:
                    data, target = data.cuda(), target.cuda()  # Move data to GPU
                optimizer.zero_grad()
                output, _ = model(data)
                loss = categorical_cross_entropy(output, target)
                # backward
                loss.backward()
                optimizer.step()
                train_loss += loss.item()#*data.size(0)

            # calculate average loss over an epoch
            train_loss = train_loss/len(train_loader.dataset)

            print('Epoch: {} \tTraining Loss: {:.6f}'.format(epoch+1, train_loss))

            model.eval()
########每次按照规定的epoch训练之后，都用full全部数据通过网络一次，记住标签和网络输出
###############################################################################            
            for data, _ in full_data_loader:
                if train_on_gpu:
                    data = data.cuda()  # Move data to GPU
                _, activations = model(data)
#定义多少epoch进行存储每层的输出，前20每次都存，高于200次100次再存一次
            if epoch < 20:       # Log for all first 20 epochs
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            #pickle.HIGHEST_PROTOCOL 用于指定 pickle 协议的版本，以确保最高的兼容性和效率
            elif (epoch < 100) and (epoch % 5 == 0):    # Then for every 5th epoch
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            elif (epoch < 200) and (epoch % 10 == 0):    # Then every 10th
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            elif (epoch % 100 == 0):                # Then every 100th
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
         #####################****************************************
            correct = 0
            total = 0
            with torch.no_grad():
                for data, target in test_loader:  # Assuming test_loader is defined elsewhere
                    if train_on_gpu:
                        data, target = data.cuda(), target.cuda()  # Move data to GPU
                    output, _ = model(data)
                    _, predicted = torch.max(output.data, 1)
                    total += target.size(0)
                    correct += (predicted == target).sum().item()

            accuracy = 100 * correct / total
           
            print('Test Accuracy on 10,000 images: {:.2f}%'.format(accuracy))                    
      ###########################
    def compute_MI(self, noise_variance=1e-1):
        
        MAX_EPOCHS = self.n_epochs
        self.noise_variance = noise_variance
        
        def entropy_func_upper(x):
            return kde.entropy_estimator_kl(x,self.noise_variance)
        
        def entropy_func_lower(x):
            return kde.entropy_estimator_bd(x,self.noise_variance)

        # nats to bits conversion factor
        nats2bits = 1.0/np.log(2) 


        # Save indexes of tests data for each of the output classes
        saved_labelixs = {}
        for data, targets in full_data_loader:
            trg = targets.numpy()
        for i in range(10):
            saved_labelixs[i] = trg == i

        labelprobs = np.mean(np.eye(10)[test_data.targets], axis=0)

        MI_XM_upper_array = []
        MI_YM_upper_array = []
###这段代码的作用是计算每个类别在数据集中出现的频率，并保存每个类别的索引以供后续使用
        measures = OrderedDict()
        measures['tanh'] = {}

        cur_dir = 'activations'
        if not os.path.exists(cur_dir):
            print("Directory %s not found" % cur_dir)

        # Load files saved during each epoch, and compute MI measures of the activity in that epoch
        print('*** Doing %s ***' % cur_dir)
        for epochfile in sorted(os.listdir(cur_dir)):
            if not epochfile.startswith('epoch'):
                continue

            fname = cur_dir + "/" + epochfile
            with open(fname, 'rb') as f:
                d = pickle.load(f)

            epoch = d[1]
            d = d[0]
            if epoch in measures['tanh']:# Skip this epoch if its already been processed
                continue                # this is a trick to allow us to rerun this cell multiple times)

            if epoch > MAX_EPOCHS:
                continue

            print("Doing", fname)

            num_layers = len(d)

            MI_XM_upper_epoch = []
            MI_YM_upper_epoch = []
            
            if self.PLOT_LAYERS is None:
                PLOT_LAYERS = []
                for lndx in range(num_layers):
                    PLOT_LAYERS.append(lndx)

            cepochdata = defaultdict(list)
            for lndx in range(num_layers):
                activity = d[lndx]

                # Compute marginal entropies
                h_upper = entropy_func_upper(activity)
                if self.DO_LOWER:
                    #h_lower = entropy_func_lower([activity,])[0]
                    h_lower = entropy_func_lower(activity)

                # Layer activity given input. This is simply the entropy of the Gaussian noise
                hM_given_X = kde.kde_condentropy(activity, self.noise_variance)

                # Compute conditional entropies of layer activity given output
                hM_given_Y_upper=0.
                for i in range(10):
                    hcond_upper = entropy_func_upper(activity[saved_labelixs[i],:])
                    hM_given_Y_upper += labelprobs[i] * hcond_upper

                if self.DO_LOWER:
                    hM_given_Y_lower=0.
                    for i in range(10):
                        hcond_lower = entropy_func_lower(activity[saved_labelixs[i],:])
                        hM_given_Y_lower += labelprobs[i] * hcond_lower

                cepochdata['MI_XM_upper'].append( nats2bits * (h_upper - hM_given_X) )
                cepochdata['MI_YM_upper'].append( nats2bits * (h_upper - hM_given_Y_upper) )
                cepochdata['H_M_upper'  ].append( nats2bits * h_upper )


                MI_XM_upper = nats2bits * (h_upper - hM_given_X)
                MI_YM_upper = nats2bits * (h_upper - hM_given_Y_upper)

                MI_XM_upper_epoch.append(MI_XM_upper)
                MI_YM_upper_epoch.append(MI_YM_upper)
                
                pstr = 'upper: MI(X;M)=%0.3f, MI(Y;M)=%0.3f, h_upper=%0.3f, hM_given_X=%0.3f, hM_given_Y_upper=%0.3f ' % (cepochdata['MI_XM_upper'][-1], cepochdata['MI_YM_upper'][-1], h_upper, hM_given_X, hM_given_Y_upper)
                if self.DO_LOWER:  # Compute lower bounds
                    cepochdata['MI_XM_lower'].append( nats2bits * (h_lower - hM_given_X) )
                    cepochdata['MI_YM_lower'].append( nats2bits * (h_lower - hM_given_Y_lower) )
                    cepochdata['H_M_lower'  ].append( nats2bits * h_lower )
                    pstr += ' | lower: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_lower'][-1], cepochdata['MI_YM_lower'][-1])

                if self.DO_BINNED: # Compute binner estimates
                    binxm, binym = simplebinmi.bin_calc_information2(saved_labelixs, activity, 0.5)
                    cepochdata['MI_XM_bin'].append( nats2bits * binxm )
                    cepochdata['MI_YM_bin'].append( nats2bits * binym )
                    pstr += ' | bin: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_bin'][-1], cepochdata['MI_YM_bin'][-1])

                print('- Layer %d %s' % (lndx, pstr) )

            measures['tanh'][epoch] = cepochdata
            MI_XM_upper_array.append(MI_XM_upper_epoch)
            MI_YM_upper_array.append(MI_YM_upper_epoch)
             
            #epoch += 1
        MI_XM_upper_array = np.array(MI_XM_upper_array)
        MI_YM_upper_array = np.array(MI_YM_upper_array)

    # Save the results as arrays
        np.save('D:/深度学习与信息论/MI_XM_upper_array.npy', MI_XM_upper_array)
        np.save('D:/深度学习与信息论/MI_YM_upper_array.npy', MI_YM_upper_array)

        with open('MI', 'wb') as f:
            pickle.dump(measures, f, pickle.HIGHEST_PROTOCOL)   

Plate = MI_Plate() #Create class object
Plate.save_activations() #save activations if they weren't saved already
Plate.compute_MI() #compute and save MIs if they weren't saved before
# Out:
# Epoch: 1 	Training Loss: 0.017965
# Saving activations/epoch00000000
# Test Accuracy on 10,000 images: 20.96%
# Epoch: 2 	Training Loss: 0.017716
# Saving activations/epoch00000001
# Test Accuracy on 10,000 images: 38.20%
# Epoch: 3 	Training Loss: 0.012056
# Saving activations/epoch00000002
# Test Accuracy on 10,000 images: 79.44%
# Epoch: 4 	Training Loss: 0.004467
# Saving activations/epoch00000003
# Test Accuracy on 10,000 images: 87.57%
# Epoch: 5 	Training Loss: 0.003171
# Saving activations/epoch00000004
# Test Accuracy on 10,000 images: 89.70%
# Epoch: 6 	Training Loss: 0.002431
# Saving activations/epoch00000005
# Test Accuracy on 10,000 images: 91.17%
# Epoch: 7 	Training Loss: 0.001951
# Saving activations/epoch00000006
# Test Accuracy on 10,000 images: 93.60%
# Epoch: 8 	Training Loss: 0.001609
# Saving activations/epoch00000007
# Test Accuracy on 10,000 images: 94.41%
# Epoch: 9 	Training Loss: 0.001372
# Saving activations/epoch00000008
# Test Accuracy on 10,000 images: 95.42%
# Epoch: 10 	Training Loss: 0.001192
# Saving activations/epoch00000009
# Test Accuracy on 10,000 images: 95.75%
# Epoch: 11 	Training Loss: 0.001056
# Saving activations/epoch00000010
# Test Accuracy on 10,000 images: 96.33%
# Epoch: 12 	Training Loss: 0.000953
# Saving activations/epoch00000011
# Test Accuracy on 10,000 images: 96.69%
# Epoch: 13 	Training Loss: 0.000873
# Saving activations/epoch00000012
# Test Accuracy on 10,000 images: 96.29%
# Epoch: 14 	Training Loss: 0.000806
# Saving activations/epoch00000013
# Test Accuracy on 10,000 images: 96.92%
# Epoch: 15 	Training Loss: 0.000748
# Saving activations/epoch00000014
# Test Accuracy on 10,000 images: 96.79%
# Epoch: 16 	Training Loss: 0.000700
# Saving activations/epoch00000015
# Test Accuracy on 10,000 images: 96.95%
# Epoch: 17 	Training Loss: 0.000663
# Saving activations/epoch00000016
# Test Accuracy on 10,000 images: 97.44%
# Epoch: 18 	Training Loss: 0.000628
# Saving activations/epoch00000017
# Test Accuracy on 10,000 images: 97.72%
# Epoch: 19 	Training Loss: 0.000592
# Saving activations/epoch00000018
# Test Accuracy on 10,000 images: 97.55%
# Epoch: 20 	Training Loss: 0.000562
# Saving activations/epoch00000019
# Test Accuracy on 10,000 images: 97.68%
# Epoch: 21 	Training Loss: 0.000541
# Saving activations/epoch00000020
# Test Accuracy on 10,000 images: 98.11%
# Epoch: 22 	Training Loss: 0.000517
# Test Accuracy on 10,000 images: 97.71%
# Epoch: 23 	Training Loss: 0.000497
# Test Accuracy on 10,000 images: 98.07%
# Epoch: 24 	Training Loss: 0.000482
# Test Accuracy on 10,000 images: 97.95%
# Epoch: 25 	Training Loss: 0.000468
# Test Accuracy on 10,000 images: 97.75%
# Epoch: 26 	Training Loss: 0.000454
# Saving activations/epoch00000025
# Test Accuracy on 10,000 images: 98.32%
# Epoch: 27 	Training Loss: 0.000436
# Test Accuracy on 10,000 images: 98.04%
# Epoch: 28 	Training Loss: 0.000417
# Test Accuracy on 10,000 images: 98.21%
# Epoch: 29 	Training Loss: 0.000412
# Test Accuracy on 10,000 images: 98.15%
# Epoch: 30 	Training Loss: 0.000394
# Test Accuracy on 10,000 images: 98.18%
# Epoch: 31 	Training Loss: 0.000382
# Saving activations/epoch00000030
# Test Accuracy on 10,000 images: 98.40%
# Epoch: 32 	Training Loss: 0.000372
# Test Accuracy on 10,000 images: 98.19%
# Epoch: 33 	Training Loss: 0.000361
# Test Accuracy on 10,000 images: 98.18%
# Epoch: 34 	Training Loss: 0.000353
# Test Accuracy on 10,000 images: 98.32%
# Epoch: 35 	Training Loss: 0.000345
# Test Accuracy on 10,000 images: 98.53%
# Epoch: 36 	Training Loss: 0.000331
# Saving activations/epoch00000035
# Test Accuracy on 10,000 images: 98.57%
# Epoch: 37 	Training Loss: 0.000323
# Test Accuracy on 10,000 images: 98.51%
# Epoch: 38 	Training Loss: 0.000316
# Test Accuracy on 10,000 images: 98.60%
# Epoch: 39 	Training Loss: 0.000307
# Test Accuracy on 10,000 images: 98.55%
# Epoch: 40 	Training Loss: 0.000302
# Test Accuracy on 10,000 images: 98.60%
# Epoch: 41 	Training Loss: 0.000293
# Saving activations/epoch00000040
# Test Accuracy on 10,000 images: 98.35%
# Epoch: 42 	Training Loss: 0.000290
# Test Accuracy on 10,000 images: 98.35%
# Epoch: 43 	Training Loss: 0.000282
# Test Accuracy on 10,000 images: 98.61%
# Epoch: 44 	Training Loss: 0.000273
# Test Accuracy on 10,000 images: 98.55%
# Epoch: 45 	Training Loss: 0.000268
# Test Accuracy on 10,000 images: 98.28%
# Epoch: 46 	Training Loss: 0.000263
# Saving activations/epoch00000045
# Test Accuracy on 10,000 images: 98.33%
# Epoch: 47 	Training Loss: 0.000257
# Test Accuracy on 10,000 images: 98.46%
# Epoch: 48 	Training Loss: 0.000245
# Test Accuracy on 10,000 images: 98.60%
# Epoch: 49 	Training Loss: 0.000246
# Test Accuracy on 10,000 images: 98.66%
# Epoch: 50 	Training Loss: 0.000237
# Test Accuracy on 10,000 images: 98.59%
# Epoch: 51 	Training Loss: 0.000230
# Saving activations/epoch00000050
# Test Accuracy on 10,000 images: 98.40%
# Epoch: 52 	Training Loss: 0.000231
# Test Accuracy on 10,000 images: 98.70%
# Epoch: 53 	Training Loss: 0.000221
# Test Accuracy on 10,000 images: 98.69%
# Epoch: 54 	Training Loss: 0.000217
# Test Accuracy on 10,000 images: 98.63%
# Epoch: 55 	Training Loss: 0.000210
# Test Accuracy on 10,000 images: 98.71%
# Epoch: 56 	Training Loss: 0.000210
# Saving activations/epoch00000055
# Test Accuracy on 10,000 images: 98.71%
# Epoch: 57 	Training Loss: 0.000204
# Test Accuracy on 10,000 images: 98.53%
# Epoch: 58 	Training Loss: 0.000200
# Test Accuracy on 10,000 images: 98.63%
# Epoch: 59 	Training Loss: 0.000196
# Test Accuracy on 10,000 images: 98.73%
# Epoch: 60 	Training Loss: 0.000192
# Test Accuracy on 10,000 images: 98.63%
# Epoch: 61 	Training Loss: 0.000187
# Saving activations/epoch00000060
# Test Accuracy on 10,000 images: 98.70%
# Epoch: 62 	Training Loss: 0.000185
# Test Accuracy on 10,000 images: 98.13%
# Epoch: 63 	Training Loss: 0.000182
# Test Accuracy on 10,000 images: 98.80%
# Epoch: 64 	Training Loss: 0.000177
# Test Accuracy on 10,000 images: 98.75%
# Epoch: 65 	Training Loss: 0.000173
# Test Accuracy on 10,000 images: 98.78%
# Epoch: 66 	Training Loss: 0.000170
# Saving activations/epoch00000065
# Test Accuracy on 10,000 images: 98.59%
# Epoch: 67 	Training Loss: 0.000166
# Test Accuracy on 10,000 images: 98.67%
# Epoch: 68 	Training Loss: 0.000161
# Test Accuracy on 10,000 images: 98.62%
# Epoch: 69 	Training Loss: 0.000160
# Test Accuracy on 10,000 images: 98.60%
# Epoch: 70 	Training Loss: 0.000156
# Test Accuracy on 10,000 images: 98.74%
# Epoch: 71 	Training Loss: 0.000155
# Saving activations/epoch00000070
# Test Accuracy on 10,000 images: 98.73%
# Epoch: 72 	Training Loss: 0.000151
# Test Accuracy on 10,000 images: 98.71%
# Epoch: 73 	Training Loss: 0.000146
# Test Accuracy on 10,000 images: 98.79%
# Epoch: 74 	Training Loss: 0.000144
# Test Accuracy on 10,000 images: 98.47%
# Epoch: 75 	Training Loss: 0.000140
# Test Accuracy on 10,000 images: 98.72%
# Epoch: 76 	Training Loss: 0.000141
# Saving activations/epoch00000075
# Test Accuracy on 10,000 images: 98.52%
# Epoch: 77 	Training Loss: 0.000135
# Test Accuracy on 10,000 images: 98.70%
# Epoch: 78 	Training Loss: 0.000131
# Test Accuracy on 10,000 images: 98.40%
# Epoch: 79 	Training Loss: 0.000132
# Test Accuracy on 10,000 images: 98.70%
# Epoch: 80 	Training Loss: 0.000130
# Test Accuracy on 10,000 images: 98.63%
# Epoch: 81 	Training Loss: 0.000124
# Saving activations/epoch00000080
# Test Accuracy on 10,000 images: 98.76%
# Epoch: 82 	Training Loss: 0.000123
# Test Accuracy on 10,000 images: 98.75%
# Epoch: 83 	Training Loss: 0.000120
# Test Accuracy on 10,000 images: 98.69%
# Epoch: 84 	Training Loss: 0.000119
# Test Accuracy on 10,000 images: 98.82%
# Epoch: 85 	Training Loss: 0.000111
# Test Accuracy on 10,000 images: 98.68%
# Epoch: 86 	Training Loss: 0.000114
# Saving activations/epoch00000085
# Test Accuracy on 10,000 images: 98.79%
# Epoch: 87 	Training Loss: 0.000108
# Test Accuracy on 10,000 images: 98.80%
# Epoch: 88 	Training Loss: 0.000106
# Test Accuracy on 10,000 images: 98.83%
# Epoch: 89 	Training Loss: 0.000105
# Test Accuracy on 10,000 images: 98.71%
# Epoch: 90 	Training Loss: 0.000101
# Test Accuracy on 10,000 images: 98.66%
# Epoch: 91 	Training Loss: 0.000100
# Saving activations/epoch00000090
# Test Accuracy on 10,000 images: 98.81%
# Epoch: 92 	Training Loss: 0.000098
# Test Accuracy on 10,000 images: 98.78%
# Epoch: 93 	Training Loss: 0.000098
# Test Accuracy on 10,000 images: 98.76%
# Epoch: 94 	Training Loss: 0.000096
# Test Accuracy on 10,000 images: 98.77%
# Epoch: 95 	Training Loss: 0.000096
# Test Accuracy on 10,000 images: 98.78%
# Epoch: 96 	Training Loss: 0.000093
# Saving activations/epoch00000095
# Test Accuracy on 10,000 images: 98.71%
# Epoch: 97 	Training Loss: 0.000087
# Test Accuracy on 10,000 images: 98.52%
# Epoch: 98 	Training Loss: 0.000089
# Test Accuracy on 10,000 images: 98.69%
# Epoch: 99 	Training Loss: 0.000084
# Test Accuracy on 10,000 images: 98.62%
# Epoch: 100 	Training Loss: 0.000087
# Test Accuracy on 10,000 images: 98.77%
# *** Doing activations ***
# Doing activations/epoch00000000
# - Layer 0 upper: MI(X;M)=13.287, MI(Y;M)=3.320, h_upper=3366.561, hM_given_X=3357.351, hM_given_Y_upper=3364.260
# - Layer 1 upper: MI(X;M)=13.283, MI(Y;M)=3.320, h_upper=1687.883, hM_given_X=1678.676, hM_given_Y_upper=1685.582
# - Layer 2 upper: MI(X;M)=0.712, MI(Y;M)=0.287, h_upper=17.623, hM_given_X=17.129, hM_given_Y_upper=17.424
# - Layer 3 upper: MI(X;M)=0.076, MI(Y;M)=0.040, h_upper=5.405, hM_given_X=5.353, hM_given_Y_upper=5.378
# - Layer 4 upper: MI(X;M)=0.000, MI(Y;M)=0.000, h_upper=2.677, hM_given_X=2.676, hM_given_Y_upper=2.677
# Doing activations/epoch00000001
# - Layer 0 upper: MI(X;M)=13.292, MI(Y;M)=3.319, h_upper=3366.565, hM_given_X=3357.351, hM_given_Y_upper=3364.264
# - Layer 1 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=1687.886, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 2 upper: MI(X;M)=4.570, MI(Y;M)=1.845, h_upper=20.297, hM_given_X=17.129, hM_given_Y_upper=19.018
# - Layer 3 upper: MI(X;M)=1.624, MI(Y;M)=0.897, h_upper=6.479, hM_given_X=5.353, hM_given_Y_upper=5.857
# - Layer 4 upper: MI(X;M)=0.010, MI(Y;M)=0.006, h_upper=2.683, hM_given_X=2.676, hM_given_Y_upper=2.679
# Doing activations/epoch00000002
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=3366.562, hM_given_X=3357.351, hM_given_Y_upper=3364.261
# - Layer 1 upper: MI(X;M)=13.291, MI(Y;M)=3.320, h_upper=1687.888, hM_given_X=1678.676, hM_given_Y_upper=1685.588
# - Layer 2 upper: MI(X;M)=13.280, MI(Y;M)=3.319, h_upper=26.334, hM_given_X=17.129, hM_given_Y_upper=24.034
# - Layer 3 upper: MI(X;M)=13.194, MI(Y;M)=3.319, h_upper=14.498, hM_given_X=5.353, hM_given_Y_upper=12.198
# - Layer 4 upper: MI(X;M)=3.312, MI(Y;M)=2.238, h_upper=4.972, hM_given_X=2.676, hM_given_Y_upper=3.421
# Doing activations/epoch00000003
# - Layer 0 upper: MI(X;M)=13.292, MI(Y;M)=3.319, h_upper=3366.565, hM_given_X=3357.351, hM_given_Y_upper=3364.264
# - Layer 1 upper: MI(X;M)=13.299, MI(Y;M)=3.320, h_upper=1687.894, hM_given_X=1678.676, hM_given_Y_upper=1685.593
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=26.339, hM_given_X=17.129, hM_given_Y_upper=24.038
# - Layer 3 upper: MI(X;M)=13.274, MI(Y;M)=3.319, h_upper=14.554, hM_given_X=5.353, hM_given_Y_upper=12.253
# - Layer 4 upper: MI(X;M)=3.653, MI(Y;M)=2.674, h_upper=5.209, hM_given_X=2.676, hM_given_Y_upper=3.355
# Doing activations/epoch00000004
# - Layer 0 upper: MI(X;M)=13.280, MI(Y;M)=3.320, h_upper=3366.556, hM_given_X=3357.351, hM_given_Y_upper=3364.255
# - Layer 1 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=1687.886, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.280, MI(Y;M)=3.319, h_upper=14.558, hM_given_X=5.353, hM_given_Y_upper=12.257
# - Layer 4 upper: MI(X;M)=3.677, MI(Y;M)=2.787, h_upper=5.225, hM_given_X=2.676, hM_given_Y_upper=3.293
# Doing activations/epoch00000005
# - Layer 0 upper: MI(X;M)=13.292, MI(Y;M)=3.320, h_upper=3366.565, hM_given_X=3357.351, hM_given_Y_upper=3364.264
# - Layer 1 upper: MI(X;M)=13.297, MI(Y;M)=3.319, h_upper=1687.893, hM_given_X=1678.676, hM_given_Y_upper=1685.592
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.284, MI(Y;M)=3.319, h_upper=14.561, hM_given_X=5.353, hM_given_Y_upper=12.260
# - Layer 4 upper: MI(X;M)=3.644, MI(Y;M)=2.864, h_upper=5.202, hM_given_X=2.676, hM_given_Y_upper=3.217
# Doing activations/epoch00000006
# - Layer 0 upper: MI(X;M)=13.265, MI(Y;M)=3.319, h_upper=3366.546, hM_given_X=3357.351, hM_given_Y_upper=3364.245
# - Layer 1 upper: MI(X;M)=13.295, MI(Y;M)=3.319, h_upper=1687.891, hM_given_X=1678.676, hM_given_Y_upper=1685.591
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.284, MI(Y;M)=3.319, h_upper=14.561, hM_given_X=5.353, hM_given_Y_upper=12.260
# - Layer 4 upper: MI(X;M)=3.604, MI(Y;M)=2.976, h_upper=5.175, hM_given_X=2.676, hM_given_Y_upper=3.112
# Doing activations/epoch00000007
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=3366.562, hM_given_X=3357.351, hM_given_Y_upper=3364.261
# - Layer 1 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=1687.886, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=14.561, hM_given_X=5.353, hM_given_Y_upper=12.260
# - Layer 4 upper: MI(X;M)=3.569, MI(Y;M)=3.006, h_upper=5.150, hM_given_X=2.676, hM_given_Y_upper=3.066
# Doing activations/epoch00000008
# - Layer 0 upper: MI(X;M)=13.285, MI(Y;M)=3.320, h_upper=3366.560, hM_given_X=3357.351, hM_given_Y_upper=3364.259
# - Layer 1 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=1687.886, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=14.561, hM_given_X=5.353, hM_given_Y_upper=12.261
# - Layer 4 upper: MI(X;M)=3.535, MI(Y;M)=3.059, h_upper=5.127, hM_given_X=2.676, hM_given_Y_upper=3.007
# Doing activations/epoch00000009
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=3366.562, hM_given_X=3357.351, hM_given_Y_upper=3364.261
# - Layer 1 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=1687.885, hM_given_X=1678.676, hM_given_Y_upper=1685.584
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=14.562, hM_given_X=5.353, hM_given_Y_upper=12.261
# - Layer 4 upper: MI(X;M)=3.519, MI(Y;M)=3.069, h_upper=5.116, hM_given_X=2.676, hM_given_Y_upper=2.988
# Doing activations/epoch00000010
# - Layer 0 upper: MI(X;M)=13.291, MI(Y;M)=3.320, h_upper=3366.564, hM_given_X=3357.351, hM_given_Y_upper=3364.263
# - Layer 1 upper: MI(X;M)=13.301, MI(Y;M)=3.320, h_upper=1687.895, hM_given_X=1678.676, hM_given_Y_upper=1685.594
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=14.562, hM_given_X=5.353, hM_given_Y_upper=12.261
# - Layer 4 upper: MI(X;M)=3.496, MI(Y;M)=3.102, h_upper=5.100, hM_given_X=2.676, hM_given_Y_upper=2.949
# Doing activations/epoch00000011
# - Layer 0 upper: MI(X;M)=13.290, MI(Y;M)=3.320, h_upper=3366.563, hM_given_X=3357.351, hM_given_Y_upper=3364.262
# - Layer 1 upper: MI(X;M)=13.310, MI(Y;M)=3.320, h_upper=1687.902, hM_given_X=1678.676, hM_given_Y_upper=1685.601
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=14.562, hM_given_X=5.353, hM_given_Y_upper=12.261
# - Layer 4 upper: MI(X;M)=3.492, MI(Y;M)=3.124, h_upper=5.097, hM_given_X=2.676, hM_given_Y_upper=2.932
# Doing activations/epoch00000012
# - Layer 0 upper: MI(X;M)=13.277, MI(Y;M)=3.320, h_upper=3366.554, hM_given_X=3357.351, hM_given_Y_upper=3364.253
# - Layer 1 upper: MI(X;M)=13.307, MI(Y;M)=3.320, h_upper=1687.899, hM_given_X=1678.676, hM_given_Y_upper=1685.598
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=14.562, hM_given_X=5.353, hM_given_Y_upper=12.261
# - Layer 4 upper: MI(X;M)=3.489, MI(Y;M)=3.109, h_upper=5.095, hM_given_X=2.676, hM_given_Y_upper=2.939
# Doing activations/epoch00000013
# - Layer 0 upper: MI(X;M)=13.294, MI(Y;M)=3.320, h_upper=3366.566, hM_given_X=3357.351, hM_given_Y_upper=3364.265
# - Layer 1 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=1687.886, hM_given_X=1678.676, hM_given_Y_upper=1685.586
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=14.562, hM_given_X=5.353, hM_given_Y_upper=12.261
# - Layer 4 upper: MI(X;M)=3.482, MI(Y;M)=3.140, h_upper=5.090, hM_given_X=2.676, hM_given_Y_upper=2.913
# Doing activations/epoch00000014
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.320, h_upper=3366.563, hM_given_X=3357.351, hM_given_Y_upper=3364.262
# - Layer 1 upper: MI(X;M)=13.289, MI(Y;M)=3.320, h_upper=1687.887, hM_given_X=1678.676, hM_given_Y_upper=1685.586
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=14.562, hM_given_X=5.353, hM_given_Y_upper=12.261
# - Layer 4 upper: MI(X;M)=3.468, MI(Y;M)=3.137, h_upper=5.080, hM_given_X=2.676, hM_given_Y_upper=2.906
# Doing activations/epoch00000015
# - Layer 0 upper: MI(X;M)=13.287, MI(Y;M)=3.320, h_upper=3366.561, hM_given_X=3357.351, hM_given_Y_upper=3364.260
# - Layer 1 upper: MI(X;M)=13.289, MI(Y;M)=3.320, h_upper=1687.887, hM_given_X=1678.676, hM_given_Y_upper=1685.586
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=14.562, hM_given_X=5.353, hM_given_Y_upper=12.261
# - Layer 4 upper: MI(X;M)=3.464, MI(Y;M)=3.144, h_upper=5.077, hM_given_X=2.676, hM_given_Y_upper=2.898
# Doing activations/epoch00000016
# - Layer 0 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=3366.560, hM_given_X=3357.351, hM_given_Y_upper=3364.259
# - Layer 1 upper: MI(X;M)=13.305, MI(Y;M)=3.320, h_upper=1687.898, hM_given_X=1678.676, hM_given_Y_upper=1685.597
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.562, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.442, MI(Y;M)=3.161, h_upper=5.063, hM_given_X=2.676, hM_given_Y_upper=2.872
# Doing activations/epoch00000017
# - Layer 0 upper: MI(X;M)=13.284, MI(Y;M)=3.320, h_upper=3366.559, hM_given_X=3357.351, hM_given_Y_upper=3364.258
# - Layer 1 upper: MI(X;M)=13.286, MI(Y;M)=3.320, h_upper=1687.885, hM_given_X=1678.676, hM_given_Y_upper=1685.584
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=14.562, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.436, MI(Y;M)=3.174, h_upper=5.058, hM_given_X=2.676, hM_given_Y_upper=2.858
# Doing activations/epoch00000018
# - Layer 0 upper: MI(X;M)=13.297, MI(Y;M)=3.320, h_upper=3366.568, hM_given_X=3357.351, hM_given_Y_upper=3364.267
# - Layer 1 upper: MI(X;M)=13.295, MI(Y;M)=3.320, h_upper=1687.891, hM_given_X=1678.676, hM_given_Y_upper=1685.590
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.439, MI(Y;M)=3.162, h_upper=5.060, hM_given_X=2.676, hM_given_Y_upper=2.868
# Doing activations/epoch00000019
# - Layer 0 upper: MI(X;M)=13.293, MI(Y;M)=3.319, h_upper=3366.565, hM_given_X=3357.351, hM_given_Y_upper=3364.264
# - Layer 1 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=1687.884, hM_given_X=1678.676, hM_given_Y_upper=1685.583
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.440, MI(Y;M)=3.169, h_upper=5.061, hM_given_X=2.676, hM_given_Y_upper=2.864
# Doing activations/epoch00000020
# - Layer 0 upper: MI(X;M)=13.294, MI(Y;M)=3.320, h_upper=3366.566, hM_given_X=3357.351, hM_given_Y_upper=3364.265
# - Layer 1 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=1687.885, hM_given_X=1678.676, hM_given_Y_upper=1685.584
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.422, MI(Y;M)=3.194, h_upper=5.048, hM_given_X=2.676, hM_given_Y_upper=2.835
# Doing activations/epoch00000025
# - Layer 0 upper: MI(X;M)=13.286, MI(Y;M)=3.320, h_upper=3366.560, hM_given_X=3357.351, hM_given_Y_upper=3364.259
# - Layer 1 upper: MI(X;M)=13.282, MI(Y;M)=3.320, h_upper=1687.882, hM_given_X=1678.676, hM_given_Y_upper=1685.581
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.407, MI(Y;M)=3.208, h_upper=5.038, hM_given_X=2.676, hM_given_Y_upper=2.815
# Doing activations/epoch00000030
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.320, h_upper=3366.562, hM_given_X=3357.351, hM_given_Y_upper=3364.261
# - Layer 1 upper: MI(X;M)=13.277, MI(Y;M)=3.319, h_upper=1687.879, hM_given_X=1678.676, hM_given_Y_upper=1685.578
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.403, MI(Y;M)=3.212, h_upper=5.035, hM_given_X=2.676, hM_given_Y_upper=2.808
# Doing activations/epoch00000035
# - Layer 0 upper: MI(X;M)=13.285, MI(Y;M)=3.320, h_upper=3366.560, hM_given_X=3357.351, hM_given_Y_upper=3364.258
# - Layer 1 upper: MI(X;M)=13.275, MI(Y;M)=3.319, h_upper=1687.877, hM_given_X=1678.676, hM_given_Y_upper=1685.576
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.391, MI(Y;M)=3.218, h_upper=5.027, hM_given_X=2.676, hM_given_Y_upper=2.796
# Doing activations/epoch00000040
# - Layer 0 upper: MI(X;M)=13.290, MI(Y;M)=3.320, h_upper=3366.563, hM_given_X=3357.351, hM_given_Y_upper=3364.262
# - Layer 1 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=1687.885, hM_given_X=1678.676, hM_given_Y_upper=1685.584
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.390, MI(Y;M)=3.207, h_upper=5.026, hM_given_X=2.676, hM_given_Y_upper=2.803
# Doing activations/epoch00000045
# - Layer 0 upper: MI(X;M)=13.284, MI(Y;M)=3.320, h_upper=3366.559, hM_given_X=3357.351, hM_given_Y_upper=3364.258
# - Layer 1 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=1687.886, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.393, MI(Y;M)=3.205, h_upper=5.029, hM_given_X=2.676, hM_given_Y_upper=2.807
# Doing activations/epoch00000050
# - Layer 0 upper: MI(X;M)=13.291, MI(Y;M)=3.319, h_upper=3366.564, hM_given_X=3357.351, hM_given_Y_upper=3364.263
# - Layer 1 upper: MI(X;M)=13.289, MI(Y;M)=3.320, h_upper=1687.887, hM_given_X=1678.676, hM_given_Y_upper=1685.586
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.387, MI(Y;M)=3.209, h_upper=5.024, hM_given_X=2.676, hM_given_Y_upper=2.800
# Doing activations/epoch00000055
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.320, h_upper=3366.562, hM_given_X=3357.351, hM_given_Y_upper=3364.261
# - Layer 1 upper: MI(X;M)=13.294, MI(Y;M)=3.319, h_upper=1687.891, hM_given_X=1678.676, hM_given_Y_upper=1685.590
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.371, MI(Y;M)=3.225, h_upper=5.013, hM_given_X=2.676, hM_given_Y_upper=2.778
# Doing activations/epoch00000060
# - Layer 0 upper: MI(X;M)=13.286, MI(Y;M)=3.320, h_upper=3366.561, hM_given_X=3357.351, hM_given_Y_upper=3364.259
# - Layer 1 upper: MI(X;M)=13.277, MI(Y;M)=3.319, h_upper=1687.879, hM_given_X=1678.676, hM_given_Y_upper=1685.578
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.367, MI(Y;M)=3.221, h_upper=5.010, hM_given_X=2.676, hM_given_Y_upper=2.778
# Doing activations/epoch00000065
# - Layer 0 upper: MI(X;M)=13.294, MI(Y;M)=3.320, h_upper=3366.566, hM_given_X=3357.351, hM_given_Y_upper=3364.264
# - Layer 1 upper: MI(X;M)=13.279, MI(Y;M)=3.319, h_upper=1687.880, hM_given_X=1678.676, hM_given_Y_upper=1685.579
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.370, MI(Y;M)=3.214, h_upper=5.012, hM_given_X=2.676, hM_given_Y_upper=2.785
# Doing activations/epoch00000070
# - Layer 0 upper: MI(X;M)=13.290, MI(Y;M)=3.320, h_upper=3366.563, hM_given_X=3357.351, hM_given_Y_upper=3364.262
# - Layer 1 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=1687.885, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.364, MI(Y;M)=3.225, h_upper=5.008, hM_given_X=2.676, hM_given_Y_upper=2.773
# Doing activations/epoch00000075
# - Layer 0 upper: MI(X;M)=13.284, MI(Y;M)=3.320, h_upper=3366.559, hM_given_X=3357.351, hM_given_Y_upper=3364.258
# - Layer 1 upper: MI(X;M)=13.281, MI(Y;M)=3.319, h_upper=1687.881, hM_given_X=1678.676, hM_given_Y_upper=1685.581
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.366, MI(Y;M)=3.210, h_upper=5.010, hM_given_X=2.676, hM_given_Y_upper=2.785
# Doing activations/epoch00000080
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=3366.562, hM_given_X=3357.351, hM_given_Y_upper=3364.261
# - Layer 1 upper: MI(X;M)=13.279, MI(Y;M)=3.320, h_upper=1687.880, hM_given_X=1678.676, hM_given_Y_upper=1685.579
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.358, MI(Y;M)=3.225, h_upper=5.004, hM_given_X=2.676, hM_given_Y_upper=2.769
# Doing activations/epoch00000085
# - Layer 0 upper: MI(X;M)=13.286, MI(Y;M)=3.320, h_upper=3366.560, hM_given_X=3357.351, hM_given_Y_upper=3364.259
# - Layer 1 upper: MI(X;M)=13.281, MI(Y;M)=3.319, h_upper=1687.881, hM_given_X=1678.676, hM_given_Y_upper=1685.580
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.361, MI(Y;M)=3.225, h_upper=5.006, hM_given_X=2.676, hM_given_Y_upper=2.771
# Doing activations/epoch00000090
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=3366.562, hM_given_X=3357.351, hM_given_Y_upper=3364.261
# - Layer 1 upper: MI(X;M)=13.289, MI(Y;M)=3.319, h_upper=1687.887, hM_given_X=1678.676, hM_given_Y_upper=1685.586
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3
self.conv1(x))  # 第一层卷积 + ReLU激活 
        xx= torch.flatten(x, 1)
        activations.append(xx.cpu().data.numpy())#layer1
        x = self.pool(x)
        x = self.act2(self.conv2(x))  # 第二层卷积 + ReLU激活
        xx= torch.flatten(x, 1)
        activations.append(xx.cpu().data.numpy())#layer1
        x = self.pool(x)
        x = x.view(-1, 32 * 7 * 7)            # 展平操作，为全连接层做准备
        x = self.act3(self.fc1(x))               # 第一个全连接层 + ReLU激活
        activations.append(x.cpu().data.numpy())#layer1
        x = self.act4(self.fc2(x))               # 第一个全连接层 + ReLU激活
        activations.append(x.cpu().data.numpy())#layer1
        x = self.fc3(x)# 第二个全连接层（输出层）
        x = torch.softmax(x, dim=1)
        activations.append(x.cpu().data.numpy())
        return x, activations


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
class MI_Plate():
    def __init__(self, n_epochs=100, DO_LOWER=False, DO_BINNED=False, PLOT_LAYERS=None):
        super(MI_Plate, self).__init__()
        
        self.n_epochs = n_epochs
        self.DO_LOWER = DO_LOWER
        self.DO_BINNED = DO_BINNED
        self.PLOT_LAYERS = PLOT_LAYERS
#DO_LOWER和DO_BINNED是用于控制数据预处理的布尔值，PLOT_LAYERS是用于指定绘制哪些层的激活值的列表
    def save_activations(self):
        
        if not os.path.exists('activations'):
            print("Making directory", 'activations')
            os.mkdir('activations')
            
        model = Net()
        model.apply(init_weights)

        optimizer = optim.SGD(model.parameters(), lr=0.01)
        #optimizer = optim.Adam(model.parameters(), lr=0.001)
        # Move model to GPU if available
        if train_on_gpu:
            model.cuda()
       
        for epoch in range(self.n_epochs):
            # monitor training loss
            train_loss = 0.0

            ###################
            # train the model #
            ###################
            model.train()

            for data, target in train_loader:
                if train_on_gpu:
                    data, target = data.cuda(), target.cuda()  # Move data to GPU
                optimizer.zero_grad()
                output, _ = model(data)
                loss = categorical_cross_entropy(output, target)
                # backward
                loss.backward()
                optimizer.step()
                train_loss += loss.item()#*data.size(0)

            # calculate average loss over an epoch
            train_loss = train_loss/len(train_loader.dataset)

            print('Epoch: {} \tTraining Loss: {:.6f}'.format(epoch+1, train_loss))

            model.eval()
########每次按照规定的epoch训练之后，都用full全部数据通过网络一次，记住标签和网络输出
###############################################################################            
            for data, _ in full_data_loader:
                if train_on_gpu:
                    data = data.cuda()  # Move data to GPU
                _, activations = model(data)
#定义多少epoch进行存储每层的输出，前20每次都存，高于200次100次再存一次
            if epoch < 20:       # Log for all first 20 epochs
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            #pickle.HIGHEST_PROTOCOL 用于指定 pickle 协议的版本，以确保最高的兼容性和效率
            elif (epoch < 100) and (epoch % 5 == 0):    # Then for every 5th epoch
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            elif (epoch < 200) and (epoch % 10 == 0):    # Then every 10th
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            elif (epoch % 100 == 0):                # Then every 100th
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
         #####################****************************************
            correct = 0
            total = 0
            with torch.no_grad():
                for data, target in test_loader:  # Assuming test_loader is defined elsewhere
                    if train_on_gpu:
                        data, target = data.cuda(), target.cuda()  # Move data to GPU
                    output, _ = model(data)
                    _, predicted = torch.max(output.data, 1)
                    total += target.size(0)
                    correct += (predicted == target).sum().item()

            accuracy = 100 * correct / total
            print('Test Accuracy on 10,000 images: {:.2f}%'.format(accuracy))  
      ###########################
    def compute_MI(self, noise_variance=1e-1):
        
        MAX_EPOCHS = self.n_epochs
        self.noise_variance = noise_variance
        
        def entropy_func_upper(x):
            return kde.entropy_estimator_kl(x,self.noise_variance)
        
        def entropy_func_lower(x):
            return kde.entropy_estimator_bd(x,self.noise_variance)

        # nats to bits conversion factor
        nats2bits = 1.0/np.log(2) 


        # Save indexes of tests data for each of the output classes
        saved_labelixs = {}
        for data, targets in full_data_loader:
            trg = targets.numpy()
        for i in range(10):
            saved_labelixs[i] = trg == i

        labelprobs = np.mean(np.eye(10)[test_data.targets], axis=0)

        MI_XM_upper_array = []
        MI_YM_upper_array = []
###这段代码的作用是计算每个类别在数据集中出现的频率，并保存每个类别的索引以供后续使用
        measures = OrderedDict()
        measures['tanh'] = {}

        cur_dir = 'activations'
        if not os.path.exists(cur_dir):
            print("Directory %s not found" % cur_dir)

        # Load files saved during each epoch, and compute MI measures of the activity in that epoch
        print('*** Doing %s ***' % cur_dir)
        for epochfile in sorted(os.listdir(cur_dir)):
            if not epochfile.startswith('epoch'):
                continue

            fname = cur_dir + "/" + epochfile
            with open(fname, 'rb') as f:
                d = pickle.load(f)

            epoch = d[1]
            d = d[0]
            if epoch in measures['tanh']:# Skip this epoch if its already been processed
                continue                # this is a trick to allow us to rerun this cell multiple times)

            if epoch > MAX_EPOCHS:
                continue

            print("Doing", fname)

            num_layers = len(d)

            MI_XM_upper_epoch = []
            MI_YM_upper_epoch = []
            
            if self.PLOT_LAYERS is None:
                PLOT_LAYERS = []
                for lndx in range(num_layers):
                    PLOT_LAYERS.append(lndx)

            cepochdata = defaultdict(list)
            for lndx in range(num_layers):
                activity = d[lndx]

                # Compute marginal entropies
                h_upper = entropy_func_upper(activity)
                if self.DO_LOWER:
                    #h_lower = entropy_func_lower([activity,])[0]
                    h_lower = entropy_func_lower(activity)

                # Layer activity given input. This is simply the entropy of the Gaussian noise
                hM_given_X = kde.kde_condentropy(activity, self.noise_variance)

                # Compute conditional entropies of layer activity given output
                hM_given_Y_upper=0.
                for i in range(10):
                    hcond_upper = entropy_func_upper(activity[saved_labelixs[i],:])
                    hM_given_Y_upper += labelprobs[i] * hcond_upper

                if self.DO_LOWER:
                    hM_given_Y_lower=0.
                    for i in range(10):
                        hcond_lower = entropy_func_lower(activity[saved_labelixs[i],:])
                        hM_given_Y_lower += labelprobs[i] * hcond_lower

                cepochdata['MI_XM_upper'].append( nats2bits * (h_upper - hM_given_X) )
                cepochdata['MI_YM_upper'].append( nats2bits * (h_upper - hM_given_Y_upper) )
                cepochdata['H_M_upper'  ].append( nats2bits * h_upper )


                MI_XM_upper = nats2bits * (h_upper - hM_given_X)
                MI_YM_upper = nats2bits * (h_upper - hM_given_Y_upper)

                MI_XM_upper_epoch.append(MI_XM_upper)
                MI_YM_upper_epoch.append(MI_YM_upper)
                
                pstr = 'upper: MI(X;M)=%0.3f, MI(Y;M)=%0.3f, h_upper=%0.3f, hM_given_X=%0.3f, hM_given_Y_upper=%0.3f ' % (cepochdata['MI_XM_upper'][-1], cepochdata['MI_YM_upper'][-1], h_upper, hM_given_X, hM_given_Y_upper)
                if self.DO_LOWER:  # Compute lower bounds
                    cepochdata['MI_XM_lower'].append( nats2bits * (h_lower - hM_given_X) )
                    cepochdata['MI_YM_lower'].append( nats2bits * (h_lower - hM_given_Y_lower) )
                    cepochdata['H_M_lower'  ].append( nats2bits * h_lower )
                    pstr += ' | lower: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_lower'][-1], cepochdata['MI_YM_lower'][-1])

                if self.DO_BINNED: # Compute binner estimates
                    binxm, binym = simplebinmi.bin_calc_information2(saved_labelixs, activity, 0.5)
                    cepochdata['MI_XM_bin'].append( nats2bits * binxm )
                    cepochdata['MI_YM_bin'].append( nats2bits * binym )
                    pstr += ' | bin: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_bin'][-1], cepochdata['MI_YM_bin'][-1])

                print('- Layer %d %s' % (lndx, pstr) )

            measures['tanh'][epoch] = cepochdata
            MI_XM_upper_array.append(MI_XM_upper_epoch)
            MI_YM_upper_array.append(MI_YM_upper_epoch)
             
            #epoch += 1
        MI_XM_upper_array = np.array(MI_XM_upper_array)
        MI_YM_upper_array = np.array(MI_YM_upper_array)

    # Save the results as arrays
        np.save('D:/深度学习与信息论/MI_XM_upper_arrayS.npy', MI_XM_upper_array)
        np.save('D:/深度学习与信息论/MI_YM_upper_arrayS.npy', MI_YM_upper_array)

        with open('MI', 'wb') as f:
            pickle.dump(measures, f, pickle.HIGHEST_PROTOCOL) 

Plate = MI_Plate() #Create class object
Plate.save_activations() #save activations if they weren't saved already
Plate.compute_MI() #compute and save MIs if they weren't saved before
# Out:
# Epoch: 1 	Training Loss: 0.012094
# Saving activations/epoch00000000
# Test Accuracy on 10,000 images: 86.69%
# Epoch: 2 	Training Loss: 0.003012
# Saving activations/epoch00000001
# Test Accuracy on 10,000 images: 91.43%
# Epoch: 3 	Training Loss: 0.002041
# Saving activations/epoch00000002
# Test Accuracy on 10,000 images: 93.62%
# Epoch: 4 	Training Loss: 0.001574
# Saving activations/epoch00000003
# Test Accuracy on 10,000 images: 94.46%
# Epoch: 5 	Training Loss: 0.001282
# Saving activations/epoch00000004
# Test Accuracy on 10,000 images: 94.37%
# Epoch: 6 	Training Loss: 0.001072
# Saving activations/epoch00000005
# Test Accuracy on 10,000 images: 96.55%
# Epoch: 7 	Training Loss: 0.000923
# Saving activations/epoch00000006
# Test Accuracy on 10,000 images: 96.94%
# Epoch: 8 	Training Loss: 0.000825
# Saving activations/epoch00000007
# Test Accuracy on 10,000 images: 96.88%
# Epoch: 9 	Training Loss: 0.000742
# Saving activations/epoch00000008
# Test Accuracy on 10,000 images: 97.21%
# Epoch: 10 	Training Loss: 0.000685
# Saving activations/epoch00000009
# Test Accuracy on 10,000 images: 97.29%
# Epoch: 11 	Training Loss: 0.000629
# Saving activations/epoch00000010
# Test Accuracy on 10,000 images: 96.50%
# Epoch: 12 	Training Loss: 0.000594
# Saving activations/epoch00000011
# Test Accuracy on 10,000 images: 97.70%
# Epoch: 13 	Training Loss: 0.000552
# Saving activations/epoch00000012
# Test Accuracy on 10,000 images: 97.65%
# Epoch: 14 	Training Loss: 0.000517
# Saving activations/epoch00000013
# Test Accuracy on 10,000 images: 97.82%
# Epoch: 15 	Training Loss: 0.000496
# Saving activations/epoch00000014
# Test Accuracy on 10,000 images: 97.91%
# Epoch: 16 	Training Loss: 0.000467
# Saving activations/epoch00000015
# Test Accuracy on 10,000 images: 98.00%
# Epoch: 17 	Training Loss: 0.000451
# Saving activations/epoch00000016
# Test Accuracy on 10,000 images: 98.01%
# Epoch: 18 	Training Loss: 0.000427
# Saving activations/epoch00000017
# Test Accuracy on 10,000 images: 97.88%
# Epoch: 19 	Training Loss: 0.000408
# Saving activations/epoch00000018
# Test Accuracy on 10,000 images: 98.06%
# Epoch: 20 	Training Loss: 0.000395
# Saving activations/epoch00000019
# Test Accuracy on 10,000 images: 98.35%
# Epoch: 21 	Training Loss: 0.000382
# Saving activations/epoch00000020
# Test Accuracy on 10,000 images: 97.99%
# Epoch: 22 	Training Loss: 0.000365
# Test Accuracy on 10,000 images: 98.46%
# Epoch: 23 	Training Loss: 0.000351
# Test Accuracy on 10,000 images: 98.39%
# Epoch: 24 	Training Loss: 0.000342
# Test Accuracy on 10,000 images: 98.53%
# Epoch: 25 	Training Loss: 0.000331
# Test Accuracy on 10,000 images: 98.40%
# Epoch: 26 	Training Loss: 0.000319
# Saving activations/epoch00000025
# Test Accuracy on 10,000 images: 98.43%
# Epoch: 27 	Training Loss: 0.000306
# Test Accuracy on 10,000 images: 98.59%
# Epoch: 28 	Training Loss: 0.000302
# Test Accuracy on 10,000 images: 98.46%
# Epoch: 29 	Training Loss: 0.000293
# Test Accuracy on 10,000 images: 98.49%
# Epoch: 30 	Training Loss: 0.000285
# Test Accuracy on 10,000 images: 98.61%
# Epoch: 31 	Training Loss: 0.000274
# Saving activations/epoch00000030
# Test Accuracy on 10,000 images: 98.44%
# Epoch: 32 	Training Loss: 0.000268
# Test Accuracy on 10,000 images: 98.59%
# Epoch: 33 	Training Loss: 0.000262
# Test Accuracy on 10,000 images: 98.73%
# Epoch: 34 	Training Loss: 0.000252
# Test Accuracy on 10,000 images: 98.65%
# Epoch: 35 	Training Loss: 0.000244
# Test Accuracy on 10,000 images: 98.59%
# Epoch: 36 	Training Loss: 0.000241
# Saving activations/epoch00000035
# Test Accuracy on 10,000 images: 98.59%
# Epoch: 37 	Training Loss: 0.000233
# Test Accuracy on 10,000 images: 98.55%
# Epoch: 38 	Training Loss: 0.000228
# Test Accuracy on 10,000 images: 98.55%
# Epoch: 39 	Training Loss: 0.000224
# Test Accuracy on 10,000 images: 98.48%
# Epoch: 40 	Training Loss: 0.000219
# Test Accuracy on 10,000 images: 98.69%
# Epoch: 41 	Training Loss: 0.000207
# Saving activations/epoch00000040
# Test Accuracy on 10,000 images: 98.65%
# Epoch: 42 	Training Loss: 0.000207
# Test Accuracy on 10,000 images: 98.65%
# Epoch: 43 	Training Loss: 0.000200
# Test Accuracy on 10,000 images: 98.87%
# Epoch: 44 	Training Loss: 0.000192
# Test Accuracy on 10,000 images: 98.74%
# Epoch: 45 	Training Loss: 0.000189
# Test Accuracy on 10,000 images: 98.49%
# Epoch: 46 	Training Loss: 0.000189
# Saving activations/epoch00000045
# Test Accuracy on 10,000 images: 98.64%
# Epoch: 47 	Training Loss: 0.000183
# Test Accuracy on 10,000 images: 98.72%
# Epoch: 48 	Training Loss: 0.000175
# Test Accuracy on 10,000 images: 98.80%
# Epoch: 49 	Training Loss: 0.000171
# Test Accuracy on 10,000 images: 98.79%
# Epoch: 50 	Training Loss: 0.000171
# Test Accuracy on 10,000 images: 98.81%
# Epoch: 51 	Training Loss: 0.000166
# Saving activations/epoch00000050
# Test Accuracy on 10,000 images: 98.69%
# Epoch: 52 	Training Loss: 0.000160
# Test Accuracy on 10,000 images: 98.82%
# Epoch: 53 	Training Loss: 0.000154
# Test Accuracy on 10,000 images: 98.82%
# Epoch: 54 	Training Loss: 0.000150
# Test Accuracy on 10,000 images: 98.72%
# Epoch: 55 	Training Loss: 0.000149
# Test Accuracy on 10,000 images: 98.84%
# Epoch: 56 	Training Loss: 0.000147
# Saving activations/epoch00000055
# Test Accuracy on 10,000 images: 98.76%
# Epoch: 57 	Training Loss: 0.000141
# Test Accuracy on 10,000 images: 98.50%
# Epoch: 58 	Training Loss: 0.000138
# Test Accuracy on 10,000 images: 98.82%
# Epoch: 59 	Training Loss: 0.000135
# Test Accuracy on 10,000 images: 98.61%
# Epoch: 60 	Training Loss: 0.000131
# Test Accuracy on 10,000 images: 98.75%
# Epoch: 61 	Training Loss: 0.000129
# Saving activations/epoch00000060
# Test Accuracy on 10,000 images: 98.88%
# Epoch: 62 	Training Loss: 0.000126
# Test Accuracy on 10,000 images: 98.79%
# Epoch: 63 	Training Loss: 0.000121
# Test Accuracy on 10,000 images: 98.85%
# Epoch: 64 	Training Loss: 0.000119
# Test Accuracy on 10,000 images: 98.84%
# Epoch: 65 	Training Loss: 0.000117
# Test Accuracy on 10,000 images: 98.83%
# Epoch: 66 	Training Loss: 0.000113
# Saving activations/epoch00000065
# Test Accuracy on 10,000 images: 98.83%
# Epoch: 67 	Training Loss: 0.000111
# Test Accuracy on 10,000 images: 98.71%
# Epoch: 68 	Training Loss: 0.000107
# Test Accuracy on 10,000 images: 98.80%
# Epoch: 69 	Training Loss: 0.000107
# Test Accuracy on 10,000 images: 98.87%
# Epoch: 70 	Training Loss: 0.000105
# Test Accuracy on 10,000 images: 98.91%
# Epoch: 71 	Training Loss: 0.000098
# Saving activations/epoch00000070
# Test Accuracy on 10,000 images: 98.94%
# Epoch: 72 	Training Loss: 0.000100
# Test Accuracy on 10,000 images: 98.83%
# Epoch: 73 	Training Loss: 0.000096
# Test Accuracy on 10,000 images: 98.86%
# Epoch: 74 	Training Loss: 0.000091
# Test Accuracy on 10,000 images: 98.89%
# Epoch: 75 	Training Loss: 0.000090
# Test Accuracy on 10,000 images: 98.80%
# Epoch: 76 	Training Loss: 0.000089
# Saving activations/epoch00000075
# Test Accuracy on 10,000 images: 98.79%
# Epoch: 77 	Training Loss: 0.000086
# Test Accuracy on 10,000 images: 98.88%
# Epoch: 78 	Training Loss: 0.000084
# Test Accuracy on 10,000 images: 98.95%
# Epoch: 79 	Training Loss: 0.000081
# Test Accuracy on 10,000 images: 98.88%
# Epoch: 80 	Training Loss: 0.000080
# Test Accuracy on 10,000 images: 98.84%
# Epoch: 81 	Training Loss: 0.000077
# Saving activations/epoch00000080
# Test Accuracy on 10,000 images: 98.62%
# Epoch: 82 	Training Loss: 0.000079
# Test Accuracy on 10,000 images: 98.80%
# Epoch: 83 	Training Loss: 0.000076
# Test Accuracy on 10,000 images: 98.91%
# Epoch: 84 	Training Loss: 0.000073
# Test Accuracy on 10,000 images: 98.86%
# Epoch: 85 	Training Loss: 0.000071
# Test Accuracy on 10,000 images: 98.83%
# Epoch: 86 	Training Loss: 0.000069
# Saving activations/epoch00000085
# Test Accuracy on 10,000 images: 98.80%
# Epoch: 87 	Training Loss: 0.000070
# Test Accuracy on 10,000 images: 98.91%
# Epoch: 88 	Training Loss: 0.000066
# Test Accuracy on 10,000 images: 98.89%
# Epoch: 89 	Training Loss: 0.000065
# Test Accuracy on 10,000 images: 98.76%
# Epoch: 90 	Training Loss: 0.000063
# Test Accuracy on 10,000 images: 98.79%
# Epoch: 91 	Training Loss: 0.000060
# Saving activations/epoch00000090
# Test Accuracy on 10,000 images: 98.84%
# Epoch: 92 	Training Loss: 0.000061
# Test Accuracy on 10,000 images: 98.87%
# Epoch: 93 	Training Loss: 0.000058
# Test Accuracy on 10,000 images: 98.96%
# Epoch: 94 	Training Loss: 0.000058
# Test Accuracy on 10,000 images: 98.90%
# Epoch: 95 	Training Loss: 0.000054
# Test Accuracy on 10,000 images: 98.84%
# Epoch: 96 	Training Loss: 0.000053
# Saving activations/epoch00000095
# Test Accuracy on 10,000 images: 98.83%
# Epoch: 97 	Training Loss: 0.000053
# Test Accuracy on 10,000 images: 98.91%
# Epoch: 98 	Training Loss: 0.000053
# Test Accuracy on 10,000 images: 98.83%
# Epoch: 99 	Training Loss: 0.000049
# Test Accuracy on 10,000 images: 98.81%
# Epoch: 100 	Training Loss: 0.000048
# Test Accuracy on 10,000 images: 98.90%
# *** Doing activations ***
# Doing activations/epoch00000000
# - Layer 0 upper: MI(X;M)=13.296, MI(Y;M)=3.320, h_upper=3366.567, hM_given_X=3357.351, hM_given_Y_upper=3364.266
# - Layer 1 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=1687.885, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 2 upper: MI(X;M)=13.273, MI(Y;M)=3.319, h_upper=26.329, hM_given_X=17.129, hM_given_Y_upper=24.028
# - Layer 3 upper: MI(X;M)=13.250, MI(Y;M)=3.319, h_upper=14.537, hM_given_X=5.353, hM_given_Y_upper=12.236
# - Layer 4 upper: MI(X;M)=3.614, MI(Y;M)=2.617, h_upper=5.181, hM_given_X=2.676, hM_given_Y_upper=3.367
# Doing activations/epoch00000001
# - Layer 0 upper: MI(X;M)=13.295, MI(Y;M)=3.320, h_upper=3366.566, hM_given_X=3357.351, hM_given_Y_upper=3364.265
# - Layer 1 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=1687.885, hM_given_X=1678.676, hM_given_Y_upper=1685.584
# - Layer 2 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=26.338, hM_given_X=17.129, hM_given_Y_upper=24.037
# - Layer 3 upper: MI(X;M)=13.277, MI(Y;M)=3.319, h_upper=14.556, hM_given_X=5.353, hM_given_Y_upper=12.255
# - Layer 4 upper: MI(X;M)=3.643, MI(Y;M)=2.863, h_upper=5.202, hM_given_X=2.676, hM_given_Y_upper=3.217
# Doing activations/epoch00000002
# - Layer 0 upper: MI(X;M)=13.290, MI(Y;M)=3.320, h_upper=3366.563, hM_given_X=3357.351, hM_given_Y_upper=3364.262
# - Layer 1 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=1687.886, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 2 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=26.339, hM_given_X=17.129, hM_given_Y_upper=24.038
# - Layer 3 upper: MI(X;M)=13.281, MI(Y;M)=3.319, h_upper=14.558, hM_given_X=5.353, hM_given_Y_upper=12.258
# - Layer 4 upper: MI(X;M)=3.593, MI(Y;M)=2.963, h_upper=5.167, hM_given_X=2.676, hM_given_Y_upper=3.113
# Doing activations/epoch00000003
# - Layer 0 upper: MI(X;M)=13.295, MI(Y;M)=3.320, h_upper=3366.567, hM_given_X=3357.351, hM_given_Y_upper=3364.266
# - Layer 1 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=1687.884, hM_given_X=1678.676, hM_given_Y_upper=1685.583
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=26.339, hM_given_X=17.129, hM_given_Y_upper=24.038
# - Layer 3 upper: MI(X;M)=13.283, MI(Y;M)=3.319, h_upper=14.560, hM_given_X=5.353, hM_given_Y_upper=12.259
# - Layer 4 upper: MI(X;M)=3.567, MI(Y;M)=3.017, h_upper=5.149, hM_given_X=2.676, hM_given_Y_upper=3.058
# Doing activations/epoch00000004
# - Layer 0 upper: MI(X;M)=13.293, MI(Y;M)=3.319, h_upper=3366.565, hM_given_X=3357.351, hM_given_Y_upper=3364.264
# - Layer 1 upper: MI(X;M)=13.289, MI(Y;M)=3.319, h_upper=1687.887, hM_given_X=1678.676, hM_given_Y_upper=1685.586
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=26.339, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.284, MI(Y;M)=3.319, h_upper=14.561, hM_given_X=5.353, hM_given_Y_upper=12.260
# - Layer 4 upper: MI(X;M)=3.557, MI(Y;M)=3.030, h_upper=5.142, hM_given_X=2.676, hM_given_Y_upper=3.041
# Doing activations/epoch00000005
# - Layer 0 upper: MI(X;M)=13.282, MI(Y;M)=3.320, h_upper=3366.557, hM_given_X=3357.351, hM_given_Y_upper=3364.256
# - Layer 1 upper: MI(X;M)=13.291, MI(Y;M)=3.319, h_upper=1687.889, hM_given_X=1678.676, hM_given_Y_upper=1685.588
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=26.339, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=14.561, hM_given_X=5.353, hM_given_Y_upper=12.261
# - Layer 4 upper: MI(X;M)=3.506, MI(Y;M)=3.114, h_upper=5.107, hM_given_X=2.676, hM_given_Y_upper=2.948
# Doing activations/epoch00000006
# - Layer 0 upper: MI(X;M)=13.283, MI(Y;M)=3.320, h_upper=3366.558, hM_given_X=3357.351, hM_given_Y_upper=3364.257
# - Layer 1 upper: MI(X;M)=13.282, MI(Y;M)=3.319, h_upper=1687.882, hM_given_X=1678.676, hM_given_Y_upper=1685.581
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=14.562, hM_given_X=5.353, hM_given_Y_upper=12.261
# - Layer 4 upper: MI(X;M)=3.485, MI(Y;M)=3.132, h_upper=5.092, hM_given_X=2.676, hM_given_Y_upper=2.921
# Doing activations/epoch00000007
# - Layer 0 upper: MI(X;M)=13.297, MI(Y;M)=3.320, h_upper=3366.568, hM_given_X=3357.351, hM_given_Y_upper=3364.267
# - Layer 1 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=1687.885, hM_given_X=1678.676, hM_given_Y_upper=1685.584
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=14.562, hM_given_X=5.353, hM_given_Y_upper=12.261
# - Layer 4 upper: MI(X;M)=3.484, MI(Y;M)=3.140, h_upper=5.091, hM_given_X=2.676, hM_given_Y_upper=2.915
# Doing activations/epoch00000008
# - Layer 0 upper: MI(X;M)=13.277, MI(Y;M)=3.320, h_upper=3366.554, hM_given_X=3357.351, hM_given_Y_upper=3364.253
# - Layer 1 upper: MI(X;M)=13.290, MI(Y;M)=3.320, h_upper=1687.887, hM_given_X=1678.676, hM_given_Y_upper=1685.587
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=14.562, hM_given_X=5.353, hM_given_Y_upper=12.261
# - Layer 4 upper: MI(X;M)=3.460, MI(Y;M)=3.149, h_upper=5.074, hM_given_X=2.676, hM_given_Y_upper=2.892
# Doing activations/epoch00000009
# - Layer 0 upper: MI(X;M)=13.273, MI(Y;M)=3.319, h_upper=3366.551, hM_given_X=3357.351, hM_given_Y_upper=3364.250
# - Layer 1 upper: MI(X;M)=13.294, MI(Y;M)=3.319, h_upper=1687.890, hM_given_X=1678.676, hM_given_Y_upper=1685.590
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=14.562, hM_given_X=5.353, hM_given_Y_upper=12.261
# - Layer 4 upper: MI(X;M)=3.467, MI(Y;M)=3.159, h_upper=5.079, hM_given_X=2.676, hM_given_Y_upper=2.890
# Doing activations/epoch00000010
# - Layer 0 upper: MI(X;M)=13.297, MI(Y;M)=3.320, h_upper=3366.568, hM_given_X=3357.351, hM_given_Y_upper=3364.267
# - Layer 1 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=1687.885, hM_given_X=1678.676, hM_given_Y_upper=1685.584
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=14.562, hM_given_X=5.353, hM_given_Y_upper=12.261
# - Layer 4 upper: MI(X;M)=3.481, MI(Y;M)=3.127, h_upper=5.089, hM_given_X=2.676, hM_given_Y_upper=2.921
# Doing activations/epoch00000011
# - Layer 0 upper: MI(X;M)=13.293, MI(Y;M)=3.320, h_upper=3366.565, hM_given_X=3357.351, hM_given_Y_upper=3364.264
# - Layer 1 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=1687.884, hM_given_X=1678.676, hM_given_Y_upper=1685.583
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=14.562, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.443, MI(Y;M)=3.180, h_upper=5.063, hM_given_X=2.676, hM_given_Y_upper=2.858
# Doing activations/epoch00000012
# - Layer 0 upper: MI(X;M)=13.296, MI(Y;M)=3.319, h_upper=3366.567, hM_given_X=3357.351, hM_given_Y_upper=3364.266
# - Layer 1 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=1687.886, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.562, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.452, MI(Y;M)=3.181, h_upper=5.069, hM_given_X=2.676, hM_given_Y_upper=2.865
# Doing activations/epoch00000013
# - Layer 0 upper: MI(X;M)=13.284, MI(Y;M)=3.319, h_upper=3366.559, hM_given_X=3357.351, hM_given_Y_upper=3364.259
# - Layer 1 upper: MI(X;M)=13.292, MI(Y;M)=3.319, h_upper=1687.889, hM_given_X=1678.676, hM_given_Y_upper=1685.588
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.430, MI(Y;M)=3.184, h_upper=5.054, hM_given_X=2.676, hM_given_Y_upper=2.847
# Doing activations/epoch00000014
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.320, h_upper=3366.562, hM_given_X=3357.351, hM_given_Y_upper=3364.261
# - Layer 1 upper: MI(X;M)=13.290, MI(Y;M)=3.319, h_upper=1687.888, hM_given_X=1678.676, hM_given_Y_upper=1685.587
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.425, MI(Y;M)=3.185, h_upper=5.050, hM_given_X=2.676, hM_given_Y_upper=2.843
# Doing activations/epoch00000015
# - Layer 0 upper: MI(X;M)=13.291, MI(Y;M)=3.319, h_upper=3366.564, hM_given_X=3357.351, hM_given_Y_upper=3364.263
# - Layer 1 upper: MI(X;M)=13.284, MI(Y;M)=3.319, h_upper=1687.884, hM_given_X=1678.676, hM_given_Y_upper=1685.583
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.422, MI(Y;M)=3.197, h_upper=5.048, hM_given_X=2.676, hM_given_Y_upper=2.832
# Doing activations/epoch00000016
# - Layer 0 upper: MI(X;M)=13.285, MI(Y;M)=3.320, h_upper=3366.560, hM_given_X=3357.351, hM_given_Y_upper=3364.258
# - Layer 1 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=1687.886, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.413, MI(Y;M)=3.196, h_upper=5.042, hM_given_X=2.676, hM_given_Y_upper=2.827
# Doing activations/epoch00000017
# - Layer 0 upper: MI(X;M)=13.297, MI(Y;M)=3.320, h_upper=3366.568, hM_given_X=3357.351, hM_given_Y_upper=3364.267
# - Layer 1 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=1687.886, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.426, MI(Y;M)=3.187, h_upper=5.051, hM_given_X=2.676, hM_given_Y_upper=2.843
# Doing activations/epoch00000018
# - Layer 0 upper: MI(X;M)=13.303, MI(Y;M)=3.320, h_upper=3366.572, hM_given_X=3357.351, hM_given_Y_upper=3364.271
# - Layer 1 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=1687.886, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.414, MI(Y;M)=3.197, h_upper=5.043, hM_given_X=2.676, hM_given_Y_upper=2.827
# Doing activations/epoch00000019
# - Layer 0 upper: MI(X;M)=13.295, MI(Y;M)=3.320, h_upper=3366.566, hM_given_X=3357.351, hM_given_Y_upper=3364.265
# - Layer 1 upper: MI(X;M)=13.294, MI(Y;M)=3.319, h_upper=1687.890, hM_given_X=1678.676, hM_given_Y_upper=1685.589
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.407, MI(Y;M)=3.213, h_upper=5.038, hM_given_X=2.676, hM_given_Y_upper=2.810
# Doing activations/epoch00000020
# - Layer 0 upper: MI(X;M)=13.287, MI(Y;M)=3.320, h_upper=3366.561, hM_given_X=3357.351, hM_given_Y_upper=3364.260
# - Layer 1 upper: MI(X;M)=13.290, MI(Y;M)=3.319, h_upper=1687.887, hM_given_X=1678.676, hM_given_Y_upper=1685.587
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.420, MI(Y;M)=3.195, h_upper=5.047, hM_given_X=2.676, hM_given_Y_upper=2.833
# Doing activations/epoch00000025
# - Layer 0 upper: MI(X;M)=13.300, MI(Y;M)=3.320, h_upper=3366.570, hM_given_X=3357.351, hM_given_Y_upper=3364.269
# - Layer 1 upper: MI(X;M)=13.282, MI(Y;M)=3.319, h_upper=1687.882, hM_given_X=1678.676, hM_given_Y_upper=1685.582
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.396, MI(Y;M)=3.218, h_upper=5.030, hM_given_X=2.676, hM_given_Y_upper=2.800
# Doing activations/epoch00000030
# - Layer 0 upper: MI(X;M)=13.292, MI(Y;M)=3.319, h_upper=3366.565, hM_given_X=3357.351, hM_given_Y_upper=3364.264
# - Layer 1 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=1687.886, hM_given_X=1678.676, hM_given_Y_upper=1685.586
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.398, MI(Y;M)=3.216, h_upper=5.032, hM_given_X=2.676, hM_given_Y_upper=2.803
# Doing activations/epoch00000035
# - Layer 0 upper: MI(X;M)=13.292, MI(Y;M)=3.320, h_upper=3366.564, hM_given_X=3357.351, hM_given_Y_upper=3364.263
# - Layer 1 upper: MI(X;M)=13.291, MI(Y;M)=3.319, h_upper=1687.888, hM_given_X=1678.676, hM_given_Y_upper=1685.587
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.389, MI(Y;M)=3.224, h_upper=5.025, hM_given_X=2.676, hM_given_Y_upper=2.790
# Doing activations/epoch00000040
# - Layer 0 upper: MI(X;M)=13.291, MI(Y;M)=3.319, h_upper=3366.564, hM_given_X=3357.351, hM_given_Y_upper=3364.263
# - Layer 1 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=1687.886, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.378, MI(Y;M)=3.228, h_upper=5.018, hM_given_X=2.676, hM_given_Y_upper=2.781
# Doing activations/epoch00000045
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.320, h_upper=3366.563, hM_given_X=3357.351, hM_given_Y_upper=3364.262
# - Layer 1 upper: MI(X;M)=13.290, MI(Y;M)=3.319, h_upper=1687.888, hM_given_X=1678.676, hM_given_Y_upper=1685.587
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.379, MI(Y;M)=3.229, h_upper=5.019, hM_given_X=2.676, hM_given_Y_upper=2.781
# Doing activations/epoch00000050
# - Layer 0 upper: MI(X;M)=13.285, MI(Y;M)=3.320, h_upper=3366.560, hM_given_X=3357.351, hM_given_Y_upper=3364.259
# - Layer 1 upper: MI(X;M)=13.292, MI(Y;M)=3.320, h_upper=1687.889, hM_given_X=1678.676, hM_given_Y_upper=1685.588
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.376, MI(Y;M)=3.229, h_upper=5.017, hM_given_X=2.676, hM_given_Y_upper=2.779
# Doing activations/epoch00000055
# - Layer 0 upper: MI(X;M)=13.294, MI(Y;M)=3.320, h_upper=3366.566, hM_given_X=3357.351, hM_given_Y_upper=3364.265
# - Layer 1 upper: MI(X;M)=13.284, MI(Y;M)=3.319, h_upper=1687.884, hM_given_X=1678.676, hM_given_Y_upper=1685.583
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.372, MI(Y;M)=3.233, h_upper=5.014, hM_given_X=2.676, hM_given_Y_upper=2.773
# Doing activations/epoch00000060
# - Layer 0 upper: MI(X;M)=13.307, MI(Y;M)=3.320, h_upper=3366.575, hM_given_X=3357.351, hM_given_Y_upper=3364.274
# - Layer 1 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=1687.885, hM_given_X=1678.676, hM_given_Y_upper=1685.584
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.364, MI(Y;M)=3.233, h_upper=5.008, hM_given_X=2.676, hM_given_Y_upper=2.767
# Doing activations/epoch00000065
# - Layer 0 upper: MI(X;M)=13.309, MI(Y;M)=3.320, h_upper=3366.577, hM_given_X=3357.351, hM_given_Y_upper=3364.276
# - Layer 1 upper: MI(X;M)=13.284, MI(Y;M)=3.319, h_upper=1687.884, hM_given_X=1678.676, hM_given_Y_upper=1685.583
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.366, MI(Y;M)=3.234, h_upper=5.010, hM_given_X=2.676, hM_given_Y_upper=2.768
# Doing activations/epoch00000070
# - Layer 0 upper: MI(X;M)=13.305, MI(Y;M)=3.320, h_upper=3366.573, hM_given_X=3357.351, hM_given_Y_upper=3364.272
# - Layer 1 upper: MI(X;M)=13.293, MI(Y;M)=3.319, h_upper=1687.889, hM_given_X=1678.676, hM_given_Y_upper=1685.589
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.361, MI(Y;M)=3.235, h_upper=5.006, hM_given_X=2.676, hM_given_Y_upper=2.764
# Doing activations/epoch00000075
# - Layer 0 upper: MI(X;M)=13.300, MI(Y;M)=3.320, h_upper=3366.570, hM_given_X=3357.351, hM_given_Y_upper=3364.269
# - Layer 1 upper: MI(X;M)=13.284, MI(Y;M)=3.319, h_upper=1687.884, hM_given_X=1678.676, hM_given_Y_upper=1685.583
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.359, MI(Y;M)=3.227, h_upper=5.004, hM_given_X=2.676, hM_given_Y_upper=2.767
# Doing activations/epoch00000080
# - Layer 0 upper: MI(X;M)=13.309, MI(Y;M)=3.320, h_upper=3366.576, hM_given_X=3357.351, hM_given_Y_upper=3364.275
# - Layer 1 upper: MI(X;M)=13.284, MI(Y;M)=3.319, h_upper=1687.883, hM_given_X=1678.676, hM_given_Y_upper=1685.582
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.361, MI(Y;M)=3.220, h_upper=5.006, hM_given_X=2.676, hM_given_Y_upper=2.774
# Doing activations/epoch00000085
# - Layer 0 upper: MI(X;M)=13.324, MI(Y;M)=3.320, h_upper=3366.587, hM_given_X=3357.351, hM_given_Y_upper=3364.286
# - Layer 1 upper: MI(X;M)=13.289, MI(Y;M)=3.319, h_upper=1687.887, hM_given_X=1678.676, hM_given_Y_upper=1685.586
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.357, MI(Y;M)=3.229, h_upper=5.003, hM_given_X=2.676, hM_given_Y_upper=2.765
# Doing activations/epoch00000090
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=3366.562, hM_given_X=3357.351, hM_given_Y_upper=3364.261
# - Layer 1 upper: MI(X;M)=13.283, MI(Y;M)=3.319, h_upper=1687.882, hM_given_X=1678.676, hM_given_Y_upper=1685.582
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.359, MI(Y;M)=3.229, h_upper=5.005, hM_given_X=2.676, hM_given_Y_upper=2.767
# Doing activations/epoch00000095
# - Layer 0 upper: MI(X;M)=13.316, MI(Y;M)=3.320, h_upper=3366.581, hM_given_X=3357.351, hM_given_Y_upper=3364.280
# - Layer 1 upper: MI(X;M)=13.283, MI(Y;M)=3.319, h_upper=1687.883, hM_given_X=1678.676, hM_given_Y_upper=1685.582
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.354, MI(Y;M)=3.226, h_upper=5.001, hM_given_X=2.676, hM_given_Y_upper=2.765

# %%
accuracyG = [
    86.69, 91.43, 93.62, 94.46, 94.37, 96.55, 96.94, 96.88, 97.21, 97.29,
    96.50, 97.70, 97.65, 97.82, 97.91, 98.00, 98.01, 97.88, 98.06, 98.35,
    97.99, 98.46, 98.39, 98.53, 98.40, 98.43, 98.59, 98.46, 98.49, 98.61,
    98.44, 98.59, 98.73, 98.65, 98.59, 98.55, 98.55, 98.48, 98.69, 98.65,
self).__init__()
        self.sigma = nn.Parameter(torch.tensor(0.3))

    def forward(self, input):
        temp = input/2*(1+torch.erf(input/math.sqrt(2)/self.sigma))#GELU
        #temp = input*torch.sigmoid(input)#SiLU
        return temp
        
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, padding=1)  # 输入通道数1，输出通道数16，卷积核大小3x3
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1) # 输入通道数16，输出通道数32，卷积核大小3x3
        self.pool = nn.MaxPool2d(2, 2)                           # 2x2的最大池化层
        self.fc1 = nn.Linear(32 * 7 * 7, 64)                    # 全连接层，输入维度32*7*7，输出维度64
        self.fc2 = nn.Linear(64, 20)                            # 全连接层，输入维度64，输出维度10（对应10个类别）
        self.fc3 = nn.Linear(20, 10)
        self.act1 = CustomActivation()
        self.act2 = CustomActivation()
        self.act3 = CustomActivation()
        self.act4 = CustomActivation()
    def forward(self, x):
        activations = []
        x = self.act1(self.conv1(x))  # 第一层卷积 + ReLU激活 
        xx= torch.flatten(x, 1)
        activations.append(xx.cpu().data.numpy())#layer1
        x = self.pool(x)
        x = self.act2(self.conv2(x))  # 第二层卷积 + ReLU激活
        xx= torch.flatten(x, 1)
        activations.append(xx.cpu().data.numpy())#layer1
        x = self.pool(x)
        x = x.view(-1, 32 * 7 * 7)            # 展平操作，为全连接层做准备
        x = self.act3(self.fc1(x))               # 第一个全连接层 + ReLU激活
        activations.append(x.cpu().data.numpy())#layer1
        x = self.act4(self.fc2(x))               # 第一个全连接层 + ReLU激活
        activations.append(x.cpu().data.numpy())#layer1
        x = self.fc3(x)# 第二个全连接层（输出层）
        x = torch.softmax(x, dim=1)
        activations.append(x.cpu().data.numpy())
        return x, activations


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

class MI_Plate():
    def __init__(self, n_epochs=100, DO_LOWER=False, DO_BINNED=False, PLOT_LAYERS=None):
        super(MI_Plate, self).__init__()
        
        self.n_epochs = n_epochs
        self.DO_LOWER = DO_LOWER
        self.DO_BINNED = DO_BINNED
        self.PLOT_LAYERS = PLOT_LAYERS
#DO_LOWER和DO_BINNED是用于控制数据预处理的布尔值，PLOT_LAYERS是用于指定绘制哪些层的激活值的列表
    def save_activations(self):
        
        if not os.path.exists('activations'):
            print("Making directory", 'activations')
            os.mkdir('activations')
            
        model = Net()
        model.apply(init_weights)

        optimizer = optim.SGD(model.parameters(), lr=0.01)
        #optimizer = optim.Adam(model.parameters(), lr=0.001)
        # Move model to GPU if available
        if train_on_gpu:
            model.cuda()

        for epoch in range(self.n_epochs):
            # monitor training loss
            train_loss = 0.0

            ###################
            # train the model #
            ###################
            model.train()

            for data, target in train_loader:
                if train_on_gpu:
                    data, target = data.cuda(), target.cuda()  # Move data to GPU
                optimizer.zero_grad()
                output, _ = model(data)
                loss = categorical_cross_entropy(output, target)
                # backward
                loss.backward()
                optimizer.step()
                train_loss += loss.item()#*data.size(0)

            # calculate average loss over an epoch
            train_loss = train_loss/len(train_loader.dataset)

            print('Epoch: {} \tTraining Loss: {:.6f}'.format(epoch+1, train_loss))

            model.eval()
########每次按照规定的epoch训练之后，都用full全部数据通过网络一次，记住标签和网络输出
###############################################################################            
            for data, _ in full_data_loader:
                if train_on_gpu:
                    data = data.cuda()  # Move data to GPU
                _, activations = model(data)
#定义多少epoch进行存储每层的输出，前20每次都存，高于200次100次再存一次
            if epoch < 20:       # Log for all first 20 epochs
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            #pickle.HIGHEST_PROTOCOL 用于指定 pickle 协议的版本，以确保最高的兼容性和效率
            elif (epoch < 100) and (epoch % 5 == 0):    # Then for every 5th epoch
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            elif (epoch < 200) and (epoch % 10 == 0):    # Then every 10th
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            elif (epoch % 100 == 0):                # Then every 100th
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
         #####################****************************************
            correct = 0
            total = 0
            with torch.no_grad():
                for data, target in test_loader:  # Assuming test_loader is defined elsewhere
                    if train_on_gpu:
                        data, target = data.cuda(), target.cuda()  # Move data to GPU
                    output, _ = model(data)
                    _, predicted = torch.max(output.data, 1)
                    total += target.size(0)
                    correct += (predicted == target).sum().item()

            accuracy = 100 * correct / total
            print('Test Accuracy on 10,000 images: {:.2f}%'.format(accuracy))  
      ###########################
    def compute_MI(self, noise_variance=1e-1):
        
        MAX_EPOCHS = self.n_epochs
        self.noise_variance = noise_variance
        
        def entropy_func_upper(x):
            return kde.entropy_estimator_kl(x,self.noise_variance)
        
        def entropy_func_lower(x):
            return kde.entropy_estimator_bd(x,self.noise_variance)

        # nats to bits conversion factor
        nats2bits = 1.0/np.log(2) 


        # Save indexes of tests data for each of the output classes
        saved_labelixs = {}
        for data, targets in full_data_loader:
            trg = targets.numpy()
        for i in range(10):
            saved_labelixs[i] = trg == i

        labelprobs = np.mean(np.eye(10)[test_data.targets], axis=0)

        MI_XM_upper_array = []
        MI_YM_upper_array = []
###这段代码的作用是计算每个类别在数据集中出现的频率，并保存每个类别的索引以供后续使用
        measures = OrderedDict()
        measures['tanh'] = {}

        cur_dir = 'activations'
        if not os.path.exists(cur_dir):
            print("Directory %s not found" % cur_dir)

        # Load files saved during each epoch, and compute MI measures of the activity in that epoch
        print('*** Doing %s ***' % cur_dir)
        for epochfile in sorted(os.listdir(cur_dir)):
            if not epochfile.startswith('epoch'):
                continue

            fname = cur_dir + "/" + epochfile
            with open(fname, 'rb') as f:
                d = pickle.load(f)

            epoch = d[1]
            d = d[0]
            if epoch in measures['tanh']:# Skip this epoch if its already been processed
                continue                # this is a trick to allow us to rerun this cell multiple times)

            if epoch > MAX_EPOCHS:
                continue

            print("Doing", fname)

            num_layers = len(d)

            MI_XM_upper_epoch = []
            MI_YM_upper_epoch = []
            
            if self.PLOT_LAYERS is None:
                PLOT_LAYERS = []
                for lndx in range(num_layers):
                    PLOT_LAYERS.append(lndx)

            cepochdata = defaultdict(list)
            for lndx in range(num_layers):
                activity = d[lndx]

                # Compute marginal entropies
                h_upper = entropy_func_upper(activity)
                if self.DO_LOWER:
                    #h_lower = entropy_func_lower([activity,])[0]
                    h_lower = entropy_func_lower(activity)

                # Layer activity given input. This is simply the entropy of the Gaussian noise
                hM_given_X = kde.kde_condentropy(activity, self.noise_variance)

                # Compute conditional entropies of layer activity given output
                hM_given_Y_upper=0.
                for i in range(10):
                    hcond_upper = entropy_func_upper(activity[saved_labelixs[i],:])
                    hM_given_Y_upper += labelprobs[i] * hcond_upper

                if self.DO_LOWER:
                    hM_given_Y_lower=0.
                    for i in range(10):
                        hcond_lower = entropy_func_lower(activity[saved_labelixs[i],:])
                        hM_given_Y_lower += labelprobs[i] * hcond_lower

                cepochdata['MI_XM_upper'].append( nats2bits * (h_upper - hM_given_X) )
                cepochdata['MI_YM_upper'].append( nats2bits * (h_upper - hM_given_Y_upper) )
                cepochdata['H_M_upper'  ].append( nats2bits * h_upper )


                MI_XM_upper = nats2bits * (h_upper - hM_given_X)
                MI_YM_upper = nats2bits * (h_upper - hM_given_Y_upper)

                MI_XM_upper_epoch.append(MI_XM_upper)
                MI_YM_upper_epoch.append(MI_YM_upper)
                
                pstr = 'upper: MI(X;M)=%0.3f, MI(Y;M)=%0.3f, h_upper=%0.3f, hM_given_X=%0.3f, hM_given_Y_upper=%0.3f ' % (cepochdata['MI_XM_upper'][-1], cepochdata['MI_YM_upper'][-1], h_upper, hM_given_X, hM_given_Y_upper)
                if self.DO_LOWER:  # Compute lower bounds
                    cepochdata['MI_XM_lower'].append( nats2bits * (h_lower - hM_given_X) )
                    cepochdata['MI_YM_lower'].append( nats2bits * (h_lower - hM_given_Y_lower) )
                    cepochdata['H_M_lower'  ].append( nats2bits * h_lower )
                    pstr += ' | lower: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_lower'][-1], cepochdata['MI_YM_lower'][-1])

                if self.DO_BINNED: # Compute binner estimates
                    binxm, binym = simplebinmi.bin_calc_information2(saved_labelixs, activity, 0.5)
                    cepochdata['MI_XM_bin'].append( nats2bits * binxm )
                    cepochdata['MI_YM_bin'].append( nats2bits * binym )
                    pstr += ' | bin: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_bin'][-1], cepochdata['MI_YM_bin'][-1])

                print('- Layer %d %s' % (lndx, pstr) )

            measures['tanh'][epoch] = cepochdata
            MI_XM_upper_array.append(MI_XM_upper_epoch)
            MI_YM_upper_array.append(MI_YM_upper_epoch)
             
            #epoch += 1
        MI_XM_upper_array = np.array(MI_XM_upper_array)
        MI_YM_upper_array = np.array(MI_YM_upper_array)

    # Save the results as arrays
        np.save('D:/深度学习与信息论/MI_XM_upper_arrayG.npy', MI_XM_upper_array)
        np.save('D:/深度学习与信息论/MI_YM_upper_arrayG.npy', MI_YM_upper_array)

        with open('MI', 'wb') as f:
            pickle.dump(measures, f, pickle.HIGHEST_PROTOCOL) 

Plate = MI_Plate() #Create class object
Plate.save_activations() #save activations if they weren't saved already
Plate.compute_MI() #compute and save MIs if they weren't saved before
# Out:
# Epoch: 1 	Training Loss: 0.010358
# Saving activations/epoch00000000
# Test Accuracy on 10,000 images: 86.74%
# Epoch: 2 	Training Loss: 0.002717
# Saving activations/epoch00000001
# Test Accuracy on 10,000 images: 92.14%
# Epoch: 3 	Training Loss: 0.001911
# Saving activations/epoch00000002
# Test Accuracy on 10,000 images: 94.48%
# Epoch: 4 	Training Loss: 0.001476
# Saving activations/epoch00000003
# Test Accuracy on 10,000 images: 94.72%
# Epoch: 5 	Training Loss: 0.001224
# Saving activations/epoch00000004
# Test Accuracy on 10,000 images: 95.87%
# Epoch: 6 	Training Loss: 0.001034
# Saving activations/epoch00000005
# Test Accuracy on 10,000 images: 96.43%
# Epoch: 7 	Training Loss: 0.000910
# Saving activations/epoch00000006
# Test Accuracy on 10,000 images: 96.94%
# Epoch: 8 	Training Loss: 0.000807
# Saving activations/epoch00000007
# Test Accuracy on 10,000 images: 97.13%
# Epoch: 9 	Training Loss: 0.000744
# Saving activations/epoch00000008
# Test Accuracy on 10,000 images: 97.02%
# Epoch: 10 	Training Loss: 0.000693
# Saving activations/epoch00000009
# Test Accuracy on 10,000 images: 97.32%
# Epoch: 11 	Training Loss: 0.000636
# Saving activations/epoch00000010
# Test Accuracy on 10,000 images: 97.71%
# Epoch: 12 	Training Loss: 0.000596
# Saving activations/epoch00000011
# Test Accuracy on 10,000 images: 97.69%
# Epoch: 13 	Training Loss: 0.000563
# Saving activations/epoch00000012
# Test Accuracy on 10,000 images: 97.99%
# Epoch: 14 	Training Loss: 0.000531
# Saving activations/epoch00000013
# Test Accuracy on 10,000 images: 97.99%
# Epoch: 15 	Training Loss: 0.000507
# Saving activations/epoch00000014
# Test Accuracy on 10,000 images: 98.15%
# Epoch: 16 	Training Loss: 0.000477
# Saving activations/epoch00000015
# Test Accuracy on 10,000 images: 98.11%
# Epoch: 17 	Training Loss: 0.000458
# Saving activations/epoch00000016
# Test Accuracy on 10,000 images: 98.13%
# Epoch: 18 	Training Loss: 0.000439
# Saving activations/epoch00000017
# Test Accuracy on 10,000 images: 98.18%
# Epoch: 19 	Training Loss: 0.000417
# Saving activations/epoch00000018
# Test Accuracy on 10,000 images: 98.16%
# Epoch: 20 	Training Loss: 0.000403
# Saving activations/epoch00000019
# Test Accuracy on 10,000 images: 97.79%
# Epoch: 21 	Training Loss: 0.000390
# Saving activations/epoch00000020
# Test Accuracy on 10,000 images: 98.23%
# Epoch: 22 	Training Loss: 0.000376
# Test Accuracy on 10,000 images: 98.30%
# Epoch: 23 	Training Loss: 0.000358
# Test Accuracy on 10,000 images: 98.27%
# Epoch: 24 	Training Loss: 0.000345
# Test Accuracy on 10,000 images: 98.43%
# Epoch: 25 	Training Loss: 0.000335
# Test Accuracy on 10,000 images: 98.51%
# Epoch: 26 	Training Loss: 0.000324
# Saving activations/epoch00000025
# Test Accuracy on 10,000 images: 98.59%
# Epoch: 27 	Training Loss: 0.000314
# Test Accuracy on 10,000 images: 98.20%
# Epoch: 28 	Training Loss: 0.000305
# Test Accuracy on 10,000 images: 98.21%
# Epoch: 29 	Training Loss: 0.000295
# Test Accuracy on 10,000 images: 98.26%
# Epoch: 30 	Training Loss: 0.000288
# Test Accuracy on 10,000 images: 98.70%
# Epoch: 31 	Training Loss: 0.000276
# Saving activations/epoch00000030
# Test Accuracy on 10,000 images: 98.56%
# Epoch: 32 	Training Loss: 0.000263
# Test Accuracy on 10,000 images: 98.20%
# Epoch: 33 	Training Loss: 0.000260
# Test Accuracy on 10,000 images: 98.64%
# Epoch: 34 	Training Loss: 0.000251
# Test Accuracy on 10,000 images: 98.65%
# Epoch: 35 	Training Loss: 0.000251
# Test Accuracy on 10,000 images: 98.67%
# Epoch: 36 	Training Loss: 0.000240
# Saving activations/epoch00000035
# Test Accuracy on 10,000 images: 98.63%
# Epoch: 37 	Training Loss: 0.000232
# Test Accuracy on 10,000 images: 98.60%
# Epoch: 38 	Training Loss: 0.000224
# Test Accuracy on 10,000 images: 98.71%
# Epoch: 39 	Training Loss: 0.000222
# Test Accuracy on 10,000 images: 98.59%
# Epoch: 40 	Training Loss: 0.000215
# Test Accuracy on 10,000 images: 98.60%
# Epoch: 41 	Training Loss: 0.000213
# Saving activations/epoch00000040
# Test Accuracy on 10,000 images: 98.75%
# Epoch: 42 	Training Loss: 0.000200
# Test Accuracy on 10,000 images: 98.73%
# Epoch: 43 	Training Loss: 0.000198
# Test Accuracy on 10,000 images: 98.67%
# Epoch: 44 	Training Loss: 0.000190
# Test Accuracy on 10,000 images: 98.68%
# Epoch: 45 	Training Loss: 0.000189
# Test Accuracy on 10,000 images: 98.67%
# Epoch: 46 	Training Loss: 0.000182
# Saving activations/epoch00000045
# Test Accuracy on 10,000 images: 98.19%
# Epoch: 47 	Training Loss: 0.000184
# Test Accuracy on 10,000 images: 98.74%
# Epoch: 48 	Training Loss: 0.000174
# Test Accuracy on 10,000 images: 98.71%
# Epoch: 49 	Training Loss: 0.000172
# Test Accuracy on 10,000 images: 98.73%
# Epoch: 50 	Training Loss: 0.000164
# Test Accuracy on 10,000 images: 98.76%
# Epoch: 51 	Training Loss: 0.000161
# Saving activations/epoch00000050
# Test Accuracy on 10,000 images: 98.69%
# Epoch: 52 	Training Loss: 0.000159
# Test Accuracy on 10,000 images: 98.73%
# Epoch: 53 	Training Loss: 0.000152
# Test Accuracy on 10,000 images: 98.79%
# Epoch: 54 	Training Loss: 0.000149
# Test Accuracy on 10,000 images: 98.62%
# Epoch: 55 	Training Loss: 0.000144
# Test Accuracy on 10,000 images: 98.68%
# Epoch: 56 	Training Loss: 0.000143
# Saving activations/epoch00000055
# Test Accuracy on 10,000 images: 98.78%
# Epoch: 57 	Training Loss: 0.000138
# Test Accuracy on 10,000 images: 98.79%
# Epoch: 58 	Training Loss: 0.000133
# Test Accuracy on 10,000 images: 98.85%
# Epoch: 59 	Training Loss: 0.000132
# Test Accuracy on 10,000 images: 98.82%
# Epoch: 60 	Training Loss: 0.000129
# Test Accuracy on 10,000 images: 98.67%
# Epoch: 61 	Training Loss: 0.000128
# Saving activations/epoch00000060
# Test Accuracy on 10,000 images: 98.61%
# Epoch: 62 	Training Loss: 0.000121
# Test Accuracy on 10,000 images: 98.74%
# Epoch: 63 	Training Loss: 0.000117
# Test Accuracy on 10,000 images: 98.72%
# Epoch: 64 	Training Loss: 0.000121
# Test Accuracy on 10,000 images: 98.69%
# Epoch: 65 	Training Loss: 0.000110
# Test Accuracy on 10,000 images: 98.73%
# Epoch: 66 	Training Loss: 0.000110
# Saving activations/epoch00000065
# Test Accuracy on 10,000 images: 98.64%
# Epoch: 67 	Training Loss: 0.000108
# Test Accuracy on 10,000 images: 98.75%
# Epoch: 68 	Training Loss: 0.000105
# Test Accuracy on 10,000 images: 98.73%
# Epoch: 69 	Training Loss: 0.000103
# Test Accuracy on 10,000 images: 98.79%
# Epoch: 70 	Training Loss: 0.000100
# Test Accuracy on 10,000 images: 98.68%
# Epoch: 71 	Training Loss: 0.000097
# Saving activations/epoch00000070
# Test Accuracy on 10,000 images: 98.77%
# Epoch: 72 	Training Loss: 0.000094
# Test Accuracy on 10,000 images: 98.69%
# Epoch: 73 	Training Loss: 0.000094
# Test Accuracy on 10,000 images: 98.80%
# Epoch: 74 	Training Loss: 0.000091
# Test Accuracy on 10,000 images: 98.76%
# Epoch: 75 	Training Loss: 0.000091
# Test Accuracy on 10,000 images: 98.71%
# Epoch: 76 	Training Loss: 0.000084
# Saving activations/epoch00000075
# Test Accuracy on 10,000 images: 98.69%
# Epoch: 77 	Training Loss: 0.000085
# Test Accuracy on 10,000 images: 98.73%
# Epoch: 78 	Training Loss: 0.000082
# Test Accuracy on 10,000 images: 98.85%
# Epoch: 79 	Training Loss: 0.000077
# Test Accuracy on 10,000 images: 98.68%
# Epoch: 80 	Training Loss: 0.000077
# Test Accuracy on 10,000 images: 98.82%
# Epoch: 81 	Training Loss: 0.000075
# Saving activations/epoch00000080
# Test Accuracy on 10,000 images: 98.81%
# Epoch: 82 	Training Loss: 0.000076
# Test Accuracy on 10,000 images: 98.85%
# Epoch: 83 	Training Loss: 0.000072
# Test Accuracy on 10,000 images: 98.83%
# Epoch: 84 	Training Loss: 0.000072
# Test Accuracy on 10,000 images: 98.65%
# Epoch: 85 	Training Loss: 0.000070
# Test Accuracy on 10,000 images: 98.77%
# Epoch: 86 	Training Loss: 0.000067
# Saving activations/epoch00000085
# Test Accuracy on 10,000 images: 98.81%
# Epoch: 87 	Training Loss: 0.000064
# Test Accuracy on 10,000 images: 98.63%
# Epoch: 88 	Training Loss: 0.000064
# Test Accuracy on 10,000 images: 98.79%
# Epoch: 89 	Training Loss: 0.000062
# Test Accuracy on 10,000 images: 98.79%
# Epoch: 90 	Training Loss: 0.000063
# Test Accuracy on 10,000 images: 98.79%
# Epoch: 91 	Training Loss: 0.000060
# Saving activations/epoch00000090
# Test Accuracy on 10,000 images: 98.77%
# Epoch: 92 	Training Loss: 0.000057
# Test Accuracy on 10,000 images: 98.74%
# Epoch: 93 	Training Loss: 0.000055
# Test Accuracy on 10,000 images: 98.74%
# Epoch: 94 	Training Loss: 0.000058
# Test Accuracy on 10,000 images: 98.86%
# Epoch: 95 	Training Loss: 0.000056
# Test Accuracy on 10,000 images: 98.72%
# Epoch: 96 	Training Loss: 0.000053
# Saving activations/epoch00000095
# Test Accuracy on 10,000 images: 98.79%
# Epoch: 97 	Training Loss: 0.000051
# Test Accuracy on 10,000 images: 98.76%
# Epoch: 98 	Training Loss: 0.000051
# Test Accuracy on 10,000 images: 98.78%
# Epoch: 99 	Training Loss: 0.000048
# Test Accuracy on 10,000 images: 98.79%
# Epoch: 100 	Training Loss: 0.000046
# Test Accuracy on 10,000 images: 98.82%
# *** Doing activations ***
# Doing activations/epoch00000000
# - Layer 0 upper: MI(X;M)=13.290, MI(Y;M)=3.320, h_upper=3366.563, hM_given_X=3357.351, hM_given_Y_upper=3364.262
# - Layer 1 upper: MI(X;M)=13.283, MI(Y;M)=3.319, h_upper=1687.883, hM_given_X=1678.676, hM_given_Y_upper=1685.582
# - Layer 2 upper: MI(X;M)=13.281, MI(Y;M)=3.319, h_upper=26.335, hM_given_X=17.129, hM_given_Y_upper=24.034
# - Layer 3 upper: MI(X;M)=13.264, MI(Y;M)=3.319, h_upper=14.547, hM_given_X=5.353, hM_given_Y_upper=12.246
# - Layer 4 upper: MI(X;M)=3.667, MI(Y;M)=2.659, h_upper=5.218, hM_given_X=2.676, hM_given_Y_upper=3.375
# Doing activations/epoch00000001
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.319, h_upper=3366.562, hM_given_X=3357.351, hM_given_Y_upper=3364.262
# - Layer 1 upper: MI(X;M)=13.283, MI(Y;M)=3.319, h_upper=1687.883, hM_given_X=1678.676, hM_given_Y_upper=1685.582
# - Layer 2 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=26.339, hM_given_X=17.129, hM_given_Y_upper=24.038
# - Layer 3 upper: MI(X;M)=13.281, MI(Y;M)=3.319, h_upper=14.559, hM_given_X=5.353, hM_given_Y_upper=12.258
# - Layer 4 upper: MI(X;M)=3.627, MI(Y;M)=2.905, h_upper=5.191, hM_given_X=2.676, hM_given_Y_upper=3.177
# Doing activations/epoch00000002
# - Layer 0 upper: MI(X;M)=13.292, MI(Y;M)=3.320, h_upper=3366.564, hM_given_X=3357.351, hM_given_Y_upper=3364.264
# - Layer 1 upper: MI(X;M)=13.282, MI(Y;M)=3.319, h_upper=1687.882, hM_given_X=1678.676, hM_given_Y_upper=1685.581
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=26.339, hM_given_X=17.129, hM_given_Y_upper=24.038
# - Layer 3 upper: MI(X;M)=13.284, MI(Y;M)=3.319, h_upper=14.561, hM_given_X=5.353, hM_given_Y_upper=12.260
# - Layer 4 upper: MI(X;M)=3.582, MI(Y;M)=3.008, h_upper=5.159, hM_given_X=2.676, hM_given_Y_upper=3.074
# Doing activations/epoch00000003
# - Layer 0 upper: MI(X;M)=13.294, MI(Y;M)=3.320, h_upper=3366.566, hM_given_X=3357.351, hM_given_Y_upper=3364.265
# - Layer 1 upper: MI(X;M)=13.292, MI(Y;M)=3.319, h_upper=1687.889, hM_given_X=1678.676, hM_given_Y_upper=1685.588
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=26.339, hM_given_X=17.129, hM_given_Y_upper=24.038
# - Layer 3 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=14.562, hM_given_X=5.353, hM_given_Y_upper=12.261
# - Layer 4 upper: MI(X;M)=3.551, MI(Y;M)=3.026, h_upper=5.138, hM_given_X=2.676, hM_given_Y_upper=3.041
# Doing activations/epoch00000004
# - Layer 0 upper: MI(X;M)=13.293, MI(Y;M)=3.320, h_upper=3366.565, hM_given_X=3357.351, hM_given_Y_upper=3364.264
# - Layer 1 upper: MI(X;M)=13.281, MI(Y;M)=3.319, h_upper=1687.881, hM_given_X=1678.676, hM_given_Y_upper=1685.581
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=26.339, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=14.562, hM_given_X=5.353, hM_given_Y_upper=12.261
# - Layer 4 upper: MI(X;M)=3.517, MI(Y;M)=3.091, h_upper=5.114, hM_given_X=2.676, hM_given_Y_upper=2.972
# Doing activations/epoch00000005
# - Layer 0 upper: MI(X;M)=13.294, MI(Y;M)=3.320, h_upper=3366.566, hM_given_X=3357.351, hM_given_Y_upper=3364.265
# - Layer 1 upper: MI(X;M)=13.289, MI(Y;M)=3.319, h_upper=1687.887, hM_given_X=1678.676, hM_given_Y_upper=1685.586
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=26.339, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.562, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.509, MI(Y;M)=3.112, h_upper=5.109, hM_given_X=2.676, hM_given_Y_upper=2.952
# Doing activations/epoch00000006
# - Layer 0 upper: MI(X;M)=13.290, MI(Y;M)=3.320, h_upper=3366.563, hM_given_X=3357.351, hM_given_Y_upper=3364.262
# - Layer 1 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=1687.884, hM_given_X=1678.676, hM_given_Y_upper=1685.583
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.479, MI(Y;M)=3.137, h_upper=5.088, hM_given_X=2.676, hM_given_Y_upper=2.914
# Doing activations/epoch00000007
# - Layer 0 upper: MI(X;M)=13.296, MI(Y;M)=3.320, h_upper=3366.568, hM_given_X=3357.351, hM_given_Y_upper=3364.267
# - Layer 1 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=1687.885, hM_given_X=1678.676, hM_given_Y_upper=1685.584
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.467, MI(Y;M)=3.147, h_upper=5.080, hM_given_X=2.676, hM_given_Y_upper=2.899
# Doing activations/epoch00000008
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.319, h_upper=3366.562, hM_given_X=3357.351, hM_given_Y_upper=3364.262
# - Layer 1 upper: MI(X;M)=13.281, MI(Y;M)=3.319, h_upper=1687.881, hM_given_X=1678.676, hM_given_Y_upper=1685.581
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.471, MI(Y;M)=3.146, h_upper=5.082, hM_given_X=2.676, hM_given_Y_upper=2.902
# Doing activations/epoch00000009
# - Layer 0 upper: MI(X;M)=13.286, MI(Y;M)=3.320, h_upper=3366.560, hM_given_X=3357.351, hM_given_Y_upper=3364.259
# - Layer 1 upper: MI(X;M)=13.289, MI(Y;M)=3.319, h_upper=1687.887, hM_given_X=1678.676, hM_given_Y_upper=1685.586
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.448, MI(Y;M)=3.158, h_upper=5.066, hM_given_X=2.676, hM_given_Y_upper=2.877
# Doing activations/epoch00000010
# - Layer 0 upper: MI(X;M)=13.295, MI(Y;M)=3.320, h_upper=3366.567, hM_given_X=3357.351, hM_given_Y_upper=3364.266
# - Layer 1 upper: MI(X;M)=13.291, MI(Y;M)=3.319, h_upper=1687.888, hM_given_X=1678.676, hM_given_Y_upper=1685.587
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.441, MI(Y;M)=3.171, h_upper=5.062, hM_given_X=2.676, hM_given_Y_upper=2.864
# Doing activations/epoch00000011
# - Layer 0 upper: MI(X;M)=13.294, MI(Y;M)=3.320, h_upper=3366.566, hM_given_X=3357.351, hM_given_Y_upper=3364.265
# - Layer 1 upper: MI(X;M)=13.291, MI(Y;M)=3.319, h_upper=1687.888, hM_given_X=1678.676, hM_given_Y_upper=1685.588
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.435, MI(Y;M)=3.178, h_upper=5.057, hM_given_X=2.676, hM_given_Y_upper=2.855
# Doing activations/epoch00000012
# - Layer 0 upper: MI(X;M)=13.297, MI(Y;M)=3.320, h_upper=3366.568, hM_given_X=3357.351, hM_given_Y_upper=3364.267
# - Layer 1 upper: MI(X;M)=13.285, MI(Y;M)=3.320, h_upper=1687.884, hM_given_X=1678.676, hM_given_Y_upper=1685.583
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.429, MI(Y;M)=3.188, h_upper=5.053, hM_given_X=2.676, hM_given_Y_upper=2.844
# Doing activations/epoch00000013
# - Layer 0 upper: MI(X;M)=13.283, MI(Y;M)=3.320, h_upper=3366.558, hM_given_X=3357.351, hM_given_Y_upper=3364.257
# - Layer 1 upper: MI(X;M)=13.295, MI(Y;M)=3.320, h_upper=1687.891, hM_given_X=1678.676, hM_given_Y_upper=1685.590
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.425, MI(Y;M)=3.186, h_upper=5.051, hM_given_X=2.676, hM_given_Y_upper=2.842
# Doing activations/epoch00000014
# - Layer 0 upper: MI(X;M)=13.284, MI(Y;M)=3.319, h_upper=3366.559, hM_given_X=3357.351, hM_given_Y_upper=3364.259
# - Layer 1 upper: MI(X;M)=13.295, MI(Y;M)=3.319, h_upper=1687.891, hM_given_X=1678.676, hM_given_Y_upper=1685.591
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.431, MI(Y;M)=3.202, h_upper=5.055, hM_given_X=2.676, hM_given_Y_upper=2.835
# Doing activations/epoch00000015
# - Layer 0 upper: MI(X;M)=13.284, MI(Y;M)=3.320, h_upper=3366.559, hM_given_X=3357.351, hM_given_Y_upper=3364.258
# - Layer 1 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=1687.885, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.416, MI(Y;M)=3.194, h_upper=5.044, hM_given_X=2.676, hM_given_Y_upper=2.830
# Doing activations/epoch00000016
# - Layer 0 upper: MI(X;M)=13.294, MI(Y;M)=3.320, h_upper=3366.566, hM_given_X=3357.351, hM_given_Y_upper=3364.265
# - Layer 1 upper: MI(X;M)=13.291, MI(Y;M)=3.319, h_upper=1687.888, hM_given_X=1678.676, hM_given_Y_upper=1685.587
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.413, MI(Y;M)=3.199, h_upper=5.042, hM_given_X=2.676, hM_given_Y_upper=2.825
# Doing activations/epoch00000017
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=3366.562, hM_given_X=3357.351, hM_given_Y_upper=3364.261
# - Layer 1 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=1687.885, hM_given_X=1678.676, hM_given_Y_upper=1685.584
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.412, MI(Y;M)=3.202, h_upper=5.042, hM_given_X=2.676, hM_given_Y_upper=2.822
# Doing activations/epoch00000018
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=3366.562, hM_given_X=3357.351, hM_given_Y_upper=3364.261
# - Layer 1 upper: MI(X;M)=13.292, MI(Y;M)=3.319, h_upper=1687.889, hM_given_X=1678.676, hM_given_Y_upper=1685.588
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.410, MI(Y;M)=3.202, h_upper=5.040, hM_given_X=2.676, hM_given_Y_upper=2.821
# Doing activations/epoch00000019
# - Layer 0 upper: MI(X;M)=13.294, MI(Y;M)=3.320, h_upper=3366.566, hM_given_X=3357.351, hM_given_Y_upper=3364.265
# - Layer 1 upper: MI(X;M)=13.291, MI(Y;M)=3.319, h_upper=1687.888, hM_given_X=1678.676, hM_given_Y_upper=1685.587
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.421, MI(Y;M)=3.183, h_upper=5.048, hM_given_X=2.676, hM_given_Y_upper=2.841
# Doing activations/epoch00000020
# - Layer 0 upper: MI(X;M)=13.295, MI(Y;M)=3.320, h_upper=3366.567, hM_given_X=3357.351, hM_given_Y_upper=3364.266
# - Layer 1 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=1687.885, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.406, MI(Y;M)=3.208, h_upper=5.038, hM_given_X=2.676, hM_given_Y_upper=2.814
# Doing activations/epoch00000025
# - Layer 0 upper: MI(X;M)=13.297, MI(Y;M)=3.320, h_upper=3366.568, hM_given_X=3357.351, hM_given_Y_upper=3364.267
# - Layer 1 upper: MI(X;M)=13.295, MI(Y;M)=3.319, h_upper=1687.891, hM_given_X=1678.676, hM_given_Y_upper=1685.590
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.391, MI(Y;M)=3.223, h_upper=5.027, hM_given_X=2.676, hM_given_Y_upper=2.793
# Doing activations/epoch00000030
# - Layer 0 upper: MI(X;M)=13.283, MI(Y;M)=3.320, h_upper=3366.558, hM_given_X=3357.351, hM_given_Y_upper=3364.257
# - Layer 1 upper: MI(X;M)=13.293, MI(Y;M)=3.319, h_upper=1687.890, hM_given_X=1678.676, hM_given_Y_upper=1685.589
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.386, MI(Y;M)=3.220, h_upper=5.024, hM_given_X=2.676, hM_given_Y_upper=2.791
# Doing activations/epoch00000035
# - Layer 0 upper: MI(X;M)=13.306, MI(Y;M)=3.320, h_upper=3366.574, hM_given_X=3357.351, hM_given_Y_upper=3364.273
# - Layer 1 upper: MI(X;M)=13.294, MI(Y;M)=3.320, h_upper=1687.890, hM_given_X=1678.676, hM_given_Y_upper=1685.589
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.379, MI(Y;M)=3.221, h_upper=5.019, hM_given_X=2.676, hM_given_Y_upper=2.786
# Doing activations/epoch00000040
# - Layer 0 upper: MI(X;M)=13.281, MI(Y;M)=3.320, h_upper=3366.557, hM_given_X=3357.351, hM_given_Y_upper=3364.255
# - Layer 1 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=1687.885, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.376, MI(Y;M)=3.228, h_upper=5.016, hM_given_X=2.676, hM_given_Y_upper=2.779
# Doing activations/epoch00000045
# - Layer 0 upper: MI(X;M)=13.280, MI(Y;M)=3.319, h_upper=3366.556, hM_given_X=3357.351, hM_given_Y_upper=3364.255
# - Layer 1 upper: MI(X;M)=13.298, MI(Y;M)=3.319, h_upper=1687.893, hM_given_X=1678.676, hM_given_Y_upper=1685.592
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.384, MI(Y;M)=3.199, h_upper=5.022, hM_given_X=2.676, hM_given_Y_upper=2.805
# Doing activations/epoch00000050
# - Layer 0 upper: MI(X;M)=13.310, MI(Y;M)=3.320, h_upper=3366.577, hM_given_X=3357.351, hM_given_Y_upper=3364.276
# - Layer 1 upper: MI(X;M)=13.294, MI(Y;M)=3.320, h_upper=1687.890, hM_given_X=1678.676, hM_given_Y_upper=1685.589
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.368, MI(Y;M)=3.224, h_upper=5.011, hM_given_X=2.676, hM_given_Y_upper=2.776
# Doing activations/epoch00000055
# - Layer 0 upper: MI(X;M)=13.284, MI(Y;M)=3.319, h_upper=3366.559, hM_given_X=3357.351, hM_given_Y_upper=3364.258
# - Layer 1 upper: MI(X;M)=13.295, MI(Y;M)=3.319, h_upper=1687.891, hM_given_X=1678.676, hM_given_Y_upper=1685.590
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.361, MI(Y;M)=3.223, h_upper=5.006, hM_given_X=2.676, hM_given_Y_upper=2.772
# Doing activations/epoch00000060
# - Layer 0 upper: MI(X;M)=13.296, MI(Y;M)=3.320, h_upper=3366.567, hM_given_X=3357.351, hM_given_Y_upper=3364.266
# - Layer 1 upper: MI(X;M)=13.282, MI(Y;M)=3.319, h_upper=1687.882, hM_given_X=1678.676, hM_given_Y_upper=1685.581
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.367, MI(Y;M)=3.221, h_upper=5.010, hM_given_X=2.676, hM_given_Y_upper=2.778
# Doing activations/epoch00000065
# - Layer 0 upper: MI(X;M)=13.300, MI(Y;M)=3.320, h_upper=3366.570, hM_given_X=3357.351, hM_given_Y_upper=3364.269
# - Layer 1 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=1687.886, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.365, MI(Y;M)=3.214, h_upper=5.009, hM_given_X=2.676, hM_given_Y_upper=2.781
# Doing activations/epoch00000070
# - Layer 0 upper: MI(X;M)=13.302, MI(Y;M)=3.320, h_upper=3366.571, hM_given_X=3357.351, hM_given_Y_upper=3364.270
# - Layer 1 upper: MI(X;M)=13.291, MI(Y;M)=3.319, h_upper=1687.888, hM_given_X=1678.676, hM_given_Y_upper=1685.587
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.352, MI(Y;M)=3.223, h_upper=5.000, hM_given_X=2.676, hM_given_Y_upper=2.766
# Doing activations/epoch00000075
# - Layer 0 upper: MI(X;M)=13.300, MI(Y;M)=3.320, h_upper=3366.570, hM_given_X=3357.351, hM_given_Y_upper=3364.269
# - Layer 1 upper: MI(X;M)=13.291, MI(Y;M)=3.319, h_upper=1687.889, hM_given_X=1678.676, hM_given_Y_upper=1685.588
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.356, MI(Y;M)=3.219, h_upper=5.002, hM_given_X=2.676, hM_given_Y_upper=2.771
# Doing activations/epoch00000080
# - Layer 0 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=3366.561, hM_given_X=3357.351, hM_given_Y_upper=3364.261
# - Layer 1 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=1687.886, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.349, MI(Y;M)=3.224, h_upper=4.998, hM_given_X=2.676, hM_given_Y_upper=2.763
# Doing activations/epoch00000085
# - Layer 0 upper: MI(X;M)=13.278, MI(Y;M)=3.320, h_upper=3366.555, hM_given_X=3357.351, hM_given_Y_upper=3364.254
# - Layer 1 upper: MI(X;M)=13.279, MI(Y;M)=3.319, h_upper=1687.880, hM_given_X=1678.676, hM_given_Y_upper=1685.579
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.352, MI(Y;M)=3.225, h_upper=5.000, hM_given_X=2.676, hM_given_Y_upper=2.764
# Doing activations/epoch00000090
# - Layer 0 upper: MI(X;M)=13.314, MI(Y;M)=3.320, h_upper=3366.580, hM_given_X=3357.351, hM_given_Y_upper=3364.278
# - Layer 1 upper: MI(X;M)=13.292, MI(Y;M)=3.319, h_upper=1687.889, hM_given_X=1678.676, hM_given_Y_upper=1685.588
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.351, MI(Y;M)=3.220, h_upper=4.999, hM_given_X=2.676, hM_given_Y_upper=2.767
# Doing activations/epoch00000095
# - Layer 0 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=3366.560, hM_given_X=3357.351, hM_given_Y_upper=3364.259
# - Layer 1 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=1687.885, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=14.563, hM_given_X=5.353, hM_given_Y_upper=12.262
# - Layer 4 upper: MI(X;M)=3.347, MI(Y;M)=3.224, h_upper=4.997, hM_given_X=2.676, hM_given_Y_upper=2.762

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import torch
import scienceplots
plt.rcParams['font.serif'] = ['Times New Roman']
mpl.rcParams['figure.dpi'] = 800
mpl.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
plt.style.use(['science', 'ieee'])
mpl.rcParams.update({'font.size': 15})

def plot_information_plane(IXT_array, ITY_array, num_epochs, every_n_early=1, every_n_late=5):
    assert len(IXT_array) == len(ITY_array)

    max_index = len(IXT_array)

    fig, ax = plt.subplots(figsize=(5, 3.5))
    ax.set_xlabel('$I(X;T)$', fontsize=15)
    ax.set_ylabel('$I(T;Y)$', fontsize=15)

    cmap = plt.get_cmap('gnuplot')
    colors = [cmap(i) for i in np.linspace(0, 1, num_epochs + 1)]

    for i in range(0, max_index):
        IXT = IXT_array[i, :]
        ITY = ITY_array[i, :]
        
        # 根据 epoch 的范围调整 every_n
        if i < 20:
            color_idx = i * every_n_early
        else:
            color_idx = 20 * every_n_early + (i - 20) * every_n_late

        ax.plot(IXT, ITY, marker='o', markersize=3, markeredgewidth=0.04,
                linestyle='-', linewidth=0.5, color=colors[color_idx], zorder=10)

    sm = plt.cm.ScalarMappable(cmap=cmap, norm=plt.Normalize(vmin=0, vmax=1))
    sm._A = []

    # 使用ax参数指定颜色条位置
    cbar = plt.colorbar(sm, ax=ax, ticks=[])
    cbar.set_label('epoch number', fontsize=15)
    cbar.ax.tick_params(labelsize=15)
    cbar.ax.text(0.5, -0.01, 0, transform=cbar.ax.transAxes, va='top', ha='center')
    cbar.ax.text(0.5, 1.0, str(num_epochs), transform=cbar.ax.transAxes, va='bottom', ha='center')

    ax.set_xticks([0, 2, 4, 6, 8, 10, 12, 14])
    ax.set_yticks([2.5, 3.0, 3.5])
    ax.set_ylim(2.0, 3.5)  # 修改y轴坐标范围
    # Adjust coordinates of text according to the plot area
    ax.text(-0.2, 0.98, '(d)', fontdict={'size': 15, 'color': 'black'}, transform=ax.transAxes)

    fig.savefig('D:/深度学习与信息论/Fig8dd.eps', dpi=800)
    plt.show()

IXT_array = np.load('D:/深度学习与信息论/MI_XM_upper_arrayG.npy')
ITY_array = np.load('D:/深度学习与信息论/MI_YM_upper_arrayG.npy')


plot_information_plane(IXT_array, ITY_array, num_epochs=100, every_n_early=1, every_n_late=5)

# %%
IXT_array
# Out:
# array([[13.2904231 , 13.28280629, 13.28051802, 13.26429105,  3.66701294],
#        [13.28901422, 13.28315851, 13.28615355, 13.28105592,  3.62748135],
#        [13.29183198, 13.28227796, 13.28680158, 13.28432978,  3.58157408],
#        [13.29359309, 13.29178791, 13.28713178, 13.28556737,  3.55121749],
#        [13.29324087, 13.28104519, 13.28731477, 13.28613698,  3.51703867],
#        [13.29394531, 13.28861793, 13.28742484, 13.28653185,  3.50923328],
#        [13.29007088, 13.28491961, 13.28752115, 13.28678226,  3.47937431],
#        [13.29641085, 13.28615238, 13.28755555, 13.28690127,  3.46747098],
#        [13.28901422, 13.28104519, 13.28763328, 13.28715443,  3.47060059],
#        [13.28584424, 13.28914626, 13.28768901, 13.28720809,  3.44806624],
#        [13.29500197, 13.29055514, 13.28768763, 13.28721703,  3.44111231],
#        [13.29394531, 13.29125958, 13.28769245, 13.28718745,  3.43482189],
    98.69, 98.82, 98.82, 98.72, 98.84, 98.76, 98.50, 98.82, 98.61, 98.75, 
    98.88, 98.79, 98.85, 98.84, 98.83, 98.83, 98.71, 98.80, 98.87, 98.91, 
    98.94, 98.83, 98.86, 98.89, 98.80, 98.79, 98.88, 98.95, 98.88, 98.84, 
    98.62, 98.80, 98.91, 98.86, 98.83, 98.80, 98.91, 98.89, 98.76, 98.79, 
    98.84, 98.87, 98.96, 98.90, 98.84, 98.83, 98.91, 98.83, 98.81, 98.90])


accuracyG = np.array([
    86.74, 92.14, 94.48, 94.72, 95.87, 96.43, 96.94, 97.13, 97.02, 97.32, 
    97.71, 97.69, 97.99, 97.99, 98.15, 98.11, 98.13, 98.18, 98.16, 97.79, 
    98.23, 98.30, 98.27, 98.43, 98.51, 98.59, 98.20, 98.21, 98.26, 98.70, 
    98.56, 98.20, 98.64, 98.65, 98.67, 98.63, 98.60, 98.71, 98.59, 98.60, 
    98.75, 98.73, 98.67, 98.68, 98.67, 98.19, 98.74, 98.71, 98.73, 98.76, 
    98.69, 98.73, 98.79, 98.62, 98.68, 98.78, 98.79, 98.85, 98.82, 98.67, 
    98.61, 98.74, 98.72, 98.69, 98.73, 98.64, 98.75, 98.73, 98.79, 98.70, 
    98.77, 98.69, 98.80, 98.76, 98.71, 98.69, 98.73, 98.85, 98.68, 98.82, 
    98.81, 98.85, 98.83, 98.65, 98.77, 98.81, 98.63, 98.79, 98.79, 98.79, 
    98.77, 98.74, 98.74, 98.86, 98.72, 98.79, 98.76, 98.78, 98.79, 98.82])


import matplotlib.pyplot as plt
import matplotlib as mpl
import scienceplots

plt.rcParams['font.serif'] = ['Times New Roman']
mpl.rcParams['figure.dpi'] = 800
mpl.rcParams['axes.unicode_minus'] = False

plt.rcParams['text.usetex'] = True
plt.rcParams['text.latex.preamble'] = r'\usepackage{amsmath, amssymb}'
plt.style.use(['science','ieee'])

fig, ax = plt.subplots(figsize=(5, 4))
plt.cla()
plt.tick_params(labelsize=15)
ax.set_xlabel('epoch number', fontsize=15)
ax.set_ylabel(r"Test accuracy", fontsize=15, labelpad=1)
ax.set_xlim(-5, len(accuracyReLU)+2)  # Adjust x-axis limits to start from epoch 1
ax.set_ylim(0.2, 1)

# Create the x-axis array to represent epoch numbers
epochs = np.arange(1, len(accuracyReLU) + 1)

# Plot the accuracy curves
ax.plot(epochs, 0.01*accuracyReLU, 'g--', lw=1, label=r"ReLU")
ax.plot(epochs, 0.01*accuracyS, 'b:', lw=1, label=r"SiLU")
ax.plot(epochs, 0.01*accuracyG, 'r-', lw=0.5, label=r"GELU")

ax.text(-20, 0.99, '(a)', fontdict={'size': 15, 'color': 'black'})
ax.legend(loc='upper right', fontsize=15)

# patch = mpl.patches.Rectangle((0.980,85),0.022,15,linewidth=1,linestyle='--',edgecolor='gray',facecolor='none')
# ax.add_patch(patch)
# left, bottom, width, height = [0.3, 0.2, 0.57, 0.3]
# ax2 = fig.add_axes([left, bottom, width, height])

# step = np.arange(1,101)

# ax2.plot(step[85:], 0.01*accuracyReLU[85:], 'g--')
# ax2.plot(step[85:], 0.01*accuracyS[85:], 'b:')
# ax2.plot(step[85:], 0.01*accuracyG[85:], 'r-')
# ax2.set_yticks([0.980,0.982,0.984,0.986])

plt.show()

fig.savefig('D:/深度学习与信息论/Fig8a.eps', dpi=800)
