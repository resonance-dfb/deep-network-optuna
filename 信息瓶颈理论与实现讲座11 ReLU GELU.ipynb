# %%
#######################################################################################
##https://github.com/Huma97/Information-Bottleneck-Theory-of-Deep-Learning/tree/master#
#######################################################################################
##讲座7把神经网络可以分层定义，引入可学习激活函数
import os
from collections import defaultdict, OrderedDict#为了自动建目录
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import pickle
from torchvision import datasets
import torchvision.transforms as transforms
import matplotlib as mpl
#import scienceplots
import math
train_on_gpu = torch.cuda.is_available()
##判断是否有GPU
if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
    
def categorical_cross_entropy(output, target):
    num_classes = 10
    epsilon = 10e-8
        
    output = torch.clamp(output, epsilon, 1. - epsilon)
    ##使用torch.clamp函数将output张量中的值限制在一个范围内，防止出现数值过大或过小的情况，第一个参数是要处理的张量，第二个参数是下限，第三个参数是上限。
    target = target.float()  # Ensure target is float
    target = target.reshape(target.shape[0], 1).to(output.device)  # Move target to the same device as output
    one_hot_target = (target == torch.arange(num_classes).reshape(1, num_classes).to(output.device)).float()
    return torch.mean(-torch.sum(one_hot_target * torch.log(output), 1))
#将target张量转换为独热编码的形式，即将每个类别的索引转换为一个长度为num_classes的向量，其中对应类别的位置为1，其他位置为0。
#最小化这个损失函数意味着我们希望预测值与真实标签之间的差异越小越好，即模型的预测结果与真实情况越接近
def init_weights(m):
    if type(m) == nn.Linear:
        nn.init.xavier_uniform_(m.weight)  # 使用 nn.init.xavier_uniform_对于权系数进行初始化
        m.bias.data.fill_(0.0)  # 使用 fill_ 方法来设置偏置为 0
# Out:
# CUDA is available!  Training on GPU ...

# %% [markdown]
# # Downloading MNIST dataset

# %%
#分批训练size，Mnist数据集60000=5w：1w
batch_size = 128

# convert data to a normalized torch.FloatTensor
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))  # 标准化
])
# choose the training and test datasets
train_data = datasets.MNIST('./MNIST_data/', download=True, train=True, transform=transform)
test_data = datasets.MNIST('./MNIST_data/', download=True, train=False, transform=transform)

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size)
#分批载入
full_data_loader = torch.utils.data.DataLoader(test_data, batch_size=10000)
#全部载入测试

# %% [markdown]
# # Class for creating NN

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, padding=1)  # 输入通道数1，输出通道数16，卷积核大小3x3
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1) # 输入通道数16，输出通道数32，卷积核大小3x3
        self.pool = nn.MaxPool2d(2, 2)                           # 2x2的最大池化层
        self.fc1 = nn.Linear(32 * 7 * 7, 64)                    # 全连接层，输入维度32*7*7，输出维度64
        self.fc2 = nn.Linear(64, 10)                            # 全连接层，输入维度64，输出维度10（对应10个类别）

    def forward(self, x):
        activations = []
        x = F.relu(self.conv1(x))  # 第一层卷积 + ReLU激活 
        xx= torch.flatten(x, 1)
        activations.append(xx.cpu().data.numpy())#layer1
        x = self.pool(x)
        x = F.relu(self.conv2(x))  # 第二层卷积 + ReLU激活
        xx= torch.flatten(x, 1)
        activations.append(xx.cpu().data.numpy())#layer1
        x = self.pool(x)
        x = x.view(-1, 32 * 7 * 7)            # 展平操作，为全连接层做准备
        x = F.relu(self.fc1(x))               # 第一个全连接层 + ReLU激活
        activations.append(x.cpu().data.numpy())#layer1
        x = self.fc2(x)# 第二个全连接层（输出层）
        x = torch.softmax(x, dim=1)
        activations.append(x.cpu().data.numpy())
        return x, activations

# class Net(nn.Module):
#     def __init__(self):
#         super(Net, self).__init__()
#         self.conv1 = nn.Conv2d(1, 32, 3, 1)
#         self.conv2 = nn.Conv2d(32, 64, 3, 1)
#         self.dropout1 = nn.Dropout(0.25)
#         self.dropout2 = nn.Dropout(0.5)
#         self.fc1 = nn.Linear(9216, 128)
#         self.fc2 = nn.Linear(128, 10)

#     def forward(self, x):
#         activations = []
#         x = self.conv1(x)
#         x = F.relu(x)
#         xx= torch.flatten(x, 1)
#         activations.append(xx.cpu().data.numpy())#layer1
#         x = self.conv2(x)
#         x = F.relu(x)
#         xx= torch.flatten(x, 1)
#         activations.append(xx.cpu().data.numpy())#layer1
#         x = F.max_pool2d(x, 2)
#         x = self.dropout1(x)
#         xx= torch.flatten(x, 1)
#         activations.append(xx.cpu().data.numpy())#layer
#         x = torch.flatten(x, 1)
#         x = self.fc1(x)
#         x = F.relu(x)
#         activations.append(x.cpu().data.numpy())#layer3
#         x = self.dropout2(x)
#         x = self.fc2(x)
#         x = torch.softmax(x, dim=1)
#         activations.append(x.cpu().data.numpy())#layer4
#         return x, activations
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Class for saving activations, computing MI and plotting

# %%
import kde
# 这段代码是用Python来实现一些熵估计方法，特别是用于估计混合高斯模型的熵。以下是对每个函数的简要解释：
#需要下载https://github.com/Huma97/Information-Bottleneck-Theory-of-Deep-Learning/tree/master，jupyter载入
# get_dists(X):
# 这个函数用来计算输入数据集X中样本之间的成对欧氏距离的平方。它首先计算每个样本向量的平方范数，并将结果扩展为列向量，然后使用矩阵乘法和广播来计算所有样本对之间的距离平方。

# get_shape(x):
# 这个函数用来获取输入矩阵x的形状信息，返回矩阵的列数（特征维度）和行数（样本数）。

# entropy_estimator_kl(x, var):
# 这个函数基于KL散度的方法估计输入数据集x的熵，假设数据集服从多个高斯分布的混合模型。它首先计算数据集中样本之间的成对欧氏距离的平方，然后根据给定的方差var计算距离的对数概率，并最终求取其均值。

# entropy_estimator_bd(x, var):
# 这个函数基于Bhattacharyya系数的方法估计输入数据集x的熵的下界，同样假设数据集服从多个高斯分布的混合模型。它首先利用entropy_estimator_kl函数计算KL散度的估计值，然后加上一个校正项。

# kde_condentropy(output, var):
# 这个函数计算输出的多元高斯分布的条件熵，假设每个维度的方差均为var。
import simplebinmi
#需要下载https://github.com/Huma97/Information-Bottleneck-Theory-of-Deep-Learning/tree/master，jupyter载入
# get_unique_probs(x):
# 这个函数用于计算输入数据集x中每个唯一样本出现的概率。首先，它将输入数据x转换为字节视图，并将其看作是void类型的视图，这样可以方便地比较数据集中的唯一样本。然后，使用NumPy的np.unique函数找到唯一的样本，同时计算出现的次数。最后，将每个唯一样本出现的次数除以总样本数，得到概率值。

# bin_calc_information(inputdata, layerdata, num_of_bins):
# 这个函数用于计算给定输入数据和某一层的输出数据之间的信息量。首先，使用get_unique_probs函数计算输入数据集中每个唯一样本的概率，并将结果存储在p_xs中。然后，将输出数据分成num_of_bins个区间，并计算每个区间中的样本出现的概率。接着，利用信息论中的熵的定义来计算层的熵（H_LAYER）和给定输入的条件下层的熵（H_LAYER_GIVEN_INPUT）。最后，返回两者之差，即信息量。

# bin_calc_information2(labelixs, layerdata, binsize):
# 这个函数也用于计算信息量，与上一个函数相似，但在计算输出的条件熵时使用了一种简化的方法。首先，将层的输出数据划分成多个区间，然后计算每个区间中样本出现的概率。接着，利用这些概率值计算层的熵（H_LAYER）。然后，对于每个标签，通过求取其样本在层输出中的平均位置，计算出条件熵，然后将所有标签对应的条件熵加和。最后，返回层的熵和在给定输出的情况下层的条件熵之差。

# %%
class MI_Plate():
    def __init__(self, n_epochs=100, DO_LOWER=False, DO_BINNED=False, PLOT_LAYERS=None):
        super(MI_Plate, self).__init__()
        
        self.n_epochs = n_epochs
        self.DO_LOWER = DO_LOWER
        self.DO_BINNED = DO_BINNED
        self.PLOT_LAYERS = PLOT_LAYERS
#DO_LOWER和DO_BINNED是用于控制数据预处理的布尔值，PLOT_LAYERS是用于指定绘制哪些层的激活值的列表
    def save_activations(self):
        
        if not os.path.exists('activations'):
            print("Making directory", 'activations')
            os.mkdir('activations')
            
        model = Net()
        #model.apply(init_weights)

        optimizer = optim.SGD(model.parameters(), lr=0.001)
        #optimizer = optim.Adam(model.parameters(), lr=0.001)
        # Move model to GPU if available
        if train_on_gpu:
            model.cuda()
        accuracies = []  # List to store accuracies
        for epoch in range(self.n_epochs):
            # monitor training loss
            train_loss = 0.0

            ###################
            # train the model #
            ###################
            model.train()

            for data, target in train_loader:
                if train_on_gpu:
                    data, target = data.cuda(), target.cuda()  # Move data to GPU
                optimizer.zero_grad()
                output, _ = model(data)
                loss = categorical_cross_entropy(output, target)
                # backward
                loss.backward()
                optimizer.step()
                train_loss += loss.item()#*data.size(0)

            # calculate average loss over an epoch
            train_loss = train_loss/len(train_loader.dataset)

            print('Epoch: {} \tTraining Loss: {:.6f}'.format(epoch+1, train_loss))

            model.eval()
########每次按照规定的epoch训练之后，都用full全部数据通过网络一次，记住标签和网络输出
###############################################################################            
            for data, _ in full_data_loader:
                if train_on_gpu:
                    data = data.cuda()  # Move data to GPU
                _, activations = model(data)
#定义多少epoch进行存储每层的输出，前20每次都存，高于200次100次再存一次
            if epoch < 20:       # Log for all first 20 epochs
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            #pickle.HIGHEST_PROTOCOL 用于指定 pickle 协议的版本，以确保最高的兼容性和效率
            elif (epoch < 100) and (epoch % 5 == 0):    # Then for every 5th epoch
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            elif (epoch < 200) and (epoch % 10 == 0):    # Then every 10th
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            elif (epoch % 100 == 0):                # Then every 100th
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
         #####################****************************************
            correct = 0
            total = 0
            with torch.no_grad():
                for data, target in test_loader:  # Assuming test_loader is defined elsewhere
                    if train_on_gpu:
                        data, target = data.cuda(), target.cuda()  # Move data to GPU
                    output, _ = model(data)
                    _, predicted = torch.max(output.data, 1)
                    total += target.size(0)
                    correct += (predicted == target).sum().item()

            accuracy = 100 * correct / total
            accuracies.append(accuracy)  # Store accuracy
            print('Test Accuracy on 10,000 images: {:.2f}%'.format(accuracy))                    
      ###########################
    def compute_MI(self, noise_variance=1e-1):
        
        MAX_EPOCHS = self.n_epochs
        self.noise_variance = noise_variance
        
        def entropy_func_upper(x):
            return kde.entropy_estimator_kl(x,self.noise_variance)
        
        def entropy_func_lower(x):
            return kde.entropy_estimator_bd(x,self.noise_variance)

        # nats to bits conversion factor
        nats2bits = 1.0/np.log(2) 


        # Save indexes of tests data for each of the output classes
        saved_labelixs = {}
        for data, targets in full_data_loader:
            trg = targets.numpy()
        for i in range(10):
            saved_labelixs[i] = trg == i

        labelprobs = np.mean(np.eye(10)[test_data.targets], axis=0)

        MI_XM_upper_array = []
        MI_YM_upper_array = []
###这段代码的作用是计算每个类别在数据集中出现的频率，并保存每个类别的索引以供后续使用
        measures = OrderedDict()
        measures['tanh'] = {}

        cur_dir = 'activations'
        if not os.path.exists(cur_dir):
            print("Directory %s not found" % cur_dir)

        # Load files saved during each epoch, and compute MI measures of the activity in that epoch
        print('*** Doing %s ***' % cur_dir)
        for epochfile in sorted(os.listdir(cur_dir)):
            if not epochfile.startswith('epoch'):
                continue

            fname = cur_dir + "/" + epochfile
            with open(fname, 'rb') as f:
                d = pickle.load(f)

            epoch = d[1]
            d = d[0]
            if epoch in measures['tanh']:# Skip this epoch if its already been processed
                continue                # this is a trick to allow us to rerun this cell multiple times)

            if epoch > MAX_EPOCHS:
                continue

            print("Doing", fname)

            num_layers = len(d)

            MI_XM_upper_epoch = []
            MI_YM_upper_epoch = []
            
            if self.PLOT_LAYERS is None:
                PLOT_LAYERS = []
                for lndx in range(num_layers):
                    PLOT_LAYERS.append(lndx)

            cepochdata = defaultdict(list)
            for lndx in range(num_layers):
                activity = d[lndx]

                # Compute marginal entropies
                h_upper = entropy_func_upper(activity)
                if self.DO_LOWER:
                    #h_lower = entropy_func_lower([activity,])[0]
                    h_lower = entropy_func_lower(activity)

                # Layer activity given input. This is simply the entropy of the Gaussian noise
                hM_given_X = kde.kde_condentropy(activity, self.noise_variance)

                # Compute conditional entropies of layer activity given output
                hM_given_Y_upper=0.
                for i in range(10):
                    hcond_upper = entropy_func_upper(activity[saved_labelixs[i],:])
                    hM_given_Y_upper += labelprobs[i] * hcond_upper

                if self.DO_LOWER:
                    hM_given_Y_lower=0.
                    for i in range(10):
                        hcond_lower = entropy_func_lower(activity[saved_labelixs[i],:])
                        hM_given_Y_lower += labelprobs[i] * hcond_lower

                cepochdata['MI_XM_upper'].append( nats2bits * (h_upper - hM_given_X) )
                cepochdata['MI_YM_upper'].append( nats2bits * (h_upper - hM_given_Y_upper) )
                cepochdata['H_M_upper'  ].append( nats2bits * h_upper )


                MI_XM_upper = nats2bits * (h_upper - hM_given_X)
                MI_YM_upper = nats2bits * (h_upper - hM_given_Y_upper)

                MI_XM_upper_epoch.append(MI_XM_upper)
                MI_YM_upper_epoch.append(MI_YM_upper)
                
                pstr = 'upper: MI(X;M)=%0.3f, MI(Y;M)=%0.3f, h_upper=%0.3f, hM_given_X=%0.3f, hM_given_Y_upper=%0.3f ' % (cepochdata['MI_XM_upper'][-1], cepochdata['MI_YM_upper'][-1], h_upper, hM_given_X, hM_given_Y_upper)
                if self.DO_LOWER:  # Compute lower bounds
                    cepochdata['MI_XM_lower'].append( nats2bits * (h_lower - hM_given_X) )
                    cepochdata['MI_YM_lower'].append( nats2bits * (h_lower - hM_given_Y_lower) )
                    cepochdata['H_M_lower'  ].append( nats2bits * h_lower )
                    pstr += ' | lower: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_lower'][-1], cepochdata['MI_YM_lower'][-1])

                if self.DO_BINNED: # Compute binner estimates
                    binxm, binym = simplebinmi.bin_calc_information2(saved_labelixs, activity, 0.5)
                    cepochdata['MI_XM_bin'].append( nats2bits * binxm )
                    cepochdata['MI_YM_bin'].append( nats2bits * binym )
                    pstr += ' | bin: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_bin'][-1], cepochdata['MI_YM_bin'][-1])

                print('- Layer %d %s' % (lndx, pstr) )

            measures['tanh'][epoch] = cepochdata
            MI_XM_upper_array.append(MI_XM_upper_epoch)
            MI_YM_upper_array.append(MI_YM_upper_epoch)
             
            #epoch += 1
        MI_XM_upper_array = np.array(MI_XM_upper_array)
        MI_YM_upper_array = np.array(MI_YM_upper_array)

    # Save the results as arrays
        np.save('D:/深度学习与信息论/MI_XM_upper_array.npy', MI_XM_upper_array)
        np.save('D:/深度学习与信息论/MI_YM_upper_array.npy', MI_YM_upper_array)

        with open('MI', 'wb') as f:
            pickle.dump(measures, f, pickle.HIGHEST_PROTOCOL)   

Plate = MI_Plate() #Create class object
Plate.save_activations() #save activations if they weren't saved already
Plate.compute_MI() #compute and save MIs if they weren't saved before
# Out:
# Epoch: 1 	Training Loss: 0.017800
# Saving activations/epoch00000000
# Test Accuracy on 10,000 images: 25.21%
# Epoch: 2 	Training Loss: 0.017070
# Saving activations/epoch00000001
# Test Accuracy on 10,000 images: 46.57%
# Epoch: 3 	Training Loss: 0.015117
# Saving activations/epoch00000002
# Test Accuracy on 10,000 images: 68.84%
# Epoch: 4 	Training Loss: 0.010152
# Saving activations/epoch00000003
# Test Accuracy on 10,000 images: 79.15%
# Epoch: 5 	Training Loss: 0.005825
# Saving activations/epoch00000004
# Test Accuracy on 10,000 images: 84.80%
# Epoch: 6 	Training Loss: 0.004205
# Saving activations/epoch00000005
# Test Accuracy on 10,000 images: 87.89%
# Epoch: 7 	Training Loss: 0.003476
# Saving activations/epoch00000006
# Test Accuracy on 10,000 images: 89.39%
# Epoch: 8 	Training Loss: 0.003061
# Saving activations/epoch00000007
# Test Accuracy on 10,000 images: 90.15%
# Epoch: 9 	Training Loss: 0.002789
# Saving activations/epoch00000008
# Test Accuracy on 10,000 images: 90.88%
# Epoch: 10 	Training Loss: 0.002590
# Saving activations/epoch00000009
# Test Accuracy on 10,000 images: 91.32%
# Epoch: 11 	Training Loss: 0.002439
# Saving activations/epoch00000010
# Test Accuracy on 10,000 images: 91.74%
# Epoch: 12 	Training Loss: 0.002314
# Saving activations/epoch00000011
# Test Accuracy on 10,000 images: 92.25%
# Epoch: 13 	Training Loss: 0.002206
# Saving activations/epoch00000012
# Test Accuracy on 10,000 images: 92.47%
# Epoch: 14 	Training Loss: 0.002110
# Saving activations/epoch00000013
# Test Accuracy on 10,000 images: 92.92%
# Epoch: 15 	Training Loss: 0.002023
# Saving activations/epoch00000014
# Test Accuracy on 10,000 images: 93.26%
# Epoch: 16 	Training Loss: 0.001944
# Saving activations/epoch00000015
# Test Accuracy on 10,000 images: 93.29%
# Epoch: 17 	Training Loss: 0.001869
# Saving activations/epoch00000016
# Test Accuracy on 10,000 images: 93.76%
# Epoch: 18 	Training Loss: 0.001798
# Saving activations/epoch00000017
# Test Accuracy on 10,000 images: 93.89%
# Epoch: 19 	Training Loss: 0.001734
# Saving activations/epoch00000018
# Test Accuracy on 10,000 images: 94.04%
# Epoch: 20 	Training Loss: 0.001672
# Saving activations/epoch00000019
# Test Accuracy on 10,000 images: 94.34%
# Epoch: 21 	Training Loss: 0.001613
# Saving activations/epoch00000020
# Test Accuracy on 10,000 images: 94.42%
# Epoch: 22 	Training Loss: 0.001556
# Test Accuracy on 10,000 images: 94.64%
# Epoch: 23 	Training Loss: 0.001504
# Test Accuracy on 10,000 images: 94.92%
# Epoch: 24 	Training Loss: 0.001453
# Test Accuracy on 10,000 images: 95.14%
# Epoch: 25 	Training Loss: 0.001406
# Test Accuracy on 10,000 images: 95.19%
# Epoch: 26 	Training Loss: 0.001361
# Saving activations/epoch00000025
# Test Accuracy on 10,000 images: 95.34%
# Epoch: 27 	Training Loss: 0.001318
# Test Accuracy on 10,000 images: 95.67%
# Epoch: 28 	Training Loss: 0.001276
# Test Accuracy on 10,000 images: 95.63%
# Epoch: 29 	Training Loss: 0.001237
# Test Accuracy on 10,000 images: 95.89%
# Epoch: 30 	Training Loss: 0.001202
# Test Accuracy on 10,000 images: 96.06%
# Epoch: 31 	Training Loss: 0.001166
# Saving activations/epoch00000030
# Test Accuracy on 10,000 images: 96.03%
# Epoch: 32 	Training Loss: 0.001133
# Test Accuracy on 10,000 images: 96.23%
# Epoch: 33 	Training Loss: 0.001101
# Test Accuracy on 10,000 images: 96.29%
# Epoch: 34 	Training Loss: 0.001074
# Test Accuracy on 10,000 images: 96.40%
# Epoch: 35 	Training Loss: 0.001045
# Test Accuracy on 10,000 images: 96.37%
# Epoch: 36 	Training Loss: 0.001018
# Saving activations/epoch00000035
# Test Accuracy on 10,000 images: 96.61%
# Epoch: 37 	Training Loss: 0.000994
# Test Accuracy on 10,000 images: 96.59%
# Epoch: 38 	Training Loss: 0.000971
# Test Accuracy on 10,000 images: 96.81%
# Epoch: 39 	Training Loss: 0.000947
# Test Accuracy on 10,000 images: 96.71%
# Epoch: 40 	Training Loss: 0.000925
# Test Accuracy on 10,000 images: 96.84%
# Epoch: 41 	Training Loss: 0.000906
# Saving activations/epoch00000040
# Test Accuracy on 10,000 images: 96.93%
# Epoch: 42 	Training Loss: 0.000885
# Test Accuracy on 10,000 images: 97.00%
# Epoch: 43 	Training Loss: 0.000867
# Test Accuracy on 10,000 images: 97.03%
# Epoch: 44 	Training Loss: 0.000848
# Test Accuracy on 10,000 images: 97.08%
# Epoch: 45 	Training Loss: 0.000830
# Test Accuracy on 10,000 images: 97.16%
# Epoch: 46 	Training Loss: 0.000815
# Saving activations/epoch00000045
# Test Accuracy on 10,000 images: 97.10%
# Epoch: 47 	Training Loss: 0.000802
# Test Accuracy on 10,000 images: 97.25%
# Epoch: 48 	Training Loss: 0.000786
# Test Accuracy on 10,000 images: 97.27%
# Epoch: 49 	Training Loss: 0.000772
# Test Accuracy on 10,000 images: 97.32%
# Epoch: 50 	Training Loss: 0.000757
# Test Accuracy on 10,000 images: 97.36%
# Epoch: 51 	Training Loss: 0.000746
# Saving activations/epoch00000050
# Test Accuracy on 10,000 images: 97.37%
# Epoch: 52 	Training Loss: 0.000734
# Test Accuracy on 10,000 images: 97.43%
# Epoch: 53 	Training Loss: 0.000722
# Test Accuracy on 10,000 images: 97.45%
# Epoch: 54 	Training Loss: 0.000712
# Test Accuracy on 10,000 images: 97.49%
# Epoch: 55 	Training Loss: 0.000699
# Test Accuracy on 10,000 images: 97.44%
# Epoch: 56 	Training Loss: 0.000690
# Saving activations/epoch00000055
# Test Accuracy on 10,000 images: 97.56%
# Epoch: 57 	Training Loss: 0.000679
# Test Accuracy on 10,000 images: 97.66%
# Epoch: 58 	Training Loss: 0.000670
# Test Accuracy on 10,000 images: 97.55%
# Epoch: 59 	Training Loss: 0.000660
# Test Accuracy on 10,000 images: 97.63%
# Epoch: 60 	Training Loss: 0.000652
# Test Accuracy on 10,000 images: 97.65%
# Epoch: 61 	Training Loss: 0.000641
# Saving activations/epoch00000060
# Test Accuracy on 10,000 images: 97.75%
# Epoch: 62 	Training Loss: 0.000634
# Test Accuracy on 10,000 images: 97.79%
# Epoch: 63 	Training Loss: 0.000626
# Test Accuracy on 10,000 images: 97.64%
# Epoch: 64 	Training Loss: 0.000618
# Test Accuracy on 10,000 images: 97.72%
# Epoch: 65 	Training Loss: 0.000612
# Test Accuracy on 10,000 images: 97.80%
# Epoch: 66 	Training Loss: 0.000605
# Saving activations/epoch00000065
# Test Accuracy on 10,000 images: 97.81%
# Epoch: 67 	Training Loss: 0.000597
# Test Accuracy on 10,000 images: 97.75%
# Epoch: 68 	Training Loss: 0.000589
# Test Accuracy on 10,000 images: 97.84%
# Epoch: 69 	Training Loss: 0.000584
# Test Accuracy on 10,000 images: 97.77%
# Epoch: 70 	Training Loss: 0.000576
# Test Accuracy on 10,000 images: 97.88%
# Epoch: 71 	Training Loss: 0.000571
# Saving activations/epoch00000070
# Test Accuracy on 10,000 images: 97.80%
# Epoch: 72 	Training Loss: 0.000564
# Test Accuracy on 10,000 images: 97.96%
# Epoch: 73 	Training Loss: 0.000559
# Test Accuracy on 10,000 images: 97.87%
# Epoch: 74 	Training Loss: 0.000552
# Test Accuracy on 10,000 images: 98.01%
# Epoch: 75 	Training Loss: 0.000546
# Test Accuracy on 10,000 images: 97.85%
# Epoch: 76 	Training Loss: 0.000540
# Saving activations/epoch00000075
# Test Accuracy on 10,000 images: 97.98%
# Epoch: 77 	Training Loss: 0.000535
# Test Accuracy on 10,000 images: 98.00%
# Epoch: 78 	Training Loss: 0.000530
# Test Accuracy on 10,000 images: 97.98%
# Epoch: 79 	Training Loss: 0.000524
# Test Accuracy on 10,000 images: 98.03%
# Epoch: 80 	Training Loss: 0.000521
# Test Accuracy on 10,000 images: 97.96%
# Epoch: 81 	Training Loss: 0.000515
# Saving activations/epoch00000080
# Test Accuracy on 10,000 images: 97.96%
# Epoch: 82 	Training Loss: 0.000512
# Test Accuracy on 10,000 images: 98.04%
# Epoch: 83 	Training Loss: 0.000506
# Test Accuracy on 10,000 images: 97.99%
# Epoch: 84 	Training Loss: 0.000502
# Test Accuracy on 10,000 images: 98.12%
# Epoch: 85 	Training Loss: 0.000497
# Test Accuracy on 10,000 images: 98.15%
# Epoch: 86 	Training Loss: 0.000493
# Saving activations/epoch00000085
# Test Accuracy on 10,000 images: 98.18%
# Epoch: 87 	Training Loss: 0.000489
# Test Accuracy on 10,000 images: 98.18%
# Epoch: 88 	Training Loss: 0.000484
# Test Accuracy on 10,000 images: 98.13%
# Epoch: 89 	Training Loss: 0.000479
# Test Accuracy on 10,000 images: 98.18%
# Epoch: 90 	Training Loss: 0.000476
# Test Accuracy on 10,000 images: 98.16%
# Epoch: 91 	Training Loss: 0.000472
# Saving activations/epoch00000090
# Test Accuracy on 10,000 images: 98.20%
# Epoch: 92 	Training Loss: 0.000469
# Test Accuracy on 10,000 images: 98.15%
# Epoch: 93 	Training Loss: 0.000465
# Test Accuracy on 10,000 images: 98.15%
# Epoch: 94 	Training Loss: 0.000462
# Test Accuracy on 10,000 images: 98.10%
# Epoch: 95 	Training Loss: 0.000456
# Test Accuracy on 10,000 images: 98.19%
# Epoch: 96 	Training Loss: 0.000452
# Saving activations/epoch00000095
# Test Accuracy on 10,000 images: 98.21%
# Epoch: 97 	Training Loss: 0.000449
# Test Accuracy on 10,000 images: 98.19%
# Epoch: 98 	Training Loss: 0.000447
# Test Accuracy on 10,000 images: 98.25%
# Epoch: 99 	Training Loss: 0.000444
# Test Accuracy on 10,000 images: 98.25%
# Epoch: 100 	Training Loss: 0.000440
# Test Accuracy on 10,000 images: 98.23%
# *** Doing activations ***
# Doing activations/epoch00000000
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.319, h_upper=3366.562, hM_given_X=3357.351, hM_given_Y_upper=3364.262
# - Layer 1 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=1687.886, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 2 upper: MI(X;M)=3.212, MI(Y;M)=1.078, h_upper=19.356, hM_given_X=17.129, hM_given_Y_upper=18.609
# - Layer 3 upper: MI(X;M)=0.004, MI(Y;M)=0.002, h_upper=2.679, hM_given_X=2.676, hM_given_Y_upper=2.678
# Doing activations/epoch00000001
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.319, h_upper=3366.562, hM_given_X=3357.351, hM_given_Y_upper=3364.262
# - Layer 1 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=1687.886, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 2 upper: MI(X;M)=7.115, MI(Y;M)=2.281, h_upper=22.061, hM_given_X=17.129, hM_given_Y_upper=20.480
# - Layer 3 upper: MI(X;M)=0.035, MI(Y;M)=0.022, h_upper=2.700, hM_given_X=2.676, hM_given_Y_upper=2.685
# Doing activations/epoch00000002
# - Layer 0 upper: MI(X;M)=13.290, MI(Y;M)=3.319, h_upper=3366.563, hM_given_X=3357.351, hM_given_Y_upper=3364.262
# - Layer 1 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=1687.886, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 2 upper: MI(X;M)=12.347, MI(Y;M)=3.267, h_upper=25.687, hM_given_X=17.129, hM_given_Y_upper=23.423
# - Layer 3 upper: MI(X;M)=0.423, MI(Y;M)=0.284, h_upper=2.970, hM_given_X=2.676, hM_given_Y_upper=2.773
# Doing activations/epoch00000003
# - Layer 0 upper: MI(X;M)=13.290, MI(Y;M)=3.320, h_upper=3366.563, hM_given_X=3357.351, hM_given_Y_upper=3364.262
# - Layer 1 upper: MI(X;M)=13.289, MI(Y;M)=3.319, h_upper=1687.887, hM_given_X=1678.676, hM_given_Y_upper=1685.587
# - Layer 2 upper: MI(X;M)=13.237, MI(Y;M)=3.319, h_upper=26.305, hM_given_X=17.129, hM_given_Y_upper=24.004
# - Layer 3 upper: MI(X;M)=2.362, MI(Y;M)=1.633, h_upper=4.314, hM_given_X=2.676, hM_given_Y_upper=3.182
# Doing activations/epoch00000004
# - Layer 0 upper: MI(X;M)=13.287, MI(Y;M)=3.320, h_upper=3366.561, hM_given_X=3357.351, hM_given_Y_upper=3364.260
# - Layer 1 upper: MI(X;M)=13.290, MI(Y;M)=3.319, h_upper=1687.887, hM_given_X=1678.676, hM_given_Y_upper=1685.587
# - Layer 2 upper: MI(X;M)=13.283, MI(Y;M)=3.319, h_upper=26.337, hM_given_X=17.129, hM_given_Y_upper=24.036
# - Layer 3 upper: MI(X;M)=3.360, MI(Y;M)=2.375, h_upper=5.005, hM_given_X=2.676, hM_given_Y_upper=3.359
# Doing activations/epoch00000005
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=3366.562, hM_given_X=3357.351, hM_given_Y_upper=3364.260
# - Layer 1 upper: MI(X;M)=13.293, MI(Y;M)=3.320, h_upper=1687.890, hM_given_X=1678.676, hM_given_Y_upper=1685.589
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=26.339, hM_given_X=17.129, hM_given_Y_upper=24.038
# - Layer 3 upper: MI(X;M)=3.594, MI(Y;M)=2.617, h_upper=5.168, hM_given_X=2.676, hM_given_Y_upper=3.354
# Doing activations/epoch00000006
# - Layer 0 upper: MI(X;M)=13.291, MI(Y;M)=3.320, h_upper=3366.564, hM_given_X=3357.351, hM_given_Y_upper=3364.262
# - Layer 1 upper: MI(X;M)=13.290, MI(Y;M)=3.320, h_upper=1687.888, hM_given_X=1678.676, hM_given_Y_upper=1685.587
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=26.339, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.651, MI(Y;M)=2.726, h_upper=5.207, hM_given_X=2.676, hM_given_Y_upper=3.317
# Doing activations/epoch00000007
# - Layer 0 upper: MI(X;M)=13.287, MI(Y;M)=3.320, h_upper=3366.561, hM_given_X=3357.351, hM_given_Y_upper=3364.260
# - Layer 1 upper: MI(X;M)=13.276, MI(Y;M)=3.319, h_upper=1687.878, hM_given_X=1678.676, hM_given_Y_upper=1685.577
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.666, MI(Y;M)=2.785, h_upper=5.218, hM_given_X=2.676, hM_given_Y_upper=3.287
# Doing activations/epoch00000008
# - Layer 0 upper: MI(X;M)=13.285, MI(Y;M)=3.320, h_upper=3366.560, hM_given_X=3357.351, hM_given_Y_upper=3364.259
# - Layer 1 upper: MI(X;M)=13.300, MI(Y;M)=3.319, h_upper=1687.894, hM_given_X=1678.676, hM_given_Y_upper=1685.593
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.668, MI(Y;M)=2.825, h_upper=5.219, hM_given_X=2.676, hM_given_Y_upper=3.261
# Doing activations/epoch00000009
# - Layer 0 upper: MI(X;M)=13.285, MI(Y;M)=3.320, h_upper=3366.560, hM_given_X=3357.351, hM_given_Y_upper=3364.258
# - Layer 1 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=1687.885, hM_given_X=1678.676, hM_given_Y_upper=1685.584
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.662, MI(Y;M)=2.852, h_upper=5.215, hM_given_X=2.676, hM_given_Y_upper=3.238
# Doing activations/epoch00000010
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.320, h_upper=3366.563, hM_given_X=3357.351, hM_given_Y_upper=3364.262
# - Layer 1 upper: MI(X;M)=13.290, MI(Y;M)=3.320, h_upper=1687.888, hM_given_X=1678.676, hM_given_Y_upper=1685.587
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.655, MI(Y;M)=2.875, h_upper=5.210, hM_given_X=2.676, hM_given_Y_upper=3.217
# Doing activations/epoch00000011
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.320, h_upper=3366.562, hM_given_X=3357.351, hM_given_Y_upper=3364.261
# - Layer 1 upper: MI(X;M)=13.298, MI(Y;M)=3.320, h_upper=1687.893, hM_given_X=1678.676, hM_given_Y_upper=1685.592
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.647, MI(Y;M)=2.892, h_upper=5.205, hM_given_X=2.676, hM_given_Y_upper=3.200
# Doing activations/epoch00000012
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=3366.562, hM_given_X=3357.351, hM_given_Y_upper=3364.260
# - Layer 1 upper: MI(X;M)=13.301, MI(Y;M)=3.319, h_upper=1687.895, hM_given_X=1678.676, hM_given_Y_upper=1685.595
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.638, MI(Y;M)=2.908, h_upper=5.198, hM_given_X=2.676, hM_given_Y_upper=3.183
# Doing activations/epoch00000013
# - Layer 0 upper: MI(X;M)=13.287, MI(Y;M)=3.320, h_upper=3366.561, hM_given_X=3357.351, hM_given_Y_upper=3364.260
# - Layer 1 upper: MI(X;M)=13.299, MI(Y;M)=3.320, h_upper=1687.894, hM_given_X=1678.676, hM_given_Y_upper=1685.592
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.631, MI(Y;M)=2.926, h_upper=5.193, hM_given_X=2.676, hM_given_Y_upper=3.165
# Doing activations/epoch00000014
# - Layer 0 upper: MI(X;M)=13.286, MI(Y;M)=3.320, h_upper=3366.560, hM_given_X=3357.351, hM_given_Y_upper=3364.259
# - Layer 1 upper: MI(X;M)=13.299, MI(Y;M)=3.320, h_upper=1687.894, hM_given_X=1678.676, hM_given_Y_upper=1685.593
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.623, MI(Y;M)=2.942, h_upper=5.188, hM_given_X=2.676, hM_given_Y_upper=3.149
# Doing activations/epoch00000015
# - Layer 0 upper: MI(X;M)=13.295, MI(Y;M)=3.320, h_upper=3366.567, hM_given_X=3357.351, hM_given_Y_upper=3364.266
# - Layer 1 upper: MI(X;M)=13.316, MI(Y;M)=3.320, h_upper=1687.906, hM_given_X=1678.676, hM_given_Y_upper=1685.605
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.618, MI(Y;M)=2.941, h_upper=5.185, hM_given_X=2.676, hM_given_Y_upper=3.146
# Doing activations/epoch00000016
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.320, h_upper=3366.562, hM_given_X=3357.351, hM_given_Y_upper=3364.262
# - Layer 1 upper: MI(X;M)=13.304, MI(Y;M)=3.319, h_upper=1687.897, hM_given_X=1678.676, hM_given_Y_upper=1685.596
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.608, MI(Y;M)=2.965, h_upper=5.177, hM_given_X=2.676, hM_given_Y_upper=3.122
# Doing activations/epoch00000017
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=3366.562, hM_given_X=3357.351, hM_given_Y_upper=3364.261
# - Layer 1 upper: MI(X;M)=13.292, MI(Y;M)=3.319, h_upper=1687.889, hM_given_X=1678.676, hM_given_Y_upper=1685.588
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.601, MI(Y;M)=2.975, h_upper=5.173, hM_given_X=2.676, hM_given_Y_upper=3.110
# Doing activations/epoch00000018
# - Layer 0 upper: MI(X;M)=13.290, MI(Y;M)=3.320, h_upper=3366.563, hM_given_X=3357.351, hM_given_Y_upper=3364.262
# - Layer 1 upper: MI(X;M)=13.289, MI(Y;M)=3.319, h_upper=1687.887, hM_given_X=1678.676, hM_given_Y_upper=1685.586
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.594, MI(Y;M)=2.984, h_upper=5.168, hM_given_X=2.676, hM_given_Y_upper=3.099
# Doing activations/epoch00000019
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=3366.562, hM_given_X=3357.351, hM_given_Y_upper=3364.261
# - Layer 1 upper: MI(X;M)=13.278, MI(Y;M)=3.319, h_upper=1687.879, hM_given_X=1678.676, hM_given_Y_upper=1685.578
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.589, MI(Y;M)=2.999, h_upper=5.164, hM_given_X=2.676, hM_given_Y_upper=3.085
# Doing activations/epoch00000020
# - Layer 0 upper: MI(X;M)=13.284, MI(Y;M)=3.320, h_upper=3366.559, hM_given_X=3357.351, hM_given_Y_upper=3364.258
# - Layer 1 upper: MI(X;M)=13.276, MI(Y;M)=3.320, h_upper=1687.878, hM_given_X=1678.676, hM_given_Y_upper=1685.577
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.582, MI(Y;M)=3.004, h_upper=5.159, hM_given_X=2.676, hM_given_Y_upper=3.077
# Doing activations/epoch00000025
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=3366.562, hM_given_X=3357.351, hM_given_Y_upper=3364.261
# - Layer 1 upper: MI(X;M)=13.304, MI(Y;M)=3.320, h_upper=1687.898, hM_given_X=1678.676, hM_given_Y_upper=1685.597
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.555, MI(Y;M)=3.051, h_upper=5.141, hM_given_X=2.676, hM_given_Y_upper=3.026
# Doing activations/epoch00000030
# - Layer 0 upper: MI(X;M)=13.286, MI(Y;M)=3.320, h_upper=3366.560, hM_given_X=3357.351, hM_given_Y_upper=3364.259
# - Layer 1 upper: MI(X;M)=13.310, MI(Y;M)=3.320, h_upper=1687.902, hM_given_X=1678.676, hM_given_Y_upper=1685.601
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.529, MI(Y;M)=3.089, h_upper=5.123, hM_given_X=2.676, hM_given_Y_upper=2.982
# Doing activations/epoch00000035
# - Layer 0 upper: MI(X;M)=13.284, MI(Y;M)=3.320, h_upper=3366.559, hM_given_X=3357.351, hM_given_Y_upper=3364.258
# - Layer 1 upper: MI(X;M)=13.303, MI(Y;M)=3.320, h_upper=1687.897, hM_given_X=1678.676, hM_given_Y_upper=1685.596
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.509, MI(Y;M)=3.116, h_upper=5.109, hM_given_X=2.676, hM_given_Y_upper=2.949
# Doing activations/epoch00000040
# - Layer 0 upper: MI(X;M)=13.292, MI(Y;M)=3.320, h_upper=3366.564, hM_given_X=3357.351, hM_given_Y_upper=3364.263
# - Layer 1 upper: MI(X;M)=13.284, MI(Y;M)=3.319, h_upper=1687.884, hM_given_X=1678.676, hM_given_Y_upper=1685.583
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.493, MI(Y;M)=3.133, h_upper=5.097, hM_given_X=2.676, hM_given_Y_upper=2.925
# Doing activations/epoch00000045
# - Layer 0 upper: MI(X;M)=13.285, MI(Y;M)=3.320, h_upper=3366.560, hM_given_X=3357.351, hM_given_Y_upper=3364.258
# - Layer 1 upper: MI(X;M)=13.316, MI(Y;M)=3.320, h_upper=1687.905, hM_given_X=1678.676, hM_given_Y_upper=1685.604
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.481, MI(Y;M)=3.147, h_upper=5.089, hM_given_X=2.676, hM_given_Y_upper=2.908
# Doing activations/epoch00000050
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=3366.562, hM_given_X=3357.351, hM_given_Y_upper=3364.261
# - Layer 1 upper: MI(X;M)=13.307, MI(Y;M)=3.320, h_upper=1687.900, hM_given_X=1678.676, hM_given_Y_upper=1685.599
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.470, MI(Y;M)=3.162, h_upper=5.081, hM_given_X=2.676, hM_given_Y_upper=2.890
# Doing activations/epoch00000055
# - Layer 0 upper: MI(X;M)=13.290, MI(Y;M)=3.320, h_upper=3366.563, hM_given_X=3357.351, hM_given_Y_upper=3364.262
# - Layer 1 upper: MI(X;M)=13.282, MI(Y;M)=3.319, h_upper=1687.882, hM_given_X=1678.676, hM_given_Y_upper=1685.581
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.460, MI(Y;M)=3.170, h_upper=5.075, hM_given_X=2.676, hM_given_Y_upper=2.878
# Doing activations/epoch00000060
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=3366.562, hM_given_X=3357.351, hM_given_Y_upper=3364.261
# - Layer 1 upper: MI(X;M)=13.292, MI(Y;M)=3.319, h_upper=1687.889, hM_given_X=1678.676, hM_given_Y_upper=1685.588
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.454, MI(Y;M)=3.182, h_upper=5.071, hM_given_X=2.676, hM_given_Y_upper=2.865
# Doing activations/epoch00000065
# - Layer 0 upper: MI(X;M)=13.286, MI(Y;M)=3.320, h_upper=3366.560, hM_given_X=3357.351, hM_given_Y_upper=3364.259
# - Layer 1 upper: MI(X;M)=13.269, MI(Y;M)=3.319, h_upper=1687.873, hM_given_X=1678.676, hM_given_Y_upper=1685.572
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.446, MI(Y;M)=3.186, h_upper=5.065, hM_given_X=2.676, hM_given_Y_upper=2.856
# Doing activations/epoch00000070
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=3366.562, hM_given_X=3357.351, hM_given_Y_upper=3364.261
# - Layer 1 upper: MI(X;M)=13.305, MI(Y;M)=3.320, h_upper=1687.898, hM_given_X=1678.676, hM_given_Y_upper=1685.597
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.442, MI(Y;M)=3.187, h_upper=5.062, hM_given_X=2.676, hM_given_Y_upper=2.853
# Doing activations/epoch00000075
# - Layer 0 upper: MI(X;M)=13.291, MI(Y;M)=3.320, h_upper=3366.564, hM_given_X=3357.351, hM_given_Y_upper=3364.262
# - Layer 1 upper: MI(X;M)=13.321, MI(Y;M)=3.320, h_upper=1687.909, hM_given_X=1678.676, hM_given_Y_upper=1685.608
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.437, MI(Y;M)=3.193, h_upper=5.059, hM_given_X=2.676, hM_given_Y_upper=2.846
# Doing activations/epoch00000080
# - Layer 0 upper: MI(X;M)=13.291, MI(Y;M)=3.320, h_upper=3366.564, hM_given_X=3357.351, hM_given_Y_upper=3364.263
# - Layer 1 upper: MI(X;M)=13.264, MI(Y;M)=3.319, h_upper=1687.870, hM_given_X=1678.676, hM_given_Y_upper=1685.569
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.433, MI(Y;M)=3.198, h_upper=5.056, hM_given_X=2.676, hM_given_Y_upper=2.839
# Doing activations/epoch00000085
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=3366.562, hM_given_X=3357.351, hM_given_Y_upper=3364.261
# - Layer 1 upper: MI(X;M)=13.304, MI(Y;M)=3.320, h_upper=1687.897, hM_given_X=1678.676, hM_given_Y_upper=1685.596
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.429, MI(Y;M)=3.202, h_upper=5.053, hM_given_X=2.676, hM_given_Y_upper=2.834
# Doing activations/epoch00000090
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.320, h_upper=3366.563, hM_given_X=3357.351, hM_given_Y_upper=3364.262
# - Layer 1 upper: MI(X;M)=13.305, MI(Y;M)=3.320, h_upper=1687.898, hM_given_X=1678.676, hM_given_Y_upper=1685.597
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.427, MI(Y;M)=3.208, h_upper=5.052, hM_given_X=2.676, hM_given_Y_upper=2.828
# Doing activations/epoch00000095
# - Layer 0 upper: MI(X;M)=13.291, MI(Y;M)=3.320, h_upper=3366.564, hM_given_X=3357.351, hM_given_Y_upper=3364.262
# - Layer 1 upper: MI(X;M)=13.317, MI(Y;M)=3.320, h_upper=1687.906, hM_given_X=1678.676, hM_given_Y_upper=1685.605
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.422, MI(Y;M)=3.208, h_upper=5.049, hM_given_X=2.676, hM_given_Y_upper=2.825

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import torch
import scienceplots
plt.rcParams['font.serif'] = ['Times New Roman']
mpl.rcParams['figure.dpi'] = 800
mpl.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
plt.style.use(['science', 'ieee'])
mpl.rcParams.update({'font.size': 15})

def plot_information_plane(IXT_array, ITY_array, num_epochs, every_n_early=1, every_n_late=5):
    assert len(IXT_array) == len(ITY_array)

    max_index = len(IXT_array)

    fig, ax = plt.subplots(figsize=(5, 3.5))
    ax.set_xlabel('$I(X;T)$', fontsize=15)
    ax.set_ylabel('$I(T;Y)$', fontsize=15)

    cmap = plt.get_cmap('gnuplot')
    colors = [cmap(i) for i in np.linspace(0, 1, num_epochs + 1)]

    for i in range(0, max_index):
        IXT = IXT_array[i, :]
        ITY = ITY_array[i, :]
        
        # 根据 epoch 的范围调整 every_n
        if i < 20:
            color_idx = i * every_n_early
        else:
            color_idx = 20 * every_n_early + (i - 20) * every_n_late

        ax.plot(IXT, ITY, marker='o', markersize=3, markeredgewidth=0.04,
                linestyle='-', linewidth=0.5, color=colors[color_idx], zorder=10)

    sm = plt.cm.ScalarMappable(cmap=cmap, norm=plt.Normalize(vmin=0, vmax=1))
    sm._A = []

    # 使用ax参数指定颜色条位置
    cbar = plt.colorbar(sm, ax=ax, ticks=[])
    cbar.set_label('epoch number', fontsize=15)
    cbar.ax.tick_params(labelsize=15)
    cbar.ax.text(0.5, -0.01, 0, transform=cbar.ax.transAxes, va='top', ha='center')
    cbar.ax.text(0.5, 1.0, str(num_epochs), transform=cbar.ax.transAxes, va='bottom', ha='center')

    ax.set_xticks([0, 2, 4, 6, 8, 10, 12, 14])
    ax.set_yticks([0, 0.5, 1, 1.5, 2, 2.5, 3.0, 3.5])
    ax.set_ylim(-0.05, 3.5)  # 修改y轴坐标范围
    # Adjust coordinates of text according to the plot area
    ax.text(-0.2, 0.98, '(b)', fontdict={'size': 15, 'color': 'black'}, transform=ax.transAxes)

    #fig.savefig('D:/深度学习与信息论/Fig8b.eps', dpi=800)
    plt.show()

IXT_array = np.load('D:/深度学习与信息论/MI_XM_upper_array.npy')
print(IXT_array)
ITY_array = np.load('D:/深度学习与信息论/MI_YM_upper_array.npy')
print(ITY_array)

plot_information_plane(IXT_array, ITY_array, num_epochs=100, every_n_early=1, every_n_late=5
# %%
class CustomActivation(nn.Module):
    def __init__(self):
        super(CustomActivation, self).__init__()
        self.sigma = nn.Parameter(torch.tensor(0.45))

    def forward(self, input):
        #temp = input/2*(1+torch.erf(input/math.sqrt(2)/self.sigma))#GELU
        temp = input*torch.sigmoid(input/self.sigma)#SiLU
        return temp

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, padding=1)  # 输入通道数1，输出通道数16，卷积核大小3x3
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1) # 输入通道数16，输出通道数32，卷积核大小3x3
        self.pool = nn.MaxPool2d(2, 2)                           # 2x2的最大池化层
        self.fc1 = nn.Linear(32 * 7 * 7, 64)                    # 全连接层，输入维度32*7*7，输出维度64
        self.fc2 = nn.Linear(64, 10)                            # 全连接层，输入维度64，输出维度10（对应10个类别）
        self.act1 = CustomActivation()
        self.act2 = CustomActivation()
        self.act3 = CustomActivation()

    def forward(self, x):
        activations = []
        x = self.act1(self.conv1(x))  # 第一层卷积 + ReLU激活 
        xx= torch.flatten(x, 1)
        activations.append(xx.cpu().data.numpy())#layer1
        x = self.pool(x)
        x = self.act2(self.conv2(x))  # 第二层卷积 + ReLU激活
        xx= torch.flatten(x, 1)
        activations.append(xx.cpu().data.numpy())#layer1
        x = self.pool(x)
        x = x.view(-1, 32 * 7 * 7)            # 展平操作，为全连接层做准备
        x = self.act3(self.fc1(x))               # 第一个全连接层 + ReLU激活
        activations.append(x.cpu().data.numpy())#layer1
        x = self.fc2(x)# 第二个全连接层（输出层）
        x = torch.softmax(x, dim=1)
        activations.append(x.cpu().data.numpy())
        return x, activations


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
class MI_Plate():
    def __init__(self, n_epochs=100, DO_LOWER=False, DO_BINNED=False, PLOT_LAYERS=None):
        super(MI_Plate, self).__init__()
        
        self.n_epochs = n_epochs
        self.DO_LOWER = DO_LOWER
        self.DO_BINNED = DO_BINNED
        self.PLOT_LAYERS = PLOT_LAYERS
#DO_LOWER和DO_BINNED是用于控制数据预处理的布尔值，PLOT_LAYERS是用于指定绘制哪些层的激活值的列表
    def save_activations(self):
        
        if not os.path.exists('activations'):
            print("Making directory", 'activations')
            os.mkdir('activations')
            
        model = Net()
        #model.apply(init_weights)

        optimizer = optim.SGD(model.parameters(), lr=0.001)
        #optimizer = optim.Adam(model.parameters(), lr=0.001)
        # Move model to GPU if available
        if train_on_gpu:
            model.cuda()
        accuracies = []  # List to store accuracies
        for epoch in range(self.n_epochs):
            # monitor training loss
            train_loss = 0.0

            ###################
            # train the model #
            ###################
            model.train()

            for data, target in train_loader:
                if train_on_gpu:
                    data, target = data.cuda(), target.cuda()  # Move data to GPU
                optimizer.zero_grad()
                output, _ = model(data)
                loss = categorical_cross_entropy(output, target)
                # backward
                loss.backward()
                optimizer.step()
                train_loss += loss.item()#*data.size(0)

            # calculate average loss over an epoch
            train_loss = train_loss/len(train_loader.dataset)

            print('Epoch: {} \tTraining Loss: {:.6f}'.format(epoch+1, train_loss))

            model.eval()
########每次按照规定的epoch训练之后，都用full全部数据通过网络一次，记住标签和网络输出
###############################################################################            
            for data, _ in full_data_loader:
                if train_on_gpu:
                    data = data.cuda()  # Move data to GPU
                _, activations = model(data)
#定义多少epoch进行存储每层的输出，前20每次都存，高于200次100次再存一次
            if epoch < 20:       # Log for all first 20 epochs
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            #pickle.HIGHEST_PROTOCOL 用于指定 pickle 协议的版本，以确保最高的兼容性和效率
            elif (epoch < 100) and (epoch % 5 == 0):    # Then for every 5th epoch
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            elif (epoch < 200) and (epoch % 10 == 0):    # Then every 10th
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            elif (epoch % 100 == 0):                # Then every 100th
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
         #####################****************************************
            correct = 0
            total = 0
            with torch.no_grad():
                for data, target in test_loader:  # Assuming test_loader is defined elsewhere
                    if train_on_gpu:
                        data, target = data.cuda(), target.cuda()  # Move data to GPU
                    output, _ = model(data)
                    _, predicted = torch.max(output.data, 1)
                    total += target.size(0)
                    correct += (predicted == target).sum().item()

            accuracy = 100 * correct / total
            accuracies.append(accuracy)  # Store accuracy
            print('Test Accuracy on 10,000 images: {:.2f}%'.format(accuracy))  
        return accuracies
      ###########################
    def compute_MI(self, noise_variance=1e-1):
        
        MAX_EPOCHS = self.n_epochs
        self.noise_variance = noise_variance
        
        def entropy_func_upper(x):
            return kde.entropy_estimator_kl(x,self.noise_variance)
        
        def entropy_func_lower(x):
            return kde.entropy_estimator_bd(x,self.noise_variance)

        # nats to bits conversion factor
        nats2bits = 1.0/np.log(2) 


        # Save indexes of tests data for each of the output classes
        saved_labelixs = {}
        for data, targets in full_data_loader:
            trg = targets.numpy()
        for i in range(10):
            saved_labelixs[i] = trg == i

        labelprobs = np.mean(np.eye(10)[test_data.targets], axis=0)

        MI_XM_upper_array = []
        MI_YM_upper_array = []
###这段代码的作用是计算每个类别在数据集中出现的频率，并保存每个类别的索引以供后续使用
        measures = OrderedDict()
        measures['tanh'] = {}

        cur_dir = 'activations'
        if not os.path.exists(cur_dir):
            print("Directory %s not found" % cur_dir)

        # Load files saved during each epoch, and compute MI measures of the activity in that epoch
        print('*** Doing %s ***' % cur_dir)
        for epochfile in sorted(os.listdir(cur_dir)):
            if not epochfile.startswith('epoch'):
                continue

            fname = cur_dir + "/" + epochfile
            with open(fname, 'rb') as f:
                d = pickle.load(f)

            epoch = d[1]
            d = d[0]
            if epoch in measures['tanh']:# Skip this epoch if its already been processed
                continue                # this is a trick to allow us to rerun this cell multiple times)

            if epoch > MAX_EPOCHS:
                continue

            print("Doing", fname)

            num_layers = len(d)

            MI_XM_upper_epoch = []
            MI_YM_upper_epoch = []
            
            if self.PLOT_LAYERS is None:
                PLOT_LAYERS = []
                for lndx in range(num_layers):
                    PLOT_LAYERS.append(lndx)

            cepochdata = defaultdict(list)
            for lndx in range(num_layers):
                activity = d[lndx]

                # Compute marginal entropies
                h_upper = entropy_func_upper(activity)
                if self.DO_LOWER:
                    #h_lower = entropy_func_lower([activity,])[0]
                    h_lower = entropy_func_lower(activity)

                # Layer activity given input. This is simply the entropy of the Gaussian noise
                hM_given_X = kde.kde_condentropy(activity, self.noise_variance)

                # Compute conditional entropies of layer activity given output
                hM_given_Y_upper=0.
                for i in range(10):
                    hcond_upper = entropy_func_upper(activity[saved_labelixs[i],:])
                    hM_given_Y_upper += labelprobs[i] * hcond_upper

                if self.DO_LOWER:
                    hM_given_Y_lower=0.
                    for i in range(10):
                        hcond_lower = entropy_func_lower(activity[saved_labelixs[i],:])
                        hM_given_Y_lower += labelprobs[i] * hcond_lower

                cepochdata['MI_XM_upper'].append( nats2bits * (h_upper - hM_given_X) )
                cepochdata['MI_YM_upper'].append( nats2bits * (h_upper - hM_given_Y_upper) )
                cepochdata['H_M_upper'  ].append( nats2bits * h_upper )


                MI_XM_upper = nats2bits * (h_upper - hM_given_X)
                MI_YM_upper = nats2bits * (h_upper - hM_given_Y_upper)

                MI_XM_upper_epoch.append(MI_XM_upper)
                MI_YM_upper_epoch.append(MI_YM_upper)
                
                pstr = 'upper: MI(X;M)=%0.3f, MI(Y;M)=%0.3f, h_upper=%0.3f, hM_given_X=%0.3f, hM_given_Y_upper=%0.3f ' % (cepochdata['MI_XM_upper'][-1], cepochdata['MI_YM_upper'][-1], h_upper, hM_given_X, hM_given_Y_upper)
                if self.DO_LOWER:  # Compute lower bounds
                    cepochdata['MI_XM_lower'].append( nats2bits * (h_lower - hM_given_X) )
                    cepochdata['MI_YM_lower'].append( nats2bits * (h_lower - hM_given_Y_lower) )
                    cepochdata['H_M_lower'  ].append( nats2bits * h_lower )
                    pstr += ' | lower: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_lower'][-1], cepochdata['MI_YM_lower'][-1])

                if self.DO_BINNED: # Compute binner estimates
                    binxm, binym = simplebinmi.bin_calc_information2(saved_labelixs, activity, 0.5)
                    cepochdata['MI_XM_bin'].append( nats2bits * binxm )
                    cepochdata['MI_YM_bin'].append( nats2bits * binym )
                    pstr += ' | bin: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_bin'][-1], cepochdata['MI_YM_bin'][-1])

                print('- Layer %d %s' % (lndx, pstr) )

            measures['tanh'][epoch] = cepochdata
            MI_XM_upper_array.append(MI_XM_upper_epoch)
            MI_YM_upper_array.append(MI_YM_upper_epoch)
             
            #epoch += 1
        MI_XM_upper_array = np.array(MI_XM_upper_array)
        MI_YM_upper_array = np.array(MI_YM_upper_array)

    # Save the results as arrays
        np.save('D:/深度学习与信息论/MI_XM_upper_arrayS.npy', MI_XM_upper_array)
        np.save('D:/深度学习与信息论/MI_YM_upper_arrayS.npy', MI_YM_upper_array)

        with open('MI', 'wb') as f:
            pickle.dump(measures, f, pickle.HIGHEST_PROTOCOL) 

Plate = MI_Plate() #Create class object
Plate.save_activations() #save activations if they weren't saved already
Plate.compute_MI() #compute and save MIs if they weren't saved before
# Out:
# Epoch: 1 	Training Loss: 0.017815
# Saving activations/epoch00000000
# Test Accuracy on 10,000 images: 30.17%
# Epoch: 2 	Training Loss: 0.017075
# Saving activations/epoch00000001
# Test Accuracy on 10,000 images: 56.42%
# Epoch: 3 	Training Loss: 0.013219
# Saving activations/epoch00000002
# Test Accuracy on 10,000 images: 77.90%
# Epoch: 4 	Training Loss: 0.006978
# Saving activations/epoch00000003
# Test Accuracy on 10,000 images: 84.46%
# Epoch: 5 	Training Loss: 0.004431
# Saving activations/epoch00000004
# Test Accuracy on 10,000 images: 87.64%
# Epoch: 6 	Training Loss: 0.003502
# Saving activations/epoch00000005
# Test Accuracy on 10,000 images: 89.39%
# Epoch: 7 	Training Loss: 0.003034
# Saving activations/epoch00000006
# Test Accuracy on 10,000 images: 90.43%
# Epoch: 8 	Training Loss: 0.002745
# Saving activations/epoch00000007
# Test Accuracy on 10,000 images: 91.09%
# Epoch: 9 	Training Loss: 0.002540
# Saving activations/epoch00000008
# Test Accuracy on 10,000 images: 91.63%
# Epoch: 10 	Training Loss: 0.002379
# Saving activations/epoch00000009
# Test Accuracy on 10,000 images: 92.00%
# Epoch: 11 	Training Loss: 0.002248
# Saving activations/epoch00000010
# Test Accuracy on 10,000 images: 92.37%
# Epoch: 12 	Training Loss: 0.002134
# Saving activations/epoch00000011
# Test Accuracy on 10,000 images: 92.90%
# Epoch: 13 	Training Loss: 0.002032
# Saving activations/epoch00000012
# Test Accuracy on 10,000 images: 93.01%
# Epoch: 14 	Training Loss: 0.001940
# Saving activations/epoch00000013
# Test Accuracy on 10,000 images: 93.37%
# Epoch: 15 	Training Loss: 0.001855
# Saving activations/epoch00000014
# Test Accuracy on 10,000 images: 93.63%
# Epoch: 16 	Training Loss: 0.001776
# Saving activations/epoch00000015
# Test Accuracy on 10,000 images: 93.91%
# Epoch: 17 	Training Loss: 0.001704
# Saving activations/epoch00000016
# Test Accuracy on 10,000 images: 94.16%
# Epoch: 18 	Training Loss: 0.001635
# Saving activations/epoch00000017
# Test Accuracy on 10,000 images: 94.35%
# Epoch: 19 	Training Loss: 0.001572
# Saving activations/epoch00000018
# Test Accuracy on 10,000 images: 94.68%
# Epoch: 20 	Training Loss: 0.001512
# Saving activations/epoch00000019
# Test Accuracy on 10,000 images: 94.91%
# Epoch: 21 	Training Loss: 0.001456
# Saving activations/epoch00000020
# Test Accuracy on 10,000 images: 94.94%
# Epoch: 22 	Training Loss: 0.001404
# Test Accuracy on 10,000 images: 95.30%
# Epoch: 23 	Training Loss: 0.001356
# Test Accuracy on 10,000 images: 95.39%
# Epoch: 24 	Training Loss: 0.001308
# Test Accuracy on 10,000 images: 95.41%
# Epoch: 25 	Training Loss: 0.001264
# Test Accuracy on 10,000 images: 95.51%
# Epoch: 26 	Training Loss: 0.001226
# Saving activations/epoch00000025
# Test Accuracy on 10,000 images: 95.78%
# Epoch: 27 	Training Loss: 0.001187
# Test Accuracy on 10,000 images: 95.87%
# Epoch: 28 	Training Loss: 0.001151
# Test Accuracy on 10,000 images: 95.76%
# Epoch: 29 	Training Loss: 0.001117
# Test Accuracy on 10,000 images: 96.06%
# Epoch: 30 	Training Loss: 0.001086
# Test Accuracy on 10,000 images: 96.17%
# Epoch: 31 	Training Loss: 0.001056
# Saving activations/epoch00000030
# Test Accuracy on 10,000 images: 96.18%
# Epoch: 32 	Training Loss: 0.001029
# Test Accuracy on 10,000 images: 96.28%
# Epoch: 33 	Training Loss: 0.001003
# Test Accuracy on 10,000 images: 96.37%
# Epoch: 34 	Training Loss: 0.000979
# Test Accuracy on 10,000 images: 96.55%
# Epoch: 35 	Training Loss: 0.000954
# Test Accuracy on 10,000 images: 96.63%
# Epoch: 36 	Training Loss: 0.000932
# Saving activations/epoch00000035
# Test Accuracy on 10,000 images: 96.56%
# Epoch: 37 	Training Loss: 0.000910
# Test Accuracy on 10,000 images: 96.81%
# Epoch: 38 	Training Loss: 0.000890
# Test Accuracy on 10,000 images: 96.88%
# Epoch: 39 	Training Loss: 0.000872
# Test Accuracy on 10,000 images: 96.78%
# Epoch: 40 	Training Loss: 0.000853
# Test Accuracy on 10,000 images: 96.98%
# Epoch: 41 	Training Loss: 0.000837
# Saving activations/epoch00000040
# Test Accuracy on 10,000 images: 97.04%
# Epoch: 42 	Training Loss: 0.000819
# Test Accuracy on 10,000 images: 97.07%
# Epoch: 43 	Training Loss: 0.000804
# Test Accuracy on 10,000 images: 97.07%
# Epoch: 44 	Training Loss: 0.000789
# Test Accuracy on 10,000 images: 97.07%
# Epoch: 45 	Training Loss: 0.000775
# Test Accuracy on 10,000 images: 97.21%
# Epoch: 46 	Training Loss: 0.000761
# Saving activations/epoch00000045
# Test Accuracy on 10,000 images: 97.25%
# Epoch: 47 	Training Loss: 0.000749
# Test Accuracy on 10,000 images: 97.18%
# Epoch: 48 	Training Loss: 0.000736
# Test Accuracy on 10,000 images: 97.36%
# Epoch: 49 	Training Loss: 0.000724
# Test Accuracy on 10,000 images: 97.28%
# Epoch: 50 	Training Loss: 0.000713
# Test Accuracy on 10,000 images: 97.40%
# Epoch: 51 	Training Loss: 0.000701
# Saving activations/epoch00000050
# Test Accuracy on 10,000 images: 97.40%
# Epoch: 52 	Training Loss: 0.000691
# Test Accuracy on 10,000 images: 97.50%
# Epoch: 53 	Training Loss: 0.000680
# Test Accuracy on 10,000 images: 97.42%
# Epoch: 54 	Training Loss: 0.000670
# Test Accuracy on 10,000 images: 97.51%
# Epoch: 55 	Training Loss: 0.000660
# Test Accuracy on 10,000 images: 97.54%
# Epoch: 56 	Training Loss: 0.000652
# Saving activations/epoch00000055
# Test Accuracy on 10,000 images: 97.54%
# Epoch: 57 	Training Loss: 0.000643
# Test Accuracy on 10,000 images: 97.55%
# Epoch: 58 	Training Loss: 0.000634
# Test Accuracy on 10,000 images: 97.61%
# Epoch: 59 	Training Loss: 0.000626
# Test Accuracy on 10,000 images: 97.67%
# Epoch: 60 	Training Loss: 0.000618
# Test Accuracy on 10,000 images: 97.67%
# Epoch: 61 	Training Loss: 0.000611
# Saving activations/epoch00000060
# Test Accuracy on 10,000 images: 97.69%
# Epoch: 62 	Training Loss: 0.000603
# Test Accuracy on 10,000 images: 97.71%
# Epoch: 63 	Training Loss: 0.000595
# Test Accuracy on 10,000 images: 97.71%
# Epoch: 64 	Training Loss: 0.000588
# Test Accuracy on 10,000 images: 97.70%
# Epoch: 65 	Training Loss: 0.000580
# Test Accuracy on 10,000 images: 97.76%
# Epoch: 66 	Training Loss: 0.000574
# Saving activations/epoch00000065
# Test Accuracy on 10,000 images: 97.74%
# Epoch: 67 	Training Loss: 0.000568
# Test Accuracy on 10,000 images: 97.82%
# Epoch: 68 	Training Loss: 0.000562
# Test Accuracy on 10,000 images: 97.85%
# Epoch: 69 	Training Loss: 0.000556
# Test Accuracy on 10,000 images: 97.88%
# Epoch: 70 	Training Loss: 0.000550
# Test Accuracy on 10,000 images: 97.81%
# Epoch: 71 	Training Loss: 0.000543
# Saving activations/epoch00000070
# Test Accuracy on 10,000 images: 97.86%
# Epoch: 72 	Training Loss: 0.000539
# Test Accuracy on 10,000 images: 97.88%
# Epoch: 73 	Training Loss: 0.000533
# Test Accuracy on 10,000 images: 97.91%
# Epoch: 74 	Training Loss: 0.000528
# Test Accuracy on 10,000 images: 97.91%
# Epoch: 75 	Training Loss: 0.000522
# Test Accuracy on 10,000 images: 97.97%
# Epoch: 76 	Training Loss: 0.000517
# Saving activations/epoch00000075
# Test Accuracy on 10,000 images: 97.91%
# Epoch: 77 	Training Loss: 0.000512
# Test Accuracy on 10,000 images: 97.98%
# Epoch: 78 	Training Loss: 0.000508
# Test Accuracy on 10,000 images: 98.01%
# Epoch: 79 	Training Loss: 0.000504
# Test Accuracy on 10,000 images: 97.97%
# Epoch: 80 	Training Loss: 0.000497
# Test Accuracy on 10,000 images: 98.00%
# Epoch: 81 	Training Loss: 0.000495
# Saving activations/epoch00000080
# Test Accuracy on 10,000 images: 98.11%
# Epoch: 82 	Training Loss: 0.000490
# Test Accuracy on 10,000 images: 98.04%
# Epoch: 83 	Training Loss: 0.000486
# Test Accuracy on 10,000 images: 98.08%
# Epoch: 84 	Training Loss: 0.000481
# Test Accuracy on 10,000 images: 98.12%
# Epoch: 85 	Training Loss: 0.000477
# Test Accuracy on 10,000 images: 98.16%
# Epoch: 86 	Training Loss: 0.000473
# Saving activations/epoch00000085
# Test Accuracy on 10,000 images: 98.13%
# Epoch: 87 	Training Loss: 0.000469
# Test Accuracy on 10,000 images: 98.14%
# Epoch: 88 	Training Loss: 0.000466
# Test Accuracy on 10,000 images: 98.16%
# Epoch: 89 	Training Loss: 0.000462
# Test Accuracy on 10,000 images: 98.16%
# Epoch: 90 	Training Loss: 0.000458
# Test Accuracy on 10,000 images: 98.24%
# Epoch: 91 	Training Loss: 0.000454
# Saving activations/epoch00000090
# Test Accuracy on 10,000 images: 98.25%
# Epoch: 92 	Training Loss: 0.000450
# Test Accuracy on 10,000 images: 98.16%
# Epoch: 93 	Training Loss: 0.000446
# Test Accuracy on 10,000 images: 98.10%
# Epoch: 94 	Training Loss: 0.000445
# Test Accuracy on 10,000 images: 98.21%
# Epoch: 95 	Training Loss: 0.000440
# Test Accuracy on 10,000 images: 98.29%
# Epoch: 96 	Training Loss: 0.000437
# Saving activations/epoch00000095
# Test Accuracy on 10,000 images: 98.32%
# Epoch: 97 	Training Loss: 0.000433
# Test Accuracy on 10,000 images: 98.24%
# Epoch: 98 	Training Loss: 0.000430
# Test Accuracy on 10,000 images: 98.32%
# Epoch: 99 	Training Loss: 0.000427
# Test Accuracy on 10,000 images: 98.31%
# Epoch: 100 	Training Loss: 0.000423
# Test Accuracy on 10,000 images: 98.26%
# *** Doing activations ***
# Doing activations/epoch00000000
# - Layer 0 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=3366.560, hM_given_X=3357.351, hM_given_Y_upper=3364.260
# - Layer 1 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=1687.886, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 2 upper: MI(X;M)=2.500, MI(Y;M)=0.851, h_upper=18.862, hM_given_X=17.129, hM_given_Y_upper=18.272
# - Layer 3 upper: MI(X;M)=0.003, MI(Y;M)=0.001, h_upper=2.678, hM_given_X=2.676, hM_given_Y_upper=2.677
# Doing activations/epoch00000001
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=3366.562, hM_given_X=3357.351, hM_given_Y_upper=3364.261
# - Layer 1 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=1687.886, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 2 upper: MI(X;M)=8.637, MI(Y;M)=2.597, h_upper=23.116, hM_given_X=17.129, hM_given_Y_upper=21.315
# - Layer 3 upper: MI(X;M)=0.051, MI(Y;M)=0.032, h_upper=2.712, hM_given_X=2.676, hM_given_Y_upper=2.690
# Doing activations/epoch00000002
# - Layer 0 upper: MI(X;M)=13.296, MI(Y;M)=3.320, h_upper=3366.567, hM_given_X=3357.351, hM_given_Y_upper=3364.266
# - Layer 1 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=1687.885, hM_given_X=1678.676, hM_given_Y_upper=1685.584
# - Layer 2 upper: MI(X;M)=13.153, MI(Y;M)=3.319, h_upper=26.246, hM_given_X=17.129, hM_given_Y_upper=23.946
# - Layer 3 upper: MI(X;M)=1.364, MI(Y;M)=0.937, h_upper=3.622, hM_given_X=2.676, hM_given_Y_upper=2.972
# Doing activations/epoch00000003
# - Layer 0 upper: MI(X;M)=13.286, MI(Y;M)=3.320, h_upper=3366.560, hM_given_X=3357.351, hM_given_Y_upper=3364.259
# - Layer 1 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=1687.885, hM_given_X=1678.676, hM_given_Y_upper=1685.584
# - Layer 2 upper: MI(X;M)=13.281, MI(Y;M)=3.319, h_upper=26.335, hM_given_X=17.129, hM_given_Y_upper=24.034
# - Layer 3 upper: MI(X;M)=3.194, MI(Y;M)=2.251, h_upper=4.891, hM_given_X=2.676, hM_given_Y_upper=3.330
# Doing activations/epoch00000004
# - Layer 0 upper: MI(X;M)=13.260, MI(Y;M)=3.319, h_upper=3366.543, hM_given_X=3357.351, hM_given_Y_upper=3364.242
# - Layer 1 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=1687.885, hM_given_X=1678.676, hM_given_Y_upper=1685.584
# - Layer 2 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=26.339, hM_given_X=17.129, hM_given_Y_upper=24.038
# - Layer 3 upper: MI(X;M)=3.566, MI(Y;M)=2.601, h_upper=5.148, hM_given_X=2.676, hM_given_Y_upper=3.345
# Doing activations/epoch00000005
# - Layer 0 upper: MI(X;M)=13.290, MI(Y;M)=3.319, h_upper=3366.563, hM_given_X=3357.351, hM_given_Y_upper=3364.262
# - Layer 1 upper: MI(X;M)=13.291, MI(Y;M)=3.320, h_upper=1687.888, hM_given_X=1678.676, hM_given_Y_upper=1685.588
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=26.339, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.648, MI(Y;M)=2.728, h_upper=5.205, hM_given_X=2.676, hM_given_Y_upper=3.314
# Doing activations/epoch00000006
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.320, h_upper=3366.562, hM_given_X=3357.351, hM_given_Y_upper=3364.261
# - Layer 1 upper: MI(X;M)=13.292, MI(Y;M)=3.320, h_upper=1687.889, hM_given_X=1678.676, hM_given_Y_upper=1685.588
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=26.339, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.667, MI(Y;M)=2.792, h_upper=5.219, hM_given_X=2.676, hM_given_Y_upper=3.284
# Doing activations/epoch00000007
# - Layer 0 upper: MI(X;M)=13.291, MI(Y;M)=3.320, h_upper=3366.564, hM_given_X=3357.351, hM_given_Y_upper=3364.263
# - Layer 1 upper: MI(X;M)=13.298, MI(Y;M)=3.319, h_upper=1687.893, hM_given_X=1678.676, hM_given_Y_upper=1685.592
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.666, MI(Y;M)=2.829, h_upper=5.217, hM_given_X=2.676, hM_given_Y_upper=3.256
# Doing activations/epoch00000008
# - Layer 0 upper: MI(X;M)=13.284, MI(Y;M)=3.320, h_upper=3366.559, hM_given_X=3357.351, hM_given_Y_upper=3364.258
# - Layer 1 upper: MI(X;M)=13.301, MI(Y;M)=3.319, h_upper=1687.895, hM_given_X=1678.676, hM_given_Y_upper=1685.595
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.659, MI(Y;M)=2.859, h_upper=5.213, hM_given_X=2.676, hM_given_Y_upper=3.231
# Doing activations/epoch00000009
# - Layer 0 upper: MI(X;M)=13.267, MI(Y;M)=3.319, h_upper=3366.547, hM_given_X=3357.351, hM_given_Y_upper=3364.246
# - Layer 1 upper: MI(X;M)=13.297, MI(Y;M)=3.320, h_upper=1687.893, hM_given_X=1678.676, hM_given_Y_upper=1685.592
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.652, MI(Y;M)=2.882, h_upper=5.208, hM_given_X=2.676, hM_given_Y_upper=3.210
# Doing activations/epoch00000010
# - Layer 0 upper: MI(X;M)=13.307, MI(Y;M)=3.320, h_upper=3366.575, hM_given_X=3357.351, hM_given_Y_upper=3364.274
# - Layer 1 upper: MI(X;M)=13.295, MI(Y;M)=3.319, h_upper=1687.891, hM_given_X=1678.676, hM_given_Y_upper=1685.590
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.641, MI(Y;M)=2.898, h_upper=5.200, hM_given_X=2.676, hM_given_Y_upper=3.191
# Doing activations/epoch00000011
# - Layer 0 upper: MI(X;M)=13.296, MI(Y;M)=3.320, h_upper=3366.568, hM_given_X=3357.351, hM_given_Y_upper=3364.267
# - Layer 1 upper: MI(X;M)=13.307, MI(Y;M)=3.319, h_upper=1687.899, hM_given_X=1678.676, hM_given_Y_upper=1685.598
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.635, MI(Y;M)=2.920, h_upper=5.196, hM_given_X=2.676, hM_given_Y_upper=3.172
# Doing activations/epoch00000012
# - Layer 0 upper: MI(X;M)=13.311, MI(Y;M)=3.320, h_upper=3366.578, hM_given_X=3357.351, hM_given_Y_upper=3364.277
# - Layer 1 upper: MI(X;M)=13.297, MI(Y;M)=3.320, h_upper=1687.892, hM_given_X=1678.676, hM_given_Y_upper=1685.591
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.625, MI(Y;M)=2.930, h_upper=5.189, hM_given_X=2.676, hM_given_Y_upper=3.158
# Doing activations/epoch00000013
# - Layer 0 upper: MI(X;M)=13.282, MI(Y;M)=3.320, h_upper=3366.558, hM_given_X=3357.351, hM_given_Y_upper=3364.257
# - Layer 1 upper: MI(X;M)=13.291, MI(Y;M)=3.319, h_upper=1687.888, hM_given_X=1678.676, hM_given_Y_upper=1685.587
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.617, MI(Y;M)=2.948, h_upper=5.184, hM_given_X=2.676, hM_given_Y_upper=3.140
# Doing activations/epoch00000014
# - Layer 0 upper: MI(X;M)=13.328, MI(Y;M)=3.320, h_upper=3366.590, hM_given_X=3357.351, hM_given_Y_upper=3364.289
# - Layer 1 upper: MI(X;M)=13.314, MI(Y;M)=3.320, h_upper=1687.904, hM_given_X=1678.676, hM_given_Y_upper=1685.603
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.610, MI(Y;M)=2.964, h_upper=5.179, hM_given_X=2.676, hM_given_Y_upper=3.124
# Doing activations/epoch00000015
# - Layer 0 upper: MI(X;M)=13.249, MI(Y;M)=3.320, h_upper=3366.534, hM_given_X=3357.351, hM_given_Y_upper=3364.233
# - Layer 1 upper: MI(X;M)=13.303, MI(Y;M)=3.320, h_upper=1687.896, hM_given_X=1678.676, hM_given_Y_upper=1685.595
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.601, MI(Y;M)=2.975, h_upper=5.173, hM_given_X=2.676, hM_given_Y_upper=3.110
# Doing activations/epoch00000016
# - Layer 0 upper: MI(X;M)=13.318, MI(Y;M)=3.320, h_upper=3366.582, hM_given_X=3357.351, hM_given_Y_upper=3364.281
# - Layer 1 upper: MI(X;M)=13.311, MI(Y;M)=3.319, h_upper=1687.902, hM_given_X=1678.676, hM_given_Y_upper=1685.601
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.594, MI(Y;M)=2.988, h_upper=5.167, hM_given_X=2.676, hM_given_Y_upper=3.096
# Doing activations/epoch00000017
# - Layer 0 upper: MI(X;M)=13.285, MI(Y;M)=3.320, h_upper=3366.560, hM_given_X=3357.351, hM_given_Y_upper=3364.259
# - Layer 1 upper: MI(X;M)=13.315, MI(Y;M)=3.320, h_upper=1687.905, hM_given_X=1678.676, hM_given_Y_upper=1685.604
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.587, MI(Y;M)=3.002, h_upper=5.163, hM_given_X=2.676, hM_given_Y_upper=3.082
# Doing activations/epoch00000018
# - Layer 0 upper: MI(X;M)=13.275, MI(Y;M)=3.320, h_upper=3366.552, hM_given_X=3357.351, hM_given_Y_upper=3364.251
# - Layer 1 upper: MI(X;M)=13.311, MI(Y;M)=3.320, h_upper=1687.902, hM_given_X=1678.676, hM_given_Y_upper=1685.601
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.581, MI(Y;M)=3.015, h_upper=5.159, hM_given_X=2.676, hM_given_Y_upper=3.069
# Doing activations/epoch00000019
# - Layer 0 upper: MI(X;M)=13.286, MI(Y;M)=3.320, h_upper=3366.560, hM_given_X=3357.351, hM_given_Y_upper=3364.259
# - Layer 1 upper: MI(X;M)=13.305, MI(Y;M)=3.319, h_upper=1687.898, hM_given_X=1678.676, hM_given_Y_upper=1685.597
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.573, MI(Y;M)=3.025, h_upper=5.153, hM_given_X=2.676, hM_given_Y_upper=3.057
# Doing activations/epoch00000020
# - Layer 0 upper: MI(X;M)=13.271, MI(Y;M)=3.320, h_upper=3366.550, hM_given_X=3357.351, hM_given_Y_upper=3364.249
# - Layer 1 upper: MI(X;M)=13.304, MI(Y;M)=3.320, h_upper=1687.897, hM_given_X=1678.676, hM_given_Y_upper=1685.596
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.566, MI(Y;M)=3.032, h_upper=5.148, hM_given_X=2.676, hM_given_Y_upper=3.047
# Doing activations/epoch00000025
# - Layer 0 upper: MI(X;M)=13.253, MI(Y;M)=3.319, h_upper=3366.538, hM_given_X=3357.351, hM_given_Y_upper=3364.237
# - Layer 1 upper: MI(X;M)=13.295, MI(Y;M)=3.320, h_upper=1687.891, hM_given_X=1678.676, hM_given_Y_upper=1685.590
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.539, MI(Y;M)=3.075, h_upper=5.130, hM_given_X=2.676, hM_given_Y_upper=2.998
# Doing activations/epoch00000030
# - Layer 0 upper: MI(X;M)=13.276, MI(Y;M)=3.320, h_upper=3366.554, hM_given_X=3357.351, hM_given_Y_upper=3364.253
# - Layer 1 upper: MI(X;M)=13.305, MI(Y;M)=3.320, h_upper=1687.898, hM_given_X=1678.676, hM_given_Y_upper=1685.597
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.517, MI(Y;M)=3.103, h_upper=5.114, hM_given_X=2.676, hM_given_Y_upper=2.963
# Doing activations/epoch00000035
# - Layer 0 upper: MI(X;M)=13.310, MI(Y;M)=3.320, h_upper=3366.577, hM_given_X=3357.351, hM_given_Y_upper=3364.276
# - Layer 1 upper: MI(X;M)=13.295, MI(Y;M)=3.319, h_upper=1687.891, hM_given_X=1678.676, hM_given_Y_upper=1685.590
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.498, MI(Y;M)=3.121, h_upper=5.101, hM_given_X=2.676, hM_given_Y_upper=2.938
# Doing activations/epoch00000040
# - Layer 0 upper: MI(X;M)=13.259, MI(Y;M)=3.320, h_upper=3366.542, hM_given_X=3357.351, hM_given_Y_upper=3364.241
# - Layer 1 upper: MI(X;M)=13.329, MI(Y;M)=3.320, h_upper=1687.915, hM_given_X=1678.676, hM_given_Y_upper=1685.614
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.481, MI(Y;M)=3.139, h_upper=5.089, hM_given_X=2.676, hM_given_Y_upper=2.914
# Doing activations/epoch00000045
# - Layer 0 upper: MI(X;M)=13.275, MI(Y;M)=3.320, h_upper=3366.553, hM_given_X=3357.351, hM_given_Y_upper=3364.252
# - Layer 1 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=1687.886, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.469, MI(Y;M)=3.151, h_upper=5.081, hM_given_X=2.676, hM_given_Y_upper=2.897
# Doing activations/epoch00000050
# - Layer 0 upper: MI(X;M)=13.275, MI(Y;M)=3.320, h_upper=3366.553, hM_given_X=3357.351, hM_given_Y_upper=3364.252
# - Layer 1 upper: MI(X;M)=13.305, MI(Y;M)=3.320, h_upper=1687.898, hM_given_X=1678.676, hM_given_Y_upper=1685.597
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.460, MI(Y;M)=3.161, h_upper=5.075, hM_given_X=2.676, hM_given_Y_upper=2.883
# Doing activations/epoch00000055
# - Layer 0 upper: MI(X;M)=13.274, MI(Y;M)=3.320, h_upper=3366.552, hM_given_X=3357.351, hM_given_Y_upper=3364.251
# - Layer 1 upper: MI(X;M)=13.284, MI(Y;M)=3.319, h_upper=1687.884, hM_given_X=1678.676, hM_given_Y_upper=1685.583
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.452, MI(Y;M)=3.169, h_upper=5.069, hM_given_X=2.676, hM_given_Y_upper=2.873
# Doing activations/epoch00000060
# - Layer 0 upper: MI(X;M)=13.267, MI(Y;M)=3.320, h_upper=3366.547, hM_given_X=3357.351, hM_given_Y_upper=3364.246
# - Layer 1 upper: MI(X;M)=13.325, MI(Y;M)=3.320, h_upper=1687.912, hM_given_X=1678.676, hM_given_Y_upper=1685.611
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.447, MI(Y;M)=3.179, h_upper=5.066, hM_given_X=2.676, hM_given_Y_upper=2.862
# Doing activations/epoch00000065
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.320, h_upper=3366.562, hM_given_X=3357.351, hM_given_Y_upper=3364.260
# - Layer 1 upper: MI(X;M)=13.311, MI(Y;M)=3.320, h_upper=1687.902, hM_given_X=1678.676, hM_given_Y_upper=1685.601
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.440, MI(Y;M)=3.181, h_upper=5.061, hM_given_X=2.676, hM_given_Y_upper=2.856
# Doing activations/epoch00000070
# - Layer 0 upper: MI(X;M)=13.287, MI(Y;M)=3.320, h_upper=3366.561, hM_given_X=3357.351, hM_given_Y_upper=3364.260
# - Layer 1 upper: MI(X;M)=13.320, MI(Y;M)=3.320, h_upper=1687.908, hM_given_X=1678.676, hM_given_Y_upper=1685.607
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.438, MI(Y;M)=3.189, h_upper=5.060, hM_given_X=2.676, hM_given_Y_upper=2.849
# Doing activations/epoch00000075
# - Layer 0 upper: MI(X;M)=13.306, MI(Y;M)=3.320, h_upper=3366.574, hM_given_X=3357.351, hM_given_Y_upper=3364.273
# - Layer 1 upper: MI(X;M)=13.317, MI(Y;M)=3.320, h_upper=1687.906, hM_given_X=1678.676, hM_given_Y_upper=1685.605
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.433, MI(Y;M)=3.191, h_upper=5.056, hM_given_X=2.676, hM_given_Y_upper=2.844
# Doing activations/epoch00000080
# - Layer 0 upper: MI(X;M)=13.277, MI(Y;M)=3.320, h_upper=3366.554, hM_given_X=3357.351, hM_given_Y_upper=3364.253
# - Layer 1 upper: MI(X;M)=13.309, MI(Y;M)=3.319, h_upper=1687.901, hM_given_X=1678.676, hM_given_Y_upper=1685.600
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.428, MI(Y;M)=3.198, h_upper=5.052, hM_given_X=2.676, hM_given_Y_upper=2.836
# Doing activations/epoch00000085
# - Layer 0 upper: MI(X;M)=13.328, MI(Y;M)=3.320, h_upper=3366.589, hM_given_X=3357.351, hM_given_Y_upper=3364.288
# - Layer 1 upper: MI(X;M)=13.307, MI(Y;M)=3.320, h_upper=1687.899, hM_given_X=1678.676, hM_given_Y_upper=1685.598
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.426, MI(Y;M)=3.203, h_upper=5.051, hM_given_X=2.676, hM_given_Y_upper=2.831
# Doing activations/epoch00000090
# - Layer 0 upper: MI(X;M)=13.256, MI(Y;M)=3.320, h_upper=3366.540, hM_given_X=3357.351, hM_given_Y_upper=3364.239
# - Layer 1 upper: MI(X;M)=13.326, MI(Y;M)=3.320, h_upper=1687.913, hM_given_X=1678.676, hM_given_Y_upper=1685.612
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.422, MI(Y;M)=3.209, h_upper=5.048, hM_given_X=2.676, hM_given_Y_upper=2.824
# Doing activations/epoch00000095
# - Layer 0 upper: MI(X;M)=13.251, MI(Y;M)=3.320, h_upper=3366.536, hM_given_X=3357.351, hM_given_Y_upper=3364.235
# - Layer 1 upper: MI(X;M)=13.323, MI(Y;M)=3.320, h_upper=1687.911, hM_given_X=1678.676, hM_given_Y_upper=1685.610
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.417, MI(Y;M)=3.211, h_upper=5.045, hM_given_X=2.676, hM_given_Y_upper=2.820

# %%
accuracy_array = [
    30.17, 56.42, 77.90, 84.46, 87.64, 89.39, 90.43, 91.09, 91.63, 92.00,
    92.37, 92.90, 93.01, 93.37, 93.63, 93.91, 94.16, 94.35, 94.68, 94.91,
    94.94, 95.30, 95.39, 95.41, 95.51, 95.78, 95.87, 95.76, 96.06, 96.17,
    96.18, 96.28, 96.37, 96.55, 96.63, 96.56, 96.81, 96.88, 96.78, 96.98,
    97.04, 97.07, 97.07, 97.07, 97.21, 97.25, 97.18, 97.36, 97.28, 97.40,
    97.40, 97.50, 97.42, 97.51, 97.54, 97.54, 97.55, 97.61, 97.67, 97.67,
    97.69, 97.71, 97.71, 97.70, 97.76, 97.74, 97.82, 97.85, 97.88, 97.81,
    97.86, 97.88, 97.91, 97.91, 97.97, 97.91, 97.98, 98.01, 97.97, 98.00,
    98.11, 98.04, 98.08, 98.12, 98.16, 98.13, 98.14, 98.16, 98.16, 98.24,
    98.25, 98.16, 98.10, 98.21, 98.29, 98.32, 98.24, 98.32, 98.31, 98.26
]

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import torch
import scienceplots
plt.rcParams['font.serif'] = ['Times New Roman']
mpl.rcParams['figure.dpi'] = 800
mpl.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
plt.style.use(['science', 'ieee'])
mpl.rcParams.update({'font.size': 15})

def plot_information_plane(IXT_array, ITY_array, num_epochs, every_n_early=1, every_n_late=5):
    assert len(IXT_array) == len(ITY_array)

    max_index = len(IXT_array)

    fig, ax = plt.subplots(figsize=(5, 3.5))
    ax.set_xlabel('$I(X;T)$', fontsize=15)
    ax.set_ylabel('$I(T;Y)$', fontsize=15)

    cmap = plt.get_cmap('gnuplot')
    colors = [cmap(i) for i in np.linspace(0, 1, num_epochs + 1)]

    for i in range(0, max_index):
        IXT = IXT_array[i, :]
        ITY = ITY_array[i, :]
        
        # 根据 epoch 的范围调整 every_n
        if i < 20:
            color_idx = i * every_n_early
        else:
            color_idx = 20 * every_n_early + (i - 20) * every_n_late

        ax.plot(IXT, ITY, marker='o', markersize=3, markeredgewidth=0.04,
                linestyle='-', linewidth=0.5, color=colors[color_idx], zorder=10)

    sm = plt.cm.ScalarMappable(cmap=cmap, norm=plt.Normalize(vmin=0, vmax=1))
    sm._A = []

    # 使用ax参数指定颜色条位置
    cbar = plt.colorbar(sm, ax=ax, ticks=[])
    cbar.set_label('epoch number', fontsize=15)
    cbar.ax.tick_params(labelsize=15)
    cbar.ax.text(0.5, -0.01, 0, transform=cbar.ax.transAxes, va='top', ha='center')
    cbar.ax.text(0.5, 1.0, str(num_epochs), transform=cbar.ax.transAxes, va='bottom', ha='center')

    ax.set_xticks([0, 2, 4, 6, 8, 10, 12, 14])
    ax.set_yticks([0, 0.5, 1, 1.5, 2, 2.5, 3.0, 3.5])
    ax.set_ylim(-0.05, 3.5)  # 修改y轴坐标范围
    # Adjust coordinates of text according to the plot area
    ax.text(-0.2, 0.98, '(c)', fontdict={'size': 15, 'color': 'black'}, transform=ax.transAxes)

    fig.savefig('D:/深度学习与信息论/Fig8c.eps', dpi=800)
    plt.show()

IXT_array = np.load('D:/深度学习与信息论/MI_XM_upper_arrayS.npy')
ITY_array = np.load('D:/深度学习与信息论/MI_YM_upper_arrayS.npy')


plot_information_plane(IXT_array, ITY_array, num_epochs=100, every_n_early=1, every_n_late=5)

# %%
IXT_array
# Out:
# array([[1.32858442e+01, 1.32877374e+01, 2.49997679e+00, 2.79047825e-03],
#        [1.32883098e+01, 1.32872090e+01, 8.63651040e+00, 5.12104738e-02],
#        [1.32957064e+01, 1.32858002e+01, 1.31529757e+01, 1.36359202e+00],
#        [1.32858442e+01, 1.32856241e+01, 1.32805345e+01, 3.19419822e+00],
#        [3.31947726e+00, 3.31933111e+00, 3.31942494e+00, 2.60084190e+00],
#        [3.31943161e+00, 3.31952625e+00, 3.31942120e+00, 2.72779122e+00],
#        [3.31979588e+00, 3.31952403e+00, 3.31942209e+00, 2.79156411e+00],
#        [3.31984660e+00, 3.31942186e+00, 3.31942221e+00, 2.82928387e+00],
#        [3.31974217e+00, 3.31937108e+00, 3.31942137e+00, 2.85889076e+00],
#        [3.31946761e+00, 3.31963826e+00, 3.31942205e+00, 2.88185494e+00],
#        [3.31981895e+00, 3.31945544e+00, 3.31942182e+00, 2.89802458e+00],
#        [3.31968489e+00, 3.31948263e+00, 3.31942021e+00, 2.92012887e+00],
#        [3.31974273e+00, 3.31970754e+00, 3.31942167e+00, 2.93049356e+00],
#        [3.31975094e+00, 3.31947777e+00, 3.31942137e+00, 2.94812041e+00],
#        [3.31993543e+00, 3.31972883e+00, 3.31942493e+00, 2.96410290e+00],
#        [3.31974741e+00, 3.31965272e+00, 3.31941881e+00, 2.97544983e+00],
#        [3.32018794e+00, 3.31945178e+00, 3.31942103e+00, 2.98807430e+00],
#        [3.31950907e+00, 3.31976996e+00, 3.31942026e+00, 3.00178942e+00],
#        [3.31999738e+00, 3.31963225e+00, 3.31942115e+00, 3.01519916e+00],
#        [3.31954837e+00, 3.31944660e+00, 3.31941910e+00, 3.02485517e+00],
#        [3.31962128e+00, 3.31961176e+00, 3.31942459e+00, 3.03193951e+00],
#        [3.31949896e+00, 3.31956038e+00, 3.31942176e+00, 3.07481473e+00],
#        [3.31975682e+00, 3.31959953e+00, 3.31942117e+00, 3.10313900e+00],
#        [3.31985632e+00, 3.31937431e+00, 3.31942920e+00, 3.12051687e+00],
#        [3.31985442e+00, 3.31969895e+00, 3.31942093e+00, 3.13913486e+00],
#        [3.31978330e+00, 3.31944151e+00, 3.31942471e+00, 3.15087205e+00],
#        [3.31974706e+00, 3.31975030e+00, 3.31942096e+00, 3.16124221e+00],
#        [3.31987654e+00, 3.31925237e+00, 3.31942438e+00, 3.16852915e+00],
#        [3.31997336e+00, 3.31962391e+00, 3.31942400e+00, 3.17873246e+00],
#        [3.32002834e+00, 3.31976465e+00, 3.31941969e+00, 3.18138770e+00],
#        [3.31973572e+00, 3.31997333e+00, 3.31942979e+00, 3.18904407e+00],
#        [3.31988601e+00, 3.31972272e+00, 3.31941888e+00, 3.19114574e+00],
#        [3.31986185e+00, 3.31949487e+00, 3.31941722e+00, 3.19811199e+00],
#        [3.32019237e+00, 3.31972267e+00, 3.31942395e+00, 3.20308803e+00],
#        [3.31950389e+00, 3.31963824e+00, 3.31942579e+00, 3.20913891e+00],
#        [3.32015842e+00, 3.31973384e+00, 3.31942373e+00, 3.21059099e+00]])

# %%
class CustomActivation(nn.Module):
    def __init__(self):
        super(CustomActivation, self).__init__()
        self.sigma = nn.Parameter(torch.tensor(3.0))

    def forward(self, input):
        temp = input/2*(1+torch.erf(input/math.sqrt(2)/self.sigma))#GELU
        #temp = input*torch.sigmoid(input)#SiLU
        return temp
        
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, padding=1)  # 输入通道数1，输出通道数16，卷积核大小3x3
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1) # 输入通道数16，输出通道数32，卷积核大小3x3
        self.pool = nn.MaxPool2d(2, 2)                           # 2x2的最大池化层
        self.fc1 = nn.Linear(32 * 7 * 7, 64)                    # 全连接层，输入维度32*7*7，输出维度64
        self.fc2 = nn.Linear(64, 10)                            # 全连接层，输入维度64，输出维度10（对应10个类别）
        self.act1 = CustomActivation()
        self.act2 = CustomActivation()
        self.act3 = CustomActivation()

    def forward(self, x):
        activations = []
        x = self.act1(self.conv1(x))  # 第一层卷积 + ReLU激活 
        xx= torch.flatten(x, 1)
        activations.append(xx.cpu().data.numpy())#layer1
        x = self.pool(x)
        x = self.act2(self.conv2(x))  # 第二层卷积 + ReLU激活
        xx= torch.flatten(x, 1)
        activations.append(xx.cpu().data.numpy())#layer1
        x = self.pool(x)
        x = x.view(-1, 32 * 7 * 7)            # 展平操作，为全连接层做准备
        x = self.act3(self.fc1(x))               # 第一个全连接层 + ReLU激活
        activations.append(x.cpu().data.numpy())#layer1
        x = self.fc2(x)# 第二个全连接层（输出层）
        x = torch.softmax(x, dim=1)
        activations.append(x.cpu().data.numpy())
        return x, activations


class MI_Plate():
    def __init__(self, n_epochs=100, DO_LOWER=False, DO_BINNED=False, PLOT_LAYERS=None):
        super(MI_Plate, self).__init__()
        
        self.n_epochs = n_epochs
        self.DO_LOWER = DO_LOWER
        self.DO_BINNED = DO_BINNED
        self.PLOT_LAYERS = PLOT_LAYERS
#DO_LOWER和DO_BINNED是用于控制数据预处理的布尔值，PLOT_LAYERS是用于指定绘制哪些层的激活值的列表
    def save_activations(self):
        
        if not os.path.exists('activations'):
            print("Making directory", 'activations')
            os.mkdir('activations')
            
        model = Net()
        model.apply(init_weights)

        optimizer = optim.SGD(model.parameters(), lr=0.001)
        #optimizer = optim.Adam(model.parameters(), lr=0.001)
        # Move model to GPU if available
        if train_on_gpu:
            model.cuda()
        accuracies = []  # List to store accuracies
        for epoch in range(self.n_epochs):
            # monitor training loss
            train_loss = 0.0

            ###################
            # train the model #
            ###################
            model.train()

            for data, target in train_loader:
                if train_on_gpu:
                    data, target = data.cuda(), target.cuda()  # Move data to GPU
                optimizer.zero_grad()
                output, _ = model(data)
                loss = categorical_cross_entropy(output, target)
                # backward
                loss.backward()
                optimizer.step()
                train_loss += loss.item()#*data.size(0)

            # calculate average loss over an epoch
            train_loss = train_loss/len(train_loader.dataset)

            print('Epoch: {} \tTraining Loss: {:.6f}'.format(epoch+1, train_loss))

            model.eval()
########每次按照规定的epoch训练之后，都用full全部数据通过网络一次，记住标签和网络输出
###############################################################################            
            for data, _ in full_data_loader:
                if train_on_gpu:
                    data = data.cuda()  # Move data to GPU
                _, activations = model(data)
#定义多少epoch进行存储每层的输出，前20每次都存，高于200次100次再存一次
            if epoch < 20:       # Log for all first 20 epochs
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            #pickle.HIGHEST_PROTOCOL 用于指定 pickle 协议的版本，以确保最高的兼容性和效率
            elif (epoch < 100) and (epoch % 5 == 0):    # Then for every 5th epoch
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            elif (epoch < 200) and (epoch % 10 == 0):    # Then every 10th
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
            elif (epoch % 100 == 0):                # Then every 100th
                fname = 'activations' + "/epoch%08d"% epoch
                print("Saving", fname)
                with open(fname, 'wb') as f:
                    pickle.dump([activations, epoch], f, pickle.HIGHEST_PROTOCOL)
         #####################****************************************
            correct = 0
            total = 0
            with torch.no_grad():
                for data, target in test_loader:  # Assuming test_loader is defined elsewhere
                    if train_on_gpu:
                        data, target = data.cuda(), target.cuda()  # Move data to GPU
                    output, _ = model(data)
                    _, predicted = torch.max(output.data, 1)
                    total += target.size(0)
                    correct += (predicted == target).sum().item()

            accuracy = 100 * correct / total
            accuracies.append(accuracy)  # Store accuracy
            print('Test Accuracy on 10,000 images: {:.2f}%'.format(accuracy))  
        return accuracies
      ###########################
    def compute_MI(self, noise_variance=1e-1):
        
        MAX_EPOCHS = self.n_epochs
        self.noise_variance = noise_variance
        
        def entropy_func_upper(x):
            return kde.entropy_estimator_kl(x,self.noise_variance)
        
        def entropy_func_lower(x):
            return kde.entropy_estimator_bd(x,self.noise_variance)

        # nats to bits conversion factor
        nats2bits = 1.0/np.log(2) 


        # Save indexes of tests data for each of the output classes
        saved_labelixs = {}
        for data, targets in full_data_loader:
            trg = targets.numpy()
        for i in range(10):
            saved_labelixs[i] = trg == i

        labelprobs = np.mean(np.eye(10)[test_data.targets], axis=0)

        MI_XM_upper_array = []
        MI_YM_upper_array = []
###这段代码的作用是计算每个类别在数据集中出现的频率，并保存每个类别的索引以供后续使用
        measures = OrderedDict()
        measures['tanh'] = {}

        cur_dir = 'activations'
        if not os.path.exists(cur_dir):
            print("Directory %s not found" % cur_dir)

        # Load files saved during each epoch, and compute MI measures of the activity in that epoch
        print('*** Doing %s ***' % cur_dir)
        for epochfile in sorted(os.listdir(cur_dir)):
            if not epochfile.startswith('epoch'):
                continue

            fname = cur_dir + "/" + epochfile
            with open(fname, 'rb') as f:
                d = pickle.load(f)

            epoch = d[1]
            d = d[0]
            if epoch in measures['tanh']:# Skip this epoch if its already been processed
                continue                # this is a trick to allow us to rerun this cell multiple times)

            if epoch > MAX_EPOCHS:
                continue

            print("Doing", fname)

            num_layers = len(d)

            MI_XM_upper_epoch = []
            MI_YM_upper_epoch = []
            
            if self.PLOT_LAYERS is None:
                PLOT_LAYERS = []
                for lndx in range(num_layers):
                    PLOT_LAYERS.append(lndx)

            cepochdata = defaultdict(list)
            for lndx in range(num_layers):
                activity = d[lndx]

                # Compute marginal entropies
                h_upper = entropy_func_upper(activity)
                if self.DO_LOWER:
                    #h_lower = entropy_func_lower([activity,])[0]
                    h_lower = entropy_func_lower(activity)

                # Layer activity given input. This is simply the entropy of the Gaussian noise
                hM_given_X = kde.kde_condentropy(activity, self.noise_variance)

                # Compute conditional entropies of layer activity given output
                hM_given_Y_upper=0.
                for i in range(10):
                    hcond_upper = entropy_func_upper(activity[saved_labelixs[i],:])
                    hM_given_Y_upper += labelprobs[i] * hcond_upper

                if self.DO_LOWER:
                    hM_given_Y_lower=0.
                    for i in range(10):
                        hcond_lower = entropy_func_lower(activity[saved_labelixs[i],:])
                        hM_given_Y_lower += labelprobs[i] * hcond_lower

                cepochdata['MI_XM_upper'].append( nats2bits * (h_upper - hM_given_X) )
                cepochdata['MI_YM_upper'].append( nats2bits * (h_upper - hM_given_Y_upper) )
                cepochdata['H_M_upper'  ].append( nats2bits * h_upper )


                MI_XM_upper = nats2bits * (h_upper - hM_given_X)
                MI_YM_upper = nats2bits * (h_upper - hM_given_Y_upper)

                MI_XM_upper_epoch.append(MI_XM_upper)
                MI_YM_upper_epoch.append(MI_YM_upper)
                
                pstr = 'upper: MI(X;M)=%0.3f, MI(Y;M)=%0.3f, h_upper=%0.3f, hM_given_X=%0.3f, hM_given_Y_upper=%0.3f ' % (cepochdata['MI_XM_upper'][-1], cepochdata['MI_YM_upper'][-1], h_upper, hM_given_X, hM_given_Y_upper)
                if self.DO_LOWER:  # Compute lower bounds
                    cepochdata['MI_XM_lower'].append( nats2bits * (h_lower - hM_given_X) )
                    cepochdata['MI_YM_lower'].append( nats2bits * (h_lower - hM_given_Y_lower) )
                    cepochdata['H_M_lower'  ].append( nats2bits * h_lower )
                    pstr += ' | lower: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_lower'][-1], cepochdata['MI_YM_lower'][-1])

                if self.DO_BINNED: # Compute binner estimates
                    binxm, binym = simplebinmi.bin_calc_information2(saved_labelixs, activity, 0.5)
                    cepochdata['MI_XM_bin'].append( nats2bits * binxm )
                    cepochdata['MI_YM_bin'].append( nats2bits * binym )
                    pstr += ' | bin: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_bin'][-1], cepochdata['MI_YM_bin'][-1])

                print('- Layer %d %s' % (lndx, pstr) )

            measures['tanh'][epoch] = cepochdata
            MI_XM_upper_array.append(MI_XM_upper_epoch)
            MI_YM_upper_array.append(MI_YM_upper_epoch)
             
            #epoch += 1
        MI_XM_upper_array = np.array(MI_XM_upper_array)
        MI_YM_upper_array = np.array(MI_YM_upper_array)

    # Save the results as arrays
        np.save('D:/深度学习与信息论/MI_XM_upper_arrayG.npy', MI_XM_upper_array)
        np.save('D:/深度学习与信息论/MI_YM_upper_arrayG.npy', MI_YM_upper_array)

        with open('MI', 'wb') as f:
            pickle.dump(measures, f, pickle.HIGHEST_PROTOCOL) 

Plate = MI_Plate() #Create class object
Plate.save_activations() #save activations if they weren't saved already
Plate.compute_MI() #compute and save MIs if they weren't saved before
# Out:
# Epoch: 1 	Training Loss: 0.017670
# Saving activations/epoch00000000
# Test Accuracy on 10,000 images: 38.03%
# Epoch: 2 	Training Loss: 0.015973
# Saving activations/epoch00000001
# Test Accuracy on 10,000 images: 63.33%
# Epoch: 3 	Training Loss: 0.008902
# Saving activations/epoch00000002
# Test Accuracy on 10,000 images: 83.30%
# Epoch: 4 	Training Loss: 0.004160
# Saving activations/epoch00000003
# Test Accuracy on 10,000 images: 87.96%
# Epoch: 5 	Training Loss: 0.003196
# Saving activations/epoch00000004
# Test Accuracy on 10,000 images: 89.74%
# Epoch: 6 	Training Loss: 0.002766
# Saving activations/epoch00000005
# Test Accuracy on 10,000 images: 90.97%
# Epoch: 7 	Training Loss: 0.002485
# Saving activations/epoch00000006
# Test Accuracy on 10,000 images: 91.63%
# Epoch: 8 	Training Loss: 0.002274
# Saving activations/epoch00000007
# Test Accuracy on 10,000 images: 92.38%
# Epoch: 9 	Training Loss: 0.002097
# Saving activations/epoch00000008
# Test Accuracy on 10,000 images: 93.04%
# Epoch: 10 	Training Loss: 0.001945
# Saving activations/epoch00000009
# Test Accuracy on 10,000 images: 93.41%
# Epoch: 11 	Training Loss: 0.001814
# Saving activations/epoch00000010
# Test Accuracy on 10,000 images: 93.89%
# Epoch: 12 	Training Loss: 0.001699
# Saving activations/epoch00000011
# Test Accuracy on 10,000 images: 94.36%
# Epoch: 13 	Training Loss: 0.001594
# Saving activations/epoch00000012
# Test Accuracy on 10,000 images: 94.77%
# Epoch: 14 	Training Loss: 0.001507
# Saving activations/epoch00000013
# Test Accuracy on 10,000 images: 94.94%
# Epoch: 15 	Training Loss: 0.001427
# Saving activations/epoch00000014
# Test Accuracy on 10,000 images: 95.19%
# Epoch: 16 	Training Loss: 0.001355
# Saving activations/epoch00000015
# Test Accuracy on 10,000 images: 95.55%
# Epoch: 17 	Training Loss: 0.001292
# Saving activations/epoch00000016
# Test Accuracy on 10,000 images: 95.58%
# Epoch: 18 	Training Loss: 0.001236
# Saving activations/epoch00000017
# Test Accuracy on 10,000 images: 95.77%
# Epoch: 19 	Training Loss: 0.001185
# Saving activations/epoch00000018
# Test Accuracy on 10,000 images: 95.95%
# Epoch: 20 	Training Loss: 0.001138
# Saving activations/epoch00000019
# Test Accuracy on 10,000 images: 96.00%
# Epoch: 21 	Training Loss: 0.001096
# Saving activations/epoch00000020
# Test Accuracy on 10,000 images: 96.25%
# Epoch: 22 	Training Loss: 0.001059
# Test Accuracy on 10,000 images: 96.33%
# Epoch: 23 	Training Loss: 0.001022
# Test Accuracy on 10,000 images: 96.40%
# Epoch: 24 	Training Loss: 0.000989
# Test Accuracy on 10,000 images: 96.55%
# Epoch: 25 	Training Loss: 0.000958
# Test Accuracy on 10,000 images: 96.58%
# Epoch: 26 	Training Loss: 0.000930
# Saving activations/epoch00000025
# Test Accuracy on 10,000 images: 96.77%
# Epoch: 27 	Training Loss: 0.000904
# Test Accuracy on 10,000 images: 96.72%
# Epoch: 28 	Training Loss: 0.000878
# Test Accuracy on 10,000 images: 96.77%
# Epoch: 29 	Training Loss: 0.000856
# Test Accuracy on 10,000 images: 96.93%
# Epoch: 30 	Training Loss: 0.000833
# Test Accuracy on 10,000 images: 96.92%
# Epoch: 31 	Training Loss: 0.000813
# Saving activations/epoch00000030
# Test Accuracy on 10,000 images: 97.05%
# Epoch: 32 	Training Loss: 0.000794
# Test Accuracy on 10,000 images: 97.14%
# Epoch: 33 	Training Loss: 0.000777
# Test Accuracy on 10,000 images: 97.13%
# Epoch: 34 	Training Loss: 0.000760
# Test Accuracy on 10,000 images: 97.20%
# Epoch: 35 	Training Loss: 0.000744
# Test Accuracy on 10,000 images: 97.33%
# Epoch: 36 	Training Loss: 0.000729
# Saving activations/epoch00000035
# Test Accuracy on 10,000 images: 97.32%
# Epoch: 37 	Training Loss: 0.000715
# Test Accuracy on 10,000 images: 97.34%
# Epoch: 38 	Training Loss: 0.000700
# Test Accuracy on 10,000 images: 97.30%
# Epoch: 39 	Training Loss: 0.000686
# Test Accuracy on 10,000 images: 97.34%
# Epoch: 40 	Training Loss: 0.000674
# Test Accuracy on 10,000 images: 97.48%
# Epoch: 41 	Training Loss: 0.000663
# Saving activations/epoch00000040
# Test Accuracy on 10,000 images: 97.56%
# Epoch: 42 	Training Loss: 0.000652
# Test Accuracy on 10,000 images: 97.52%
# Epoch: 43 	Training Loss: 0.000642
# Test Accuracy on 10,000 images: 97.56%
# Epoch: 44 	Training Loss: 0.000632
# Test Accuracy on 10,000 images: 97.63%
# Epoch: 45 	Training Loss: 0.000621
# Test Accuracy on 10,000 images: 97.68%
# Epoch: 46 	Training Loss: 0.000613
# Saving activations/epoch00000045
# Test Accuracy on 10,000 images: 97.67%
# Epoch: 47 	Training Loss: 0.000604
# Test Accuracy on 10,000 images: 97.61%
# Epoch: 48 	Training Loss: 0.000594
# Test Accuracy on 10,000 images: 97.72%
# Epoch: 49 	Training Loss: 0.000586
# Test Accuracy on 10,000 images: 97.78%
# Epoch: 50 	Training Loss: 0.000577
# Test Accuracy on 10,000 images: 97.78%
# Epoch: 51 	Training Loss: 0.000569
# Saving activations/epoch00000050
# Test Accuracy on 10,000 images: 97.78%
# Epoch: 52 	Training Loss: 0.000563
# Test Accuracy on 10,000 images: 97.77%
# Epoch: 53 	Training Loss: 0.000555
# Test Accuracy on 10,000 images: 97.84%
# Epoch: 54 	Training Loss: 0.000548
# Test Accuracy on 10,000 images: 97.93%
# Epoch: 55 	Training Loss: 0.000540
# Test Accuracy on 10,000 images: 98.03%
# Epoch: 56 	Training Loss: 0.000535
# Saving activations/epoch00000055
# Test Accuracy on 10,000 images: 97.91%
# Epoch: 57 	Training Loss: 0.000527
# Test Accuracy on 10,000 images: 97.93%
# Epoch: 58 	Training Loss: 0.000522
# Test Accuracy on 10,000 images: 97.83%
# Epoch: 59 	Training Loss: 0.000517
# Test Accuracy on 10,000 images: 97.86%
# Epoch: 60 	Training Loss: 0.000511
# Test Accuracy on 10,000 images: 98.01%
# Epoch: 61 	Training Loss: 0.000504
# Saving activations/epoch00000060
# Test Accuracy on 10,000 images: 98.01%
# Epoch: 62 	Training Loss: 0.000499
# Test Accuracy on 10,000 images: 98.00%
# Epoch: 63 	Training Loss: 0.000494
# Test Accuracy on 10,000 images: 97.98%
# Epoch: 64 	Training Loss: 0.000486
# Test Accuracy on 10,000 images: 98.00%
# Epoch: 65 	Training Loss: 0.000482
# Test Accuracy on 10,000 images: 98.03%
# Epoch: 66 	Training Loss: 0.000477
# Saving activations/epoch00000065
# Test Accuracy on 10,000 images: 98.05%
# Epoch: 67 	Training Loss: 0.000473
# Test Accuracy on 10,000 images: 97.95%
# Epoch: 68 	Training Loss: 0.000468
# Test Accuracy on 10,000 images: 98.08%
# Epoch: 69 	Training Loss: 0.000464
# Test Accuracy on 10,000 images: 98.11%
# Epoch: 70 	Training Loss: 0.000459
# Test Accuracy on 10,000 images: 98.11%
# Epoch: 71 	Training Loss: 0.000455
# Saving activations/epoch00000070
# Test Accuracy on 10,000 images: 98.16%
# Epoch: 72 	Training Loss: 0.000449
# Test Accuracy on 10,000 images: 98.08%
# Epoch: 73 	Training Loss: 0.000445
# Test Accuracy on 10,000 images: 98.14%
# Epoch: 74 	Training Loss: 0.000442
# Test Accuracy on 10,000 images: 98.14%
# Epoch: 75 	Training Loss: 0.000438
# Test Accuracy on 10,000 images: 98.08%
# Epoch: 76 	Training Loss: 0.000434
# Saving activations/epoch00000075
# Test Accuracy on 10,000 images: 98.17%
# Epoch: 77 	Training Loss: 0.000431
# Test Accuracy on 10,000 images: 98.15%
# Epoch: 78 	Training Loss: 0.000425
# Test Accuracy on 10,000 images: 98.15%
# Epoch: 79 	Training Loss: 0.000424
# Test Accuracy on 10,000 images: 98.25%
# Epoch: 80 	Training Loss: 0.000420
# Test Accuracy on 10,000 images: 98.29%
# Epoch: 81 	Training Loss: 0.000415
# Saving activations/epoch00000080
# Test Accuracy on 10,000 images: 98.22%
# Epoch: 82 	Training Loss: 0.000411
# Test Accuracy on 10,000 images: 98.28%
# Epoch: 83 	Training Loss: 0.000409
# Test Accuracy on 10,000 images: 98.19%
# Epoch: 84 	Training Loss: 0.000404
# Test Accuracy on 10,000 images: 98.19%
# Epoch: 85 	Training Loss: 0.000402
# Test Accuracy on 10,000 images: 98.30%
# Epoch: 86 	Training Loss: 0.000400
# Saving activations/epoch00000085
# Test Accuracy on 10,000 images: 98.30%
# Epoch: 87 	Training Loss: 0.000396
# Test Accuracy on 10,000 images: 98.21%
# Epoch: 88 	Training Loss: 0.000392
# Test Accuracy on 10,000 images: 98.33%
# Epoch: 89 	Training Loss: 0.000389
# Test Accuracy on 10,000 images: 98.20%
# Epoch: 90 	Training Loss: 0.000386
# Test Accuracy on 10,000 images: 98.26%
# Epoch: 91 	Training Loss: 0.000383
# Saving activations/epoch00000090
# Test Accuracy on 10,000 images: 98.36%
# Epoch: 92 	Training Loss: 0.000380
# Test Accuracy on 10,000 images: 98.30%
# Epoch: 93 	Training Loss: 0.000377
# Test Accuracy on 10,000 images: 98.30%
# Epoch: 94 	Training Loss: 0.000375
# Test Accuracy on 10,000 images: 98.32%
# Epoch: 95 	Training Loss: 0.000372
# Test Accuracy on 10,000 images: 98.28%
# Epoch: 96 	Training Loss: 0.000369
# Saving activations/epoch00000095
# Test Accuracy on 10,000 images: 98.43%
# Epoch: 97 	Training Loss: 0.000366
# Test Accuracy on 10,000 images: 98.32%
# Epoch: 98 	Training Loss: 0.000364
# Test Accuracy on 10,000 images: 98.30%
# Epoch: 99 	Training Loss: 0.000361
# Test Accuracy on 10,000 images: 98.42%
# Epoch: 100 	Training Loss: 0.000359
# Test Accuracy on 10,000 images: 98.45%
# *** Doing activations ***
# Doing activations/epoch00000000
# - Layer 0 upper: MI(X;M)=13.300, MI(Y;M)=3.320, h_upper=3366.570, hM_given_X=3357.351, hM_given_Y_upper=3364.269
# - Layer 1 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=1687.886, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 2 upper: MI(X;M)=4.609, MI(Y;M)=1.293, h_upper=20.324, hM_given_X=17.129, hM_given_Y_upper=19.428
# - Layer 3 upper: MI(X;M)=0.020, MI(Y;M)=0.008, h_upper=2.690, hM_given_X=2.676, hM_given_Y_upper=2.685
# Doing activations/epoch00000001
# - Layer 0 upper: MI(X;M)=13.284, MI(Y;M)=3.320, h_upper=3366.559, hM_given_X=3357.351, hM_given_Y_upper=3364.258
# - Layer 1 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=1687.886, hM_given_X=1678.676, hM_given_Y_upper=1685.586
# - Layer 2 upper: MI(X;M)=11.925, MI(Y;M)=3.154, h_upper=25.395, hM_given_X=17.129, hM_given_Y_upper=23.209
# - Layer 3 upper: MI(X;M)=0.356, MI(Y;M)=0.200, h_upper=2.923, hM_given_X=2.676, hM_given_Y_upper=2.785
# Doing activations/epoch00000002
# - Layer 0 upper: MI(X;M)=13.269, MI(Y;M)=3.320, h_upper=3366.549, hM_given_X=3357.351, hM_given_Y_upper=3364.248
# - Layer 1 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=1687.886, hM_given_X=1678.676, hM_given_Y_upper=1685.586
# - Layer 2 upper: MI(X;M)=13.272, MI(Y;M)=3.319, h_upper=26.329, hM_given_X=17.129, hM_given_Y_upper=24.028
# - Layer 3 upper: MI(X;M)=3.383, MI(Y;M)=2.253, h_upper=5.022, hM_given_X=2.676, hM_given_Y_upper=3.460
# Doing activations/epoch00000003
# - Layer 0 upper: MI(X;M)=13.347, MI(Y;M)=3.320, h_upper=3366.603, hM_given_X=3357.351, hM_given_Y_upper=3364.302
# - Layer 1 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=1687.884, hM_given_X=1678.676, hM_given_Y_upper=1685.583
# - Layer 2 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=26.338, hM_given_X=17.129, hM_given_Y_upper=24.038
# - Layer 3 upper: MI(X;M)=3.690, MI(Y;M)=2.659, h_upper=5.234, hM_given_X=2.676, hM_given_Y_upper=3.391
# Doing activations/epoch00000004
# - Layer 0 upper: MI(X;M)=13.229, MI(Y;M)=3.319, h_upper=3366.521, hM_given_X=3357.351, hM_given_Y_upper=3364.220
# - Layer 1 upper: MI(X;M)=13.292, MI(Y;M)=3.319, h_upper=1687.889, hM_given_X=1678.676, hM_given_Y_upper=1685.588
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=26.339, hM_given_X=17.129, hM_given_Y_upper=24.038
# - Layer 3 upper: MI(X;M)=3.693, MI(Y;M)=2.767, h_upper=5.236, hM_given_X=2.676, hM_given_Y_upper=3.319
# Doing activations/epoch00000005
# - Layer 0 upper: MI(X;M)=13.238, MI(Y;M)=3.319, h_upper=3366.527, hM_given_X=3357.351, hM_given_Y_upper=3364.226
# - Layer 1 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=1687.885, hM_given_X=1678.676, hM_given_Y_upper=1685.584
# - Layer 2 upper: MI(X;M)=13.287, MI(Y;M)=3.319, h_upper=26.339, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.678, MI(Y;M)=2.825, h_upper=5.226, hM_given_X=2.676, hM_given_Y_upper=3.268
# Doing activations/epoch00000006
# - Layer 0 upper: MI(X;M)=13.287, MI(Y;M)=3.320, h_upper=3366.561, hM_given_X=3357.351, hM_given_Y_upper=3364.260
# - Layer 1 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=1687.886, hM_given_X=1678.676, hM_given_Y_upper=1685.585
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.655, MI(Y;M)=2.860, h_upper=5.210, hM_given_X=2.676, hM_given_Y_upper=3.228
# Doing activations/epoch00000007
# - Layer 0 upper: MI(X;M)=13.321, MI(Y;M)=3.320, h_upper=3366.585, hM_given_X=3357.351, hM_given_Y_upper=3364.283
# - Layer 1 upper: MI(X;M)=13.285, MI(Y;M)=3.319, h_upper=1687.884, hM_given_X=1678.676, hM_given_Y_upper=1685.583
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.641, MI(Y;M)=2.899, h_upper=5.200, hM_given_X=2.676, hM_given_Y_upper=3.190
# Doing activations/epoch00000008
# - Layer 0 upper: MI(X;M)=13.284, MI(Y;M)=3.320, h_upper=3366.559, hM_given_X=3357.351, hM_given_Y_upper=3364.258
# - Layer 1 upper: MI(X;M)=13.284, MI(Y;M)=3.319, h_upper=1687.884, hM_given_X=1678.676, hM_given_Y_upper=1685.583
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3
# - Layer 1 upper: MI(X;M)=13.295, MI(Y;M)=3.319, h_upper=1687.891, hM_given_X=1678.676, hM_given_Y_upper=1685.590
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.498, MI(Y;M)=3.130, h_upper=5.101, hM_given_X=2.676, hM_given_Y_upper=2.932
# Doing activations/epoch00000030
# - Layer 0 upper: MI(X;M)=13.283, MI(Y;M)=3.320, h_upper=3366.558, hM_given_X=3357.351, hM_given_Y_upper=3364.257
# - Layer 1 upper: MI(X;M)=13.284, MI(Y;M)=3.319, h_upper=1687.884, hM_given_X=1678.676, hM_given_Y_upper=1685.583
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.481, MI(Y;M)=3.142, h_upper=5.089, hM_given_X=2.676, hM_given_Y_upper=2.911
# Doing activations/epoch00000035
# - Layer 0 upper: MI(X;M)=13.213, MI(Y;M)=3.320, h_upper=3366.510, hM_given_X=3357.351, hM_given_Y_upper=3364.209
# - Layer 1 upper: MI(X;M)=13.283, MI(Y;M)=3.319, h_upper=1687.883, hM_given_X=1678.676, hM_given_Y_upper=1685.582
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.466, MI(Y;M)=3.153, h_upper=5.079, hM_given_X=2.676, hM_given_Y_upper=2.894
# Doing activations/epoch00000040
# - Layer 0 upper: MI(X;M)=13.362, MI(Y;M)=3.320, h_upper=3366.613, hM_given_X=3357.351, hM_given_Y_upper=3364.312
# - Layer 1 upper: MI(X;M)=13.286, MI(Y;M)=3.319, h_upper=1687.885, hM_given_X=1678.676, hM_given_Y_upper=1685.584
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.456, MI(Y;M)=3.169, h_upper=5.072, hM_given_X=2.676, hM_given_Y_upper=2.876
# Doing activations/epoch00000045
# - Layer 0 upper: MI(X;M)=13.376, MI(Y;M)=3.320, h_upper=3366.623, hM_given_X=3357.351, hM_given_Y_upper=3364.321
# - Layer 1 upper: MI(X;M)=13.274, MI(Y;M)=3.319, h_upper=1687.876, hM_given_X=1678.676, hM_given_Y_upper=1685.576
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.449, MI(Y;M)=3.176, h_upper=5.067, hM_given_X=2.676, hM_given_Y_upper=2.865
# Doing activations/epoch00000050
# - Layer 0 upper: MI(X;M)=13.259, MI(Y;M)=3.320, h_upper=3366.542, hM_given_X=3357.351, hM_given_Y_upper=3364.241
# - Layer 1 upper: MI(X;M)=13.310, MI(Y;M)=3.319, h_upper=1687.901, hM_given_X=1678.676, hM_given_Y_upper=1685.600
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.442, MI(Y;M)=3.182, h_upper=5.063, hM_given_X=2.676, hM_given_Y_upper=2.857
# Doing activations/epoch00000055
# - Layer 0 upper: MI(X;M)=13.384, MI(Y;M)=3.320, h_upper=3366.628, hM_given_X=3357.351, hM_given_Y_upper=3364.327
# - Layer 1 upper: MI(X;M)=13.305, MI(Y;M)=3.320, h_upper=1687.898, hM_given_X=1678.676, hM_given_Y_upper=1685.597
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.434, MI(Y;M)=3.187, h_upper=5.057, hM_given_X=2.676, hM_given_Y_upper=2.848
# Doing activations/epoch00000060
# - Layer 0 upper: MI(X;M)=13.445, MI(Y;M)=3.321, h_upper=3366.671, hM_given_X=3357.351, hM_given_Y_upper=3364.369
# - Layer 1 upper: MI(X;M)=13.315, MI(Y;M)=3.319, h_upper=1687.905, hM_given_X=1678.676, hM_given_Y_upper=1685.604
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.427, MI(Y;M)=3.190, h_upper=5.052, hM_given_X=2.676, hM_given_Y_upper=2.841
# Doing activations/epoch00000065
# - Layer 0 upper: MI(X;M)=13.354, MI(Y;M)=3.321, h_upper=3366.607, hM_given_X=3357.351, hM_given_Y_upper=3364.306
# - Layer 1 upper: MI(X;M)=13.285, MI(Y;M)=3.320, h_upper=1687.884, hM_given_X=1678.676, hM_given_Y_upper=1685.583
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.422, MI(Y;M)=3.195, h_upper=5.049, hM_given_X=2.676, hM_given_Y_upper=2.834
# Doing activations/epoch00000070
# - Layer 0 upper: MI(X;M)=13.250, MI(Y;M)=3.319, h_upper=3366.535, hM_given_X=3357.351, hM_given_Y_upper=3364.234
# - Layer 1 upper: MI(X;M)=13.320, MI(Y;M)=3.319, h_upper=1687.909, hM_given_X=1678.676, hM_given_Y_upper=1685.608
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.418, MI(Y;M)=3.201, h_upper=5.046, hM_given_X=2.676, hM_given_Y_upper=2.827
# Doing activations/epoch00000075
# - Layer 0 upper: MI(X;M)=13.290, MI(Y;M)=3.320, h_upper=3366.563, hM_given_X=3357.351, hM_given_Y_upper=3364.262
# - Layer 1 upper: MI(X;M)=13.295, MI(Y;M)=3.319, h_upper=1687.891, hM_given_X=1678.676, hM_given_Y_upper=1685.590
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.414, MI(Y;M)=3.200, h_upper=5.043, hM_given_X=2.676, hM_given_Y_upper=2.825
# Doing activations/epoch00000080
# - Layer 0 upper: MI(X;M)=13.175, MI(Y;M)=3.320, h_upper=3366.484, hM_given_X=3357.351, hM_given_Y_upper=3364.183
# - Layer 1 upper: MI(X;M)=13.299, MI(Y;M)=3.319, h_upper=1687.894, hM_given_X=1678.676, hM_given_Y_upper=1685.593
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.413, MI(Y;M)=3.205, h_upper=5.042, hM_given_X=2.676, hM_given_Y_upper=2.820
# Doing activations/epoch00000085
# - Layer 0 upper: MI(X;M)=13.287, MI(Y;M)=3.320, h_upper=3366.561, hM_given_X=3357.351, hM_given_Y_upper=3364.260
# - Layer 1 upper: MI(X;M)=13.322, MI(Y;M)=3.320, h_upper=1687.910, hM_given_X=1678.676, hM_given_Y_upper=1685.609
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.408, MI(Y;M)=3.209, h_upper=5.039, hM_given_X=2.676, hM_given_Y_upper=2.815
# Doing activations/epoch00000090
# - Layer 0 upper: MI(X;M)=13.257, MI(Y;M)=3.320, h_upper=3366.541, hM_given_X=3357.351, hM_given_Y_upper=3364.239
# - Layer 1 upper: MI(X;M)=13.274, MI(Y;M)=3.319, h_upper=1687.876, hM_given_X=1678.676, hM_given_Y_upper=1685.575
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.406, MI(Y;M)=3.210, h_upper=5.037, hM_given_X=2.676, hM_given_Y_upper=2.812
# Doing activations/epoch00000095
# - Layer 0 upper: MI(X;M)=13.201, MI(Y;M)=3.320, h_upper=3366.502, hM_given_X=3357.351, hM_given_Y_upper=3364.201
# - Layer 1 upper: MI(X;M)=13.296, MI(Y;M)=3.320, h_upper=1687.892, hM_given_X=1678.676, hM_given_Y_upper=1685.591
# - Layer 2 upper: MI(X;M)=13.288, MI(Y;M)=3.319, h_upper=26.340, hM_given_X=17.129, hM_given_Y_upper=24.039
# - Layer 3 upper: MI(X;M)=3.403, MI(Y;M)=3.213, h_upper=5.035, hM_given_X=2.676, hM_given_Y_upper=2.808

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import torch
import scienceplots
plt.rcParams['font.serif'] = ['Times New Roman']
mpl.rcParams['figure.dpi'] = 800
mpl.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
plt.style.use(['science', 'ieee'])
mpl.rcParams.update({'font.size': 15})

def plot_information_plane(IXT_array, ITY_array, num_epochs, every_n_early=1, every_n_late=5):
    assert len(IXT_array) == len(ITY_array)

    max_index = len(IXT_array)

    fig, ax = plt.subplots(figsize=(5, 3.5))
    ax.set_xlabel('$I(X;T)$', fontsize=15)
    ax.set_ylabel('$I(T;Y)$', fontsize=15)

    cmap = plt.get_cmap('gnuplot')
    colors = [cmap(i) for i in np.linspace(0, 1, num_epochs + 1)]

    for i in range(0, max_index):
        IXT = IXT_array[i, :]
        ITY = ITY_array[i, :]
        
        # 根据 epoch 的范围调整 every_n
        if i < 20:
            color_idx = i * every_n_early
        else:
            color_idx = 20 * every_n_early + (i - 20) * every_n_late

        ax.plot(IXT, ITY, marker='o', markersize=3, markeredgewidth=0.04,
                linestyle='-', linewidth=0.5, color=colors[color_idx], zorder=10)

    sm = plt.cm.ScalarMappable(cmap=cmap, norm=plt.Normalize(vmin=0, vmax=1))
    sm._A = []

    # 使用ax参数指定颜色条位置
    cbar = plt.colorbar(sm, ax=ax, ticks=[])
    cbar.set_label('epoch number', fontsize=15)
    cbar.ax.tick_params(labelsize=15)
    cbar.ax.text(0.5, -0.01, 0, transform=cbar.ax.transAxes, va='top', ha='center')
    cbar.ax.text(0.5, 1.0, str(num_epochs), transform=cbar.ax.transAxes, va='bottom', ha='center')

    ax.set_xticks([0, 2, 4, 6, 8, 10, 12, 14])
    ax.set_yticks([0, 0.5, 1, 1.5, 2, 2.5, 3.0, 3.5])
    ax.set_ylim(-0.05, 3.5)  # 修改y轴坐标范围
    # Adjust coordinates of text according to the plot area
    ax.text(-0.2, 0.98, '(d)', fontdict={'size': 15, 'color': 'black'}, transform=ax.transAxes)

    fig.savefig('D:/深度学习与信息论/Fig8d.eps', dpi=800)
    plt.show()

IXT_array = np.load('D:/深度学习与信息论/MI_XM_upper_arrayG.npy')
ITY_array = np.load('D:/深度学习与信息论/MI_YM_upper_arrayG.npy')


plot_information_plane(IXT_array, ITY_array, num_epochs=100, every_n_early=1, every_n_late=5)

# %%
IXT_array
# Out:
# array([[13.30028528, 13.28773738,  4.60922981,  0.0201535 ],
#        [13.28408313, 13.28826571, 11.92546602,  0.35614741],
#        [13.26928987, 13.28826571, 13.27170012,  3.38322767],
#        [13.3471306 , 13.28509572, 13.28595473,  3.68976029],
#        [13.22878452, 13.29178791, 13.2871366 ,  3.69325461],
#        [13.23759003, 13.2865046 , 13.2873932 ,  3.678043  ],
#        [13.28725312, 13.2880896 , 13.2875528 ,  3.65528252],
#        [13.32106628, 13.28491961, 13.28760439,  3.64058161],
#        [13.28408313, 13.28439128, 13.2876381 ,  3.6256512 ],
#        [13.27809539, 13.28773738, 13.28765736,  3.61046328],
#        [13.31437409, 13.28897015, 13.28766768,  3.60008922],
#        [13.29922861, 13.29636678, 13.28765667,  3.58541319],
#        [13.26964209, 13.28439128, 13.28772203,  3.57874884],
#        [13.32846291, 13.28351073, 13.28767525,  3.56738648],
#        [13.35593611, 13.30182619, 13.28772684,  3.55717349],
#        [13.22808008, 13.28315851, 13.28773166,  3.54757767],
#        [13.31261299, 13.29619067, 13.28777225,  3.54140311],
#        [13.29817195, 13.28861793, 13.28772753,  3.535529  ],
#        [13.27281208, 13.30182619, 13.28770758,  3.52977399],
#        [13.22702342, 13.3071095 , 13.28773647,  3.52401967],
#        [13.26435879, 13.28791349, 13.28774129,  3.51771639],
#        [13.26013214, 13.29495789, 13.28768075,  3.49800301],
#        [13.28302647, 13.28421517, 13.28770139,  3.48116846],
#        [13.21328682, 13.28333462, 13.28777913,  3.46628793],
#        [13.36192386, 13.28597627, 13.28775711,  3.45583274],
#        [13.37601268, 13.27382467, 13.28776193,  3.44853064],
#        [13.2594277 , 13.30975115, 13.28776743,  3.44246796],
#        [13.38376153, 13.30482007, 13.28772959,  3.434492  ],
#        [13.44540011, 13.31450613, 13.28784792,  3.42712569],
#        [13.35382279, 13.28491961, 13.28786718,  3.4222532 ],
#        [13.24956553, 13.32031777, 13.28791671,  3.41847993],
#        [13.29007088, 13.29495789, 13.28783622,  3.41416791],
#        [13.17524701, 13.29936065, 13.28781008,  3.41272244],
#        [13.28725312, 13.32225498, 13.287883  ,  3.40839733],
#        [13.25731438, 13.27364856, 13.28787406,  3.40609691],
#        [13.20131132, 13.29619067, 13.28777362,  3.40328028]])

# %%
ITY_array
# Out:
# array([[3.31972448, 3.31943735, 1.29332078, 0.00773966],
#        [3.31978785, 3.31935402, 3.15447557, 0.19982086],
#        [3.31971349, 3.31921792, 3.31941936, 2.25321256],
